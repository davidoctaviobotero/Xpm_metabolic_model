# %%
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

from time import time

import cobra
import os
from os.path import join
from cobra.flux_analysis import calculate_phenotype_phase_plane

data_dir = "/Users/davidbotero/Dropbox (UCSD SBRG)/Xam_Multistrain_Recon/Metabolic_model/"
xam_model = cobra.io.read_sbml_model(join(data_dir, "Xam_CIO151.sbml"))

# %% [raw]
# rxn05226_c0: D-glucose transport via PEP:Pyr PTS_c0
# rxn05468_c0: Oxygen exchange

# %%
data = calculate_phenotype_phase_plane(xam_model, "rxn05226_c0", "rxn05468_c0")
data.plot_matplotlib();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-71b8501eca73> in <module>()
#       1 data = calculate_phenotype_phase_plane(xam_model, "rxn05226_c0", "rxn05468_c0")
# ----> 2 data.plot_matplotlib.ylabel('some numbers')
#       3 data.plot_matplotlib();
#
# AttributeError: 'function' object has no attribute 'ylabel'

# %% [markdown]
# rxn05147_c0: D-Glucose-ABC transport_c0

# %%
data = calculate_phenotype_phase_plane(xam_model, "rxn05147_c0", "rxn05468_c0")
data.plot_matplotlib();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8a0025781f48> in <module>()
#       1 data = calculate_phenotype_phase_plane(xam_model, "rxn05147_c0", "rxn05468_c0")
#       2 data.plot_matplotlib();
# ----> 3 plt.xlabel('some numbers')
#
# NameError: name 'plt' is not defined
