# %%
import os
import pandas as pd
pd.options.display.max_rows = 1000
from matplotlib import pyplot as plt

from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

import seaborn as sns; sns.set(color_codes=True)

import sys
sys.getrecursionlimit()
sys.setrecursionlimit(10000)

import numpy as np
np.set_printoptions(precision=5, suppress=True)  # suppress scientific float notation

from collections import defaultdict

data_dir = "/Users/david/Dropbox (UCSD SBRG)/Xam_Multistrain_Recon/Metabolic_model/BiGG_Model/CSM/In_vitro"

# %% [markdown]
# #### Reading Table of Fluxes

# %%
Xam_void_fluxes = pd.read_csv('Xam_cluster-void.tsv', sep='\t', index_col=0, header=None, names=['rxn', 'void'])
Xam_rpfCGH_fluxes = pd.read_csv('Xam_cluster-rpfCGH.tsv', sep='\t', index_col=0, header=None, names=['rxn', 'rpfCGH'])
Xam_rpfCGH_fluxes = pd.read_csv('Xam_cluster-rpfCGH_DEGs.tsv', sep='\t', index_col=0, header=None, names=['rxn', 'rpfCGH_DEGs'])

# %%
xam_fluxes = pd.concat([Xam_void_fluxes, Xam_rpfCGH_fluxes,Xam_rpfCGH_fluxes], axis=1, join='inner')
xam_fluxes_2 = xam_fluxes.fillna(value=0)

# %%
xam_fluxes_2
# Out:
#                             void  rpfCGH_DEGs  rpfCGH_DEGs
# rxn
# 10FTHFGLULL              0.00000      0.00000      0.00000
# 2DHPFALDL                0.00000      0.00000      0.00000
# 2HBO                     0.00000      0.00000      0.00000
# 2OH3K5MPPISO             0.00000      0.00000      0.00000
# 34DHOXPEGOX              0.00000      0.00000      0.00000
# 34HPPOR                  0.00000      0.00000      0.00000
# 3HAO                     0.00000      0.00000      0.00000
# 3HBCOAHL                 0.00000      0.00000      0.00000
# 3HLYTCL                  0.00000      0.00000      0.00000
# 3OAR100                  0.00000      0.00000      0.00000
# 3OAR120                  0.00000      0.00000      0.00000
# 3OAR40_1                 0.00000      0.00000      0.00000
# 3OAR60                   0.00000      0.00000      0.00000
# 3OAR80                   0.00000      0.00000      0.00000
# 3OAS80                   0.00000      0.00000      0.00000
# ...

# %% [markdown]
# #### Calculating Linkage Matrix

# %%
xam_fluxes_array = pd.DataFrame.as_matrix(xam_fluxes)
xam_fluxes_array.shape
Z = linkage(xam_fluxes_array, metric='euclidean', method='ward',)
c, coph_dists = cophenet(Z, pdist(xam_fluxes_array))
c

# %% [markdown]
# #### Calculating Full Dendrogram

# %%
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram P. infestans')
plt.xlabel('Reaction Fluxes')
plt.ylabel('Distance')
den = dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
    color_threshold=0.25*max(Z[:,2]),
)

# %%
plt.show(den)
#den

# %% [markdown]
# #### Mapping Index and Reactions

# %%
pif_map_index = pd.read_csv('Pifresultfba-06.txt', sep='\t',usecols=["rxn"])
pif_map_index.index.name = 'index'
pif_map_index
# Out:
#                rxn
# index
# 0           R04404
# 1           R00216
# 2           R00330
# 3           R00233
# 4           R00243
# 5           R05725
# 6           R00610
# 7           R00945
# 8           R02541
# 9           R00667
# 10          R02565
# 11          R03914
# 12          R01433
# 13          R10851
# 14          R01130
# 15          R08575
# 16          R01082
# 17          R00181
# 18          R00802
# 19          R01773
# 20          R00342
# 21          R00435
# 22          R00858
# 23          R04433
# 24          R00315
# 25          R00801
# 26          R00112
# 27          R11308
# 28          R01286
# 29          R02094
# 30          R00238
# 31          R01318
# 32          R01226
# 33          R00625
# 34          R05209
# 35          R01395
# 36          R00026
# 37          R00722
# 38          R01778
# 39          R03778
# 40          R00437
# 41          R05801
# 42          R00068
# 43          R00483
# 44          R00512
# 45          R04964
# ...

# %% [markdown]
# #### Mapping Groups to Dataframe of Fluxes

# %%
#del df_groups
df_groups = pd.DataFrame.from_dict(den["ivl"], dtype=int)
df_groups['group'] = pd.DataFrame.from_dict(den["color_list"])
df_groups.set_index(0, inplace=True)
df_groups.index.name = 'index'
df_groups
# Out:
#       group
# index
# 606       g
# 605       g
# 604       g
# 538       g
# 587       g
# 474       g
# 507       g
# 385       g
# 341       g
# 403       g
# 408       g
# 405       g
# 406       g
# 489       g
# 593       g
# 576       g
# 571       g
# 567       g
# 556       g
# 542       g
# 533       g
# 532       g
# 512       g
# 492       g
# 491       g
# 482       g
# 479       g
# 476       g
# 470       g
# 464       g
# 458       g
# 452       g
# 449       g
# 444       g
# 436       g
# 404       g
# 402       g
# 398       g
# 397       g
# 389       g
# 379       g
# 378       g
# 376       g
# 374       g
# 369       g
# 366       g
# 365       g
# 364       g
# 363       g
# 349       g
# ...     ...
# 331       g
# 367       g
# 373       g
# 434       g
# 381       r
# 526       r
# 495       r
# 522       r
# 498       r
# 208       r
# 184       r
# 165       r
# 124       r
# 102       r
# 52        r
# 70        r
# 393       r
# 601       r
# ...

# %%
#del df_fluxes_groups
df_fluxes_groups = pd.concat([pif_map_index, df_groups], axis=1, join='inner')
df_fluxes_groups.set_index('rxn', inplace=True)
df_fluxes_groups
# Out:
#                    group
# rxn
# R10691                 g
# R10690                 g
# R10689                 g
# R03688                 g
# R08926                 g
# R01787                 g
# R02703                 g
# R3DB47CC1_B            g
# cysteine_Henninger     g
# R00228                 g
# R00319                 g
# R00236                 g
# R00316                 g
# R02235                 g
# R09666                 g
# R06872                 g
# R05816                 g
# R05680                 g
# R04638                 g
# R04177                 g
# R03399                 g
# R03398                 g
# R02756                 g
# R02242                 g
# R02241                 g
# R02052                 g
# R01818                 g
# R01794                 g
# R01511                 g
# R01319                 g
# R01196                 g
# R00978                 g
# R00936                 g
# R00883                 g
# R00870                 g
# ...

# %%
pif_fluxes_groups = pd.concat([pif_fluxes, df_fluxes_groups], axis=1, join='inner')
pif_fluxes_groups
# Out:
#                             RSA         2dpi         3dpi          4dpi group
# rxn
# R10691              -703.821463 -1000.000000 -1000.000000 -9.255151e+02     g
# R10690              -703.821463 -1000.000000 -1000.000000 -9.255151e+02     g
# R10689              -703.821463 -1000.000000 -1000.000000 -9.255151e+02     g
# R03688              -703.821463 -1000.000000 -1000.000000 -9.255151e+02     g
# R08926              -703.821463 -1000.000000 -1000.000000 -9.255151e+02     g
# R01787              -309.577844 -1000.000000 -1000.000000 -1.000000e+03     g
# R02703              -523.540900 -1000.000000 -1000.000000 -1.000000e+03     g
# R3DB47CC1_B        -1000.000000  -700.714872 -1000.000000 -5.631348e+02     g
# cysteine_Henninger  -993.881952  -694.596824  -998.164586 -9.938820e+02     g
# R00228              -939.963291 -1000.000000 -1000.000000 -1.000000e+03     g
# R00319             -1000.000000  -987.715228  -947.064169 -1.000000e+03     g
# ...

# %%
pif_fluxes_groups.to_csv('Pinfestans_06_results.csv')

# %% [markdown]
# #### Coloring

# %%
#Color palet
group_pal = sns.color_palette(n_colors=len(pif_fluxes_groups.group.unique())) #n_colors=len(pif_fluxes_groups.group.unique())
group_lut = dict(zip(pif_fluxes_groups.group.unique(), group_pal))
group = pif_fluxes_groups.group
#print(group)
group_colors = pd.Series(group).map(group_lut)
print(group_colors)
# Out:
# rxn
# R10691                (0.298039215686, 0.447058823529, 0.690196078431)
# R10690                (0.298039215686, 0.447058823529, 0.690196078431)
# R10689                (0.298039215686, 0.447058823529, 0.690196078431)
# R03688                (0.298039215686, 0.447058823529, 0.690196078431)
# R08926                (0.298039215686, 0.447058823529, 0.690196078431)
# R01787                (0.298039215686, 0.447058823529, 0.690196078431)
# R02703                (0.298039215686, 0.447058823529, 0.690196078431)
# R3DB47CC1_B           (0.298039215686, 0.447058823529, 0.690196078431)
# cysteine_Henninger    (0.298039215686, 0.447058823529, 0.690196078431)
# R00228                (0.298039215686, 0.447058823529, 0.690196078431)
# R00319                (0.298039215686, 0.447058823529, 0.690196078431)
# R00236                (0.298039215686, 0.447058823529, 0.690196078431)
# R00316                (0.298039215686, 0.447058823529, 0.690196078431)
# ...

# %%
flux_distr_2 = sns.clustermap(pif_fluxes, z_score=1, row_linkage=Z, row_colors=group_colors, cmap='BuGn_r')
flux_distr_2.fig

# %%
plt.savefig("Pinfestans-06-Hierarchically-clustered_heatmap-z_score-dendrogram_colored.png", format='png', dpi=800)
