# %%
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

from time import time

import cobra
import os
from os.path import join
from cobra.flux_analysis import calculate_phenotype_phase_plane

data_dir = "/Users/david/Dropbox (UCSD SBRG)/Xam_Multistrain_Recon/Metabolic_model/BiGG_Model/"

xam_model = cobra.io.read_sbml_model(join(data_dir, ""))

# %matplotlib inline
import matplotlib
matplotlib.style.use('ggplot')
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exchange reactions

# %%
count = 0
for reactions in xam_model.reactions:
    if len(reactions.metabolites) == 1:
        print("%s : %s %s %s" % (reactions.id, reactions.reaction, reactions.lower_bound, reactions.upper_bound))
        count += 1
print(count)
# Out:
# EX_2ddglcn_e : 2ddglcn_e -->  0.0 1000.0
# EX_4hbz_e : 4hbz_e <=>  -10.0 1000.0
# EX_ac_e : ac_e -->  0.0 1000.0
# EX_acald_e : acald_e -->  0.0 1000.0
# EX_acgam_e : acgam_e -->  0.0 1000.0
# EX_adn_e : adn_e -->  0.0 1000.0
# EX_akg_e : akg_e -->  0.0 1000.0
# EX_ala__D_e : ala__D_e -->  0.0 1000.0
# EX_arab__L_e : arab__L_e -->  0.0 0.0
# EX_arbt_e : arbt_e -->  0.0 1000.0
# EX_arg__L_e : arg__L_e <=>  -10.0 1000.0
# EX_ASPt5n_e : asp__L_e -->  0.0 1000.0
# EX_Biomass_e : BIOMASS_c -->  0.0 1000.0
# EX_ca2_e : ca2_e <=>  -10.0 1000.0
# EX_cbl1_e : cbl1_e -->  0.0 1000.0
# EX_cd2_e : cd2_e -->  0.0 1000.0
# EX_chol_e : chol_e -->  0.0 1000.0
# EX_cit_e : cit_e -->  0.0 1000.0
# EX_cl_e : cl_e <=>  -10.0 1000.0
# EX_co2_e : co2_e -->  0.0 1000.0
# EX_cobalt2_e : cobalt2_e <=>  -10.0 1000.0
# EX_cu2_e : cu2_e <=>  -10.0 1000.0
# EX_cytd_e : cytd_e -->  0.0 1000.0
# EX_dad_2_e : dad_2_e -->  0.0 1000.0
# EX_dcyt_e : dcyt_e -->  0.0 1000.0
# EX_dgsn_e : dgsn_e -->  0.0 1000.0
# EX_din_e : din_e -->  0.0 1000.0
# EX_DNA_e : dna_c <--  -10.0 0.0
# EX_duri_e : duri_e -->  0.0 1000.0
# EX_etha_e : etha_e -->  0.0 1000.0
# EX_etoh_e : etoh_e -->  0.0 1000.0
# EX_fe2_e : fe2_e <=>  -10.0 1000.0
# EX_fe3_e : fe3_e <=>  -10.0 1000.0
# EX_for_e : for_e -->  0.0 1000.0
# EX_fru_e : fru_e -->  0.0 0.0
# EX_fum_e : fum_e -->  0.0 1000.0
# EX_galt_e : galt_e -->  0.0 1000.0
# EX_galur_e : galur_e -->  0.0 1000.0
# EX_gam_e : gam_e -->  0.0 1000.0
# EX_glc__D_e : glc__D_e <=>  -10.0 1000.0
# EX_glcur_e : glcur_e -->  0.0 1000.0
# EX_gln__L_e : gln__L_e -->  0.0 1000.0
# EX_glu__L_e : glu__L_e -->  0.0 1000.0
# EX_gly_e : gly_e -->  0.0 1000.0
# EX_glyb_e : glyb_e -->  0.0 1000.0
# EX_glyc_e : glyc_e -->  0.0 1000.0
# EX_glycogen_e : glycogen_c -->  0.0 1000.0
# EX_h_e : h_e -->  0.0 1000.0
# EX_h2o_e : h2o_e -->  0.0 1000.0
# EX_hdca_e : hdca_e -->  0.0 1000.0
# EX_hxan_e : hxan_e -->  0.0 1000.0
# EX_ins_e : ins_e -->  0.0 1000.0
# EX_k_e : k_e <=>  -10.0 1000.0
# EX_lys__L_e : lys__L_e <=>  -10.0 1000.0
# EX_mal__L_e : mal__L_e -->  0.0 0.0
# EX_malt_e : malt_e -->  0.0 0.0
# EX_man_e : man_e -->  0.0 0.0
# EX_met__D_e : met__D_e -->  0.0 1000.0
# EX_met__L_e : met__L_e -->  0.0 1000.0
# EX_metox__R_e : metox__R_e -->  0.0 1000.0
# EX_metsox_S__L_e : metsox_S__L_e -->  0.0 1000.0
# EX_mg2_e : mg2_e <=>  -10.0 1000.0
# EX_mn2_e : mn2_e <=>  -10.0 1000.0
# EX_mqn7_e : mqn7_e <=>  -10.0 1000.0
# EX_na1_e : na1_e -->  0.0 1000.0
# EX_nh4_e : nh4_e -->  0.0 1000.0
# EX_nmn_e : nmn_e <=>  -10.0 1000.0
# EX_no2_e : no2_e -->  0.0 1000.0
# EX_no3_e : no3_e -->  0.0 1000.0
# EX_o2_e : o2_e <=>  -20.0 1000.0
# EX_ocdca_e : ocdca_e <=>  -10.0 1000.0
# EX_orn_e : orn_e -->  0.0 1000.0
# EX_pi_e : pi_e <=>  -10.0 1000.0
# EX_ppi_e : ppi_e -->  0.0 1000.0
# EX_pro__L_e : pro__L_e -->  0.0 1000.0
# EX_protein_e : protein_c <--  -10.0 0.0
# EX_ptrc_e : ptrc_e -->  0.0 1000.0
# EX_pyr_e : pyr_e -->  0.0 1000.0
# EX_q8_e : q8_e -->  0.0 1000.0
# EX_q8h2_e : q8h2_e <=>  -10.0 1000.0
# EX_rna_c0 : rna_c <--  -10.0 0.0
# EX_salcn_e : salcn_e -->  0.0 1000.0
# EX_sbt__D_e : sbt__D_e -->  0.0 1000.0
# EX_ser__D_e : ser__D_e -->  0.0 1000.0
# EX_ser__L_e : ser__L_e -->  0.0 1000.0
# EX_so4_e : so4_e <=>  -10.0 1000.0
# EX_spmd_e : spmd_e <=>  -10.0 1000.0
# EX_succ_e : succ_e -->  0.0 1000.0
# EX_sucr_e : sucr_e -->  0.0 0.0
# EX_taur_e : taur_e -->  0.0 1000.0
# EX_thmmp_e : thmmp_e <=>  -10.0 1000.0
# EX_thymd_e : thymd_e -->  0.0 1000.0
# EX_tre_e : tre_e -->  0.0 1000.0
# EX_trp__L_e : trp__L_e <=>  -10.0 1000.0
# EX_tsul_e : tsul_e -->  0.0 1000.0
# EX_ttdca_e : ttdca_e <=>  -10.0 1000.0
# EX_uri_e : uri_e -->  0.0 1000.0
# EX_xyl__D_e : xyl__D_e -->  0.0 0.0
# EX_zn2_e : zn2_e <=>  -10.0 1000.0
# 99

# %% [markdown]
# ### Phase Plane

# %%
data = calculate_phenotype_phase_plane(xam_model, "EX_glc__D_e", "EX_o2_e")
data.plot_matplotlib();
#plt.savefig('Phase_Plane_Gluc-O2_Xam.svg', format='svg', dpi=1200)
#plt.savefig('Phase_Plane_Gluc-O2_Xam.png', format='png', dpi=1200)
