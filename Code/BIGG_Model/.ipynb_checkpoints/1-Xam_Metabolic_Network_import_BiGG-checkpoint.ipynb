# %% [markdown]
# # Xam Metabolic Model BiGG

# %%
import cobra
import os
from os.path import join

data_dir = "/Users/david/Dropbox (UCSD SBRG)/Xam_Multistrain_Recon/Metabolic_model/BiGG_Model/"
xam_model = cobra.io.read_sbml_model(join(data_dir, "Xam_BiGG_minmal_media.xml"))

# %%
print (len(xam_model.reactions))
print (len(xam_model.metabolites))
print (len(xam_model.genes))
# Out:
# 1556
# 1527
# 890

# %%
cobra.io.save_matlab_model(xam_model, "xam.mat")

# %% [markdown]
# ### Reactions

# %%
print("Reactions")
print("---------")
for x in xam_model.reactions:
    print("%s : %s" % (x.id, x.reaction))
# Out:
# Reactions
# ---------
# 10FTHFGLULL : 10fthfglu__L_c + adp_c + h_c + pi_c <-- 10fthf_c + atp_c + glu__L_c
# 2DHPFALDL : 3mob_c + fald_c <=> 2dhp_c
# 2HBO : 2obut_c + h_c + nadh_c <=> 2hb_c + nad_c
# 2OH3K5MPPISO : 2h3kmtp_c + h2o_c --> 12dmpo_c + pi_c
# 34DHOXPEGOX : 34dhmald_c + h_c + nadh_c <=> 34dhoxpeg_c + nad_c
# 34HPPOR : co2_c + hgentis_c <-- 2h34hppr_c + o2_c
# 3HAO : cmusa_c <-- 3hanthrn_c + o2_c
# 3HBCOAHL : 3hmp_c + coa_c + h_c <-- 3hibutcoa_c + h2o_c
# 3HLYTCL : co2_c + dopa_c <=> 34dhphe_c + h_c
# 3OAR100 : 3odecACP_c + h_c + nadph_c <=> 3hdecACP_c + nadp_c
# 3OAR120 : 3oddecACP_c + h_c + nadph_c <=> 3hddecACP_c + nadp_c
# 3OAR40_1 : actACP_c + h_c + nadph_c <=> 3hbutACP_c + nadp_c
# 3OAR60 : 3ohexACP_c + h_c + nadph_c <=> 3hhexACP_c + nadp_c
# 3OAR80 : 3hoctACP_c + nadp_c <=> 3ooctACP_c + h_c + nadph_c
# 3OAS80 : 3ooctACP_c + ACP_c + co2_c <-- hexACP_c + malACP_c
# 4ABUTD : 4abut_c + 2.0 h_c + nadph_c <-- 4abutn_c + h2o_c + nadp_c
# 4CMLCL_kt : 5odhf2a_c + co2_c <-- 2c25dho_c + h_c
# 4HTHRS : 4hthr_c + pi_c <-- h2o_c + phthr_c
# 56DH5FLURAAMH : aflburppa_c + h_c <=> 56dh5flura_c + h2o_c
# 5FLURAPRT : 5flurimp_c + ppi_c <=> 5flura_c + prpp_c
# 5HLTDL : co2_c + srtn_c <=> 5htrp_c + h_c
# 5HXKYNDCL : 5hxkynam_c + co2_c <=> 5hxkyn_c + h_c
# A5PISO : ara5p_c <=> ru5p__D_c
# AACOAR_syn : 3hbcoa__R_c + nadp_c <=> aacoa_c + h_c + nadph_c
# AACOAT : aacoa_c + amp_c + ppi_c <-- acac_c + atp_c + coa_c
# AASPh : adp_c + h_c + paps_c <=> aps_c + atp_c
# ABUTD : 4abut_c + 2.0 h_c + nadh_c <-- 4abutn_c + h2o_c + nad_c
# ACACT1 : aacoa_c + coa_c <=> 2.0 accoa_c
# ACACT10m : 2maacoa_c + coa_c <=> accoa_c + ppcoa_c
# ACACT2 : 3ohcoa_c + coa_c <=> accoa_c + btcoa_c
# ACACT3 : 3oocoa_c + coa_c <=> accoa_c + hxcoa_c
# ACACT4m : 3odcoa_c + coa_c <=> accoa_c + occoa_c
# ACACT5m : 3oddcoa_c + coa_c <=> accoa_c + dcacoa_c
# ACACT6m : 3otdcoa_c + coa_c <=> accoa_c + ddcacoa_c
# ACACT7m : 3ohdcoa_c + coa_c <=> accoa_c + tdcoa_c
# ACALDt : acald_e <-- acald_c
# ACAS_2ahbut : 2ahbut_c + thmpp_c <=> 2ahethmpp_c + 2obut_c
# ACBIPGT : agdpcbi_c + ppi_c <=> adocbip_c + gtp_c + h_c
# ACCOAC : adp_c + h_c + malcoa_c + pi_c <=> accoa_c + atp_c + hco3_c
# ACCOAC_1 : accoa_c + cbtnCCP_c --> btnCCP_c + malcoa_c
# ACCOAL : atp_c + coa_c + ppa_c <=> adp_c + pi_c + ppcoa_c
# ACGApts : acgam_e + pep_c <=> acgam6p_c + pyr_c
# ACGK : acg5p_c + adp_c <-- acglu_c + atp_c
# ACGS : acglu_c + coa_c + h_c <-- accoa_c + glu__L_c
# ACOA40OR : btcoa_c + fad_c + h_c <-- b2coa_c + fadh2_c
# ACOAD1 : b2coa_c + h_c + nadh_c --> btcoa_c + nad_c
# ACOAD10m : 2mbcoa_c + fad_c + h_c <-- 2mb2coa_c + fadh2_c
# ACOAD2 : h_c + hx2coa_c + nadh_c --> hxcoa_c + nad_c
# ACOAD3 : h_c + nadh_c + oc2coa_c --> nad_c + occoa_c
# ACOAD4 : dc2coa_c + h_c + nadh_c --> dcacoa_c + nad_c
# ACOAD5 : dd2coa_c + h_c + nadh_c --> ddcacoa_c + nad_c
# ACOAD6 : h_c + nadh_c + td2coa_c --> nad_c + tdcoa_c
# ACOAD7 : h_c + hdd2coa_c + nadh_c --> nad_c + pmtcoa_c
# ACOAD8m : fad_c + h_c + ivcoa_c <-- 3mb2coa_c + fadh2_c
# ACOAD9m : fad_c + h_c + ibcoa_c <-- 2mp2coa_c + fadh2_c
# ACOADH2 : 2.0 2mp2coa_c + 2.0 h2o_c <-- 2.0 ibcoa_c + o2_c
# ACOATA : acACP_c + coa_c <=> ACP_c + accoa_c
# ACODA : ac_c + orn_c <=> acorn_c + h2o_c
# ACONTa : cit_c --> acon_C_c + h2o_c
# ACONTb : acon_C_c + h2o_c --> icit_c
# ACOTA : acg5sa_c + glu__L_c <=> acorn_c + akg_c
# ACPh : 3pg_c + h_c + pi_c <-- 13dpg_c + h2o_c
# ACPS1 : apoACP_c + coa_c --> ACP_c + h_c + pap_c
# ACS : accoa_c + amp_c + ppi_c <-- ac_c + atp_c + coa_c
# ACt4pp : ac_p + na1_p <=> ac_c + na1_c
# ACYP_2 : ac_c + h_c + pi_c <-- actp_c + h2o_c
# ADA : adn_c + h2o_c + h_c --> ins_c + nh4_c
# ADCL : 4adcho_c --> 4abz_c + h_c + pyr_c
# ADCS : 4adcho_c + glu__L_c <=> chor_c + gln__L_c
# ADCYRS : adcobhex_c + 4.0 adp_c + 4.0 glu__L_c + 4.0 h_c + 4.0 pi_c <=> adcobdam_c + 4.0 atp_c + 4.0 gln__L_c + 4.0 h2o_c
# ADECn : camp_c + ppi_c <-- atp_c
# ADK1 : amp_c + atp_c <=> 2.0 adp_c
# ADK2 : adp_c + ppi_c <=> amp_c + pppi_c
# ADMDC : ametam_c + co2_c <-- amet_c + h_c
# ADNK1 : adp_c + amp_c + h_c <=> adn_c + atp_c
# ADNt2 : adn_e + h_e <=> adn_c + h_c
# ADNUC : ade_c + rib__D_c <-- adn_c + h2o_c
# ADOCBIK : adocbip_c + adp_c + h_c <=> adocbi_c + atp_c
# ADOCBLS : agdpcbi_c + rdmbzi_c <=> adocbl_c + gmp_c + h_c
# ADPRDP : amp_c + 2.0 h_c + r5p_c <-- adprib_c + h2o_c
# ADPT : amp_c + ppi_c <-- ade_c + prpp_c
# ADSL1r : amp_c + fum_c <-- dcamp_c
# ADSL2r : aicar_c + fum_c <=> 25aics_c
# ADSS : asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + 2.0 h_c + pi_c
# AFAT : atp_c + fmn_c + h_c --> fad_c + ppi_c
# AGDC : ac_c + gam6p_c <=> acgam6p_c + h2o_c
# AGDI : Ncbmpts_c + nh4_c <-- agm_c + h2o_c
# AGGPR : acg5sa_c + nadp_c + pi_c <-- acg5p_c + h_c + nadph_c
# AGMHE : adphep_DD_c --> adphep_LD_c
# AGPAT120 : 1ddecg3p_c + ddcaACP_c + h_c --> ACP_c + pa120_c
# AGPAT140 : 1tdecg3p_c + myrsACP_c --> ACP_c + pa140_c
# AGPAT141 : 1tdec7eg3p_c + tdeACP_c --> ACP_c + pa141_c
# AGPAT160 : ACP_c + pa160_c <-- 1hdecg3p_c + palmACP_c
# AGPAT161 : 1hdec9eg3p_c + h_c + hdeACP_c --> ACP_c + pa161_c
# AGPAT180 : 1odecg3p_c + 2.0 h_c + ocdcaACP_c --> ACP_c + pa180_c
# AGPAT181 : 1odec11eg3p_c + octeACP_c --> ACP_c + pa181_c
# AGTi : gly_c + pyr_c <-- ala__L_c + glx_c
# AICART : 10fthf_c + aicar_c <=> fprica_c + thf_c
# AIRCr : air_c + co2_c <-- 5aizc_c + h_c
# AKGDH : co2_c + nadh_c + succoa_c <-- akg_c + coa_c + nad_c
# AKGDHe2r : dhlam_c + succoa_c <=> coa_c + sdhlam_c
# AKGt2r : akg_e + h_e <=> akg_c + h_c
# AKP1 : dhnpt_c + 2.0 h_c + 3.0 pi_c <-- ahdt_c + 3.0 h2o_c
# ALAALAr : 2.0 ala__D_c + atp_c --> adp_c + alaala_c + h_c + pi_c
# ALAR : ala__D_c <=> ala__L_c
# ALCD19 : glyald_c + h_c + nadh_c <=> glyc_c + nad_c
# ALCD2ir : acald_c + h_c + nadh_c <=> etoh_c + nad_c
# ALDD22x : ala_B_c + 2.0 h_c + nadh_c <=> aproa_c + h2o_c + nad_c
# ALDD2x : ac_c + 2.0 h_c + nadh_c <-- acald_c + h2o_c + nad_c
# ALDD31 : gly_c + 2.0 h_c + nadh_c <-- aacald_c + h2o_c + nad_c
# ALKP : dhap_c + h2o_c --> dha_c + pi_c
# AM6PTh : atp_c + man_c <=> adp_c + h_c + man6p_c
# AMAOTr : amob_c + dann_c <=> 8aonn_c + amet_c
# AMID : 4gudbutn_c + nh4_c <-- 4gudbd_c + h2o_c
# AMID2 : h2o_c + pad_c <=> nh4_c + pac_c
# AMID3 : h2o_c + iad_c --> ind3ac_c + nh4_c
# AMID4 : ac_c + nh4_c <-- ad_c + h2o_c
# AMID5 : acryl_c + nh4_c <-- aa_c + h2o_c
# AMMQT8_2 : 2dmmq8_c + amet_c --> ahcys_c + h_c + mqn8_c
# AMPTASECG : cys__L_c + gly_c <=> cgly_c + h2o_c
# ANNAT : nad_c + ppi_c <=> atp_c + h_c + nmn_c
# ANS : anth_c + glu__L_c + h_c + pyr_c <-- chor_c + gln__L_c
# ANS2 : anth_c + h2o_c + h_c + pyr_c <-- chor_c + nh4_c
# AOOA : glu__L_c + imacp_c <=> akg_c + hisp_c
# AOXHEXCYCL : 1pipdn2c_c + h2o_c <-- 6a2ohxnt_c
# AOXSr : 8aonn_c + co2_c + coa_c <-- ala__L_c + h_c + pmcoa_c
# APAPTm : ametam_c + ptrc_c --> 5mta_c + h_c + spmd_c
# APATr : ala_B_c + pyr_c <=> ala__L_c + msa_c
# APLh : alac__S_c + thmpp_c <=> 2ahethmpp_c + pyr_c
# APPAT : dpcoa_c + ppi_c <=> atp_c + h_c + pan4p_c
# APRAUR : 5aprbu_c + nadp_c <=> 5apru_c + h_c + nadph_c
# APSR : amp_c + 2.0 h_c + hso3_c + trdox_c <-- aps_c + trdrd_c
# ARBTptspp : arbt6p_c + pyr_c <=> arbt_e + pep_c
# ARD_1 : 4met2obut_c + for_c + 2.0 h_c <-- 12dmpo_c + o2_c
# ARGDC : agm_c + co2_c <-- arg__L_c + h_c
# ARGN : orn_c + urea_c <-- arg__L_c + h2o_c
# ARGORNt7 : arg__L_e + orn_c <=> arg__L_c + orn_e
# ARGSL : argsuc_c <=> arg__L_c + fum_c
# ARGSS : amp_c + argsuc_c + h_c + ppi_c <=> asp__L_c + atp_c + citr__L_c
# ASAD : 4pasp_c + h_c + nadph_c --> aspsa_c + nadp_c + pi_c
# ASNN : asn__L_c + h2o_c --> asp__L_c + nh4_c
# ASNS1 : amp_c + asn__L_c + glu__L_c + h_c + ppi_c <-- asp__L_c + atp_c + gln__L_c + h2o_c
# ASP1DC : ala_B_c + co2_c <-- asp__L_c + h_c
# ASPATh : akg_c + asp__L_c <=> glu__L_c + oaa_c
# ASPCT : asp__L_c + cbp_c --> cbasp_c + h_c + pi_c
# ASPK : 4pasp_c + adp_c <-- asp__L_c + atp_c
# ASPt2_2 : asp__L_e + 2.0 h_e <=> asp__L_c + 2.0 h_c
# ATDAMh : adp_c + dadp_c <=> atp_c + damp_c
# ATDGDm : adp_c + dgtp_c <=> atp_c + dgdp_c
# ATGDm : atp_c + gdp_c <=> adp_c + gtp_c
# ATPM : atp_c + h2o_c --> adp_c + h_c + pi_c
# ATPPRT : ppi_c + prbatp_c <-- atp_c + prpp_c
# ATPS4r : adp_c + h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c
# AUS : 5aprbu_c + h2o_c --> 4r5au_c + pi_c
# BACCL : btamp_c + ppi_c --> atp_c + btn_c + h_c
# BCTA_glu_h : akg_c + leu__L_c <=> 4mop_c + glu__L_c
# BCTA_val_h : akg_c + val__L_c <=> 3mob_c + glu__L_c
# BDH : acac_c + h_c + nadh_c <=> bhb_c + nad_c
# BETALDHx : glyb_c + 2.0 h_c + nadh_c <-- betald_c + h2o_c + nad_c
# BETALDHy : glyb_c + 2.0 h_c + nadph_c <-- betald_c + h2o_c + nadp_c
# Biomass : 0.00309646685193 10fthf_c + 0.00309646685193 2dmmq8_c + 0.00309646685193 5mthf_c + 0.00309646685193 ACP_c + 0.0106480421342 MNXM5124_c + 0.0106480421342 MNXM5129_c + 0.00309646685193 MNXM57_c + 0.0106480421342 MNXM6175_c + 0.0106480421342 MNXM6297_c + 0.0106480421342 MNXM6440_c + 0.0106480421342 MNXM7294_c + 0.0106480421342 MNXM7305_c + 0.0250105977109 MNXM7630_c + 0.00309646685193 adocbl_c + 0.427934380173 ala__L_c + 0.00309646685193 amet_c + 0.246696822701 arg__L_c + 0.200830806928 asn__L_c + 0.200830806928 asp__L_c + 40.1101757365 atp_c + 0.00309646685193 ca2_c + 0.00309646685193 cl_c + 0.00309646685193 coa_c + 0.00309646685193 cobalt2_c + 0.0250105977109 colipa_c + 0.0841036156545 ctp_c + 0.00309646685193 cu2_c + 0.0761464922056 cys__L_c + 0.0160206718346 datp_c + 0.0160206718346 dctp_c + 0.0160206718346 dgtp_c + dna_c + 0.0250105977109 dtpcudcpp_c + 0.0160206718346 dttp_c + 0.00309646685193 fad_c + 0.00309646685193 fe2_c + 0.00309646685193 fe3_c + 0.219088153013 gln__L_c + 0.219088153013 glu__L_c + 0.509869786991 gly_c + 0.135406821204 gtp_c + 35.540309243 h2o_c + 0.0792636000737 his__L_c + 0.241798510337 ile__L_c + 0.00309646685193 k_c + 0.37538884754 leu__L_c + 0.28543802049 lys__L_c + 0.127801422591 met__L_c + 0.00309646685193 mg2_c + 0.00309646685193 mn2_c + 0.00309646685193 mqn8_c + 0.00309646685193 nad_c + 0.00309646685193 nadp_c + 0.0106480421342 pe180_c + 0.0106480421342 pg180_c + 0.154519490031 phe__L_c + 0.00309646685193 pheme_c + 0.18435466534 pro__L_c + protein_c + 0.00309646685193 ptrc_c + 0.00309646685193 pydx5p_c + 0.00309646685193 q8_c + 0.00309646685193 ribflv_c + rna_c + 0.179456352976 ser__L_c + 0.00309646685193 sheme_c + 0.00309646685193 so4_c + 0.00309646685193 spmd_c + 0.00309646685193 thf_c + 0.00309646685193 thmpp_c + 0.211072732781 thr__L_c + 0.047201919145 trp__L_c + 0.120676604607 tyr__L_c + 0.0908319049068 utp_c + 0.352233189092 val__L_c + 0.00309646685193 zn2_c --> BIOMASS_c + 0.0250105977109 MNXM5258_c + 40.0 adp_c + 0.00309646685193 apoACP_c + 0.00309646685193 cbi_c + 0.00309646685193 dmbzid_c + 40.0562052099 h_c + 39.9969035331 pi_c + 0.484600765611 ppi_c
# BPNT : amp_c + pi_c <-- h2o_c + pap_c
# BTNC : adp_c + cbtnCCP_c + h_c + pi_c <=> atp_c + btnCCP_c + hco3_c
# BTND1 : biocyt_c + h2o_c <=> btn_c + lys__L_c
# BTS4 : amet_c + dtbt_c + s_c --> btn_c + dad_5_c + h_c + met__L_c
# CA2t3pp : ca2_c + h_e <-- ca2_e + h_c
# CAT : 2.0 h2o2_c --> 2.0 h2o_c + o2_c
# CBIAT : atp_c + cbi_c + h_c <=> adocbi_c + pppi_c
# CBL1abc : atp_c + cbl1_e + h2o_c + h_e --> adp_c + cbl1_c + 2.0 h_c + pi_c
# CBPS : 2.0 adp_c + cbp_c + glu__L_c + 2.0 h_c + pi_c <-- 2.0 atp_c + gln__L_c + h2o_c + hco3_c
# CD2t4pp : cd2_c + h_e + k_e <=> cd2_e + h_c + k_c
# CDPGLC46DH : cdp4dh6doglc_c + h2o_c <-- cdpglc_c
# CDPMEK : 2p4c2me_c + adp_c + h_c <=> 4c2me_c + atp_c
# CHLt2 : chol_e + h_e <=> chol_c + h_c
# CHOLD : betald_c + h_c + nadh_c <=> chol_c + nad_c
# CHORM : chor_c --> pphn_c
# CHORS : 3psme_c --> chor_c + pi_c
# CITMCOAHm : citmcoa__L_c <=> h2o_c + itaccoa_c
# CITt2r : cit_e + h_e <=> cit_c + h_c
# CLtex : cl_e <=> cl_c
# CMPA : co2_c + nh4_c + ptrc_c <-- Ncbmpts_c + h2o_c + 2.0 h_c
# CMS : 4c2me_c + ppi_c <=> 2me4p_c + ctp_c + h_c
# CO2t : co2_e <=> co2_c
# COALDDH : fer_c + 2.0 h_c + nadh_c <=> conialdh_c + h2o_c + nad_c
# COBALT2tex : cobalt2_e <=> cobalt2_c
# CPPPGO : 2.0 co2_c + 2.0 h2o_c + pppg9_c <-- cpppg3_c + 2.0 h_c + o2_c
# CPS : 2.0 adp_c + cbp_c + 3.0 h_c + pi_c <=> 2.0 atp_c + co2_c + h2o_c + nh4_c
# CS : cit_c + coa_c + h_c <-- accoa_c + h2o_c + oaa_c
# CSND : nh4_c + ura_c <-- csn_c + h2o_c + h_c
# CTPS1 : atp_c + nh4_c + utp_c <=> adp_c + ctp_c + 2.0 h_c + pi_c
# CTPS2 : atp_c + gln__L_c + h2o_c + utp_c --> adp_c + ctp_c + glu__L_c + 2.0 h_c + pi_c
# CU2abcpp : adp_c + cu2_c + h_c + pi_c <-- atp_c + cu2_e + h2o_c
# CYARTMT : amet_c + cyart_c <=> ahcys_c + h_c + menecyart_c
# CYOO2pp : 2.0 ficytC_c + h2o_c + 4.0 h_e <-- 2.0 focytC_c + 2.0 h_c + 0.5 o2_c
# CYRDAAT : atp_c + co1dam_c + h_c <=> adcobdam_c + pppi_c
# CYS : h2s_c + h_c + ser__L_c <=> cys__L_c + h2o_c
# CYSDS : h2s_c + h_c + nh4_c + pyr_c <-- cys__L_c + h2o_c
# CYSS : ac_c + cys__L_c <-- acser_c + h2s_c
# CYSS_trdrd : ac_c + cys__L_c + 2.0 h_c + hso3_c + trdox_c <-- acser_c + trdrd_c + tsul_c
# CYTBD2pp : h2o_c + 2.0 h_e + mqn8_c <-- 2.0 h_c + mql8_c + 0.5 o2_c
# CYTBO3 : h2o_c + 2.5 h_e + q8_c <-- 2.5 h_c + 0.5 o2_c + q8h2_c
# CYTD : cytd_c + h2o_c + h_c --> nh4_c + uri_c
# CYTDt2 : cytd_e + h_e <=> cytd_c + h_c
# CYTK1 : adp_c + cdp_c <=> atp_c + cmp_c
# CYTK2 : atp_c + dcmp_c <=> adp_c + dcdp_c
# DAAD : ala__D_c + fad_c + h2o_c + h_c <=> fadh2_c + nh4_c + pyr_c
# DADA : dad_2_c + h2o_c + h_c --> din_c + nh4_c
# DADNt2 : dad_2_e + h_e <=> dad_2_c + h_c
# DAGK160 : adp_c + h_c + pa160_c <=> 12dgr160_c + atp_c
# DALAt2pp : ala__D_e + h_e <=> ala__D_c + h_c
# DAPDA : h2o_c + n6all26d_c <=> 26dap_LL_c + ac_c
# DAPDC : co2_c + lys__L_c <=> 26dap__M_c + h_c
# DAPE : 26dap__M_c <=> 26dap_LL_c
# DASYN120 : cdpdddecg_c + ppi_c <=> ctp_c + pa120_c
# DASYN140 : cdpdtdecg_c + ppi_c <=> ctp_c + h_c + pa140_c
# DASYN141 : cdpdtdec7eg_c + ppi_c <=> ctp_c + pa141_c
# DASYN160 : cdpdhdecg_c + ppi_c <=> ctp_c + h_c + pa160_c
# DASYN161 : cdpdhdec9eg_c + ppi_c <=> ctp_c + pa161_c
# DASYN180 : cdpdodecg_c + ppi_c <=> ctp_c + h_c + pa180_c
# DASYN181 : cdpdodec11eg_c + ppi_c <=> ctp_c + pa181_c
# DB4PS : ru5p__D_c --> db4p_c + for_c + h_c
# DBTS : adp_c + dtbt_c + 3.0 h_c + pi_c <-- atp_c + co2_c + dann_c
# DCTPD : dctp_c + h2o_c + h_c --> dutp_c + nh4_c
# DCTPD2 : nh4_c + utp_c <-- ctp_c + h2o_c + h_c
# DCYTD : dcyt_c + h2o_c + h_c --> duri_c + nh4_c
# DCYTt2 : dcyt_e + h_e <=> dcyt_c + h_c
# DDGALK : 2dh3dgal_c + atp_c <=> 2dh3dgal6p_c + adp_c + h_c
# DDGLCNt2r : 2ddglcn_e + h_e <=> 2ddglcn_c + h_c
# DDGLK : 2ddg6p_c + adp_c + h_c <=> 2ddglcn_c + atp_c
# DDPA : 2dda7p_c + pi_c <-- e4p_c + h2o_c + pep_c
# DDPGA : glx_c + pyr_c <=> 4h2oglt_c
# DDPGALA : g3p_c + pyr_c <=> 2dh3dgal6p_c
# DGC3D : 3ddgc_c + h_c + nadh_c <=> 2dglcn_c + nad_c
# DGK1 : atp_c + dgmp_c <=> adp_c + dgdp_c
# DGSNt2 : dgsn_e + h_e <=> dgsn_c + h_c
# DHAD1 : 23dhmb_c --> 3mob_c + h2o_c
# DHCIND : dhcinnm_c + h_c + nadh_c <=> cenchddd_c + nad_c
# DHFR : dhf_c + h_c + nadph_c <=> nadp_c + thf_c
# DHFS : adp_c + dhf_c + h_c + pi_c <-- atp_c + dhpt_c + glu__L_c
# DHNPA2r : 6hmhpt_c + gcald_c <=> dhnpt_c
# DHORD2 : orot_c + q8h2_c <-- dhor__S_c + q8_c
# DHORD5 : mql8_c + orot_c <-- dhor__S_c + mqn8_c
# DHORTS : cbasp_c + h_c <=> dhor__S_c + h2o_c
# DHPD : cala_c + h_c <-- 56dura_c + h2o_c
# DHPM2 : 3uib_c + h_c <-- 56dthm_c + h2o_c
# DHPPD : dhpppn_c + h_c + nadh_c <=> cechddd_c + nad_c
# DHPPDA2 : 5apru_c + nh4_c <-- 25drapp_c + h2o_c + h_c
# DHPS2 : 4abz_c + 6hmhptpp_c --> dhpt_c + ppi_c
# DHQS : 2dda7p_c --> 3dhq_c + pi_c
# DHQTi : 3dhsk_c + h2o_c <-- 3dhq_c
# DHRT_ivcoa : dhlam_c + ivcoa_c <=> 3mbdhl_c + coa_c
# DINSt2 : din_e + h_e <=> din_c + h_c
# DLDLBT : dmlz_c + 2.0 h2o_c + h_c + pi_c <=> 4r5au_c + db4p_c
# DMATT : grdp_c + ppi_c <-- dmpp_c + ipdp_c
# DMORh : alac__S_c + h_c + nadph_c <=> 23dhmb_c + nadp_c
# DMPH : dgmp_c + h2o_c --> dgsn_c + pi_c
# DMPPS : h2mb4p_c + h_c + nadh_c --> dmpp_c + h2o_c + nad_c
# DMPPS_syn : dmpp_c + h2o_c + nadp_c <-- h2mb4p_c + h_c + nadph_c
# DMTPHT : ahcys_c + h_c + phllqne_c <-- amet_c + dmtphllqne_c
# DNGALh : amp_c + glu__L_c + h_c + nad_c + ppi_c <-- atp_c + dnad_c + gln__L_c + h2o_c
# DPCOAK : adp_c + coa_c + h_c <-- atp_c + dpcoa_c
# DPR : 2dhp_c + h_c + nadph_c <=> nadp_c + pant__R_c
# DSERt2 : h_e + ser__D_e <=> h_c + ser__D_c
# DTMPK : adp_c + dtdp_c <=> atp_c + dtmp_c
# DURIK1 : adp_c + dump_c + h_c <=> atp_c + duri_c
# DURIt2 : duri_e + h_e <=> duri_c + h_c
# DUTPDP : dump_c + h_c + ppi_c <-- dutp_c + h2o_c
# DXPRIi : 2me4p_c + nadp_c <=> dxyl5p_c + h_c + nadph_c
# DXPS : co2_c + dxyl5p_c <-- g3p_c + h_c + pyr_c
# E4PD : 4per_c + 2.0 h_c + nadh_c <-- e4p_c + h2o_c + nad_c
# EAR100y : h_c + nadph_c + tdec2eACP_c --> dcaACP_c + nadp_c
# EAR120y : 2.0 h_c + nadph_c + tddec2eACP_c --> ddcaACP_c + nadp_c
# EAR140y : 2.0 h_c + nadph_c + tmrs2eACP_c --> myrsACP_c + nadp_c
# EAR40y : but2eACP_c + 2.0 h_c + nadph_c --> butACP_c + nadp_c
# EAR60y : h_c + nadph_c + thex2eACP_c --> hexACP_c + nadp_c
# EAR80y : h_c + nadph_c + toct2eACP_c --> nadp_c + ocACP_c
# ECOAH1 : b2coa_c + h2o_c <=> 3hbcoa_c
# ECOAH12 : 2mp2coa_c + h2o_c <=> 3hibutcoa_c
# ECOAH3 : h2o_c + oc2coa_c <=> 3hocoa_c
# ECOAH4 : dc2coa_c + h2o_c <=> 3hdcoa_c
# ECOAH5 : dd2coa_c + h2o_c <=> 3hddcoa_c
# ECOAH6 : h2o_c + td2coa_c <=> 3htdcoa_c
# ECOAH7 : h2o_c + hdd2coa_c <=> 3hhdcoa_c
# ECOAH9ir : 2mb2coa_c + h2o_c <=> 3hmbcoa_c
# EDA : g3p_c + pyr_c <-- 2ddg6p_c
# EDD : 2ddg6p_c + h2o_c <-- 6pgc_c
# EDTXS1 : ACP_c + kdo2lipid4L_c <-- ddcaACP_c + kdo2lipid4_c
# EDTXS2 : kdo2lipid4L_c + myrsACP_c --> ACP_c + lipa_c
# ENO : 2pg_c --> h2o_c + pep_c
# ETHAAL : etha_c --> acald_c + nh4_c
# ETHAt2pp : etha_e + h_e <=> etha_c + h_c
# ETOHti : etoh_c <=> etoh_e
# EX_2ddglcn_e : 2ddglcn_e -->
# EX_4hbz_e : 4hbz_e <=>
# EX_ac_e : ac_e -->
# EX_acald_e : acald_e -->
# EX_acgam_e : acgam_e -->
# EX_adn_e : adn_e -->
# EX_akg_e : akg_e -->
# EX_ala__D_e : ala__D_e -->
# EX_arab__L_e : arab__L_e -->
# EX_arbt_e : arbt_e -->
# EX_arg__L_e : arg__L_e <=>
# EX_ASPt5n_e : asp__L_e -->
# EX_Biomass_e : BIOMASS_c -->
# EX_ca2_e : ca2_e <=>
# EX_cbl1_e : cbl1_e -->
# EX_cd2_e : cd2_e -->
# EX_chol_e : chol_e -->
# EX_cit_e : cit_e -->
# EX_cl_e : cl_e <=>
# EX_co2_e : co2_e -->
# EX_cobalt2_e : cobalt2_e <=>
# EX_cu2_e : cu2_e <=>
# EX_cytd_e : cytd_e -->
# EX_dad_2_e : dad_2_e -->
# EX_dcyt_e : dcyt_e -->
# EX_dgsn_e : dgsn_e -->
# EX_din_e : din_e -->
# EX_DNA_e : dna_c <--
# EX_duri_e : duri_e -->
# EX_etha_e : etha_e -->
# EX_etoh_e : etoh_e -->
# EX_fe2_e : fe2_e <=>
# EX_fe3_e : fe3_e <=>
# EX_for_e : for_e -->
# EX_fru_e : fru_e -->
# EX_fum_e : fum_e -->
# EX_galt_e : galt_e -->
# EX_galur_e : galur_e -->
# EX_gam_e : gam_e -->
# EX_glc__D_e : glc__D_e <=>
# EX_glcur_e : glcur_e -->
# EX_gln__L_e : gln__L_e -->
# EX_glu__L_e : glu__L_e -->
# EX_gly_e : gly_e -->
# EX_glyb_e : glyb_e -->
# EX_glyc_e : glyc_e -->
# EX_glycogen_e : glycogen_c -->
# EX_h_e : h_e -->
# EX_h2o_e : h2o_e <=>
# EX_hdca_e : hdca_e -->
# EX_hxan_e : hxan_e -->
# EX_ins_e : ins_e -->
# EX_k_e : k_e <=>
# EX_lys__L_e : lys__L_e <=>
# EX_mal__L_e : mal__L_e -->
# EX_malt_e : malt_e -->
# EX_man_e : man_e -->
# EX_met__D_e : met__D_e -->
# EX_met__L_e : met__L_e -->
# EX_metox__R_e : metox__R_e -->
# EX_metsox_S__L_e : metsox_S__L_e -->
# EX_mg2_e : mg2_e <=>
# EX_mn2_e : mn2_e <=>
# EX_mqn7_e : mqn7_e <=>
# EX_na1_e : na1_e -->
# EX_nh4_e : nh4_e -->
# EX_nmn_e : nmn_e <=>
# EX_no2_e : no2_e -->
# EX_no3_e : no3_e -->
# EX_o2_e : o2_e <=>
# EX_ocdca_e : ocdca_e <=>
# EX_orn_e : orn_e -->
# EX_pi_e : pi_e <=>
# EX_ppi_e : ppi_e -->
# EX_pro__L_e : pro__L_e -->
# EX_protein_e : protein_c <--
# EX_ptrc_e : ptrc_e -->
# EX_pyr_e : pyr_e -->
# EX_q8_e : q8_e -->
# EX_q8h2_e : q8h2_e <=>
# EX_rna_c0 : rna_c <--
# EX_salcn_e : salcn_e -->
# EX_sbt__D_e : sbt__D_e -->
# EX_ser__D_e : ser__D_e -->
# EX_ser__L_e : ser__L_e -->
# EX_so4_e : so4_e <=>
# EX_spmd_e : spmd_e <=>
# EX_succ_e : succ_e -->
# EX_sucr_e : sucr_e -->
# EX_taur_e : taur_e -->
# EX_thmmp_e : thmmp_e <=>
# EX_thymd_e : thymd_e -->
# EX_tre_e : tre_e -->
# EX_trp__L_e : trp__L_e <=>
# EX_tsul_e : tsul_e -->
# EX_ttdca_e : ttdca_e <=>
# EX_uri_e : uri_e -->
# EX_xyl__D_e : xyl__D_e -->
# EX_zn2_e : zn2_e <=>
# FA100ACPHi : ACP_c + dca_c + h_c <=> dcaACP_c + h2o_c
# FA80ACPHi : ACP_c + h_c + octa_c <=> h2o_c + ocACP_c
# FACOAE160 : coa_c + h_c + hdca_c <-- h2o_c + pmtcoa_c
# FACOAE180 : coa_c + h_c + ocdca_c <-- h2o_c + stcoa_c
# FACOAE1836Z9Z12Z : coa_c + h_c + lnlncg_c <=> h2o_c + lnlncgcoa_c
# FACOAL140 : amp_c + ppi_c + tdcoa_c <-- atp_c + coa_c + ttdca_c
# FACOAL160 : atp_c + coa_c + hdca_c --> amp_c + pmtcoa_c + ppi_c
# FACOAL180 : amp_c + ppi_c + stcoa_c <-- atp_c + coa_c + ocdca_c
# FAS140ACPm : ACP_c + co2_c + h2o_c + myrsACP_c + 2.0 nadp_c --> ddcaACP_c + 2.0 h_c + malACP_c + 2.0 nadph_c
# FBA : dhap_c + g3p_c <=> fdp_c
# FBA3 : s17bp_c <=> dhap_c + e4p_c
# FBP : fdp_c + h2o_c --> f6p_c + pi_c
# FCLT : fe2_c + ppp9_c <=> pheme_c
# FDH : co2_c + nadh_c <-- for_c + nad_c
# FE2abc : atp_c + fe2_e + h2o_c --> adp_c + fe2_c + h_c + pi_c
# FE3abc : atp_c + fe3_e + h2o_c --> adp_c + fe3_c + h_c + pi_c
# FERO : 4.0 fe2_c + 4.0 h_c + o2_c --> 4.0 fe3_c + 2.0 h2o_c
# FGFTh : fgam_c + 2.0 h_c + thf_c <-- gar_c + h2o_c + methf_c
# FGLU : foam_c + glu__L_c --> forglu_c + h2o_c
# FK : adp_c + fuc1p__L_c + h_c <=> atp_c + fuc__L_c
# FLVRx : 2.0 h_c + nadh_c + ribflv_c <=> nad_c + rbflvrd_c
# FMNRx : fmn_c + 2.0 h_c + nadh_c --> fmnh2_c + nad_c
# FOLR2 : fol_c + h_c + nadph_c <=> dhf_c + nadp_c
# FOMETRi : 5fthf_c + h_c <-- h2o_c + methf_c
# FORti : for_c --> for_e
# FPGFTh : fgam_c + h_c + thf_c --> 10fthf_c + gar_c
# FPGS_tm : adp_c + h_c + pi_c + thfglu_c <-- atp_c + glu__L_c + thf_c
# FPPSh : grdp_c + ipdp_c --> frdp_c + ppi_c
# FRD : fad_c + h_c + succ_c --> fadh2_c + fum_c
# FRD2 : fum_c + mql8_c --> mqn8_c + succ_c
# FRD3 : 2dmmq8_c + succ_c <-- 2dmmql8_c + fum_c
# FRD7 : fum_c + q8h2_c --> q8_c + succ_c
# FRTT : ggdp_c + ppi_c <-- frdp_c + ipdp_c
# FRUK : adp_c + fdp_c + h_c <=> atp_c + f1p_c
# FRUpts : fru_e + pep_c <=> f1p_c + pyr_c
# FT : ppi_c + ttc_ggdp_c <-- frdp_c + ipdp_c
# FTCL : 5fthf_c + atp_c --> adp_c + methf_c + pi_c
# FTHFD : for_c + h_c + thf_c <-- 10fthf_c + h2o_c
# FUM : fum_c + h2o_c --> mal__L_c
# FUMt2r : fum_e + h_e <=> fum_c + h_c
# G1PACT : acgam1p_c + coa_c + h_c <-- accoa_c + gam1p_c
# G1PTT : dtdpglu_c + ppi_c <=> dttp_c + g1p_c + h_c
# G1SAT : glu1sa_c <=> 5aop_c
# G3PAT120 : 1ddecg3p_c + ACP_c <-- ddcaACP_c + glyc3p_c
# G3PAT140 : 1tdecg3p_c + ACP_c <-- glyc3p_c + myrsACP_c
# G3PAT141 : glyc3p_c + h_c + tdeACP_c --> 1tdec7eg3p_c + ACP_c
# G3PAT160 : glyc3p_c + 3.0 h_c + palmACP_c --> 1hdecg3p_c + ACP_c
# G3PAT160_1 : 1hdecg3p_c + coa_c <-- glyc3p_c + h_c + pmtcoa_c
# G3PAT161 : glyc3p_c + 3.0 h_c + hdeACP_c --> 1hdec9eg3p_c + ACP_c
# G3PAT180 : glyc3p_c + h_c + ocdcaACP_c --> 1odecg3p_c + ACP_c
# G3PAT181 : glyc3p_c + h_c + octeACP_c --> 1odec11eg3p_c + ACP_c
# G3PD : fad_c + glyc3p_c + h_c <=> dhap_c + fadh2_c
# G3PD1 : dhap_c + h_c + nadh_c <=> glyc3p_c + nad_c
# G3PD5 : dhap_c + q8h2_c <-- glyc3p_c + q8_c
# G3PD6 : dhap_c + mql8_c <-- glyc3p_c + mqn8_c
# G3PD7 : 2dmmq8_c + glyc3p_c --> 2dmmql8_c + dhap_c
# G3PL : g3p_c + indole_c <=> 3ig3p_c
# G5DHx : glu5p_c + h_c + nadph_c --> glu5sa_c + nadp_c + pi_c
# G5SADrm : 1pyr5c_c + h2o_c + h_c <-- glu5sa_c
# G6PBDH : 6pgl_c + h_c + nadph_c <-- g6p_B_c + nadp_c
# G6PDA : gam6p_c + h2o_c --> f6p_c + nh4_c
# G6PDH2r : g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c
# G6PI : g6p_c <=> g6p_B_c
# G6PI3 : g6p_B_c <=> f6p_c
# GALCTD : galct__D_c --> 5dh4dglc_c + h2o_c
# GALCTND : 2dh3dgal_c + h2o_c <-- galctn__D_c
# GALh : adp_c + gln__L_c + h_c + pi_c <-- atp_c + glu__L_c + nh4_c
# GALM1 : glc_bD_c --> glc__D_c
# GALT1 : gagicolipa_c + h_c + udp_c <-- gicolipa_c + udpg_c
# GALTpts : galt_e + pep_c <=> galt1p_c + h_c + pyr_c
# GALUi : ppi_c + udpg_c <=> g1p_c + h_c + utp_c
# GAM : gln__L_c + h2o_c --> glu__L_c + nh4_c
# GAMpts : gam6p_c + pyr_c <=> gam_e + pep_c
# GAPD : 13dpg_c + h_c + nadh_c <=> g3p_c + nad_c + pi_c
# GAPDH_nadp_hi : 13dpg_c + h_c + nadph_c --> g3p_c + nadp_c + pi_c
# GART : adp_c + fgam_c + h_c + pi_c <-- atp_c + for_c + gar_c
# GCC2cm : h_c + lpam_c + nadh_c <=> dhlam_c + nad_c
# GCCa : alpro_c + co2_c <-- gly_c + lpro_c
# GCCb : dhlpro_c + mlthf_c + nh4_c <-- alpro_c + h_c + thf_c
# GCCc : h_c + lpro_c + nadh_c <=> dhlpro_c + nad_c
# GCL : adp_c + glucys_c + h_c + pi_c <-- atp_c + cys__L_c + glu__L_c
# GDH : akg_c + h_c + nadh_c + nh4_c <=> glu__L_c + h2o_c + nad_c
# GF6PTA : gam6p_c + glu__L_c <=> f6p_c + gln__L_c
# GGGABADr : ggbutal_c + h2o_c + nadp_c --> gg4abut_c + 2.0 h_c + nadph_c
# GGTT : pendp_c + ppi_c <-- ggdp_c + ipdp_c
# GHMT : gly_c + h2o_c + mlthf_c --> ser__L_c + thf_c
# GK1 : atp_c + gmp_c <=> adp_c + gdp_c
# GK2 : datp_c + gmp_c <=> dadp_c + gdp_c
# GLCabcpp : adp_c + glc__D_c + h_c + pi_c <-- atp_c + glc__D_e + h2o_c
# GLCpts : g6p_c + pyr_c <=> glc__D_e + pep_c
# GLCTR2 : ggagicolipa_c + h_c + udp_c <-- gagicolipa_c + udpg_c
# GLCTR3 : gggagicolipa_c + h_c + udp_c <-- ggagicolipa_c + udpg_c
# GLNabc : atp_c + gln__L_e + h2o_c <=> adp_c + gln__L_c + h_c + pi_c
# GLNSP1 : adp_c + h_c + pi_c + uaaAgtla_c <-- atp_c + nh4_c + uaaAgla_c
# GLNSP2 : atp_c + nh4_c + uaaGgla_c --> adp_c + h_c + pi_c + uaaGgtla_c
# GLNSP3 : atp_c + nh4_c + uaagmda_c --> adp_c + h_c + pi_c + uaagtmda_c
# GLU5K : adp_c + glu5p_c <=> atp_c + glu__L_c
# GLUFORT : forglu_c + thf_c <=> 5forthf_c + glu__L_c
# GLUFT : Nforglu_c + h_c + thf_c <-- 5fthf_c + glu__L_c
# GLUK_syn : atp_c + glc_bD_c <=> adp_c + g6p_B_c + h_c
# GLUPRT : glu__L_c + ppi_c + pram_c <-- gln__L_c + h2o_c + prpp_c
# GLUR : glu__D_c <=> glu__L_c
# GLUS_nadph : akg_c + gln__L_c + h_c + nadph_c --> 2.0 glu__L_c + nadp_c
# GLUt2r : glu__L_e + h_e <=> glu__L_c + h_c
# GLUTCOADHc : b2coa_c + co2_c + fadh2_c <=> fad_c + glutcoa_c + 2.0 h_c
# GLUTRR : glu1sa_c + nadp_c + trnaglu_c <=> glutrna_c + h_c + nadph_c
# GLUTRS : amp_c + glutrna_c + h_c + ppi_c <-- atp_c + glu__L_c + trnaglu_c
# GLXO1 : 2.0 h_c + nadh_c + oxa_c <=> glx_c + h2o_c + nad_c
# GLYALDDr : glyc__R_c + 2.0 h_c + nadh_c <-- glyald_c + h2o_c + nad_c
# GLYAMDTRc : arg__L_c + gly_c <=> gudac_c + orn_c
# GLYAT : 2aobut_c + coa_c <=> accoa_c + gly_c
# GLYBabc : adp_c + glyb_c + h_c + pi_c <-- atp_c + glyb_e + h2o_c
# GLYCDH_1 : h_c + hpyr_c + nadh_c --> glyc__R_c + nad_c
# GLYCK : 3pg_c + adp_c + h_c <-- atp_c + glyc__R_c
# GLYCK2 : atp_c + glyc__R_c --> 2pg_c + adp_c + h_c
# GLYCL : co2_c + mlthf_c + nadh_c + nh4_c <=> gly_c + nad_c + thf_c
# GLYCLTDx : glx_c + h_c + nadh_c <-- glyclt_c + nad_c
# GLYCLTDy : glx_c + h_c + nadph_c <-- glyclt_c + nadp_c
# GLYCOR_nadp : glyc__R_c + nadp_c <-- h_c + hpyr_c + nadph_c
# GLYCt : glyc_e <=> glyc_c
# GLYK : adp_c + glyc3p_c + h_c <=> atp_c + glyc_c
# GLYt2m : gly_e + h_e <=> gly_c + h_c
# GMHEPAT : adphep_DD_c + ppi_c <-- atp_c + gmhep1p_c + h_c
# GMP5N : gmp_c + h2o_c --> gsn_c + pi_c
# GMPS2 : amp_c + glu__L_c + gmp_c + 2.0 h_c + ppi_c <-- atp_c + gln__L_c + h2o_c + xmp_c
# GND : co2_c + nadph_c + ru5p__D_c <-- 6pgc_c + nadp_c
# GNK : 6pgc_c + adp_c + h_c <=> atp_c + glcn_c
# GNNUC : gua_c + rib__D_c <=> gsn_c + h2o_c
# GPAR : gmp_c + ppi_c <-- gua_c + prpp_c
# GPDDA1 : chol_c + glyc3p_c + h_c <-- g3pc_c + h2o_c
# GPDDA2 : etha_c + glyc3p_c + h_c <-- g3pe_c + h2o_c
# GPDDA4 : glyc3p_c + glyc_c + h_c <=> g3pg_c + h2o_c
# GTPCI : ahdt_c + for_c + h_c <-- gtp_c + h2o_c
# GTPCII2 : 25drapp_c + for_c + 2.0 h_c + ppi_c <-- gtp_c + 3.0 h2o_c
# GTPDPK : amp_c + gdptp_c <=> atp_c + gtp_c
# GUAD : nh4_c + xan_c <-- gua_c + h2o_c + h_c
# GUDBUTNAH : 4abut_c + urea_c <=> 4gudbutn_c + h2o_c
# H2Ot : h2o_e <-- h2o_c
# HACD1 : aacoa_c + h_c + nadh_c <=> 3hbcoa_c + nad_c
# HACD2 : 3ohcoa_c + h_c + nadh_c <=> 3hhcoa_c + nad_c
# HACD3 : 3oocoa_c + h_c + nadh_c <=> 3hocoa_c + nad_c
# HACD4 : 3odcoa_c + h_c + nadh_c <=> 3hdcoa_c + nad_c
# HACD5 : 3oddcoa_c + h_c + nadh_c <=> 3hddcoa_c + nad_c
# HACD6 : 3otdcoa_c + h_c + nadh_c <=> 3htdcoa_c + nad_c
# HACD7 : 3ohdcoa_c + h_c + nadh_c <=> 3hhdcoa_c + nad_c
# HACD9 : 2maacoa_c + h_c + nadh_c <=> 3hmbcoa_c + nad_c
# HACDp : 3oacoa_c + h_c + nadh_c <=> 3hacoa_c + nad_c
# HADPCOADH3 : h_c + nadh_c + oxadpcoa_c <=> 3hadpcoa_c + nad_c
# HCO3E : co2_c + h2o_c <=> h_c + hco3_c
# HDC : h_c + his__L_c <=> co2_c + hista_c
# HDCAt2 : h_e + hdca_e <=> h_c + hdca_c
# HDH : 3.0 h_c + his__L_c + 2.0 nadh_c <=> h2o_c + histd_c + 2.0 nad_c
# HEPK1 : adp_c + h_c + phhlipa_c <-- atp_c + hhlipa_c
# HEPK2 : adp_c + h_c + phphhlipa_c <-- atp_c + hphhlipa_c
# HEPT1 : adp_c + h_c + hlipa_c <-- adphep_LD_c + lipa_c
# HEPT2 : adp_c + h_c + hhlipa_c <=> adphep_LD_c + hlipa_c
# HEPT3 : adp_c + h_c + hphhlipa_c <-- adphep_LD_c + phhlipa_c
# HEPT4 : adp_c + colipa_c + h_c <-- adphep_LD_c + gggagicolipa_c
# HEX1 : adp_c + g6p_c + h_c <-- atp_c + glc__D_c
# HEXTT : hexdp_c + ipdp_c --> hepdp_c + ppi_c
# HGNTOR : 4mlacac_c + h_c <-- hgentis_c + o2_c
# HIBDkt : h_c + mmsa_c + nadh_c <=> 3hmp_c + nad_c
# HISDr : his__L_c --> nh4_c + urcan_c
# HISTP : histd_c + pi_c <-- h2o_c + hisp_c
# HIUH : 5hiu_c + h2o_c --> 5houdic_c + h_c
# HKt : adp_c + h_c + k_c + pi_c <-- atp_c + h2o_c + k_e
# HKYNH : 3hanthrn_c + ala__L_c + h_c <-- h2o_c + hLkynr_c
# HMBS : h2o_c + 4.0 ppbng_c --> hmbil_c + 4.0 nh4_c
# HMGL : acac_c + accoa_c <=> hmgcoa_c
# HPPK2 : 6hmhptpp_c + amp_c + h_c <-- 6hmhpt_c + atp_c
# HPYRDC : co2_c + gcald_c <=> h_c + hpyr_c
# HSDH : aspsa_c + h_c + nadph_c --> hom__L_c + nadp_c
# HSDx : aspsa_c + h_c + nadh_c --> hom__L_c + nad_c
# HSERTA : achms_c + coa_c <-- accoa_c + hom__L_c
# HSK : adp_c + h_c + phom_c <-- atp_c + hom__L_c
# HSPMS : 2.0 ptrc_c <=> hspmd_c + nh4_c
# Ht : h_e <=> h_c
# HXAND : h_c + nadh_c + xan_c <-- h2o_c + hxan_c + nad_c
# HXANt2pp : h_e + hxan_e <=> h_c + hxan_c
# HXPRT : imp_c + ppi_c <-- hxan_c + prpp_c
# HYD1 : 2.0 h_e + q8h2_c <-- h2_c + 2.0 h_c + q8_c
# IBPHn : h2o_c + mi34p_c <=> mi3p__D_c + pi_c
# ICDHx : akg_c + co2_c + nadh_c <-- icit_c + nad_c
# ICH : h2o_c + imp_c <=> fprica_c
# ICL : glx_c + succ_c <-- icit_c
# IDPh : h2o_c + ppi_c --> h_c + 2.0 pi_c
# IDS1 : h2mb4p_c + h_c + nadph_c --> h2o_c + ipdp_c + nadp_c
# IG3PS : gln__L_c + prlp_c --> aicar_c + eig3p_c + glu__L_c + h_c
# IGPDH : eig3p_c --> h2o_c + imacp_c
# IGPS : 3ig3p_c + co2_c + h2o_c <-- 2cpr5p_c + h_c
# IMACTD : 2.0 h_c + im4ac_c + nadh_c <-- h2o_c + im4act_c + nad_c
# IMDHT : 2ippm_c + h2o_c <=> 3c3hmp_c
# IMDHT_3c2hmp : 2ippm_c + h2o_c <=> 3c2hmp_c
# IMPD : h_c + nadh_c + xmp_c <=> h2o_c + imp_c + nad_c
# INSH : hxan_c + rib__D_c <-- h2o_c + ins_c
# INSt2 : h_e + ins_e <=> h_c + ins_c
# IPDPS : h2mb4p_c + h_c + nadh_c --> h2o_c + ipdp_c + nad_c
# IPMD : 3c4mop_c + h_c + nadh_c <=> 3c2hmp_c + nad_c
# IPPS : 3c3hmp_c + coa_c + h_c <-- 3mob_c + accoa_c + h2o_c
# ITCY : cmp_c + h_c + idp_c <=> cytd_c + itp_c
# IZPN : 4iz5pp_c + h2o_c --> forglu_c
# KARI : 2ahbut_c <=> 3hmop_c
# KARI_23dhmb : 23dhmb_c + nadp_c <=> 3hmoa_c + h_c + nadph_c
# KARI_23dhmp : 3hmop_c + h_c + nadph_c <=> 23dhmp_c + nadp_c
# KARI_3hmoa : alac__S_c <=> 3hmoa_c
# KDOCT : ckdo_c + ppi_c <-- ctp_c + kdo_c
# KDOPP : h2o_c + kdo8p_c --> kdo_c + pi_c
# KDOPS : ara5p_c + h2o_c + pep_c --> kdo8p_c + pi_c
# Kt1 : k_e --> k_c
# KYN3OX : Lkynr_c + h_c + nadph_c + o2_c --> h2o_c + hLkynr_c + nadp_c
# L_LACD2 : lac__L_c + q8_c --> pyr_c + q8h2_c
# L_LACD3 : lac__L_c + mqn8_c --> mql8_c + pyr_c
# L_LACDcm : 2.0 ficytC_c + lac__L_c <=> 2.0 focytC_c + 2.0 h_c + pyr_c
# LCADi : 2.0 h_c + lac__L_c + nadh_c <=> h2o_c + lald__L_c + nad_c
# LDH_L : h_c + nadh_c + pyr_c <=> lac__L_c + nad_c
# LPLIPAL1A120pp : ddca_c + glyc3p_c + h_c --> 1ddecg3p_c + h2o_c
# LPLIPAL1A140pp : glyc3p_c + h_c + ttdca_c <=> 1tdecg3p_c + h2o_c
# LPLIPAL1A141pp : glyc3p_c + h_c + ttdcea_c <-- 1tdec7eg3p_c + h2o_c
# LPLIPAL1A160pp : glyc3p_c + 2.0 h_c + hdca_c --> 1hdecg3p_c + h2o_c
# LPLIPAL1A180pp : glyc3p_c + h_c + ocdca_c --> 1odecg3p_c + h2o_c
# LPLIPAL2A120 : ddca_c + glyc3p_c + 2.0 h_c --> 2ddecg3p_c + h2o_c
# LPLIPAL2A140 : glyc3p_c + 2.0 h_c + ttdca_c <=> 2tdecg3p_c + h2o_c
# LPLIPAL2A141 : glyc3p_c + h_c + ttdcea_c <-- 2tdec7eg3p_c + h2o_c
# LPLIPAL2A160 : glyc3p_c + h_c + hdca_c --> 2hdecg3p_c + h2o_c
# LPLIPAL2A180 : glyc3p_c + h_c + ocdca_c --> 2odecg3p_c + h2o_c
# LPLIPAL2E160 : g3pe_c + h_c + hdca_c <=> 2agpe160_c + h2o_c
# LPLIPAL2E180 : g3pe_c + h_c + ocdca_c <=> 2agpe180_c + h2o_c
# LTDCL : co2_c + trypta_c <-- h_c + trp__L_c
# LYSRC : lys__L_c <=> lys__D_c
# LYSt2m : h_e + lys__L_c <=> h_c + lys__L_e
# MALS : coa_c + h_c + mal__L_c <-- accoa_c + glx_c + h2o_c
# MALT : h2o_c + malt_c --> 2.0 glc__D_c
# MALt2_2 : 2.0 h_e + mal__L_e <=> 2.0 h_c + mal__L_c
# MALTabc : atp_c + h2o_c + malt_e --> adp_c + h_c + malt_c + pi_c
# MALTpts : malt_e + pep_c <=> malt6p_c + pyr_c
# MAN1PT2 : gdp_c + h_c + man1p_c <=> gdpmann_c + pi_c
# MAN6PI : man6p_c <=> f6p_c
# MANAO : mana_c + nad_c <=> fruur_c + h_c + nadh_c
# MANpts : man_e + pep_c <=> man6p_c + pyr_c
# MATm : amet_c + pi_c + ppi_c <-- atp_c + h2o_c + met__L_c
# MCCC : 3mgcoa_c + adp_c + h_c + pi_c <=> 3mb2coa_c + atp_c + hco3_c
# MCITD : 2mcacn_c + h2o_c <=> 2mcit_c
# MCITL2 : micit_c <=> pyr_c + succ_c
# MCITS : 2mcit_c + coa_c + h_c <-- h2o_c + oaa_c + ppcoa_c
# MCLOR : h_c + mercppyr_c + nadh_c <=> mercplac_c + nad_c
# MCOATA : coa_c + malACP_c <=> ACP_c + h_c + malcoa_c
# MCPST : cyan_c + mercppyr_c <=> pyr_c + tcynt_c
# MCS : 2mecdp_c + cmp_c <=> 2p4c2me_c
# MCSNAH : 5mcsn_c + h2o_c + h_c --> nh4_c + thym_c
# MDH : h_c + nadh_c + oaa_c <-- mal__L_c + nad_c
# MDHC_nadp_hr : co2_c + nadph_c + pyr_c <-- mal__L_c + nadp_c
# MECDPDH2 : 2mecdp_c + nadh_c --> h2mb4p_c + h2o_c + nad_c
# METabc : adp_c + h_c + met__L_c + pi_c <-- atp_c + h2o_c + met__L_e
# METDabc : atp_c + h2o_c + met__D_e --> adp_c + h_c + met__D_c + pi_c
# METSOX1abcpp : adp_c + h_c + metsox_S__L_c + pi_c <-- atp_c + h2o_c + metsox_S__L_e
# METSOXR1 : h2o_c + met__L_c + trdox_c <=> metsox_S__L_c + trdrd_c
# MG2abc : adp_c + h_c + mg2_c + pi_c <-- atp_c + h2o_c + mg2_e
# MG2t : mg2_e --> mg2_c
# MGC : hmgcoa_c <=> 3mgcoa_c + h2o_c
# MI1PP : inost_c + pi_c <-- h2o_c + mi1p__D_c
# MI3PP : inost_c + pi_c <-- h2o_c + mi3p__D_c
# MI4PP : inost_c + pi_c <-- h2o_c + mi4p__D_c
# MICITDr : micit_c <=> 2mcacn_c + h2o_c
# MIHKPP : h2o_c + minohp_c <=> mi12356p_c + pi_c
# MMSAD3 : accoa_c + co2_c + nadh_c <=> coa_c + msa_c + nad_c
# MMSDH : co2_c + nadh_c + ppcoa_c <=> coa_c + mmsa_c + nad_c
# MN2t3pp : h_e + mn2_e --> h_c + mn2_c
# MNXR10704 : MNXM72_c + coa_c + h_c <=> acoa_c + h2o_c
# MNXR10705 : arachd_c + coa_c + h_c <=> arachdcoa_c + h2o_c
# MNXR12173 : MNXM4972_c + h_c + nadh_c <=> MNXM4910_c + nad_c
# MNXR14387 : ala__L_c + leu__L_c <-- MNXM15786_c + h2o_c
# MNXR14507 : 2.0 glc_bD_c <-- cellb_c + h2o_c
# MNXR14578 : accoa_c + oaa_c <=> malcoa_c + pyr_c
# MNXR14719 : 2obut_c + co2_c + nadh_c <=> nad_c + r3mmal_c
# MNXR14762 : MNXM5839_c + h2o_c <=> MNXM381_c + MNXM72_c
# MNXR14768 : MNXM123_c + ser__L_c <=> MNXM7231_c + h2o_c
# MNXR15065 : MNXM7231_c + h_c + succ_c <=> cys__L_c + suchms_c
# MNXR15262 : MNXM1263_c + adp_c + pi_c <=> 3hpp_c + atp_c + coa_c
# MNXR15436 : MNXM764_c + h_c + nadh_c <=> MNXM1698_c + nad_c
# MNXR15510 : MNXM1183_c + gly_c <=> gdchola_c + h2o_c
# MNXR15609 : 2ameph_c + h2o2_c <=> etha_c + h_c + pi_c
# MNXR15641 : MNXM1873_c --> h2o_c + h_c + thdp_c
# MNXR15642 : MNXM2480_c + 2.0 h_c + nadh_c <=> MNXM2566_c + nad_c
# MNXR15797 : h_c + nadh_c + xol7ah2al_c <=> nad_c + xol7ah3_c
# MNXR15867 : 2ohph_c + h2o_c + nadp_c <-- 2oph_c + h_c + nadph_c + o2_c
# MNXR1587 : dhpt_c + h2o_c <-- 4abz_c + 6hmhpt_c
# MNXR15972 : MNXM5312_c + h_c + nadh_c <=> MNXM6087_c + nad_c
# MNXR15973 : MNXM6216_c + h_c + nadh_c <=> MNXM5676_c + nad_c
# MNXR160 : MNXM1263_c + h2o_c <=> 3hpp_c + coa_c + h_c
# MNXR16018 : MNXM1854_c + h_c + nadh_c <=> MNXM590_c + fald_c + nad_c
# MNXR16204 : MNXM5635_c + h_c + nadh_c <=> hmpscoa_c + nad_c
# MNXR16236 : MNXM1129_c + 2.0 h_c + nadh_c + o2_c --> MNXM842_c + co2_c + h2o_c + nad_c
# MNXR16239 : MNXM1129_c + 2.0 h_c + nadh_c <=> MNXM6614_c + h2o_c + nad_c
# MNXR16307 : MNXM1213_c + co2_c + nadh_c <=> nad_c + phthr_c
# MNXR16994 : MNXM6043_c + h_c + nadh_c <=> MNXM6494_c + nad_c
# MNXR16995 : MNXM6044_c + 2.0 h_c + nadh_c <=> MNXM6043_c + h2o_c + nad_c
# MNXR17004 : MNXM4298_c + 2.0 h_c + nadh_c <=> MNXM4972_c + h2o_c + nad_c
# MNXR17026 : MNXM2498_c <=> MNXM2798_c
# MNXR17153 : MNXM5666_c + h_c + nadh_c <=> MNXM3152_c + h2o_c + nad_c
# MNXR17265 : MNXM1516_c + h2o_c <=> MNXM3424_c + ethamp_c + h_c
# MNXR17268 : MNXM1516_c + cmp_c + h_c <=> MNXM3424_c + cdpea_c
# MNXR17296 : MNXM1120_c + 2.0 h_c + nadh_c <=> MNXM2283_c + h2o_c + nad_c
# MNXR17297 : MNXM1120_c + 2.0 h_c + nadph_c <=> MNXM2283_c + h2o_c + nadp_c
# MNXR17649 : MNXM5874_c + h_c + nadh_c <=> MNXM5873_c + nad_c
# MNXR17653 : MNXM5870_c + h_c + nadh_c <=> MNXM5869_c + nad_c
# MNXR17657 : MNXM5866_c + h_c + nadh_c <=> MNXM5865_c + nad_c
# MNXR17827 : MNXM4528_c + 2.0 h_c + nadh_c <=> MNXM5387_c + h2o_c + nad_c
# MNXR17833 : MNXM5558_c + h_c + nadh_c <=> MNXM5522_c + nad_c
# MNXR17835 : MNXM4528_c + 2.0 h_c + nadh_c <=> MNXM6560_c + h2o_c + nad_c
# MNXR17903 : arach_c + coa_c + h_c <=> MNXM1429_c + h2o_c
# MNXR17904 : coa_c + h_c + ocdcya_c <=> h2o_c + lnlccoa_c
# MNXR17916 : MNXM11473_c + coa_c + h_c <=> MNXM6496_c + h2o_c
# MNXR17974 : MNXM10616_c + nad_c <=> MNXM2968_c + h_c + nadh_c
# MNXR17999 : MNXM3835_c + h_c + nadh_c <=> MNXM6074_c + nad_c
# MNXR18003 : MNXM6125_c + h_c + nadh_c <=> MNXM6882_c + nad_c
# MNXR18214 : betald_c + h_c + nadph_c <=> chol_c + nadp_c
# MNXR1991 : coa_c + h_c + ocdcea_c <=> h2o_c + ocdce9coa_c
# MNXR20056 : MNXM21243_c + amp_c + ppi_c <=> MNXM16121_c + atp_c + btn_c
# MNXR2062 : MNXM1051_c + nad_c <=> Sfglutth_c + h_c + nadh_c
# MNXR22677 : MNXM2404_c + h_c + nadph_c --> MNXM2405_c + nadp_c + pi_c
# MNXR2293 : fdxr_2_2_c + h_c + nadp_c <=> MNXM178_c + nadph_c
# MNXR27601 : MNXM5743_c + amp_c + ppi_c <-- atp_c + coa_c + fa1_c + h_c
# MNXR27602 : MNXM5745_c + amp_c + ppi_c <-- atp_c + coa_c + fa4_c + h_c
# MNXR27603 : MNXM5744_c + amp_c + ppi_c <-- atp_c + coa_c + fa3_c + h_c
# MNXR27604 : MNXM5746_c + amp_c + ppi_c <-- atp_c + coa_c + fa6_c + h_c
# MNXR27605 : MNXM5742_c + amp_c + ppi_c <-- atp_c + coa_c + fa12_c + h_c
# MNXR27606 : MNXM5741_c + amp_c + ppi_c <-- atp_c + coa_c + fa11_c + h_c
# MNXR27634 : MNXM10217_c + nadp_c <=> MNXM10219_c + h_c + nadph_c
# MNXR27635 : MNXM10217_c --> MNXM8149_c + h2o_c
# MNXR27636 : MNXM8149_c + h_c + nadph_c --> MNXM8147_c + nadp_c
# MNXR27638 : MNXM10368_c + nadp_c <=> MNXM10370_c + h_c + nadph_c
# MNXR27639 : MNXM10368_c --> MNXM8197_c + h2o_c
# MNXR27640 : MNXM8197_c + h_c + nadph_c --> MNXM8195_c + nadp_c
# MNXR27642 : MNXM10446_c + nadp_c <=> MNXM10448_c + h_c + nadph_c
# MNXR27643 : MNXM10446_c --> MNXM8220_c + h2o_c
# MNXR27644 : MNXM8220_c + h_c + nadph_c --> MNXM8218_c + nadp_c
# MNXR27646 : MNXM9655_c + h_c + nadph_c <=> MNXM9653_c + nadp_c
# MNXR27647 : MNXM8004_c + h2o_c <-- MNXM9653_c
# MNXR27648 : MNXM8004_c + h_c + nadph_c --> MNXM8003_c + nadp_c
# MNXR27650 : MNXM9684_c + h_c + nadph_c <=> MNXM9682_c + nadp_c
# MNXR27651 : MNXM8015_c + h2o_c <-- MNXM9682_c
# MNXR27652 : MNXM8015_c + h_c + nadph_c --> MNXM6636_c + nadp_c
# MNXR27654 : MNXM9700_c + h_c + nadph_c <=> MNXM9698_c + nadp_c
# MNXR27655 : MNXM8024_c + h2o_c <-- MNXM9698_c
# MNXR27656 : MNXM8024_c + h_c + nadph_c --> MNXM8022_c + nadp_c
# MNXR27659 : MNXM10326_c + nadp_c <=> MNXM10327_c + h_c + nadph_c
# MNXR27660 : MNXM10326_c --> MNXM8176_c + h2o_c
# MNXR27661 : MNXM8176_c + h_c + nadph_c --> MNXM8175_c + nadp_c
# MNXR27663 : MNXM10422_c + nadp_c <=> MNXM10423_c + h_c + nadph_c
# MNXR27664 : MNXM10422_c --> MNXM8210_c + h2o_c
# MNXR27665 : MNXM8210_c + h_c + nadph_c --> MNXM8209_c + nadp_c
# MNXR27667 : MNXM10474_c + nadp_c <=> MNXM10475_c + h_c + nadph_c
# MNXR27668 : MNXM10474_c --> MNXM8226_c + h2o_c
# MNXR27669 : MNXM8226_c + h_c + nadph_c --> MNXM8225_c + nadp_c
# MNXR27671 : MNXM9671_c + h_c + nadph_c <=> MNXM9670_c + nadp_c
# MNXR27672 : MNXM8011_c + h2o_c <-- MNXM9670_c
# MNXR27673 : MNXM8011_c + h_c + nadph_c --> MNXM8010_c + nadp_c
# MNXR27675 : MNXM9695_c + h_c + nadph_c <=> MNXM9694_c + nadp_c
# MNXR27676 : MNXM8019_c + h2o_c <-- MNXM9694_c
# MNXR27677 : MNXM8019_c + h_c + nadph_c --> MNXM6644_c + nadp_c
# MNXR27679 : MNXM9707_c + h_c + nadph_c <=> MNXM9706_c + nadp_c
# MNXR27680 : MNXM8027_c + h2o_c <-- MNXM9706_c
# MNXR27681 : MNXM8027_c + h_c + nadph_c --> MNXM8026_c + nadp_c
# MNXR27684 : MNXM10218_c + nadp_c <=> MNXM10220_c + h_c + nadph_c
# MNXR27686 : MNXM8150_c + h_c + nadph_c --> MNXM8148_c + nadp_c
# MNXR27688 : MNXM10367_c + nadp_c <=> MNXM10369_c + h_c + nadph_c
# MNXR27690 : MNXM8196_c + h_c + nadph_c --> MNXM8194_c + nadp_c
# MNXR27692 : MNXM10447_c + nadp_c <=> MNXM10449_c + h_c + nadph_c
# MNXR27694 : MNXM8221_c + h_c + nadph_c --> MNXM8219_c + nadp_c
# MNXR27696 : MNXM9656_c + h_c + nadph_c <=> MNXM9654_c + nadp_c
# MNXR27698 : MNXM8005_c + h_c + nadph_c --> MNXM8006_c + nadp_c
# MNXR27700 : MNXM9685_c + h_c + nadph_c <=> MNXM9683_c + nadp_c
# MNXR27702 : MNXM8016_c + h_c + nadph_c --> MNXM6637_c + nadp_c
# MNXR27704 : MNXM9701_c + h_c + nadph_c <=> MNXM9699_c + nadp_c
# MNXR27706 : MNXM8025_c + h_c + nadph_c --> MNXM8023_c + nadp_c
# MNXR2772 : h2o_c + lgt__S_c --> MNXM57_c + h_c + lac__D_c
# MNXR27735 : MNXM10035_c + nadp_c <=> MNXM10116_c + h_c + nadph_c
# MNXR27737 : MNXM9168_c + h_c + nadph_c --> MNXM7607_c + nadp_c
# MNXR27805 : adp_c + h_c + metox__R_c + pi_c <-- atp_c + h2o_c + metox__R_e
# MNXR27856 : h_e + thmmp_e --> h_c + thmmp_c
# MNXR2786 : gmhep1p_c + pi_c <-- MNXM1736_c + h2o_c
# MNXR2826 : gthox_c + h_c + nadph_c <=> 2.0 MNXM57_c + nadp_c
# MNXR2832 : MNXM57_c + adp_c + h_c + pi_c <-- atp_c + glucys_c + gly_c
# MNXR28652 : MNXM8675_c + h_c + udcpp_c <=> MNXM5258_c + prenoN_acid_c
# MNXR28653 : MNXM5258_c + prenoN_ated_c <=> MNXM8674_c + h_c + udcpp_c
# MNXR28654 : MNXM12741_c + MNXM5258_c <=> MNXM8673_c + h_c + udcpp_c
# MNXR28660 : 1tdecg3p_c + coa_c <-- glyc3p_c + tdcoa_c
# MNXR28662 : MNXM9620_c + coa_c <-- MNXM5741_c + glyc3p_c
# MNXR28663 : MNXM9603_c + coa_c <-- MNXM5742_c + glyc3p_c
# MNXR28664 : MNXM9623_c + coa_c <-- MNXM5743_c + glyc3p_c
# MNXR28665 : MNXM9622_c + coa_c <-- MNXM5744_c + glyc3p_c
# MNXR28666 : MNXM9604_c + coa_c <-- MNXM5745_c + glyc3p_c
# MNXR28667 : MNXM9621_c + coa_c <-- MNXM5746_c + glyc3p_c
# MNXR28671 : MNXM6580_c + coa_c + h_c <-- MNXM5741_c + MNXM9620_c
# MNXR28672 : MNXM6573_c + coa_c + h_c <-- MNXM5742_c + MNXM9603_c
# MNXR28673 : MNXM6583_c + coa_c + h_c <-- MNXM5743_c + MNXM9623_c
# MNXR28674 : MNXM6582_c + coa_c + h_c <-- MNXM5744_c + MNXM9622_c
# MNXR28675 : MNXM6574_c + coa_c + h_c <-- MNXM5745_c + MNXM9604_c
# MNXR28676 : MNXM6581_c + coa_c + h_c <-- MNXM5746_c + MNXM9621_c
# MNXR28683 : MNXM11393_c + cmp_c + 2.0 h_c <-- MNXM8379_c + ser__L_c
# MNXR28684 : MNXM11359_c + cmp_c + 2.0 h_c <-- MNXM8377_c + ser__L_c
# MNXR28685 : MNXM11399_c + cmp_c + 2.0 h_c <-- MNXM8382_c + ser__L_c
# MNXR28686 : MNXM11397_c + cmp_c + 2.0 h_c <-- MNXM8381_c + ser__L_c
# MNXR28687 : MNXM11361_c + cmp_c + 2.0 h_c <-- MNXM8378_c + ser__L_c
# MNXR28688 : MNXM11395_c + cmp_c + 2.0 h_c <-- MNXM8380_c + ser__L_c
# MNXR28689 : MNXM11393_c + 2.0 h_c <=> MNXM7305_c + co2_c
# MNXR28690 : MNXM11359_c + 2.0 h_c <=> MNXM7294_c + co2_c
# MNXR28691 : MNXM11399_c + 2.0 h_c <=> MNXM7308_c + co2_c
# MNXR28692 : MNXM11397_c + 2.0 h_c <=> MNXM7307_c + co2_c
# MNXR28693 : MNXM11361_c + 2.0 h_c <=> MNXM7295_c + co2_c
# MNXR28694 : MNXM11395_c + 2.0 h_c <=> MNXM7306_c + co2_c
# MNXR28710 : MNXM7958_c + atp_c <=> MNXM6580_c + adp_c
# MNXR28711 : MNXM7956_c + atp_c <=> MNXM6573_c + adp_c
# MNXR28712 : MNXM7961_c + atp_c <=> MNXM6583_c + adp_c
# MNXR28713 : MNXM7960_c + atp_c <=> MNXM6582_c + adp_c
# MNXR28714 : MNXM7957_c + atp_c <=> MNXM6574_c + adp_c
# MNXR28715 : MNXM7959_c + atp_c <=> MNXM6581_c + adp_c
# MNXR28716 : MNXM11392_c + cmp_c <=> MNXM8379_c + glyc3p_c
# MNXR28717 : MNXM11358_c + cmp_c <=> MNXM8377_c + glyc3p_c
# MNXR28718 : MNXM11398_c + cmp_c <=> MNXM8382_c + glyc3p_c
# MNXR28719 : MNXM11396_c + cmp_c <=> MNXM8381_c + glyc3p_c
# MNXR28720 : MNXM11360_c + cmp_c <=> MNXM8378_c + glyc3p_c
# MNXR28721 : MNXM11394_c + cmp_c <=> MNXM8380_c + glyc3p_c
# MNXR28722 : MNXM11392_c + h2o_c --> MNXM5129_c + h_c + pi_c
# MNXR28723 : MNXM11358_c + h2o_c --> MNXM5124_c + h_c + pi_c
# MNXR29077 : h_e + ppi_e <-- h_c + ppi_c
# MNXR29256 : amet_c + hpglu_c --> 5mthglu_c + ahcys_c + h_c
# MNXR2929 : MNXM123_c + amet_c --> ahcys_c + h_c + met__L_c
# MNXR2930 : MNXM123_c + mmet_c <=> h_c + 2.0 met__L_c
# MNXR29604 : cys__L_c + gly_c <=> MNXM8666_c + h2o_c
# MNXR29606 : gly_c + phe__L_c <=> MNXM8669_c + h2o_c
# MNXR29607 : gly_c + tyr__L_c <=> MNXM8671_c + h2o_c
# MNXR31648 : MNXM57_c + h2o_c <=> cgly_c + glu__L_c
# MNXR3231 : lgt__S_c <=> MNXM57_c + mthgxl_c
# MNXR32524 : 2h34hppr_c + glu__L_c <=> akg_c + tyr__L_c
# MNXR3277 : g3pe_c + h_c + ttdca_c <=> MNXM6598_c + h2o_c
# MNXR3279 : g3pe_c + h_c + hdca_c <=> MNXM6600_c + h2o_c
# MNXR3312 : g3pe_c + h_c + ttdca_c <=> MNXM3446_c + h2o_c
# MNXR33771 : 4hglu_c + akg_c <=> 4h2oglt_c + glu__L_c
# MNXR33785 : 3pg_c + MNXM1723_c + h_c <=> 13dpg_c + g1p_c
# MNXR33807 : atp_c + glu__L_c <=> MNXM4027_c + adp_c
# MNXR34453 : 2dr5p_c + adp_c + h_c <=> MNXM90412_c + atp_c
# MNXR3469 : 2h3kmtp_c + h2o_c <-- 5mdru1p_c
# MNXR3495 : 5mthf_c + MNXM123_c <=> met__L_c + thf_c
# MNXR3536 : MNXM624_c + adp_c + h_c <=> MNXM200_c + atp_c
# MNXR35657 : MNXM1289_c + h_c + nadph_c <=> icit_c + nadp_c
# MNXR40035 : orn__D_c <=> orn_c
# MNXR40622 : 4gudbutn_c + orn_c <=> 4abut_c + arg__L_c
# MNXR4313 : MNXM3446_c + h_c + ttdca_c <=> MNXM2859_c + h2o_c
# MNXR4335 : MNXM6598_c + h_c + ttdca_c <=> MNXM2859_c + h2o_c
# MNXR4402 : 2h34hppr_c + co2_c + nadh_c <-- nad_c + pphn_c
# MNXR4403 : 2h34hppr_c + co2_c + nadph_c <-- nadp_c + pphn_c
# MNXR4458 : MNXM1263_c <=> h2o_c + pp2coa_c
# MNXR46338 : MNXM8263_c + h2o_c <=> ala__L_c + glu__L_c
# MNXR47135 : arg__L_c + taur_c <=> MNXM3363_c + orn_c
# MNXR5314 : h2o_c + u23ga_c --> 2.0 h_c + lipidX_HP_c + ump_c
# MNXR53357 : MNXM9860_c + coa_c + h_c <=> 2mbcoa_c + ACP_c
# MNXR53358 : MNXM11926_c + coa_c + 2.0 h_c <=> ACP_c + ivcoa_c
# MNXR53359 : MNXM11912_c + coa_c + 2.0 h_c <=> ACP_c + ibcoa_c
# MNXR53360 : MNXM6636_c + coa_c + 3.0 h_c <=> ACP_c + MNXM5745_c
# MNXR53361 : MNXM8022_c + coa_c + 3.0 h_c <=> ACP_c + MNXM5742_c
# MNXR53362 : MNXM6644_c + coa_c + 3.0 h_c <=> ACP_c + MNXM5744_c
# MNXR53363 : MNXM8026_c + coa_c + 3.0 h_c <=> ACP_c + MNXM5741_c
# MNXR53364 : MNXM6637_c + coa_c + 3.0 h_c <=> ACP_c + MNXM5743_c
# MNXR53365 : MNXM8023_c + coa_c + 3.0 h_c <=> ACP_c + MNXM5746_c
# MNXR53366 : coa_c + myrsACP_c <=> ACP_c + tdcoa_c
# MNXR53368 : MNXM7607_c + coa_c + h_c <=> ACP_c + stcoa_c
# MNXR5404 : MNXM1289_c + h_c --> akg_c + co2_c
# MNXR5449 : MNXM3173_c + h_c + nadh_c <=> nad_c + thcholoylcoa_c
# MNXR5475 : amet_c + uppg3_c <=> MNXM2152_c + ahcys_c + h_c
# MNXR55674 : lipidX_HP_c + u23ga_c <=> h_c + lipidAds_c + udp_c
# MNXR55989 : h_c + pi_c + udcpp_c <-- dtpcudcpp_c + h2o_c
# MNXR55990 : dtpcudcpp_c + 8.0 ppi_c <=> frdp_c + 8.0 ipdp_c
# MNXR5630 : MNXM5283_c + coa_c --> amp_c + h_c + ppcoa_c
# MNXR5681 : pro__L_c <=> pro__D_c
# MNXR5689 : glcn_c + h_c <-- MNXM339_c + h2o_c
# MNXR5724 : MNXM1034_c + h2o_c <=> 3hmp_c + coa_c + h_c
# MNXR5727 : akg_c + 2.0 h_c + nadph_c <-- MNXM770_c + h2o_c + nadp_c
# MNXR57329 : MNXM3403_c + ppi_c <=> frdp_c
# MNXR5765 : MNXM277_c + h_c + nadh_c <=> MNXM832_c + nad_c
# MNXR578 : MNXM123_c + adn_c <=> ahcys_c + h2o_c
# MNXR58251 : MNXM4010_c + h_c + nadh_c <=> histd_c + nad_c
# MNXR5856 : h2o_c + tchola_c <=> cholate_c + taur_c
# MNXR58824 : atp_c + gmhep7p_c --> MNXM1736_c + adp_c + h_c
# MNXR5887 : MNXM5283_c + ppi_c --> atp_c + h_c + ppa_c
# MNXR5910 : cholate_c + coa_c + h_c <=> cholcoa_c + h2o_c
# MNXR59227 : 2.0 h_c + his__L_c + nadh_c <-- MNXM4010_c + h2o_c + nad_c
# MNXR5927 : gchola_c + h2o_c <=> cholate_c + gly_c
# MNXR59665 : MNXM5582_c + 2.0 h_c + udp_c <=> MNXM2794_c + MNXM5324_c
# MNXR59713 : MNXM4339_c + glc_bD_c <=> MNXM36578_c + h2o_c
# MNXR59771 : h2o_c + mescoa_c <=> MNXM5993_c
# MNXR59886 : h_c + pmcoa_c <=> MNXM5488_c + h2o_c
# MNXR60025 : MNXM5555_c + h2o_c + nadp_c <-- 2ommb_c + nadph_c + o2_c
# MNXR6030 : 3aib_c + pyr_c <=> ala__L_c + mmsa_c
# MNXR60319 : MNXM6828_c + 2.0 h_c + nadh_c <=> MNXM6827_c + h2o_c + nad_c
# MNXR60320 : 3mcat_c + co2_c + h2o_c + nad_c <-- MNXM6828_c + 2.0 h_c + nadh_c + o2_c
# MNXR60327 : MNXM6112_c + 2.0 h_c + nadh_c + o2_c --> 4mcat_c + co2_c + h2o_c + nad_c
# MNXR6043 : MNXM2152_c + amet_c <=> ahcys_c + dscl_c
# MNXR60581 : MNXM5713_c + coa_c <=> MNXM3257_c + caffcoa_c
# MNXR60651 : MNXM5766_c + 2.0 h_c + nadh_c <=> MNXM1558_c + h2o_c + nad_c
# MNXR60681 : MNXM794_c + coa_c + h_c <=> h2o_c + lnlncacoa_c
# MNXR60682 : MNXM2801_c + coa_c + h_c <=> h2o_c + tmndnccoa_c
# MNXR60684 : MNXM5607_c + coa_c + h_c <=> dlnlcgcoa_c + h2o_c
# MNXR60685 : MNXM10780_c + h2o_c <=> MNXM7102_c + coa_c + h_c
# MNXR60686 : coa_c + h_c + lgnc_c <=> h2o_c + lgnccoa_c
# MNXR60687 : MNXM11852_c + h2o_c <=> MNXM7404_c + coa_c + h_c
# MNXR60688 : MNXM11430_c + h2o_c <=> MNXM11520_c + coa_c + h_c
# MNXR60689 : coa_c + h_c + nrvnc_c <=> MNXM13000_c + h2o_c
# MNXR60692 : MNXM8271_c + coa_c + h_c <=> MNXM6497_c + h2o_c
# MNXR6106 : cellb_c + h2o_c --> 2.0 glc__D_c
# MNXR6164 : h_c + hdca_c + retinol_c <=> MNXM918_c + h2o_c
# MNXR61873 : MNXM19734_c + MNXM91319_c <=> MNXM7575_c + h2o_c
# MNXR6274 : MNXM4567_c + h_c <=> MNXM4566_c + h2o_c
# MNXR6283 : MNXM4818_c + h2o_c <=> MNXM4819_c + pi_c
# MNXR62992 : clpnd_c + coa_c + h_c <=> clpndcoa_c + h2o_c
# MNXR6311 : h_c + sbzcoa_c --> MNXM2306_c + h2o_c
# MNXR6332 : 4nph_c + h_c + pi_c <-- MNXM3867_c + h2o_c
# MNXR63965 : gly_c + met__L_c <=> MNXM55287_c + h2o_c
# MNXR63966 : MNXM40494_c + h2o_c <=> ala__L_c + asp__L_c
# ...
# NMNHYD : pi_c + rnam_c <-- h2o_c + nmn_c
# NMNTP : h_e + nmn_e <=> h_c + nmn_c
# NNDMBRT : 5prdmbz_c + h_c + nac_c <=> dmbzid_c + nicrnt_c
# NNDPR : co2_c + nicrnt_c + ppi_c <-- 2.0 h_c + prpp_c + quln_c
# NO2t2r : no2_e <=> h_c + h_e + no2_c
# NO3R1 : h2o_c + 2.0 h_e + no2_c + q8_c <-- h_c + no3_c + q8h2_c
# NO3R2 : h2o_c + 2.0 h_e + mqn8_c + no2_c <=> h_c + mql8_c + no3_c
# NO3t2 : h_e + no3_e <=> h_c + no3_c
# NPHS : sbzcoa_c --> coa_c + dhna_c
# NT5C : nicrns_c + pi_c <-- h2o_c + nicrnt_c
# NTD1 : dump_c + h2o_c --> duri_c + pi_c
# NTD10 : h2o_c + xmp_c --> pi_c + xtsn_c
# NTD11 : h2o_c + imp_c --> ins_c + pi_c
# NTD2 : pi_c + uri_c <-- h2o_c + ump_c
# NTD3 : dcmp_c + h2o_c --> dcyt_c + pi_c
# NTD4 : cmp_c + h2o_c --> cytd_c + pi_c
# NTD5 : dtmp_c + h2o_c --> pi_c + thymd_c
# NTD6 : damp_c + h2o_c --> dad_2_c + pi_c
# NTD7 : amp_c + h2o_c --> adn_c + pi_c
# NTRIR2x : 4.0 h_c + 3.0 nadh_c + no2_c --> 2.0 h2o_c + 3.0 nad_c + nh4_c
# NTRIR2y : 4.0 h_c + 3.0 nadph_c + no2_c --> 2.0 h2o_c + 3.0 nadp_c + nh4_c
# O2t : o2_e <=> o2_c
# OCDCAt2 : h_e + ocdca_e <=> h_c + ocdca_c
# OCOAT1 : aacoa_c + succ_c <=> acac_c + succoa_c
# OHPBAT : glu__L_c + ohpb_c <=> akg_c + phthr_c
# OHPHM : 2ohph_c + amet_c --> 2omph_c + ahcys_c + h_c
# OMCDC : 4mop_c + co2_c <-- 3c4mop_c + h_c
# OMPDC : co2_c + ump_c <-- h_c + orot5p_c
# OP4ENH : 4h2opntn_c <-- chpd_c + h2o_c
# OPHBDC : 2oph_c + co2_c <-- 3ophb_c + h_c
# ORDCh : co2_c + ptrc_c <-- h_c + orn_c
# ORNTA : akg_c + orn_c <-- glu5sa_c + glu__L_c
# ORPT : orot5p_c + ppi_c <-- orot_c + prpp_c
# OXAMTC : oxur_c + pi_c <=> cbp_c + oxam_c
# OXOAEL : 3oxoadp_c + h_c <-- 5odhf2a_c + h2o_c
# P5CD : glu__L_c + h_c + nadh_c <-- 1pyr5c_c + 2.0 h2o_c + nad_c
# P5CR : nadp_c + pro__L_c <=> 1pyr5c_c + 2.0 h_c + nadph_c
# P5CRx : 1pyr5c_c + 2.0 h_c + nadh_c <=> nad_c + pro__L_c
# PANTS : amp_c + h_c + pnto__R_c + ppi_c <-- ala_B_c + atp_c + pant__R_c
# PAPPT2 : uaGgla_c + ump_c <=> uAgla_c + udcpp_c
# PAPPT3 : udcpp_c + ugmda_c <=> uagmda_c + ump_c
# PAPSR : 2.0 h_c + hso3_c + pap_c + trdox_c <-- paps_c + trdrd_c
# PC8XM : hgbyr_c <=> 2.0 h_c + pre8_c
# PCADYOX : CCbuttc_c + 2.0 h_c <-- 34dhbz_c + o2_c
# PDH : coa_c + nad_c + pyr_c --> accoa_c + co2_c + nadh_c
# PDHam1hi : 2ahethmpp_c + co2_c <-- h_c + pyr_c + thmpp_c
# PDHam2hi : 2ahethmpp_c + lpam_c <=> adhlam_c + thmpp_c
# PDHbr : accoa_c + dhlam_c <=> adhlam_c + coa_c
# PDX5POi : h2o2_c + pydx5p_c <-- o2_c + pdx5p_c
# PEPCK_re : co2_c + gdp_c + pep_c <-- gtp_c + oaa_c
# PFK : adp_c + fdp_c + h_c <-- atp_c + f6p_c
# PFK_2 : adp_c + h_c + tagdp__D_c <=> atp_c + tag6p__D_c
# PFK_3 : adp_c + h_c + s17bp_c <=> atp_c + s7p_c
# PFK_adp : amp_c + fdp_c + h_c <-- adp_c + f6p_c
# PGAMT : gam6p_c <=> gam1p_c
# PGCD : 3php_c + h_c + nadh_c <=> 3pg_c + nad_c
# PGI : g6p_c <=> f6p_c
# PGK : 3pg_c + atp_c <=> 13dpg_c + adp_c
# PGL : 6pgc_c + h_c <-- 6pgl_c + h2o_c
# PGLYCP : 2pglyc_c + h2o_c --> glyclt_c + pi_c
# PGM : 3pg_c <=> 2pg_c
# PGMT : g6p_c <=> g1p_c
# PGSA120 : cmp_c + pgp120_c <=> cdpdddecg_c + glyc3p_c
# PGSA160 : cmp_c + h_c + pgp160_c <=> cdpdhdecg_c + glyc3p_c
# PGSA161 : cmp_c + h_c + pgp161_c <=> cdpdhdec9eg_c + glyc3p_c
# PGSA180 : cmp_c + h_c + pgp180_c <=> cdpdodecg_c + glyc3p_c
# PGSA181 : cmp_c + pgp181_c <=> cdpdodec11eg_c + glyc3p_c
# PHETA1 : akg_c + phe__L_c <=> glu__L_c + phpyr_c
# PHETHPTOX : dhbpt_c + h2o_c + tyr__L_c <-- o2_c + phe__L_c + thbpt_c
# PHYCBOXL : co2_c + peamn_c <-- h_c + phe__L_c
# PIabc : adp_c + h_c + 2.0 pi_c <=> atp_c + h2o_c + pi_e
# PIt2r : h_e + pi_e <=> h_c + pi_c
# PLIPA1A120pp : 2ddecg3p_c + ddca_c + h_c <=> h2o_c + pa120_c
# PLIPA1A140pp : h2o_c + pa140_c <=> 2tdecg3p_c + ttdca_c
# PLIPA1A141pp : h2o_c + pa141_c --> 2tdec7eg3p_c + ttdcea_c
# PLIPA1A160pp : 2hdecg3p_c + h_c + hdca_c <=> h2o_c + pa160_c
# PLIPA1A180pp : 2odecg3p_c + h_c + ocdca_c --> h2o_c + pa180_c
# PLIPA1E160 : 2agpe160_c + h_c + hdca_c <=> h2o_c + pe160_c
# PLIPA1E180 : 2agpe180_c + h_c + ocdca_c <=> h2o_c + pe180_c
# PLIPA2A120pp : 1ddecg3p_c + ddca_c + 2.0 h_c <=> h2o_c + pa120_c
# PLIPA2A140pp : 1tdecg3p_c + h_c + ttdca_c <=> h2o_c + pa140_c
# PLIPA2A141pp : h2o_c + pa141_c --> 1tdec7eg3p_c + ttdcea_c
# PLIPA2A160pp : 1hdecg3p_c + hdca_c <=> h2o_c + pa160_c
# PLIPA2A180pp : 1odecg3p_c + h_c + ocdca_c --> h2o_c + pa180_c
# PMPK : 2mahmp_c + adp_c <=> 4ampm_c + atp_c
# PNTK : 4ppan_c + adp_c + h_c <=> atp_c + pnto__R_c
# POX : ac_c + co2_c + q8h2_c <-- h2o_c + pyr_c + q8_c
# PPBNGS : 2.0 h2o_c + h_c + ppbng_c <-- 2.0 5aop_c
# PPC : co2_c + h2o_c + pep_c --> h_c + oaa_c + pi_c
# PPCDC : co2_c + pan4p_c <-- 4ppcys_c + h_c
# PPGPPDP : h2o_c + ppgpp_c --> gdp_c + h_c + ppi_c
# PPNCL2 : 4ppcys_c + cmp_c + h_c + ppi_c <-- 4ppan_c + ctp_c + cys__L_c
# PPNCL3 : 4ppcys_c + amp_c + h_c + ppi_c <-- 4ppan_c + atp_c + cys__L_c
# PPNDH : co2_c + h2o_c + phpyr_c <-- h_c + pphn_c
# PPOR : 2hyoxplac_c + co2_c <-- o2_c + phpyr_c
# PPPGO : 6.0 h2o_c + 2.0 ppp9_c <-- 3.0 o2_c + 2.0 pppg9_c
# PPRGL : adp_c + gar_c + h_c + pi_c <-- atp_c + gly_c + pram_c
# PPS : amp_c + 2.0 h_c + pep_c + pi_c <-- atp_c + h2o_c + pyr_c
# PPTTm : hexdp_c + ppi_c <-- ipdp_c + pendp_c
# PRACHh : prfp_c <=> h2o_c + prbamp_c
# PRADPh : h_c + ppi_c + prbamp_c <-- h2o_c + prbatp_c
# PRAI : 2cpr5p_c <=> pran_c
# PRAIS : adp_c + air_c + pi_c <=> atp_c + fpram_c
# PRAISh : 25aics_c + adp_c + 2.0 h_c + pi_c <-- 5aizc_c + asp__L_c + atp_c
# PRDX : h2o2_c + meoh_c <=> fald_c + 2.0 h2o_c
# PRFGS : adp_c + fpram_c + glu__L_c + 2.0 h_c + pi_c <-- atp_c + fgam_c + gln__L_c + h2o_c
# PRICIh : prfp_c <=> prlp_c
# PROabc : atp_c + h2o_c + pro__L_e --> adp_c + h_e + pi_c + pro__L_c
# PROAKGOX1 : akg_c + o2_c + pro__L_c --> 4hpro_LT_c + co2_c + succ_c
# PROD2 : fad_c + pro__L_c <=> 1pyr5c_c + fadh2_c
# PROt2r : h_c + pro__L_e <=> h_e + pro__L_c
# PRPPS : amp_c + h_c + prpp_c <=> atp_c + r5p_c
# PSAT : akg_c + pser__L_c <=> 3php_c + glu__L_c
# PSCIT : pep_c + skm5p_c <=> 3psme_c + pi_c
# PSD120 : co2_c + pe120_c <=> 2.0 h_c + ps120_c
# PSD160 : co2_c + pe160_c <=> h_c + ps160_c
# PSD161 : co2_c + pe161_c <=> 2.0 h_c + ps161_c
# PSD180 : co2_c + pe180_c <=> h_c + ps180_c
# PSD181 : co2_c + pe181_c <=> 2.0 h_c + ps181_c
# PSP : h2o_c + pser__L_c --> pi_c + ser__L_c
# PSP_D : h2o_c + pser__D_c --> pi_c + ser__D_c
# PSSA120 : cmp_c + 2.0 h_c + ps120_c <-- cdpdddecg_c + ser__L_c
# PSSA160 : cmp_c + h_c + ps160_c <-- cdpdhdecg_c + ser__L_c
# PSSA161 : cmp_c + 2.0 h_c + ps161_c <-- cdpdhdec9eg_c + ser__L_c
# PSSA180 : cmp_c + h_c + ps180_c <-- cdpdodecg_c + ser__L_c
# PSSA181 : cmp_c + 2.0 h_c + ps181_c <-- cdpdodec11eg_c + ser__L_c
# PTE5x : adrn_c + coa_c + h_c <=> adrncoa_c + h2o_c
# PTRCabc : atp_c + h2o_c + ptrc_e --> adp_c + h_c + pi_c + ptrc_c
# PUNP7 : r1p_c + xan_c <=> pi_c + xtsn_c
# PUTA3 : glu__L_c + 2.0 h_c + nadh_c <-- glu5sa_c + h2o_c + nad_c
# PYAM5PO : h2o2_c + nh4_c + pydx5p_c <-- h2o_c + o2_c + pyam5p_c
# PYDAMK : adp_c + h_c + pyam5p_c <=> atp_c + pydam_c
# PYDXK : adp_c + h_c + pydx5p_c <=> atp_c + pydx_c
# PYDXNK : adp_c + h_c + pdx5p_c <=> atp_c + pydxn_c
# PYDXS : g3p_c + gln__L_c + ru5p__D_c --> glu__L_c + 3.0 h2o_c + h_c + pi_c + pydx5p_c
# PYK : adp_c + h_c + pep_c <=> atp_c + pyr_c
# PYRt2 : h_e + pyr_e <-- h_c + pyr_c
# QUILSYN : cmusa_c --> h2o_c + h_c + quln_c
# R01465m : 2aobut_c + h_c + nadh_c <=> nad_c + thr__L_c
# RBFK : adp_c + fmn_c + h_c <=> atp_c + ribflv_c
# RBFSb : 2.0 dmlz_c + h_c --> 4r5au_c + ribflv_c
# RBK : adp_c + h_c + r5p_c <=> atp_c + rib__D_c
# RDH1 : h_c + nadh_c + retinal_c <=> nad_c + retinol_c
# RNDR1 : dadp_c + h2o_c + trdox_c <-- adp_c + trdrd_c
# RNDR2 : dgdp_c + h2o_c + trdox_c <-- gdp_c + trdrd_c
# RNDR3 : dcdp_c + h2o_c + trdox_c <-- cdp_c + trdrd_c
# RNDR4 : dudp_c + h2o_c + trdox_c <-- trdrd_c + udp_c
# RNMK : atp_c + rnam_c <=> adp_c + h_c + nmn_c
# RPE : ru5p__D_c <=> xu5p__D_c
# RPI : ru5p__D_c <=> r5p_c
# rxn00016_c0 : chtbs_c + h2o_c --> 2.0 acgam_c
# rxn00816_c0 : gal_bD_c + glc__D_c <=> h2o_c + lcts_c
# rxn01080_c0 : fruur_c <=> glcur_c
# rxn01292_c0 : arab__L_c <=> rbl__L_c
# rxn01457_c0 : tagur_c <=> galur_c
# rxn02362_c0 : 13dpg_c + atp_c <=> adp_c + cdpg_c + pi_c
# rxn03462_c0 : MNXM63441_c + gal_bD_c <=> MNXM2977_c + h2o_c
# rxn03893_c0 : 3ophb_c + h_c + ppi_c <-- 4hbz_c + MNXM53112_c
# rxn04052_c0 : copre8_c + h_c <=> cobn_c
# rxn05336_c0 : 3opalmACP_c + nadph_c <=> 3hpalmACP_c + nadp_c
# rxn05342_c0 : 3omrsACP_c + nadph_c <=> 3hmrsACP_c + nadp_c
# rxn05343_c0 : 3odecACP_c + ACP_c + co2_c <-- malACP_c + ocACP_c
# rxn05344_c0 : 3opalmACP_c + ACP_c + co2_c <-- malACP_c + myrsACP_c
# rxn05345_c0 : 3omrsACP_c + ACP_c + co2_c <-- ddcaACP_c + malACP_c
# rxn05346_c0 : 3ohexACP_c + ACP_c + co2_c <-- butACP_c + malACP_c
# rxn05347_c0 : ACP_c + actACP_c + co2_c <-- acACP_c + malACP_c
# rxn05348_c0 : 3oddecACP_c + ACP_c + co2_c <-- dcaACP_c + malACP_c
# rxn05359_c0 : ACP_c + MNXM10219_c + co2_c <-- MNXM9860_c + malACP_c
# rxn05363_c0 : ACP_c + MNXM10370_c + co2_c <-- MNXM8147_c + malACP_c
# rxn05367_c0 : ACP_c + MNXM10448_c + co2_c <-- MNXM8195_c + malACP_c
# rxn05371_c0 : ACP_c + MNXM9655_c + co2_c <-- MNXM8218_c + malACP_c
# rxn05375_c0 : ACP_c + MNXM9684_c + co2_c <-- MNXM8003_c + malACP_c
# rxn05379_c0 : ACP_c + MNXM9700_c + co2_c <-- MNXM6636_c + malACP_c
# rxn05384_c0 : ACP_c + MNXM10327_c + co2_c <-- MNXM11926_c + malACP_c
# rxn05388_c0 : ACP_c + MNXM10423_c + co2_c <-- MNXM8175_c + malACP_c
# rxn05392_c0 : ACP_c + MNXM10475_c + co2_c <-- MNXM8209_c + malACP_c
# rxn05396_c0 : ACP_c + MNXM9671_c + co2_c <-- MNXM8225_c + malACP_c
# rxn05400_c0 : ACP_c + MNXM9695_c + co2_c <-- MNXM8010_c + malACP_c
# rxn05404_c0 : ACP_c + MNXM9707_c + co2_c <-- MNXM6644_c + malACP_c
# rxn05409_c0 : ACP_c + MNXM10220_c + co2_c <-- MNXM11912_c + malACP_c
# rxn05413_c0 : ACP_c + MNXM10369_c + co2_c <-- MNXM8148_c + malACP_c
# rxn05417_c0 : ACP_c + MNXM10449_c + co2_c <-- MNXM8194_c + malACP_c
# rxn05421_c0 : ACP_c + MNXM9656_c + co2_c <-- MNXM8219_c + malACP_c
# rxn05425_c0 : ACP_c + MNXM9685_c + co2_c <-- MNXM8006_c + malACP_c
# rxn05429_c0 : ACP_c + MNXM9701_c + co2_c <-- MNXM6637_c + malACP_c
# rxn05460_c0 : ACP_c + MNXM10116_c + co2_c <-- MNXM25932_c + malACP_c
# rxn06181_c0 : MNXM7713_c + atp_c + h_c <=> MNXM9056_c + adp_c
# rxn06453_c0 : MNXM8658_c + udp_c <=> MNXM93437_c + udpg_c
# rxn06723_c0 : ACP_c + u23ga_c <-- 3hmrsACP_c + u3hga_c
# rxn08333_c0 : 2dmmql8_c + co2_c + ppi_c <-- MNXM53112_c + dhna_c
# rxn09448_c0 : amp_c + odecoa_c + ppi_c <-- MNXM65309_c + atp_c + coa_c
# rxn09988_c0 : 3.0 arab__L_c <-- MNXM42463_c + 2.0 h2o_c
# rxn11612_c0 : MNXM7555_c + gal_bD_c <=> MNXM1225_c + h2o_c
# rxn12008_c0 : MNXM53112_c + ppi_c <-- hepdp_c + ipdp_c
# rxn13990_c0 : acgam1p_c + adp_c + h_c <=> acgam_c + atp_c
# RZ5PP : 5prdmbz_c + h2o_c --> pi_c + rdmbzi_c
# S7PI : gmhep7p_c <-- s7p_c
# SADT : aps_c + ppi_c <-- atp_c + h_c + so4_c
# SADT2 : aps_c + gdp_c + pi_c + ppi_c <-- atp_c + gtp_c + h2o_c + so4_c
# SALCpts : pyr_c + salc6p_c <=> pep_c + salcn_e
# SAM24MT : amet_c + zymst_c <=> ahcys_c + fecost_c + h_c
# SBP : h2o_c + s17bp_c --> pi_c + s7p_c
# SBTPD : f6p_c + h_c + nadh_c <=> nad_c + sbt6p_c
# SBTpts : pyr_c + sbt6p_c <=> pep_c + sbt__D_e
# SDPDS : h2o_c + sl26da_c <=> 26dap_LL_c + succ_c
# SDPTA : akg_c + sl26da_c <=> glu__L_c + sl2a6o_c
# SELCYSTS : h2o_c + selcyst_c <=> selhcys_c + ser__L_c
# SERD_L : nh4_c + pyr_c <-- ser__L_c
# SERH : g3p_c + h2o_c + trp__L_c <-- 3ig3p_c + ser__L_c
# SERt2m : h_e + ser__L_e <=> h_c + ser__L_c
# SHCHD2 : 2.0 h_c + nadh_c + scl_c <-- dscl_c + nad_c
# SHCHF : fe2_c + scl_c <=> 2.0 h_c + sheme_c
# SHK3Dr : 3dhsk_c + h_c + nadph_c <=> nadp_c + skm_c
# SHKK : adp_c + h_c + skm5p_c <-- atp_c + skm_c
# SHSL4h : 2obut_c + h_c + nh4_c + succ_c <-- h2o_c + suchms_c
# SO4t2 : h_e + so4_e <=> h_c + so4_c
# SOTA : akg_c + sucorn_c <=> glu__L_c + sucgsa_c
# SPMDabc : atp_c + h2o_c + spmd_e --> adp_c + h_c + pi_c + spmd_c
# SPODM : 2.0 h_c + 2.0 o2s_c --> h2o2_c + o2_c
# SPTc : pyr_c + ser__L_c <=> ala__L_c + hpyr_c
# SSALx : 2.0 h_c + nadh_c + succ_c <-- h2o_c + nad_c + sucsal_c
# SUCBZL : amp_c + ppi_c + sbzcoa_c <-- atp_c + coa_c + sucbz_c
# SUCCt2b : h_e + succ_e <=> h_c + succ_c
# SUCD4 : fad_c + h_c + q8h2_c <-- fadh2_c + q8_c
# SUCLm : atp_c + coa_c + succ_c <-- adp_c + pi_c + succoa_c
# SUCRe : h2o_c + sucr_c --> fru_c + glc__D_c
# SUCRt2 : h_e + sucr_e <=> h_c + sucr_c
# SULabc : adp_c + h_c + pi_c + so4_c <-- atp_c + h2o_c + so4_e
# SULR : 4.0 h_c + hso3_c + 3.0 nadph_c <=> 3.0 h2o_c + h2s_c + 3.0 nadp_c
# TAL : thr__L_c --> 2obut_c + nh4_c
# TALA : g3p_c + s7p_c <=> e4p_c + f6p_c
# TAUDO : aacald_c + co2_c + h_c + hso3_c + succ_c <-- akg_c + o2_c + taur_c
# TAURabc : adp_c + h_c + pi_c + taur_c <-- atp_c + h2o_c + taur_e
# TDPDRE : dtdp4d6dm_c <=> dtdp4d6dg_c
# TDPDRR : dtdp4d6dm_c + h_c + nadph_c <=> dtdprmn_c + nadp_c
# TDPGDH : dtdpglu_c --> dtdp4d6dg_c + h2o_c
# TDSK : atp_c + lipidAds_c <=> adp_c + h_c + lipidA_c
# TDSRh : h_c + nadph_c + trdox_c <=> nadp_c + trdrd_c
# THD2 : 2.0 h_e + nadh_c + nadp_c <=> 2.0 h_c + nad_c + nadph_c
# THDPS : coa_c + sl2a6o_c --> h2o_c + succoa_c + thdp_c
# THIORDXi : 2.0 h2o_c + trdox_c <-- h2o2_c + trdrd_c
# THMDt2 : h_e + thymd_e <=> h_c + thymd_c
# THRA : thr__L_c --> acald_c + gly_c
# THRS : h2o_c + phom_c --> pi_c + thr__L_c
# THZPSN : 4hba_c + 4mpetz_c + ala__L_c + amp_c + co2_c + h2o_c + h_c + ppi_c <-- atp_c + cys__L_c + dxyl5p_c + tyr__L_c
# TKT1 : r5p_c + xu5p__D_c <=> g3p_c + s7p_c
# TKT2 : e4p_c + xu5p__D_c <=> f6p_c + g3p_c
# TMDK1 : adp_c + dtmp_c + h_c <=> atp_c + thymd_c
# TMDPP : 2dr1p_c + thym_c <=> pi_c + thymd_c
# TMDS : dump_c + mlthf_c --> dhf_c + dtmp_c
# TMPK : adp_c + thmpp_c <=> atp_c + thmmp_c
# TMPPP : 2mahmp_c + 4mpetz_c + h_c <=> ppi_c + thmmp_c
# TPI : g3p_c <=> dhap_c
# TPRDCOAS : 2tpr3dpcoa_c + ade_c <=> atp_c + dpcoa_c
# TRE6PP : pi_c + tre_c <-- h2o_c + tre6p_c
# TRE6PS : g6p_c + udpg_c <=> h_c + tre6p_c + udp_c
# TREpts : pep_c + tre_e <=> pyr_c + tre6p_c
# TRPO2 : Lfmkynr_c <-- o2_c + trp__L_c
# TRPS2 : h2o_c + trp__L_c <-- indole_c + ser__L_c
# TRPt2m : h_e + trp__L_e --> h_c + trp__L_c
# TSULabc : adp_c + h_e + pi_c + tsul_c <-- atp_c + h2o_c + tsul_e
# TTDCAt2 : h_e + ttdca_e <=> h_c + ttdca_c
# TYRCBOX : co2_c + tym_c <-- h_c + tyr__L_c
# UAAGDS : adp_c + h_c + pi_c + ugmd_c <-- 26dap__M_c + atp_c + uamag_c
# UAAGLS1 : adp_c + h_c + pi_c + uAgl_c <=> atp_c + lys__L_c + uamag_c
# UAGAAT : 3hmrsACP_c + h_c + uacgam_c --> ACP_c + u3aga_c
# UAGCVT : pi_c + uaccg_c <=> pep_c + uacgam_c
# UAGDP : ppi_c + uacgam_c <=> acgam1p_c + h_c + utp_c
# UAGPT2 : h_c + uaaGgla_c + udp_c <=> uaGgla_c + uacgam_c
# UAGPT3 : h_c + uaagmda_c + udp_c <=> uacgam_c + uagmda_c
# UAMAGS : atp_c + glu__D_c + uama_c --> adp_c + h_c + pi_c + uamag_c
# UAMAS : adp_c + h_c + pi_c + uama_c <-- ala__L_c + atp_c + uamr_c
# UAPGR : h_c + nadph_c + uaccg_c <=> nadp_c + uamr_c
# UDPGD : 3.0 h_c + 2.0 nadh_c + udpglcur_c <=> h2o_c + 2.0 nad_c + udpg_c
# UGAH : h2o_c + udg_c <=> nh4_c + urdglyc_c
# UGMDDS : alaala_c + atp_c + ugmd_c --> adp_c + h_c + pi_c + ugmda_c
# UHBZ1t_pp : 4hbz_e + h_e --> 4hbz_c + h_c
# UHGADA : ac_c + u3hga_c <=> h2o_c + u3aga_c
# UMPK : adp_c + udp_c <=> atp_c + ump_c
# UPP3S : h2o_c + uppg3_c <=> hmbil_c
# UPPDC1 : 4.0 co2_c + cpppg3_c <=> 4.0 h_c + uppg3_c
# UPPDC2 : 4.0 h_c + uppg1_c <=> 4.0 co2_c + cpppg1_c
# UPPRT : ppi_c + ump_c <-- prpp_c + ura_c
# URCN : h2o_c + urcan_c <=> 4iz5pp_c
# UREA : h2o_c + 2.0 h_c + urea_c --> co2_c + 2.0 nh4_c
# URFGTT : 2ombz_c + amet_c --> 2ommb_c + ahcys_c + h_c
# URIDK2m : atp_c + dump_c --> adp_c + dudp_c
# URIt2 : h_e + uri_e <=> h_c + uri_c
# VPAMTr : pyr_c + val__L_c <=> 3mob_c + ala__L_c
# X5PL3E : xu5p__L_c <=> ru5p__L_c
# XAND : h_c + nadh_c + urate_c <-- h2o_c + nad_c + xan_c
# XPPT : ppi_c + xmp_c <-- prpp_c + xan_c
# XTSNH : rib__D_c + xan_c <=> h2o_c + xtsn_c
# XYLI1 : xyl__D_c <=> xylu__D_c
# XYLI2 : fru_c <=> glc__D_c
# XYLK : adp_c + h_c + xu5p__D_c <=> atp_c + xylu__D_c
# XYLt2 : h_e + xyl__D_e <=> h_c + xyl__D_c
# ZN2t4pp : h_e + k_e + zn2_c <=> h_c + k_c + zn2_e
# G-12289 : dtpcudcpp_c + udpg_c --> MXNM5615_c + ump_c
# G-12290 : MXNM5615_c + udpg_c --> MNXM5639_c + ump_c
# MNXR113143 : MNXM5639_c + gdpmann_c + h_c --> MNXM2971_c + gdp_c
# MNXR113142 : MNXM2971_c + h_c + udpglcur_c --> MNXM2980_c + udp_c
# MNXR113144 : MNXM2980_c + gdpmann_c --> MNXM3223_c + gdp_c + h_c
# MNXR117163 : MNXM3223_c + accoa_c --> MNXM8499_c + coa_c
# MNXR117165 : MNXM8499_c + pep_c --> MNXM10150_c + pi_c
# G-12296 : MNXM8499_c + accoa_c --> MNXM12362_c + coa_c
# gumBCEJ : MNXM10150_c + MNXM12362_c --> MNXM22459_c + dtpcudcpp_c
# OF_Biomass_Synthesis : 0.2 BIOMASS_c + 0.8 MNXM22459_c -->

# %%
print("Names Reactions")
print("---------")
for x in xam_model.reactions:
    print("%s : %s" % (x.id, x.name))
# Out:
# Names Reactions
# ---------
# 10FTHFGLULL : None
# 2DHPFALDL : None
# 2HBO : None
# 2OH3K5MPPISO : None
# 34DHOXPEGOX : None
# 34HPPOR : None
# 3HAO : None
# 3HBCOAHL : None
# 3HLYTCL : None
# 3OAR100 : None
# 3OAR120 : None
# 3OAR40_1 : None
# 3OAR60 : None
# 3OAR80 : None
# 3OAS80 : None
# 4ABUTD : None
# 4CMLCL_kt : None
# 4HTHRS : None
# 56DH5FLURAAMH : None
# 5FLURAPRT : None
# 5HLTDL : None
# 5HXKYNDCL : None
# A5PISO : None
# AACOAR_syn : None
# AACOAT : None
# AASPh : None
# ABUTD : None
# ACACT1 : None
# ACACT10m : None
# ACACT2 : None
# ACACT3 : None
# ACACT4m : None
# ACACT5m : None
# ACACT6m : None
# ACACT7m : None
# ACALDt : None
# ACAS_2ahbut : None
# ACBIPGT : None
# ACCOAC : None
# ACCOAC_1 : None
# ACCOAL : None
# ACGApts : None
# ACGK : None
# ACGS : None
# ACOA40OR : None
# ACOAD1 : None
# ACOAD10m : None
# ACOAD2 : None
# ACOAD3 : None
# ACOAD4 : None
# ACOAD5 : None
# ACOAD6 : None
# ACOAD7 : None
# ACOAD8m : None
# ACOAD9m : None
# ACOADH2 : None
# ACOATA : None
# ACODA : None
# ACONTa : None
# ACONTb : None
# ACOTA : None
# ACPh : None
# ACPS1 : None
# ACS : None
# ACt4pp : None
# ACYP_2 : None
# ADA : None
# ADCL : None
# ADCS : None
# G-12290 : None
# MNXR113143 : None
# MNXR113142 : None
# MNXR113144 : None
# MNXR117163 : None
# MNXR117165 : None
# G-12296 : None
# gumBCEJ : None
# OF_Biomass_Synthesis : None

# %% [markdown]
# ### Transport and Exchange reactions

# %%
count=0
for reactions in xam_model.reactions:
    for x in reactions.metabolites:
        if (x.compartment == 'e'):
            print("%s : %s" % (reactions.id, reactions.reaction))            
            count += 1
print(count)
# Out:
# 0

# %% [markdown]
# ### Metabolites

# %%
print("")
print("Metabolites")
print("-----------")
for x in xam_model.metabolites:
    print('%9s : %s, %s, %s' % (x.id, x.name, x.charge, x.compartment))
# Out:
# Metabolites
# -----------
#       h_c : None, None, None
# 10fthfglu__L_c : None, None, None
#     adp_c : None, None, None
#      pi_c : None, None, None
#  10fthf_c : None, None, None
#     atp_c : None, None, None
#  glu__L_c : None, None, None
#    3mob_c : None, None, None
#    fald_c : None, None, None
#    2dhp_c : None, None, None
#    nadh_c : None, None, None
#   2obut_c : None, None, None
#     2hb_c : None, None, None
#     nad_c : None, None, None
#     h2o_c : None, None, None
# 2h3kmtp_c : None, None, None
#  12dmpo_c : None, None, None
# 34dhmald_c : None, None, None
# 34dhoxpeg_c : None, None, None
#     co2_c : None, None, None
# hgentis_c : None, None, None
# 2h34hppr_c : None, None, None
#      o2_c : None, None, None
#   cmusa_c : None, None, None
# 3hanthrn_c : None, None, None
#     coa_c : None, None, None
#    3hmp_c : None, None, None
# 3hibutcoa_c : None, None, None
#    dopa_c : None, None, None
# 34dhphe_c : None, None, None
# 3odecACP_c : None, None, None
#   nadph_c : None, None, None
#    nadp_c : None, None, None
# 3hdecACP_c : None, None, None
# 3oddecACP_c : None, None, None
# 3hddecACP_c : None, None, None
#  actACP_c : None, None, None
# 3hbutACP_c : None, None, None
# 3ohexACP_c : None, None, None
# 3hhexACP_c : None, None, None
# 3hoctACP_c : None, None, None
# 3ooctACP_c : None, None, None
#     ACP_c : None, None, None
#  malACP_c : None, None, None
#  hexACP_c : None, None, None
#   4abut_c : None, None, None
#  4abutn_c : None, None, None
# 5odhf2a_c : None, None, None
# 2c25dho_c : None, None, None
#   4hthr_c : None, None, None
#   phthr_c : None, None, None
# aflburppa_c : None, None, None
# 56dh5flura_c : None, None, None
#     ppi_c : None, None, None
# 5flurimp_c : None, None, None
#  5flura_c : None, None, None
#    prpp_c : None, None, None
#    srtn_c : None, None, None
#   5htrp_c : None, None, None
# 5hxkynam_c : None, None, None
#  5hxkyn_c : None, None, None
#   ara5p_c : None, None, None
# ru5p__D_c : None, None, None
# 3hbcoa__R_c : None, None, None
#   aacoa_c : None, None, None
#     amp_c : None, None, None
#    acac_c : None, None, None
#    paps_c : None, None, None
#     aps_c : None, None, None
#   accoa_c : None, None, None
# 2maacoa_c : None, None, None
#   ppcoa_c : None, None, None
#  3ohcoa_c : None, None, None
#   btcoa_c : None, None, None
#  3oocoa_c : None, None, None
#   hxcoa_c : None, None, None
#  3odcoa_c : None, None, None
#   occoa_c : None, None, None
# 3oddcoa_c : None, None, None
# selcyst_c : None, None, None
# selhcys_c : None, None, None
#     scl_c : None, None, None
#     skm_c : None, None, None
#  sucorn_c : None, None, None
#  sucgsa_c : None, None, None
#  sucsal_c : None, None, None
#   sucbz_c : None, None, None
# dtdp4d6dm_c : None, None, None
# dtdp4d6dg_c : None, None, None
#    4hba_c : None, None, None
#  4mpetz_c : None, None, None
#   2dr1p_c : None, None, None
# 2tpr3dpcoa_c : None, None, None
#   tre6p_c : None, None, None
# Lfmkynr_c : None, None, None
#     tym_c : None, None, None
#    ugmd_c : None, None, None
#   uamag_c : None, None, None
#    uAgl_c : None, None, None
#  uacgam_c : None, None, None
#   u3aga_c : None, None, None
#   uaccg_c : None, None, None
#    uama_c : None, None, None
#    uamr_c : None, None, None
# udpglcur_c : None, None, None
#     udg_c : None, None, None
# urdglyc_c : None, None, None
#   uppg1_c : None, None, None
#  cpppg1_c : None, None, None
# xu5p__L_c : None, None, None
# ru5p__L_c : None, None, None
#   urate_c : None, None, None
#  xyl__D_c : None, None, None
# xylu__D_c : None, None, None

# %% [markdown]
# ### Genes

# %%
print("")
print("Genes")
print("-----")
for x in xam_model.genes:
    associated_ids = (i.id for i in x.reactions)
    print("%s is associated with reactions: %s" %
          (x.id, "{" + ", ".join(associated_ids) + "}"))
# Out:
# Genes
# -----
# 1185660.4.peg.1057 is associated with reactions: {10FTHFGLULL, DHFS, FPGS_tm}
# 1185660.4.peg.495 is associated with reactions: {AICART, FGLU, ICH, MOHMT, 2DHPFALDL}
# 1185660.4.peg.109 is associated with reactions: {L_LACDcm, 2HBO, L_LACD2, LDH_L, L_LACD3, MCLOR}
# 1185660.4.peg.1883 is associated with reactions: {2OH3K5MPPISO}
# 1185660.4.peg.2389 is associated with reactions: {CHOLD, MNXR8926, ALCD19, MNXR15973, MNXR16994, MNXR12173, MNXR17974, RDH1, MNXR15972, MNXR17999, MNXR18003, ALCD2ir, MNXR18214, 34DHOXPEGOX, MNXR5765, MNXR15797, MNXR17153}
# 1185660.4.peg.3115 is associated with reactions: {CHOLD, MNXR8926, ALCD19, MNXR15973, MNXR16994, MNXR12173, MNXR17974, RDH1, MNXR15972, MNXR17999, MNXR18003, ALCD2ir, MNXR18214, 34DHOXPEGOX, MNXR5765, MNXR15797, MNXR17153}
# 1185660.4.peg.29 is associated with reactions: {CHOLD, MNXR8926, ALCD19, MNXR15973, MNXR16994, MNXR12173, MNXR17974, RDH1, MNXR15972, MNXR17999, MNXR18003, ALCD2ir, MNXR18214, 34DHOXPEGOX, MNXR5765, MNXR15797, MNXR17153}
# 1185660.4.peg.180 is associated with reactions: {CHOLD, MNXR8926, ALCD19, MNXR15973, MNXR16994, MNXR12173, MNXR17974, RDH1, MNXR15972, MNXR17999, MNXR18003, ALCD2ir, MNXR18214, 34DHOXPEGOX, MNXR5765, MNXR15797, MNXR17153}
# 1185660.4.peg.3035 is associated with reactions: {CHOLD, MNXR8926, ALCD19, MNXR15973, MNXR16994, MNXR12173, MNXR17974, RDH1, MNXR15972, MNXR17999, MNXR18003, ALCD2ir, MNXR18214, 34DHOXPEGOX, MNXR5765, MNXR15797, MNXR17153}
# 1185660.4.peg.3381 is associated with reactions: {MNXR85427, DHPM2, MNXR70220, 56DH5FLURAAMH, DHPD}
# 1185660.4.peg.2778 is associated with reactions: {MNXR85427, DHPM2, MNXR70220, 56DH5FLURAAMH, DHPD}
# 1185660.4.peg.2831 is associated with reactions: {MNXR85427, DHPM2, MNXR70220, 56DH5FLURAAMH, DHPD}
# 1185660.4.peg.2895 is associated with reactions: {MNXR85427, DHPM2, MNXR70220, 56DH5FLURAAMH, DHPD}
# 1185660.4.peg.1060 is associated with reactions: {GLUPRT, 5FLURAPRT, ORPT}
# 1185660.4.peg.144 is associated with reactions: {A5PISO}
# 1185660.4.peg.2694 is associated with reactions: {A5PISO}
# 1185660.4.peg.2053 is associated with reactions: {MNXR6908, AACOAR_syn}
# 1185660.4.peg.3317 is associated with reactions: {MNXR6908, AACOAR_syn}
# 1185660.4.peg.3392 is associated with reactions: {FACOAL180, MNXR27603, MNXR27605, MNXR27602, MNXR27601, FACOAL160, MNXR27606, FACOAL140, AACOAT, MNXR27604, rxn09448_c0, MNXR80370}
# Unknown is associated with reactions: {EX_cytd_e, EX_acgam_e, EDTXS2, ACCOAL, EX_so4_e, FORti, ACGApts, EX_4hbz_e, AACOAT, EX_glu__L_e, GALTpts, TRPt2m, EX_glycogen_e, EX_acald_e, FPPSh, EX_for_e, FRD, rxn08333_c0, MNXR27660, FRD2, ETOHti, FRD3, EX_2ddglcn_e, MNXR81103, FRUK, EX_rna_c0, ATPS4r, MNXR28723, CBL1abc, EX_taur_e, EX_malt_e, EX_ins_e, PDHam1hi, EX_ac_e, MNXR27639, MNXR85363, EX_k_e, AOXHEXCYCL, MNXR27647, NTRIR2x, SPMDabc, GCCc, HEPT1, EX_lys__L_e, EX_h2o_e, MNXR27655, SHCHD2, EX_gln__L_e, O2t, AOOA, S7PI, EX_mn2_e, EX_ala__D_e, EX_man_e, DMATT, G5SADrm, EX_o2_e, EX_met__D_e, EX_pro__L_e, SALCpts, HEPT3, EX_met__L_e, MANpts, MNXR27651, EX_metox__R_e, PPPGO, EX_Biomass_e, EX_metsox_S__L_e, EX_dgsn_e, PFK_2, MNXR32524, APLh, EX_mg2_e, EX_tre_e, EX_arbt_e, EX_ca2_e, EX_nh4_e, DALAt2pp, FE3abc, CU2abcpp, EX_cbl1_e, EX_mqn7_e, SBTpts, UHBZ1t_pp, FRD7, OPHBDC, EX_chol_e, EX_adn_e, EX_cit_e, EX_thymd_e, EX_nmn_e, EX_din_e, EX_cl_e, EX_no3_e, MNXR27643, EX_na1_e, EX_cobalt2_e, EX_co2_e, METSOX1abcpp, ACPS1, METDabc, AGMHE, EX_mal__L_e, EX_dad_2_e, UPPRT, EX_cu2_e, EX_zn2_e, EX_sbt__D_e, EX_akg_e, EX_fru_e, EX_pi_e, APSR, EX_ASPt5n_e, EX_h_e, EX_dcyt_e, EX_trp__L_e, GAMpts, EX_ppi_e, MNXR94267, EX_succ_e, MNXR27805, THD2, MNXR70083, EX_protein_e, EX_DNA_e, OHPHM, FAS140ACPm, PYRt2, EX_etha_e, EX_glc__D_e, EX_duri_e, CYTBO3, EX_q8_e, EX_salcn_e, SHKK, EX_etoh_e, IMDHT_3c2hmp, EX_q8h2_e, MNXR15641, EX_fe2_e, EX_sucr_e, CA2t3pp, EX_hdca_e, AUS, EX_fe3_e, PHETA1, GMHEPAT, Ht, MNXR74782, Biomass, PAPSR, EX_arab__L_e, EX_ser__L_e, EX_cd2_e, IMDHT, XYLt2, EX_thmmp_e, TREpts, EX_no2_e, EX_pyr_e, DDPA, EX_spmd_e, MALTpts, H2Ot, EX_gam_e, EX_glcur_e, HEPK1, METabc, MOAT3C, EX_galt_e, MNXR93881, ACAS_2ahbut, EX_uri_e, HEPK2, EX_orn_e, AKGt2r, MNXR27672, DADNt2, THZPSN, MNXR28652, HYD1, MNXR2786, MNXR28722, MNXR74626, MNXR28653, EX_ser__D_e, MNXR28654, EX_gly_e, HEPT4, EX_galur_e, EX_glyb_e, MNXR79883, MNXR27668, EX_glyc_e, ALAALAr, MNXR27680, MQN7t, MNXR58824, MNXR27676, EX_arg__L_e, ACALDt, PRFGS, GLCpts, EX_fum_e, EX_ptrc_e, EX_hxan_e, GLCTR2, GALT1, GLCTR3, MCCC, MG2abc, EX_ttdca_e, EX_tsul_e, MNXR94192, FRUpts, MNXR27635, PTRCabc, NA1Hth, EX_ocdca_e, EX_xyl__D_e, PYDXS, MNXR27664, ATPM, ARBTptspp, CO2t, MNXR27856}
# 1185660.4.peg.1922 is associated with reactions: {FACOAL180, MNXR27603, MNXR27605, MNXR27602, MNXR27601, FACOAL160, MNXR27606, FACOAL140, AACOAT, MNXR27604, rxn09448_c0, MNXR80370}
# 1185660.4.peg.3352 is associated with reactions: {SADT, SADT2, AASPh}
# 1185660.4.peg.2630 is associated with reactions: {MNXR60319, MNXR22677, ASAD, GGGABADr, MNXR17827, MNXR16018, MNXR74716, MNXR6969, MNXR16995, MNXR74717, MNXR84631, MNXR60651, MNXR8994, ABUTD, MNXR85287, MNXR17004, MNXR9029, MNXR74931, MNXR15436, MNXR17835, MNXR85589, MNXR16239}
# 1185660.4.peg.1581 is associated with reactions: {ACACT7m, ACACT1, ACACT2, ACACT3, ACACT4m, ACACT5m, ACACT6m, ACACT10m}
# 1185660.4.peg.2235 is associated with reactions: {ACACT7m, ACACT1, ACACT2, ACACT3, ACACT4m, ACACT5m, ACACT6m, ACACT10m}
# 1185660.4.peg.709 is associated with reactions: {ACACT1, ACACT2}
# 1185660.4.peg.193 is associated with reactions: {ACACT7m, ACACT1, ACACT2, ACACT3, ACACT4m, ACACT5m, ACACT6m, ACACT10m}
# 1185660.4.peg.3281 is associated with reactions: {ACAS_2ahbut, APLh, PDHam1hi}
# 1185660.4.peg.3282 is associated with reactions: {ACAS_2ahbut, APLh, PDHam1hi}
# 1185660.4.peg.2927 is associated with reactions: {ADOCBIK, MNXR85460, ACBIPGT}
# 1185660.4.peg.3842 is associated with reactions: {ACCOAC, BACCL, MNXR20056, MNXR85314}
# 1185660.4.peg.1647 is associated with reactions: {ACCOAC_1}
# 1185660.4.peg.2620 is associated with reactions: {ACCOAC_1}
# 1185660.4.peg.4012 is associated with reactions: {ACS, MNXR5630, ACCOAL, MNXR5887}
# 1185660.4.peg.2706 is associated with reactions: {SBTpts, GALTpts, ARBTptspp, TREpts, GLCpts, FRUpts, ACGApts, GAMpts, MALTpts, SALCpts, MANpts}
# 1185660.4.peg.2139 is associated with reactions: {SBTpts, GALTpts, ARBTptspp, TREpts, GLCpts, FRUpts, ACGApts, GAMpts, MALTpts, SALCpts, MANpts}
# 1185660.4.peg.2004 is associated with reactions: {ACGK, ASPK}
# 1185660.4.peg.3151 is associated with reactions: {ACGS}
# 1185660.4.peg.774 is associated with reactions: {ACGS}
# 1185660.4.peg.2003 is associated with reactions: {ACGS}
# 1185660.4.peg.4127 is associated with reactions: {ACGS}
# 1185660.4.peg.3346 is associated with reactions: {ACGS}
# 1185660.4.peg.2286 is associated with reactions: {ACGS}
# 1185660.4.peg.1448 is associated with reactions: {ACGS}
# 1185660.4.peg.256 is associated with reactions: {ACOA40OR, ACOAD8m}
# 1185660.4.peg.2776 is associated with reactions: {ACOAD4, ACOAD5, ACOAD3, ACOAD2, ACOAD6, MNXR79601, ACOAD7, ACOAD1}
# 1185660.4.peg.1419 is associated with reactions: {MNXR79601, ACOAD1, ACOADH2}
# 1185660.4.peg.1537 is associated with reactions: {ACOAD10m, ACOAD9m}
# 1185660.4.peg.3164 is associated with reactions: {MNXR14762, ACODA}
# 1185660.4.peg.2005 is associated with reactions: {BTND1, MNXR93703, MNXR94094, ACODA}
# 1185660.4.peg.1925 is associated with reactions: {ACONTa, MICITDr, MNXR71393, ACONTb}
# 1185660.4.peg.3257 is associated with reactions: {ACOTA}
# 1185660.4.peg.2157 is associated with reactions: {ACOTA, MNXR8691, ORNTA, SOTA, SDPTA}
# 1185660.4.peg.966 is associated with reactions: {ACPh, ACYP_2}
# xanmn_chr15_0167 is associated with reactions: {ACt4pp}
# 1185660.4.peg.306 is associated with reactions: {ADA, DADA, GUAD}
# 1185660.4.peg.4543 is associated with reactions: {ADCL, MNXR7118}
# 1185660.4.peg.452 is associated with reactions: {ADCS, ANS, ANS2}
# 1185660.4.peg.1146 is associated with reactions: {ADCS}
# 1185660.4.peg.2928 is associated with reactions: {ADCYRS}
# 1185660.4.peg.245 is associated with reactions: {ADECn, MNXR8571}
# 1185660.4.peg.178 is associated with reactions: {ADECn, MNXR8571}
# 1185660.4.peg.247 is associated with reactions: {ADECn, MNXR8571}
# 1185660.4.peg.1793 is associated with reactions: {ATDAMh, ADK1, PMPK}
# 1185660.4.peg.3265 is associated with reactions: {ADK2, ATDAMh, UMPK, ADK1}
# 1185660.4.peg.457 is associated with reactions: {ADMDC}
# 1185660.4.peg.4445 is associated with reactions: {ADNK1, DPCOAK}
# 1185660.4.peg.866 is associated with reactions: {DADNt2, INSt2, DGSNt2, ADNt2, URIt2, DINSt2, CYTDt2, DCYTt2, DURIt2, THMDt2}
# 1185660.4.peg.847 is associated with reactions: {ADNUC, MNXR578}
# 1185660.4.peg.1888 is associated with reactions: {ADNUC, MNXR578}
# 1185660.4.peg.1160 is associated with reactions: {ADNUC, INSH, GNNUC, XTSNH}
# 1185660.4.peg.305 is associated with reactions: {ADNUC, INSH, GNNUC, XTSNH}
# 1185660.4.peg.3218 is associated with reactions: {ADNUC, INSH, GNNUC, XTSNH}
# 1185660.4.peg.2916 is associated with reactions: {ADOCBLS}
# 1185660.4.peg.705 is associated with reactions: {ANNAT, ADPRDP}
# 1185660.4.peg.941 is associated with reactions: {ADPRDP}
# 1185660.4.peg.2042 is associated with reactions: {ADPT}
# 1185660.4.peg.1394 is associated with reactions: {ADSL1r, ADSL2r, ETHAAL}
# 1185660.4.peg.1178 is associated with reactions: {ADSS}
# 1185660.4.peg.2974 is associated with reactions: {RBFK, AFAT, RNMK}
# 1185660.4.peg.747 is associated with reactions: {AGDC, MNXR6532}
# 1185660.4.peg.2408 is associated with reactions: {AGDI, MNXR93834, UGAH}
# 1185660.4.peg.2002 is associated with reactions: {AGGPR}
# 1185660.4.peg.487 is associated with reactions: {MNXR28671, AGPAT140, AGPAT141, MNXR28672, MNXR28673, MNXR28674, MNXR28675, MNXR94333, MNXR94332, AGPAT180, AGPAT160, MNXR94334, AGPAT181, MNXR28676, AGPAT120, AGPAT161}
# 1185660.4.peg.176 is associated with reactions: {MNXR28671, AGPAT140, AGPAT141, MNXR28672, MNXR28673, MNXR28674, MNXR28675, MNXR94333, MNXR94332, AGPAT180, AGPAT160, MNXR94334, AGPAT181, MNXR28676, AGPAT120, AGPAT161}
# 1185660.4.peg.502 is associated with reactions: {MNXR28671, AGPAT140, AGPAT141, MNXR28672, MNXR28673, MNXR28674, MNXR28675, MNXR94333, MNXR94332, AGPAT180, AGPAT160, MNXR94334, AGPAT181, MNXR28676, AGPAT120, AGPAT161}
# 1185660.4.peg.295 is associated with reactions: {AGTi, SPTc}
# 1185660.4.peg.2585 is associated with reactions: {AIRCr, MNXR79878}
# 1185660.4.peg.2586 is associated with reactions: {AIRCr, MNXR79878}
# 1185660.4.peg.1387 is associated with reactions: {AKGDHe2r, AKGDH}
# 1185660.4.peg.1386 is associated with reactions: {AKGDH, GCC2cm}
# 1185660.4.peg.1389 is associated with reactions: {MNXR79613, MNXR70375, AKGDH}
# 1185660.4.peg.1388 is associated with reactions: {AKGDHe2r, AKGDH}
# 1185660.4.peg.1832 is associated with reactions: {ALKP, AKP1, MNXR6332}
# 1185660.4.peg.1846 is associated with reactions: {ALAR}
# 1185660.4.peg.3765 is associated with reactions: {MNXR8700, ALAR}
# 1185660.4.peg.1413 is associated with reactions: {AM6PTh}
# 1185660.4.peg.2795 is associated with reactions: {AMAOTr}
# 1185660.4.peg.4342 is associated with reactions: {AMAOTr}
# 1185660.4.peg.1978 is associated with reactions: {AMID3, MNXR93869, AMID, AMID5, AMID4, AMID2}
# 1185660.4.peg.2410 is associated with reactions: {AMID3, MNXR93869, AMID5, CMPA, AMID4, AMID, AMID2}
# 1185660.4.peg.668 is associated with reactions: {DMTPHT, AMMQT8_2, URFGTT}
# 1185660.4.peg.231 is associated with reactions: {MNXR94492, MNXR63973, MNXR29604, MNXR14387, AMPTASECG, MNXR29607, MNXR63966, MNXR80878, MNXR80879, MNXR63969, MNXR63968, MNXR46338, MNXR29606, MNXR63971, MNXR63972, MNXR63967, MNXR80876, MNXR63975, MNXR63965}
# 1185660.4.peg.1672 is associated with reactions: {MNXR94492, MNXR63973, MNXR29604, MNXR14387, AMPTASECG, MNXR29607, MNXR63966, MNXR80878, MNXR80879, MNXR63969, MNXR63968, MNXR46338, MNXR29606, MNXR63971, MNXR63972, MNXR63967, MNXR80876, MNXR63975, MNXR63965}
# 1185660.4.peg.3572 is associated with reactions: {MNXR94492, MNXR63973, MNXR29604, MNXR14387, AMPTASECG, MNXR29607, MNXR63966, MNXR80878, MNXR80879, MNXR63969, MNXR63968, MNXR46338, MNXR29606, MNXR63971, MNXR63972, MNXR63967, MNXR80876, MNXR63975, MNXR63965}
# 1185660.4.peg.3858 is associated with reactions: {MNXR94492, MNXR63973, MNXR29604, MNXR14387, AMPTASECG, MNXR29607, MNXR63966, MNXR80878, MNXR80879, MNXR63969, MNXR63968, MNXR46338, MNXR29606, MNXR63971, MNXR63972, MNXR63967, MNXR80876, MNXR63975, MNXR63965}
# 1185660.4.peg.3472 is associated with reactions: {MNXR94492, MNXR63973, MNXR29604, MNXR14387, AMPTASECG, MNXR29607, MNXR63966, MNXR80878, MNXR80879, MNXR63969, MNXR63968, MNXR46338, MNXR29606, MNXR63971, MNXR63972, MNXR63967, MNXR80876, MNXR63975, MNXR63965}
# 1185660.4.peg.3347 is associated with reactions: {MNXR94492, MNXR63973, MNXR29604, MNXR14387, AMPTASECG, MNXR29607, MNXR63966, MNXR80878, MNXR80879, MNXR63969, MNXR63968, MNXR46338, MNXR29606, MNXR63971, MNXR63972, MNXR63967, MNXR80876, MNXR63975, MNXR63965}
# 1185660.4.peg.1153 is associated with reactions: {MCITL2, ANS, ANS2}
# 1185660.4.peg.449 is associated with reactions: {ANS, ANS2}
# 1185660.4.peg.1874 is associated with reactions: {AOOA, MNXR32524, PHETA1}
# 1185660.4.peg.1114 is associated with reactions: {AOXSr, MNXR84910}
# 1185660.4.peg.3804 is associated with reactions: {APAPTm}
# 1185660.4.peg.2108 is associated with reactions: {APATr, MNXR6030}
# 1185660.4.peg.2124 is associated with reactions: {APATr, MNXR6030}
# 1185660.4.peg.2169 is associated with reactions: {APPAT}
# 1185660.4.peg.775 is associated with reactions: {DHPPDA2, APRAUR, MNXR93752}
# 1185660.4.peg.3356 is associated with reactions: {PAPSR, APSR}
# 1185660.4.peg.1884 is associated with reactions: {ARD_1}
# 1185660.4.peg.3803 is associated with reactions: {ARGDC}
# 1185660.4.peg.3883 is associated with reactions: {ARGN, IZPN}
# 1185660.4.peg.3296 is associated with reactions: {ARGORNt7}
# 1185660.4.peg.4523 is associated with reactions: {ARGORNt7}
# 1185660.4.peg.2001 is associated with reactions: {ARGSL, MNXR93778}
# 1185660.4.peg.2007 is associated with reactions: {ARGSS, CTPS1, CTPS2}
# 1185660.4.peg.959 is associated with reactions: {ASNN}
# 1185660.4.peg.2814 is associated with reactions: {ASNN}
# 1185660.4.peg.1291 is associated with reactions: {ASNS1}
# 1185660.4.peg.1339 is associated with reactions: {ASNS1}
# 1185660.4.peg.1828 is associated with reactions: {ASP1DC}
# 1185660.4.peg.655 is associated with reactions: {ASPATh, MNXR33771, MNXR32524}
# 1185660.4.peg.3324 is associated with reactions: {ASPATh, MNXR33771, MNXR32524}
# 1185660.4.peg.3128 is associated with reactions: {ASPCT, MNXR14578, MNXR84576}
# 1185660.4.peg.3122 is associated with reactions: {DAPDC, ASPK, ORDCh}
# 1185660.4.peg.1860 is associated with reactions: {HSDx, ASPK, HSDH}
# 1185660.4.peg.3301 is associated with reactions: {MALt2_2, ASPt2_2, FUMt2r}
# 1185660.4.peg.2232 is associated with reactions: {NDPK2, ATGDm, NDPK4, NDPK3, NDPK9, NDPK6, ATDGDm, NDPK7, NDPK8}
# 1185660.4.peg.1872 is associated with reactions: {ATPPRT}
# 1185660.4.peg.3725 is associated with reactions: {ATPS4r}
# 1185660.4.peg.3724 is associated with reactions: {ATPS4r}
# 1185660.4.peg.3723 is associated with reactions: {ATPS4r}
# 1185660.4.peg.3722 is associated with reactions: {ATPS4r}
# 1185660.4.peg.3721 is associated with reactions: {ATPS4r}
# 1185660.4.peg.3996 is associated with reactions: {BACCL, BTNC}
# 1185660.4.peg.953 is associated with reactions: {BCTA_glu_h, BCTA_val_h, MNXR79548}
# 1185660.4.peg.2357 is associated with reactions: {BDH}
# 1185660.4.peg.752 is associated with reactions: {BETALDHx, BETALDHy}
# 1185660.4.peg.2793 is associated with reactions: {IBPHn, MNXR75041, BPNT}
# 1185660.4.peg.2792 is associated with reactions: {IBPHn, MNXR75041, BPNT}
# 1185660.4.peg.511 is associated with reactions: {BTNC}
# 1185660.4.peg.513 is associated with reactions: {BTNC}
# 1185660.4.peg.1115 is associated with reactions: {MNXR70329, BTS4, MCPST}
# 1185660.4.peg.4194 is associated with reactions: {CAT, PRDX, MNXR73934}
# 1185660.4.peg.3862 is associated with reactions: {CAT, PRDX, MNXR73934}
# 1185660.4.peg.3039 is associated with reactions: {CAT, PRDX, MNXR73934}
# 1185660.4.peg.4534 is associated with reactions: {CAT, PRDX, MNXR73934}
# 1185660.4.peg.2885 is associated with reactions: {CBIAT, CYRDAAT}
# 1185660.4.peg.2929 is associated with reactions: {CBIAT, CYRDAAT}
# 1185660.4.peg.2932 is associated with reactions: {CBL1abc}
# 1185660.4.peg.1908 is associated with reactions: {CBPS}
# 1185660.4.peg.1910 is associated with reactions: {CBPS}
# 1185660.4.peg.4230 is associated with reactions: {CD2t4pp, ZN2t4pp}
# 1185660.4.peg.3989 is associated with reactions: {CD2t4pp, ZN2t4pp}
# 1185660.4.peg.1542 is associated with reactions: {CD2t4pp, ZN2t4pp}
# 1185660.4.peg.1496 is associated with reactions: {CDPGLC46DH, URCN}
# 1185660.4.peg.977 is associated with reactions: {CDPMEK}
# 1185660.4.peg.753 is associated with reactions: {CHLt2}
# 1185660.4.peg.751 is associated with reactions: {CHOLD}
# 1185660.4.peg.3719 is associated with reactions: {CHORM}
# 1185660.4.peg.2632 is associated with reactions: {CHORS, MNXR57329}
# 1185660.4.peg.1805 is associated with reactions: {CITMCOAHm, GALCTND, MNXR7644}
# 1185660.4.peg.3316 is associated with reactions: {CITt2r}
# 1185660.4.peg.3569 is associated with reactions: {CLtex}
# 1185660.4.peg.1763 is associated with reactions: {CMS, MNXR71295}
# 1185660.4.peg.974 is associated with reactions: {MNXR17296, MNXR17297, MNXR6970, GLUTRR, COALDDH}
# 1185660.4.peg.2098 is associated with reactions: {COBALT2tex, MG2t}
# 1185660.4.peg.3922 is associated with reactions: {CPPPGO}
# 1185660.4.peg.1757 is associated with reactions: {CPS, CTPS1, CTPS2}
# 1185660.4.peg.3216 is associated with reactions: {CS}
# 1185660.4.peg.3284 is associated with reactions: {CS, IPPS}
# 1185660.4.peg.664 is associated with reactions: {CSND, GUDBUTNAH, MCSNAH}
# 1185660.4.peg.890 is associated with reactions: {SAM24MT, TMDS, CYARTMT}
# 1185660.4.peg.3677 is associated with reactions: {CYOO2pp}
# 1185660.4.peg.3680 is associated with reactions: {CYOO2pp}
# 1185660.4.peg.3491 is associated with reactions: {CYS, MNXR14768, IGPDH, SELCYSTS}
# 1185660.4.peg.4405 is associated with reactions: {CYS, MNXR14768, IGPDH, SELCYSTS}
# 1185660.4.peg.4403 is associated with reactions: {MNXR93698, CYSDS}
# 1185660.4.peg.3490 is associated with reactions: {MNXR93698, CYSDS}
# 1185660.4.peg.3699 is associated with reactions: {CYSS, CYSS_trdrd, MNXR8221}
# 1185660.4.peg.3364 is associated with reactions: {CYSS, CYSS_trdrd, MNXR8221}
# 1185660.4.peg.2081 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2080 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2968 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2969 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2970 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2971 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2332 is associated with reactions: {FRD3, CYTBD2pp, FRD7, FRD, SUCD4, CYTBO3, FRD2}
# 1185660.4.peg.1992 is associated with reactions: {CYTBD2pp, CYTBO3, HYD1}
# 1185660.4.peg.1993 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.1990 is associated with reactions: {CYTBO3}
# 1185660.4.peg.1991 is associated with reactions: {CYTBO3}
# 1185660.4.peg.2394 is associated with reactions: {FLVRx, CYTD, MNXR94426, DCYTD, MTHFC, MTHFD}
# 1185660.4.peg.2405 is associated with reactions: {CYTK1, ITCY, CYTK2}
# 1185660.4.peg.2660 is associated with reactions: {DAAD}
# 1185660.4.peg.3766 is associated with reactions: {DAAD}
# 1185660.4.peg.885 is associated with reactions: {MNXR94180, MNXR28711, MNXR94184, MNXR94181, MNXR28712, MNXR28714, MNXR8252, MNXR94182, MNXR94179, MNXR28713, DAGK160, MNXR94183, MNXR28710, MNXR28715}
# 1185660.4.peg.604 is associated with reactions: {GLYt2m, DSERt2, DALAt2pp, SERt2m}
# 1185660.4.peg.3639 is associated with reactions: {DAPDA}
# 1185660.4.peg.3638 is associated with reactions: {DAPDA}
# 1185660.4.peg.659 is associated with reactions: {GLUR, DAPE}
# 1185660.4.peg.503 is associated with reactions: {MNXR80503, DASYN180, DASYN120, MNXR80501, MNXR80505, DASYN140, DASYN181, DASYN161, DASYN160, MNXR80502, MNXR80506, DASYN141, KDOCT, MNXR80504}
# 1185660.4.peg.1658 is associated with reactions: {MNXR80503, DASYN180, DASYN120, MNXR80501, MNXR80505, DASYN140, DASYN181, DASYN161, DASYN160, MNXR80502, MNXR80506, DASYN141, KDOCT, MNXR80504}
# 1185660.4.peg.778 is associated with reactions: {DB4PS, MNXR93771, GTPCII2}
# 1185660.4.peg.3586 is associated with reactions: {DB4PS, MNXR93771, GTPCII2}
# 1185660.4.peg.3688 is associated with reactions: {DBTS}
# 1185660.4.peg.2648 is associated with reactions: {DCTPD, DCTPD2}
# 1185660.4.peg.1803 is associated with reactions: {DDGALK, MNXR8073}
# 1185660.4.peg.340 is associated with reactions: {DDGLCNt2r}
# 1185660.4.peg.99 is associated with reactions: {DDGLK}
# 1185660.4.peg.1030 is associated with reactions: {DDPA}
# 1185660.4.peg.524 is associated with reactions: {DDPA}
# 1185660.4.peg.2340 is associated with reactions: {DDPGA, EDA}
# 1185660.4.peg.1806 is associated with reactions: {DDPGALA}
# 1185660.4.peg.3663 is associated with reactions: {DHNPA2r, DDPGALA}
# 1185660.4.peg.145 is associated with reactions: {DGC3D, MNXR6834}
# 1185660.4.peg.3224 is associated with reactions: {GK2, MNXR84761, URIDK2m, GK1, DGK1, UMPK}
# 1185660.4.peg.392 is associated with reactions: {DHAD1, MNXR79704}
# 1185660.4.peg.633 is associated with reactions: {DHCIND, DHPPD}
# 1185660.4.peg.722 is associated with reactions: {FOLR2, DHFR}
# 1185660.4.peg.892 is associated with reactions: {FOLR2, DHFR, MNXR8404}
# 1185660.4.peg.1849 is associated with reactions: {DHORD5, DHORD2}
# 1185660.4.peg.1499 is associated with reactions: {DHORTS, IZPN}
# 1185660.4.peg.2015 is associated with reactions: {DHORTS, HIUH}
# 1185660.4.peg.1775 is associated with reactions: {DHPS2, MNXR1587, MNXR85709, MNXR75271}
# 1185660.4.peg.2743 is associated with reactions: {DHQS}
# 1185660.4.peg.514 is associated with reactions: {DHQTi}
# 1185660.4.peg.4039 is associated with reactions: {DHQTi}
# 1185660.4.peg.412 is associated with reactions: {DHRT_ivcoa, MNXR79575, MNXR80058}
# 1185660.4.peg.779 is associated with reactions: {DLDLBT}
# 1185660.4.peg.2670 is associated with reactions: {MNXR85248, MNXR85267, FRTT, HEXTT, DMATT, FPPSh, MNXR85270, MNXR8219, GGTT, PPTTm, rxn12008_c0, MNXR85306, MNXR94061}
# 1185660.4.peg.3117 is associated with reactions: {MNXR85248, MNXR85267, FRTT, HEXTT, DMATT, FPPSh, MNXR85270, MNXR8219, GGTT, PPTTm, rxn12008_c0, MNXR85306, MNXR94061}
# 1185660.4.peg.3280 is associated with reactions: {KARI, KARI_3hmoa, DPR, DMORh, KARI_23dhmp, KARI_23dhmb}
# 1185660.4.peg.1452 is associated with reactions: {NTD1, NTD2, MNXR84794, NTD7, NTD5, NMNHYD, NTD10, NTD4, NTD11, DMPH, GMP5N, NT5C, NTD3, NTD6}
# 1185660.4.peg.2972 is associated with reactions: {DMPPS_syn, IDS1, IPDPS, DMPPS}
# 1185660.4.peg.4569 is associated with reactions: {DNGALh, GAM, NADS1}
# 1185660.4.peg.4233 is associated with reactions: {DPR}
# 1185660.4.peg.3888 is associated with reactions: {DTMPK}
# 1185660.4.peg.4131 is associated with reactions: {DURIK1, MNXR87173, TMDK1}
# 1185660.4.peg.181 is associated with reactions: {DUTPDP, MNXR55989}
# 1185660.4.peg.3789 is associated with reactions: {DUTPDP}
# 1185660.4.peg.1657 is associated with reactions: {DXPRIi}
# 1185660.4.peg.2487 is associated with reactions: {DXPS}
# 1185660.4.peg.3376 is associated with reactions: {GAPD, E4PD}
# 1185660.4.peg.375 is associated with reactions: {EAR100y, MNXR27648, MNXR27737, MNXR27661, MNXR27686, EAR120y, MNXR27681, MNXR27640, MNXR27673, EAR140y, MNXR27694, MNXR27644, MNXR27698, EAR40y, MNXR27652, MNXR27690, EAR60y, MNXR27702, MNXR27669, EAR80y, MNXR27677, MNXR27636, MNXR74373, MNXR27665, MNXR27706, MNXR27656}
# 1185660.4.peg.2984 is associated with reactions: {ECOAH12, ECOAH3, MNXR59771, ECOAH4, ECOAH5, ECOAH9ir, ECOAH6, ECOAH7, ECOAH1, MNXR4458}
# 1185660.4.peg.2234 is associated with reactions: {HACD2, HADPCOADH3, MNXR17653, ECOAH4, ECOAH12, MNXR17657, MNXR16204, HACD5, ECOAH5, HACD6, HACD9, ECOAH7, ECOAH1, MNXR17833, MNXR4458, MNXR5449, ECOAH3, MNXR59771, ECOAH6, ECOAH9ir, HACDp, HACD4, MNXR84520, HIBDkt, HACD1, HACD3, MNXR17649, HACD7}
# 1185660.4.peg.1440 is associated with reactions: {ECOAH12, ECOAH3, MNXR59771, ECOAH4, ECOAH5, ECOAH9ir, ECOAH6, ECOAH7, ECOAH1, MNXR4458}
# 1185660.4.peg.1548 is associated with reactions: {ECOAH12, ECOAH9ir, MNXR6494, HACD9, MNXR4458, HACD3, MNXR59771, HIBDkt, HACD1, MNXR17649, HACD2, MNXR17653, ECOAH4, MNXR17657, HACD5, ECOAH3, ECOAH5, HACD6, ECOAH7, ECOAH1, MNXR17833, HACDp, MNXR5449, HADPCOADH3, ECOAH6, LYSRC, MNXR40035, MNXR16204, HACD4, MNXR6493, MNXR84520, HACD7}
# 1185660.4.peg.912 is associated with reactions: {ECOAH12, ECOAH3, MNXR59771, ECOAH4, ECOAH5, ECOAH9ir, ECOAH6, ECOAH7, ECOAH1, MNXR4458}
# 1185660.4.peg.1538 is associated with reactions: {ECOAH12, HACD2, HACD3, HADPCOADH3, HACD4, ECOAH9ir, HACD5, HACD6, HACD7, HACD1, HACD9}
# 1185660.4.peg.2339 is associated with reactions: {EDD, MNXR4458}
# 1185660.4.peg.3295 is associated with reactions: {EDTXS1}
# 1185660.4.peg.3583 is associated with reactions: {EDTXS1}
# 1185660.4.peg.1761 is associated with reactions: {ENO}
# 1185660.4.peg.2020 is associated with reactions: {ETHAAL}
# 1185660.4.peg.2019 is associated with reactions: {ETHAAL}
# 1185660.4.peg.2018 is associated with reactions: {ETHAt2pp}
# 1185660.4.peg.1648 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3168 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.87 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.88 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.811 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1754 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3601 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3669 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1148 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.580 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1127 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1493 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.2559 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.4372 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3977 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.90 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3116 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1299 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.4515 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3616 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1684 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1489 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.2424 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.2423 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1475 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1300 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1485 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1226 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.4396 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.2592 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1010 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.4047 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.4046 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1515 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2887 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1009 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1625 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1786 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.85 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1870 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.992 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2561 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1025 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3217 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1023 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1006 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1021 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3594 is associated with reactions: {EX_protein_e, GLUFORT, GLUFT}
# 1185660.4.peg.1001 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1002 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3070 is associated with reactions: {EX_protein_e, GLUTRS}
# 1185660.4.peg.2513 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.989 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2510 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1008 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2516 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2514 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2979 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2978 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.999 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3987 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3475 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1003 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2973 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1976 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2976 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1022 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.987 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3792 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3879 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1005 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1004 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1019 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1007 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3988 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.460 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.461 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1482 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1000 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.4539 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1018 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1664 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3772 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1917 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.993 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1013 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1012 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1011 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2406 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1017 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1016 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1015 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1014 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2668 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3665 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.4542 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.988 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1480 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1139 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2511 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1483 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1484 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2010 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.749 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.990 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.991 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.3581 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.4540 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.1556 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.84 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.1024 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.2596 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.769 is associated with reactions: {PTE5x, MNXR60689, MNXR60685, FA100ACPHi, FA80ACPHi, MNXR60692, MNXR60686, MNXR59886, MNXR60687, MNXR85362, MNXR85739, MNXR62992, MNXR17916, MNXR60688, MNXR74722}
# 1185660.4.peg.2982 is associated with reactions: {FACOAE180, FACOAE160, MNXR60681, FACOAE1836Z9Z12Z, MNXR60682, MNXR85731, MNXR10705, MNXR17904, MNXR60684, MNXR1991, MNXR17903}
# 1185660.4.peg.3367 is associated with reactions: {FBA, FBA3}
# 1185660.4.peg.1875 is associated with reactions: {FBP, IGPDH, HISTP, SBP}
# 1185660.4.peg.118 is associated with reactions: {FBP}
# 1185660.4.peg.4059 is associated with reactions: {FCLT}
# 1185660.4.peg.2120 is associated with reactions: {FDH}
# 1185660.4.peg.2121 is associated with reactions: {FDH}
# 1185660.4.peg.1902 is associated with reactions: {FE2abc}
# 1185660.4.peg.2856 is associated with reactions: {FERO, MNXR7459}
# 1185660.4.peg.3174 is associated with reactions: {FGFTh, FPGFTh, FOMETRi, GCCb, GLYCL}
# 1185660.4.peg.2140 is associated with reactions: {FK, FRUK, PFK_2}
# 1185660.4.peg.337 is associated with reactions: {MNXR15642, FMNRx, MNXR7594}
# 1185660.4.peg.2331 is associated with reactions: {FRD, FRD2, FRD7, FRD3, SUCD4}
# 1185660.4.peg.2330 is associated with reactions: {FRD, FRD2, FRD7, FRD3, SUCD4}
# 1185660.4.peg.2328 is associated with reactions: {FRD, FRD2, FRD7, FRD3, SUCD4}
# 1185660.4.peg.2141 is associated with reactions: {FRUpts}
# 1185660.4.peg.1659 is associated with reactions: {FT, MNXR55990}
# 1185660.4.peg.3239 is associated with reactions: {FTCL, UAAGLS1}
# 1185660.4.peg.325 is associated with reactions: {FTHFD}
# 1185660.4.peg.1324 is associated with reactions: {FUM}
# 1185660.4.peg.1397 is associated with reactions: {FUM}
# 1185660.4.peg.139 is associated with reactions: {SUCCt2b, FUMt2r}
# 1185660.4.peg.3717 is associated with reactions: {UAGDP, MNXR75220, MNXR75221, MNXR75218, MNXR60581, MNXR75248, G1PACT, MNXR75249}
# 1185660.4.peg.3421 is associated with reactions: {G1PTT}
# 1185660.4.peg.3247 is associated with reactions: {G1SAT}
# 1185660.4.peg.4083 is associated with reactions: {G1SAT}
# 1185660.4.peg.4105 is associated with reactions: {MNXR28663, G3PAT161, MNXR92341, G3PAT180, MNXR28662, G3PAT181, G3PAT120, G3PAT140, MNXR28664, MNXR28665, G3PAT141, MNXR28666, G3PAT160, MNXR28660, MNXR28667, G3PAT160_1}
# 1185660.4.peg.640 is associated with reactions: {G3PD6, G3PD, G3PD5, G3PD7}
# 1185660.4.peg.202 is associated with reactions: {G3PD1}
# 1185660.4.peg.2625 is associated with reactions: {SERH, TRPS2, G3PL}
# 1185660.4.peg.4208 is associated with reactions: {PPBNGS, SERH, TRPS2, G3PL}
# 1185660.4.peg.2623 is associated with reactions: {SERH, TRPS2, G3PL}
# 1185660.4.peg.1998 is associated with reactions: {G5DHx}
# 1185660.4.peg.4250 is associated with reactions: {G6PBDH, G6PDH2r}
# 1185660.4.peg.2336 is associated with reactions: {G6PBDH, G6PDH2r}
# 1185660.4.peg.746 is associated with reactions: {G6PDA}
# 1185660.4.peg.1829 is associated with reactions: {G6PI, G6PI3, PGI, XYLI1, XYLI2}
# 1185660.4.peg.3784 is associated with reactions: {TDPGDH, GALCTD}
# 1185660.4.peg.3422 is associated with reactions: {TDPGDH, GALCTD}
# 1185660.4.peg.182 is associated with reactions: {GALh, GLNSP1, GLNSP3, GLNSP2}
# 1185660.4.peg.4549 is associated with reactions: {X5PL3E, GALM1}
# 1185660.4.peg.2398 is associated with reactions: {GALUi}
# 1185660.4.peg.2099 is associated with reactions: {SSALx, GAPDH_nadp_hi}
# 1185660.4.peg.2992 is associated with reactions: {GART}
# 1185660.4.peg.3732 is associated with reactions: {GCC2cm}
# 1185660.4.peg.3027 is associated with reactions: {GCCc, GCCa}
# 1185660.4.peg.2786 is associated with reactions: {GCCb, GCCc}
# 1185660.4.peg.2787 is associated with reactions: {GCCb}
# 1185660.4.peg.760 is associated with reactions: {GCL}
# 1185660.4.peg.2135 is associated with reactions: {GDH}
# 1185660.4.peg.3708 is associated with reactions: {GF6PTA}
# 1185660.4.peg.772 is associated with reactions: {GHMT}
# 1185660.4.peg.2334 is associated with reactions: {GLCabcpp, MALTabc, MNXR86939}
# xanmn_chr13_0041 is associated with reactions: {GLNabc}
# 1185660.4.peg.1999 is associated with reactions: {GLU5K}
# 1185660.4.peg.2337 is associated with reactions: {GLUK_syn, HEX1}
# 1185660.4.peg.1228 is associated with reactions: {GLUS_nadph}
# 1185660.4.peg.31 is associated with reactions: {GLUS_nadph}
# 1185660.4.peg.32 is associated with reactions: {GLUS_nadph}
# 1185660.4.peg.4102 is associated with reactions: {GLUS_nadph}
# 1185660.4.peg.3201 is associated with reactions: {GLUt2r}
# 1185660.4.peg.2666 is associated with reactions: {GLUt2r}
# 1185660.4.peg.1337 is associated with reactions: {GLUTCOADHc}
# 1185660.4.peg.933 is associated with reactions: {MNXR47135, MNXR40622, TALA, GLYAMDTRc}
# 1185660.4.peg.1045 is associated with reactions: {GLYAT}
# 1185660.4.peg.159 is associated with reactions: {GLYBabc, PROabc}
# 1185660.4.peg.160 is associated with reactions: {GLYBabc, PROabc}
# 1185660.4.peg.2631 is associated with reactions: {GLYCDH_1, GLYCLTDy, GLYCLTDx, GLYCOR_nadp}
# 1185660.4.peg.1376 is associated with reactions: {GLYCK2, PYDAMK, GLYCK, PYDXK, PYDXNK}
# 1185660.4.peg.639 is associated with reactions: {GLYCt}
# 1185660.4.peg.638 is associated with reactions: {GLYK, MNXR8269}
# 1185660.4.peg.2392 is associated with reactions: {GMPS2}
# 1185660.4.peg.4053 is associated with reactions: {GMPS2}
# 1185660.4.peg.715 is associated with reactions: {GND}
# 1185660.4.peg.4036 is associated with reactions: {GNK}
# 1185660.4.peg.1567 is associated with reactions: {GPAR, HXPRT, XPPT}
# 1185660.4.peg.78 is associated with reactions: {GPDDA2, GPDDA1, GPDDA4}
# 1185660.4.peg.1164 is associated with reactions: {GPDDA2, GPDDA1, GPDDA4}
# 1185660.4.peg.1823 is associated with reactions: {MNXR85297, MNXR73656, MNXR74388, MNXR74304, GTPCI}
# 1185660.4.peg.4161 is associated with reactions: {MNXR85297, MNXR73656, MNXR74388, MNXR74304, GTPCI}
# 1185660.4.peg.2847 is associated with reactions: {GTPDPK}
# 1185660.4.peg.1209 is associated with reactions: {GTPDPK}
# 1185660.4.peg.3221 is associated with reactions: {PPGPPDP, GTPDPK}
# 1185660.4.peg.1462 is associated with reactions: {HCO3E}
# 1185660.4.peg.4248 is associated with reactions: {HCO3E}
# 1185660.4.peg.1437 is associated with reactions: {HCO3E}
# 1185660.4.peg.1327 is associated with reactions: {HCO3E}
# 1185660.4.peg.14 is associated with reactions: {OCDCAt2, HDCAt2, TTDCAt2}
# 1185660.4.peg.1873 is associated with reactions: {MNXR58251, HDH, MNXR59227}
# 1185660.4.peg.1094 is associated with reactions: {HEPT2}
# 1185660.4.peg.426 is associated with reactions: {HGNTOR}
# 1185660.4.peg.1540 is associated with reactions: {HIBDkt}
# 1185660.4.peg.1498 is associated with reactions: {HISDr, MNXR93681}
# 1185660.4.peg.785 is associated with reactions: {HKt}
# 1185660.4.peg.787 is associated with reactions: {HKt}
# 1185660.4.peg.786 is associated with reactions: {HKt}
# 1185660.4.peg.1458 is associated with reactions: {MNXR80323, HKYNH}
# 1185660.4.peg.646 is associated with reactions: {HMBS}
# 1185660.4.peg.1897 is associated with reactions: {HMGL, MNXR6311, NPHS}
# 1185660.4.peg.1896 is associated with reactions: {HMGL, MNXR6311, NPHS}
# 1185660.4.peg.721 is associated with reactions: {HPPK2}
# 1185660.4.peg.1825 is associated with reactions: {HPPK2}
# 1185660.4.peg.2759 is associated with reactions: {HSDx, HSDH}
# 1185660.4.peg.2761 is associated with reactions: {MNXR7792, HSERTA}
# 1185660.4.peg.2762 is associated with reactions: {MNXR7792, HSERTA}
# 1185660.4.peg.1988 is associated with reactions: {MNXR7792, HSERTA}
# 1185660.4.peg.1861 is associated with reactions: {HSK, PYDAMK, PYDXK, PYDXNK}
# 1185660.4.peg.2760 is associated with reactions: {MNXR15065, MNXR79604, SHSL4h, HSPMS, MNXR8129}
# 1185660.4.peg.1213 is associated with reactions: {HXAND, XAND}
# 1185660.4.peg.3113 is associated with reactions: {HXAND, XAND}
# 1185660.4.peg.307 is associated with reactions: {HXANt2pp}
# 1185660.4.peg.1077 is associated with reactions: {ICDHx}
# 1185660.4.peg.242 is associated with reactions: {ICL}
# 1185660.4.peg.3270 is associated with reactions: {IDPh}
# 1185660.4.peg.1876 is associated with reactions: {IG3PS}
# 1185660.4.peg.1878 is associated with reactions: {IG3PS}
# 1185660.4.peg.706 is associated with reactions: {MNXR65498, NAPT, PUNP7, IG3PS}
# 1185660.4.peg.454 is associated with reactions: {IGPS}
# 1185660.4.peg.3286 is associated with reactions: {IMDHT, IMDHT_3c2hmp}
# 1185660.4.peg.2393 is associated with reactions: {IMPD}
# 1185660.4.peg.2768 is associated with reactions: {IMPD}
# 1185660.4.peg.3285 is associated with reactions: {MNXR14719, IPMD, OMCDC}
# 1185660.4.peg.2317 is associated with reactions: {KDOCT, MNXR73710}
# 1185660.4.peg.2695 is associated with reactions: {KDOPP}
# 1185660.4.peg.1759 is associated with reactions: {KDOPS}
# 1185660.4.peg.1275 is associated with reactions: {Kt1}
# 1185660.4.peg.1457 is associated with reactions: {KYN3OX, MNXR71411}
# 1185660.4.peg.1853 is associated with reactions: {LCADi}
# 1185660.4.peg.477 is associated with reactions: {MNXR94199, LPLIPAL2A160, LPLIPAL1A140pp, MNXR6274, LPLIPAL2A180, LPLIPAL1A141pp, MNXR80382, MNXR94202, LPLIPAL1A160pp, MNXR80383, LPLIPAL1A180pp, MNXR80385, LPLIPAL2A140, MNXR94218, MNXR94217, MNXR94219, MNXR3312, LPLIPAL2A141, MNXR94221, MNXR94195, MNXR94196, MNXR69346, LPLIPAL2A120, LPLIPAL2E160, MNXR94197, MNXR69337, MNXR94194, MNXR94224, MNXR3279, MNXR80380, MNXR94225, MNXR69352, MNXR94201, MNXR94226, MNXR94223, LPLIPAL2E180, MNXR94227, MNXR3277, MNXR94200, MNXR94198, MNXR94222, LPLIPAL1A120pp, MNXR94220}
# 1185660.4.peg.2865 is associated with reactions: {LYSt2m}
# 1185660.4.peg.241 is associated with reactions: {MALS, MCITS}
# 1185660.4.peg.2522 is associated with reactions: {MALT}
# 1185660.4.peg.4068 is associated with reactions: {MALT}
# 1185660.4.peg.1813 is associated with reactions: {MALT}
# 1185660.4.peg.2526 is associated with reactions: {MALT}
# 1185660.4.peg.3193 is associated with reactions: {MALT}
# 1185660.4.peg.3417 is associated with reactions: {MAN6PI, MAN1PT2, rxn01292_c0}
# 1185660.4.peg.4073 is associated with reactions: {MANAO}
# 1185660.4.peg.2704 is associated with reactions: {MANpts}
# 1185660.4.peg.859 is associated with reactions: {MATm}
# 1185660.4.peg.255 is associated with reactions: {MCCC}
# 1185660.4.peg.254 is associated with reactions: {MCCC}
# 1185660.4.peg.1155 is associated with reactions: {MCITD}
# 1185660.4.peg.1154 is associated with reactions: {MCITS, MNXR71184}
# 1185660.4.peg.1142 is associated with reactions: {MNXR53364, MNXR78083, MNXR53365, MNXR53359, MNXR53362, MNXR53361, MNXR53360, MNXR53366, MNXR53357, MNXR53358, MNXR53363, MNXR53368, MCOATA}
# 1185660.4.peg.1764 is associated with reactions: {MCS, rxn02362_c0}
# 1185660.4.peg.1036 is associated with reactions: {MDH}
# 1185660.4.peg.3300 is associated with reactions: {MDHC_nadp_hr}
# 1185660.4.peg.1843 is associated with reactions: {MECDPDH2}
# 1185660.4.peg.3743 is associated with reactions: {METDabc, METSOX1abcpp, MNXR27805, METabc}
# 1185660.4.peg.3742 is associated with reactions: {METDabc, METSOX1abcpp, MNXR27805, METabc}
# 1185660.4.peg.930 is associated with reactions: {METSOXR1}
# 1185660.4.peg.1900 is associated with reactions: {MGC}
# 1185660.4.peg.2036 is associated with reactions: {MI3PP, MI1PP, MI4PP}
# 1185660.4.peg.1624 is associated with reactions: {PSP, MIHKPP}
# 1185660.4.peg.455 is associated with reactions: {PSP, MIHKPP}
# 1185660.4.peg.1536 is associated with reactions: {MMSDH, MMSAD3}
# ...
# 1185660.4.peg.459 is associated with reactions: {MNXR60025}
# 1185660.4.peg.902 is associated with reactions: {MNXR60025}
# 1185660.4.peg.1837 is associated with reactions: {MNXR93798, MNXR6106, MNXR93845, MNXR93797, MNXR93716, MNXR93844}
# 1185660.4.peg.1804 is associated with reactions: {MNXR6164}
# 1185660.4.peg.3107 is associated with reactions: {MNXR61873}
# 1185660.4.peg.3371 is associated with reactions: {MNXR6283, PGLYCP}
# 1185660.4.peg.3692 is associated with reactions: {MNXR6283, PGLYCP}
# 1185660.4.peg.1497 is associated with reactions: {MNXR6539, NFORGLUAH}
# 1185660.4.peg.3611 is associated with reactions: {MNXR6555}
# 1185660.4.peg.3213 is associated with reactions: {MNXR67415}
# 1185660.4.peg.2843 is associated with reactions: {MNXR67415}
# 1185660.4.peg.4095 is associated with reactions: {MNXR90744, MNXR69161}
# 1185660.4.peg.2593 is associated with reactions: {MNXR70083}
# 1185660.4.peg.285 is associated with reactions: {MNXR70083}
# 1185660.4.peg.3755 is associated with reactions: {MNXR70083}
# 1185660.4.peg.2837 is associated with reactions: {MNXR70083}
# 1185660.4.peg.4566 is associated with reactions: {MNXR70083}
# 1185660.4.peg.2089 is associated with reactions: {MNXR70083}
# 1185660.4.peg.2628 is associated with reactions: {MNXR70083}
# 1185660.4.peg.2862 is associated with reactions: {MNXR70083}
# 1185660.4.peg.149 is associated with reactions: {MNXR70958, PHETHPTOX}
# 1185660.4.peg.945 is associated with reactions: {MNXR71149, TMDPP}
# 1185660.4.peg.3230 is associated with reactions: {MNXR71149, TMDPP}
# 1185660.4.peg.1241 is associated with reactions: {MNXR71171, MNXR85555, rxn03893_c0}
# 1185660.4.peg.1510 is associated with reactions: {PPNDH, MNXR7133}
# 1185660.4.peg.4025 is associated with reactions: {MNXR7136}
# 1185660.4.peg.1776 is associated with reactions: {MNXR71500}
# 1185660.4.peg.2627 is associated with reactions: {PRAI, MNXR71594}
# 1185660.4.peg.3790 is associated with reactions: {PEPCK, PPNCL3, MNXR71850, PPNCL2, PPCDC}
# 1185660.4.peg.3138 is associated with reactions: {P5CR, MNXR7297, P5CRx}
# 1185660.4.peg.1130 is associated with reactions: {MNXR73713}
# 1185660.4.peg.516 is associated with reactions: {MNXR7442}
# 1185660.4.peg.1826 is associated with reactions: {MNXR7721, MOHMT}
# 1185660.4.peg.3321 is associated with reactions: {MNXR79288}
# 1185660.4.peg.2692 is associated with reactions: {UAGCVT, MNXR79735}
# 1185660.4.peg.415 is associated with reactions: {MNXR80308, MOD_4mop, MOD_3mhtpp, MNXR80306, MOD, MNXR80309}
# 1185660.4.peg.414 is associated with reactions: {MNXR80308, MOD_4mop, MOD_3mhtpp, MNXR80306, MOD, MNXR80309}
# 1185660.4.peg.393 is associated with reactions: {MNXR80378}
# 1185660.4.peg.3276 is associated with reactions: {MNXR80464}
# 1185660.4.peg.4173 is associated with reactions: {MNXR80556, MNXR80553, MNXR80557, MNXR94338, MNXR80558, MNXR80559, MNXR80560, MNXR80561, MNXR80555}
# 1185660.4.peg.3980 is associated with reactions: {MNXR80556, MNXR80553, MNXR80557, MNXR94338, MNXR80558, MNXR80559, MNXR80560, MNXR80561, MNXR80555}
# 1185660.4.peg.4257 is associated with reactions: {MNXR80556, MNXR80553, MNXR80557, MNXR94338, MNXR80558, MNXR80559, MNXR80560, MNXR80561, MNXR80555}
# 1185660.4.peg.9 is associated with reactions: {MNXR80556, MNXR80553, MNXR80557, MNXR94338, MNXR80558, MNXR80559, MNXR80560, MNXR80561, MNXR80555}
# 1185660.4.peg.901 is associated with reactions: {MNXR80794}
# 1185660.4.peg.1287 is associated with reactions: {MNXR8203, THDPS}
# 1185660.4.peg.1071 is associated with reactions: {MNXR8303}
# 1185660.4.peg.1286 is associated with reactions: {MNXR8328}
# 1185660.4.peg.673 is associated with reactions: {MNXR84532}
# 1185660.4.peg.162 is associated with reactions: {THZPSN, MNXR84885}
# 1185660.4.peg.3682 is associated with reactions: {MNXR85051, PROD2, P5CD, PUTA3}
# 1185660.4.peg.2619 is associated with reactions: {PGAMT, MNXR85058}
# 1185660.4.peg.3769 is associated with reactions: {MNXR85179}
# 1185660.4.peg.1298 is associated with reactions: {MNXR85205}
# 1185660.4.peg.2085 is associated with reactions: {MNXR85277}
# 1185660.4.peg.1816 is associated with reactions: {XYLI2, MNXR85335, XYLI1}
# 1185660.4.peg.4064 is associated with reactions: {XYLI2, MNXR85335, XYLI1}
# 1185660.4.peg.1169 is associated with reactions: {MNXR85754, MNXR85534}
# 1185660.4.peg.147 is associated with reactions: {MNXR85856}
# 1185660.4.peg.1488 is associated with reactions: {MNXR8691, PHETA1}
# 1185660.4.peg.3251 is associated with reactions: {MNXR8691, PHETA1}
# 1185660.4.peg.2797 is associated with reactions: {MNXR87148}
# 1185660.4.peg.2853 is associated with reactions: {MNXR87148}
# 1185660.4.peg.7 is associated with reactions: {MNXR8716}
# 1185660.4.peg.3200 is associated with reactions: {TKT1, MNXR8742, TKT2}
# 1185660.4.peg.2008 is associated with reactions: {MNXR8742, OXAMTC}
# 1185660.4.peg.543 is associated with reactions: {MNXR8903}
# 1185660.4.peg.542 is associated with reactions: {MNXR8903}
# 1185660.4.peg.547 is associated with reactions: {MNXR8903}
# 1185660.4.peg.546 is associated with reactions: {MNXR8903}
# 1185660.4.peg.545 is associated with reactions: {MNXR8903}
# 1185660.4.peg.544 is associated with reactions: {MNXR8903}
# 1185660.4.peg.548 is associated with reactions: {MNXR8903}
# 1185660.4.peg.609 is associated with reactions: {MNXR93624}
# 1185660.4.peg.3404 is associated with reactions: {MNXR93625, NAPRT}
# 1185660.4.peg.917 is associated with reactions: {MNXR93694}
# 1185660.4.peg.1583 is associated with reactions: {MNXR93748, MNXR93704, MNXR93945, MNXR93966, MNXR93946, MNXR93715}
# 1185660.4.peg.1879 is associated with reactions: {MNXR93746, PRADPh, PRACHh}
# 1185660.4.peg.2465 is associated with reactions: {MNXR93752, PRACHh}
# 1185660.4.peg.1500 is associated with reactions: {MNXR93753}
# 1185660.4.peg.2028 is associated with reactions: {MNXR93774}
# 1185660.4.peg.3595 is associated with reactions: {MNXR93864, MNXR93865}
# 1185660.4.peg.3339 is associated with reactions: {MNXR93864, MNXR93865}
# 1185660.4.peg.1032 is associated with reactions: {UREA, MNXR94094}
# 1185660.4.peg.396 is associated with reactions: {MNXR94165, MNXR94164, MNXR94163, MNXR94166}
# 1185660.4.peg.4561 is associated with reactions: {MNXR94190}
# 1185660.4.peg.1451 is associated with reactions: {MNXR94325, NADK}
# 1185660.4.peg.3294 is associated with reactions: {MOAT2, MOAT}
# 1185660.4.peg.3416 is associated with reactions: {MPPM}
# 1185660.4.peg.3788 is associated with reactions: {PC8XM, PGMT, MPPM, rxn04052_c0}
# 1185660.4.peg.1568 is associated with reactions: {MTAP}
# 1185660.4.peg.833 is associated with reactions: {MTHFO, MTHFO_nadp}
# 1185660.4.peg.334 is associated with reactions: {MTHFO, MTHFO_nadp}
# 1185660.4.peg.131 is associated with reactions: {MTI}
# 1185660.4.peg.1492 is associated with reactions: {MTRI}
# 1185660.4.peg.798 is associated with reactions: {MUCCY_kt}
# 1185660.4.peg.3500 is associated with reactions: {NA1Hth}
# 1185660.4.peg.2385 is associated with reactions: {NADH5, NADH10, NADH9}
# 1185660.4.peg.2606 is associated with reactions: {NADH6}
# 1185660.4.peg.2599 is associated with reactions: {NADH6}
# 1185660.4.peg.2598 is associated with reactions: {NADH6}
# 1185660.4.peg.2607 is associated with reactions: {NADH6}
# 1185660.4.peg.2609 is associated with reactions: {NADH6}
# 1185660.4.peg.2608 is associated with reactions: {NADH6}
# 1185660.4.peg.2610 is associated with reactions: {NADH6}
# 1185660.4.peg.2611 is associated with reactions: {NADH6}
# 1185660.4.peg.2605 is associated with reactions: {NADH6}
# 1185660.4.peg.2604 is associated with reactions: {NADH6}
# 1185660.4.peg.2603 is associated with reactions: {NADH6}
# 1185660.4.peg.2602 is associated with reactions: {NADH6}
# 1185660.4.peg.2601 is associated with reactions: {NADH6}
# 1185660.4.peg.2600 is associated with reactions: {NADH6}
# 1185660.4.peg.950 is associated with reactions: {NADTRHD, THD2}
# 1185660.4.peg.946 is associated with reactions: {NADTRHD, THD2}
# 1185660.4.peg.184 is associated with reactions: {NH4t}
# 1185660.4.peg.3442 is associated with reactions: {NMNTP}
# 1185660.4.peg.2926 is associated with reactions: {NNDMBRT}
# 1185660.4.peg.2588 is associated with reactions: {NNDPR}
# 1185660.4.peg.2207 is associated with reactions: {NO2t2r, NO3t2}
# 1185660.4.peg.2205 is associated with reactions: {NO3R2, NTRIR2x, NO3R1}
# 1185660.4.peg.2206 is associated with reactions: {NTRIR2x, NTRIR2y, NO3R2}
# 1185660.4.peg.1767 is associated with reactions: {NTD1}
# 1185660.4.peg.3415 is associated with reactions: {OCOAT1}
# 1185660.4.peg.1509 is associated with reactions: {PSAT, OHPBAT}
# 1185660.4.peg.4114 is associated with reactions: {OMPDC}
# 1185660.4.peg.138 is associated with reactions: {OP4ENH}
# 1185660.4.peg.3780 is associated with reactions: {ORPT}
# 1185660.4.peg.903 is associated with reactions: {OXOAEL}
# 1185660.4.peg.905 is associated with reactions: {OXOAEL}
# 1185660.4.peg.1929 is associated with reactions: {OXOAEL}
# 1185660.4.peg.799 is associated with reactions: {OXOAEL}
# 1185660.4.peg.1827 is associated with reactions: {PANTS}
# 1185660.4.peg.907 is associated with reactions: {PCADYOX}
# 1185660.4.peg.710 is associated with reactions: {PCADYOX}
# 1185660.4.peg.711 is associated with reactions: {PCADYOX}
# xanmn_chr13_0065 is associated with reactions: {PDH}
# xanmn_chr03_0256 is associated with reactions: {PDH}
# xanmn_chr13_0067 is associated with reactions: {PDH}
# 1185660.4.peg.559 is associated with reactions: {PDHam1hi, PDHam2hi}
# 1185660.4.peg.3734 is associated with reactions: {PDHbr}
# 1185660.4.peg.3735 is associated with reactions: {PDHbr}
# 1185660.4.peg.2023 is associated with reactions: {PDX5POi, PYAM5PO}
# 1185660.4.peg.1747 is associated with reactions: {PDX5POi, PYAM5PO}
# 1185660.4.peg.4422 is associated with reactions: {PDX5POi, PYAM5PO}
# 1185660.4.peg.2203 is associated with reactions: {PDX5POi, PYAM5PO}
# 1185660.4.peg.2742 is associated with reactions: {PDX5POi, PYAM5PO}
# 1185660.4.peg.17 is associated with reactions: {PGCD}
# 1185660.4.peg.1889 is associated with reactions: {PGCD}
# 1185660.4.peg.2338 is associated with reactions: {PGL}
# 1185660.4.peg.117 is associated with reactions: {PHETA1}
# 1185660.4.peg.1434 is associated with reactions: {PIabc}
# 1185660.4.peg.1432 is associated with reactions: {PIabc}
# 1185660.4.peg.1431 is associated with reactions: {PIabc}
# 1185660.4.peg.1430 is associated with reactions: {PIabc}
# 1185660.4.peg.1429 is associated with reactions: {PIabc}
# 1185660.4.peg.3939 is associated with reactions: {PNTK}
# 1185660.4.peg.204 is associated with reactions: {POX}
# 1185660.4.peg.493 is associated with reactions: {PPRGL}
# 1185660.4.peg.2361 is associated with reactions: {PPS}
# 1185660.4.peg.3171 is associated with reactions: {PRAISh, PRAIS}
# 1185660.4.peg.444 is associated with reactions: {PRAISh}
# 1185660.4.peg.4309 is associated with reactions: {PRFGS}
# 1185660.4.peg.4324 is associated with reactions: {PRFGS}
# 1185660.4.peg.3465 is associated with reactions: {PRFGS}
# 1185660.4.peg.1877 is associated with reactions: {PRICIh}
# 1185660.4.peg.727 is associated with reactions: {PROAKGOX1}
# 1185660.4.peg.1584 is associated with reactions: {PROAKGOX1}
# 1185660.4.peg.354 is associated with reactions: {PROt2r}
# 1185660.4.peg.978 is associated with reactions: {PRPPS}
# 1185660.4.peg.1511 is associated with reactions: {PSCIT}
# 1185660.4.peg.2954 is associated with reactions: {PSP, PSP_D}
# 1185660.4.peg.2102 is associated with reactions: {SPMDabc, PTRCabc}
# 1185660.4.peg.2103 is associated with reactions: {SPMDabc, PTRCabc}
# 1185660.4.peg.2101 is associated with reactions: {SPMDabc, PTRCabc}
# 1185660.4.peg.3369 is associated with reactions: {PYK}
# 1185660.4.peg.1051 is associated with reactions: {R01465m}
# 1185660.4.peg.777 is associated with reactions: {RBFSb}
# 1185660.4.peg.4241 is associated with reactions: {RNDR1, RNDR2, RNDR3, RNDR4}
# 1185660.4.peg.4242 is associated with reactions: {RNDR1, RNDR2, RNDR3, RNDR4}
# 1185660.4.peg.3420 is associated with reactions: {RPE, TDPDRE}
# 1185660.4.peg.3241 is associated with reactions: {RPI}
# 1185660.4.peg.2801 is associated with reactions: {rxn00016_c0}
# 1185660.4.peg.4092 is associated with reactions: {rxn01080_c0, rxn01457_c0}
# 1185660.4.peg.2256 is associated with reactions: {rxn06181_c0}
# 1185660.4.peg.2519 is associated with reactions: {rxn06453_c0}
# 1185660.4.peg.1653 is associated with reactions: {rxn06723_c0}
# 1185660.4.peg.4551 is associated with reactions: {rxn09988_c0}
# 1185660.4.peg.1095 is associated with reactions: {rxn13990_c0}
# 1185660.4.peg.2925 is associated with reactions: {RZ5PP}
# 1185660.4.peg.3353 is associated with reactions: {SADT, SADT2}
# 1185660.4.peg.3428 is associated with reactions: {SBTPD}
# 1185660.4.peg.1289 is associated with reactions: {SDPDS}
# 1185660.4.peg.2756 is associated with reactions: {SERD_L}
# 1185660.4.peg.4204 is associated with reactions: {SHK3Dr}
# 1185660.4.peg.3568 is associated with reactions: {SO4t2}
# 1185660.4.peg.620 is associated with reactions: {SO4t2}
# 1185660.4.peg.2584 is associated with reactions: {SPODM}
# 1185660.4.peg.2037 is associated with reactions: {SPODM}
# 1185660.4.peg.187 is associated with reactions: {SPODM}
# 1185660.4.peg.188 is associated with reactions: {SPODM}
# 1185660.4.peg.910 is associated with reactions: {SUCBZL}
# 1185660.4.peg.4573 is associated with reactions: {SUCLm}
# 1185660.4.peg.4572 is associated with reactions: {SUCLm}
# 1185660.4.peg.1529 is associated with reactions: {SUCRe}
# 1185660.4.peg.2799 is associated with reactions: {SUCRe}
# xanmn_chr08_0051 is associated with reactions: {SUCRt2}
# 1185660.4.peg.1048 is associated with reactions: {SULabc}
# 1185660.4.peg.1049 is associated with reactions: {SULabc, TSULabc}
# 1185660.4.peg.1046 is associated with reactions: {SULabc, TSULabc}
# 1185660.4.peg.1047 is associated with reactions: {SULabc}
# 1185660.4.peg.3354 is associated with reactions: {SULR}
# 1185660.4.peg.3355 is associated with reactions: {SULR}
# 1185660.4.peg.1107 is associated with reactions: {TAL}
# 1185660.4.peg.3283 is associated with reactions: {TAL}
# 1185660.4.peg.876 is associated with reactions: {TAUDO}
# 1185660.4.peg.873 is associated with reactions: {TAURabc}
# 1185660.4.peg.875 is associated with reactions: {TAURabc}
# 1185660.4.peg.874 is associated with reactions: {TAURabc}
# 1185660.4.peg.3419 is associated with reactions: {TDPDRR}
# 1185660.4.peg.1206 is associated with reactions: {TDSRh}
# 1185660.4.peg.1207 is associated with reactions: {TDSRh}
# 1185660.4.peg.2243 is associated with reactions: {TDSRh}
# 1185660.4.peg.596 is associated with reactions: {TDSRh}
# 1185660.4.peg.3628 is associated with reactions: {THIORDXi}
# 1185660.4.peg.4558 is associated with reactions: {THIORDXi}
# 1185660.4.peg.450 is associated with reactions: {THRA}
# 1185660.4.peg.3178 is associated with reactions: {THZPSN}
# 1185660.4.peg.3179 is associated with reactions: {THZPSN}
# 1185660.4.peg.781 is associated with reactions: {TMPK}
# 1185660.4.peg.3245 is associated with reactions: {TMPPP}
# 1185660.4.peg.2612 is associated with reactions: {TPI}
# 1185660.4.peg.2162 is associated with reactions: {TPRDCOAS, UPPRT}
# 1185660.4.peg.2947 is associated with reactions: {TRE6PP}
# 1185660.4.peg.3934 is associated with reactions: {TRE6PP}
# 1185660.4.peg.2949 is associated with reactions: {TRE6PS}
# 1185660.4.peg.419 is associated with reactions: {TRPO2}
# 1185660.4.peg.418 is associated with reactions: {TRPO2}
# 1185660.4.peg.817 is associated with reactions: {UAAGDS}
# 1185660.4.peg.1651 is associated with reactions: {UAGAAT}
# 1185660.4.peg.820 is associated with reactions: {UAGPT2, UAGPT3}
# 1185660.4.peg.3119 is associated with reactions: {UAMAGS}
# 1185660.4.peg.821 is associated with reactions: {UAMAS}
# 1185660.4.peg.1848 is associated with reactions: {UAPGR}
# 1185660.4.peg.3418 is associated with reactions: {UDPGD}
# 1185660.4.peg.1406 is associated with reactions: {UDPGD}
# 1185660.4.peg.818 is associated with reactions: {UGMDDS}
# 1185660.4.peg.826 is associated with reactions: {UHGADA}
# 1185660.4.peg.196 is associated with reactions: {UPP3S}
# 1185660.4.peg.2745 is associated with reactions: {UPPDC1, UPPDC2}
# 1185660.4.peg.1905 is associated with reactions: {VPAMTr}
# 1185660.4.peg.1815 is associated with reactions: {XYLK}
# 1185660.4.peg.1817 is associated with reactions: {XYLt2}
