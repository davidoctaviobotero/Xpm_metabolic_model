# %% [markdown]
# ### Importing the model to a dataframe

# %% [markdown]
# First we import the model to a data frame:

# %%
import os
import pandas as pd
pd.options.display.max_rows = 100
data_dir = "/Users/david/Dropbox (UCSD SBRG)/Xam_Multistrain_Recon/Metabolic_model/BiGG_Model/"

# %%
xamReconBigg = pd.read_csv('Xam_BiGG-full_media-Ene-16.txt', sep='\t')

# %% [markdown]
# ### Import new model
# Now that a dataframe with BiGG_ID, BiGG_rxn and Gene-reaction-rule for Xam have been created, generate a model with BiGG reactions.

# %%
import re
import cobra
import os
from os.path import join

Xam_draft = cobra.Model('Xam')
for i, row in xamReconBigg.iterrows(): #Iterate through dataframe rows by index
    rxn = cobra.Reaction(row['ID_corrected']) #Assign reactions for each column of a line
    rxn_str = row['Equa_BiGG_Corrected']
    lb = row['LB']
    ub = row['UB']
    
    if re.search('EX_|OF_', row['ID_corrected']):
        reactants, products = re.split(r' <==>| <--| -->', row['Equa_BiGG_Corrected']) #Change characters to standards and divide reaction string to reactants and products
        stoichiometry = {}
        for met_stoich in reactants.split(' + '): #Isolate metabolites in reactants and products
            stoich, met = met_stoich.split(' ')
            stoichiometry[met] = -float(stoich) #Isolate stoichiometric coefficients for each metabolite. Stoichiometry is a dictionary so attribute key:value
            if met not in Xam_draft.metabolites: #Add to the metabolites in the model if the metabolite is not already there
                Xam_draft.add_metabolites([cobra.Metabolite(met)])

        Xam_draft.add_reaction(rxn) #Add reaction to model
        rxn.add_metabolites(stoichiometry) #Add metabolite to reaction
        rxn.lower_bound = lb
        rxn.upper_bound = ub
        if type(row['Genes']) == float:
            pass
        else:
            rxn.gene_reaction_rule = row['Genes']
        
    else:
        reactants, products = re.split(r' <==> | <-- | --> ', row['Equa_BiGG_Corrected']) #Change characters to standards and divide reaction string to reactants and products
        stoichiometry = {}
        for met_stoich in reactants.split(' + '): #Isolate metabolites in reactants
            stoich, met = met_stoich.split(' ')
            stoichiometry[met] = -float(stoich) #Isolate stoichiometric coefficients for each metabolite. Stoichiometry is a dictionary so attribute key:value
            if met not in Xam_draft.metabolites: #Add to the metabolites in the model if the metabolite is not already there
                Xam_draft.add_metabolites([cobra.Metabolite(met)])

        for met_stoich in products.split(' + '): #Isolate metabolites in reactants
            stoich, met = met_stoich.split(' ')
            stoichiometry[met] = float(stoich)
            if met not in Xam_draft.metabolites:
                Xam_draft.add_metabolites([cobra.Metabolite(met)])

        Xam_draft.add_reaction(rxn) #Add reaction to model
        rxn.add_metabolites(stoichiometry) #Add metabolite to reaction
        rxn.lower_bound = lb
        rxn.upper_bound = ub
        if type(row['Genes']) == float:
            pass
        else:
            rxn.gene_reaction_rule = row['Genes']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-06b354ce6958> in <module>()
#      30
#      31     else:
# ---> 32         reactants, products = re.split(r' <==> | <-- | --> ', row['Equa_BiGG_Corrected']) #Change characters to standards and divide reaction string to reactants and products
#      33         stoichiometry = {}
#      34         for met_stoich in reactants.split(' + '): #Isolate metabolites in reactants
#
# ValueError: need more than 1 value to unpack

# %% [markdown]
# ### Summary

# %%
print (len(Xam_draft.reactions))
print (len(Xam_draft.metabolites))
print (len(Xam_draft.genes))
# Out:
# 1556
# 1527
# 890

# %% [markdown]
# ### Reactions

# %%
print("Reactions")
print("---------")
for x in Xam_draft.reactions:
    print("%s\t%s\t%s\t%s\t%s" % (x.id, x.reaction, x.gene_reaction_rule, x.lower_bound, x.upper_bound))
# Out:
# Reactions
# ---------
# 10FTHFGLULL	10fthfglu__L_c + adp_c + h_c + pi_c <-- 10fthf_c + atp_c + glu__L_c	(1185660.4.peg.1057 and 1185660.4.peg.1057)	-1000	0
# 2DHPFALDL	3mob_c + fald_c <=> 2dhp_c	1185660.4.peg.495	-1000	1000
# 2HBO	2obut_c + h_c + nadh_c <=> 2hb_c + nad_c	1185660.4.peg.109	-1000	1000
# 2OH3K5MPPISO	2h3kmtp_c + h2o_c --> 12dmpo_c + pi_c	1185660.4.peg.1883	0	1000
# 34DHOXPEGOX	34dhmald_c + h_c + nadh_c <=> 34dhoxpeg_c + nad_c	(1185660.4.peg.29 or 1185660.4.peg.180 or 1185660.4.peg.3115 or 1185660.4.peg.3035 or 1185660.4.peg.2389)	-1000	1000
# 34HPPOR	co2_c + hgentis_c <-- 2h34hppr_c + o2_c	(1185660.4.peg.424 or 1185660.4.peg.424)	-1000	0
# 3HAO	cmusa_c <-- 3hanthrn_c + o2_c	(1185660.4.peg.1461 or 1185660.4.peg.1461)	-1000	0
# 3HBCOAHL	3hmp_c + coa_c + h_c <-- 3hibutcoa_c + h2o_c	(1185660.4.peg.1539 or 1185660.4.peg.1539)	-1000	0
# 3HLYTCL	co2_c + dopa_c <=> 34dhphe_c + h_c	1185660.4.peg.850	-1000	1000
# 3OAR100	3odecACP_c + h_c + nadph_c <=> 3hdecACP_c + nadp_c	(1185660.4.peg.4522 or 1185660.4.peg.1143 or 1185660.4.peg.409 or 1185660.4.peg.401 or 1185660.4.peg.3578 or 1185660.4.peg.1112 or 1185660.4.peg.3753)	-1000	1000
# 3OAR120	3oddecACP_c + h_c + nadph_c <=> 3hddecACP_c + nadp_c	(1185660.4.peg.3753 or 1185660.4.peg.1112 or 1185660.4.peg.401 or 1185660.4.peg.409 or 1185660.4.peg.4522 or 1185660.4.peg.1143 or 1185660.4.peg.3578)	-1000	1000
# 3OAR40_1	actACP_c + h_c + nadph_c <=> 3hbutACP_c + nadp_c	(1185660.4.peg.401 or 1185660.4.peg.409 or 1185660.4.peg.1143 or 1185660.4.peg.4522 or 1185660.4.peg.3578 or 1185660.4.peg.1112 or 1185660.4.peg.3753)	-1000	1000
# 3OAR60	3ohexACP_c + h_c + nadph_c <=> 3hhexACP_c + nadp_c	(1185660.4.peg.4522 or 1185660.4.peg.1143 or 1185660.4.peg.409 or 1185660.4.peg.401 or 1185660.4.peg.3578 or 1185660.4.peg.3753 or 1185660.4.peg.1112)	-1000	1000
# 3OAR80	3hoctACP_c + nadp_c <=> 3ooctACP_c + h_c + nadph_c	(1185660.4.peg.1112 or 1185660.4.peg.3753 or 1185660.4.peg.3578 or 1185660.4.peg.401 or 1185660.4.peg.409 or 1185660.4.peg.1143 or 1185660.4.peg.4522)	-1000	1000
# 3OAS80	3ooctACP_c + ACP_c + co2_c <-- hexACP_c + malACP_c	((1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283)) or 1185660.4.peg.3695)	-1000	0
# 4ABUTD	4abut_c + 2.0 h_c + nadph_c <-- 4abutn_c + h2o_c + nadp_c	(1185660.4.peg.4079 or 1185660.4.peg.911 or 1185660.4.peg.4080 or 1185660.4.peg.4081)	-1000	0
# 4CMLCL_kt	5odhf2a_c + co2_c <-- 2c25dho_c + h_c	(1185660.4.peg.800 or 1185660.4.peg.3063)	-1000	0
# 4HTHRS	4hthr_c + pi_c <-- h2o_c + phthr_c	1185660.4.peg.1865	-1000	0
# 56DH5FLURAAMH	aflburppa_c + h_c <=> 56dh5flura_c + h2o_c	(1185660.4.peg.3381 or 1185660.4.peg.2831 or 1185660.4.peg.2895 or 1185660.4.peg.2778)	-1000	1000
# 5FLURAPRT	5flurimp_c + ppi_c <=> 5flura_c + prpp_c	1185660.4.peg.1060	-1000	1000
# 5HLTDL	co2_c + srtn_c <=> 5htrp_c + h_c	1185660.4.peg.850	-1000	1000
# 5HXKYNDCL	5hxkynam_c + co2_c <=> 5hxkyn_c + h_c	1185660.4.peg.850	-1000	1000
# A5PISO	ara5p_c <=> ru5p__D_c	(1185660.4.peg.2694 or 1185660.4.peg.144)	-1000	1000
# AACOAR_syn	3hbcoa__R_c + nadp_c --> aacoa_c + h_c + nadph_c	((1185660.4.peg.2053 or 1185660.4.peg.3317) or (1185660.4.peg.3317 or 1185660.4.peg.2053))	0	0
# AACOAT	aacoa_c + amp_c + ppi_c --> acac_c + atp_c + coa_c	((1185660.4.peg.1922 or 1185660.4.peg.3392) and Unknown)	0	0
# AASPh	adp_c + h_c + paps_c <=> aps_c + atp_c	1185660.4.peg.3352	-1000	1000
# ABUTD	4abut_c + 2.0 h_c + nadh_c <-- 4abutn_c + h2o_c + nad_c	((1185660.4.peg.4080 or 1185660.4.peg.911 or 1185660.4.peg.4079 or 1185660.4.peg.4081) or 1185660.4.peg.2630)	-1000	0
# ACACT1	aacoa_c + coa_c <=> 2.0 accoa_c	((1185660.4.peg.1581 or 1185660.4.peg.193 or 1185660.4.peg.2235) or (1185660.4.peg.2235 or 1185660.4.peg.709 or 1185660.4.peg.193 or 1185660.4.peg.1581))	-1000	1000
# ACACT10m	2maacoa_c + coa_c <=> accoa_c + ppcoa_c	(1185660.4.peg.193 or 1185660.4.peg.1581 or 1185660.4.peg.2235)	-1000	1000
# ACACT2	3ohcoa_c + coa_c <=> accoa_c + btcoa_c	((1185660.4.peg.1581 or 1185660.4.peg.193 or 1185660.4.peg.2235) or (1185660.4.peg.2235 or 1185660.4.peg.709 or 1185660.4.peg.1581 or 1185660.4.peg.193))	-1000	1000
# ACACT3	3oocoa_c + coa_c <=> accoa_c + hxcoa_c	(1185660.4.peg.2235 or 1185660.4.peg.1581 or 1185660.4.peg.193)	-1000	1000
# ACACT4m	3odcoa_c + coa_c <=> accoa_c + occoa_c	(1185660.4.peg.193 or 1185660.4.peg.1581 or 1185660.4.peg.2235)	-1000	1000
# ACACT5m	3oddcoa_c + coa_c <=> accoa_c + dcacoa_c	(1185660.4.peg.2235 or 1185660.4.peg.193 or 1185660.4.peg.1581)	-1000	1000
# ACACT6m	3otdcoa_c + coa_c <=> accoa_c + ddcacoa_c	(1185660.4.peg.2235 or 1185660.4.peg.1581 or 1185660.4.peg.193)	-1000	1000
# ACACT7m	3ohdcoa_c + coa_c <=> accoa_c + tdcoa_c	(1185660.4.peg.193 or 1185660.4.peg.1581 or 1185660.4.peg.2235)	-1000	1000
# ACALDt	acald_e <-- acald_c	Unknown	-1000	0
# ACAS_2ahbut	2ahbut_c + thmpp_c <=> 2ahethmpp_c + 2obut_c	((1185660.4.peg.3281 and Unknown) or 1185660.4.peg.3282)	-1000	1000
# ACBIPGT	agdpcbi_c + ppi_c <=> adocbip_c + gtp_c + h_c	1185660.4.peg.2927	-1000	1000
# ACCOAC	adp_c + h_c + malcoa_c + pi_c <=> accoa_c + atp_c + hco3_c	1185660.4.peg.3842	-1000	1000
# ACCOAC_1	accoa_c + cbtnCCP_c --> btnCCP_c + malcoa_c	(1185660.4.peg.1647 and 1185660.4.peg.2620)	0	0
# ACCOAL	atp_c + coa_c + ppa_c <=> adp_c + pi_c + ppcoa_c	(Unknown and 1185660.4.peg.4012)	-1000	1000
# ACGApts	acgam_e + pep_c <=> acgam6p_c + pyr_c	(Unknown and Unknown and (1185660.4.peg.2706 or 1185660.4.peg.2139) and Unknown)	-1000	1000
# ACGK	acg5p_c + adp_c <-- acglu_c + atp_c	(1185660.4.peg.2004 or 1185660.4.peg.2004)	-1000	0
# ACGS	acglu_c + coa_c + h_c <-- accoa_c + glu__L_c	(1185660.4.peg.3151 or 1185660.4.peg.2286 or 1185660.4.peg.1448 or 1185660.4.peg.2003 or 1185660.4.peg.4127 or 1185660.4.peg.3346 or 1185660.4.peg.774)	-1000	0
# ACOA40OR	btcoa_c + fad_c + h_c <-- b2coa_c + fadh2_c	1185660.4.peg.256	-1000	0
# ACOAD1	b2coa_c + h_c + nadh_c --> btcoa_c + nad_c	(1185660.4.peg.2776 or 1185660.4.peg.1419)	0	1000
# ACOAD10m	2mbcoa_c + fad_c + h_c <-- 2mb2coa_c + fadh2_c	1185660.4.peg.1537	-1000	0
# ACOAD2	h_c + hx2coa_c + nadh_c --> hxcoa_c + nad_c	1185660.4.peg.2776	0	1000
# ACOAD3	h_c + nadh_c + oc2coa_c --> nad_c + occoa_c	1185660.4.peg.2776	0	1000
# ACOAD4	dc2coa_c + h_c + nadh_c --> dcacoa_c + nad_c	1185660.4.peg.2776	0	1000
# ACOAD5	dd2coa_c + h_c + nadh_c --> ddcacoa_c + nad_c	1185660.4.peg.2776	0	1000
# ACOAD6	h_c + nadh_c + td2coa_c --> nad_c + tdcoa_c	1185660.4.peg.2776	0	1000
# ACOAD7	h_c + hdd2coa_c + nadh_c --> nad_c + pmtcoa_c	1185660.4.peg.2776	0	1000
# ACOAD8m	fad_c + h_c + ivcoa_c <-- 3mb2coa_c + fadh2_c	1185660.4.peg.256	-1000	0
# ACOAD9m	fad_c + h_c + ibcoa_c <-- 2mp2coa_c + fadh2_c	1185660.4.peg.1537	-1000	0
# ACOADH2	2.0 2mp2coa_c + 2.0 h2o_c <-- 2.0 ibcoa_c + o2_c	1185660.4.peg.1419	-1000	0
# ACOATA	acACP_c + coa_c <=> ACP_c + accoa_c	(1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283))	-1000	1000
# ACODA	ac_c + orn_c <=> acorn_c + h2o_c	(1185660.4.peg.2005 or 1185660.4.peg.3164)	-1000	1000
# ACONTa	cit_c --> acon_C_c + h2o_c	(1185660.4.peg.1925 and 1185660.4.peg.1925)	0	1000
# ACONTb	acon_C_c + h2o_c --> icit_c	(1185660.4.peg.1925 and 1185660.4.peg.1925)	0	1000
# ACOTA	acg5sa_c + glu__L_c <=> acorn_c + akg_c	(1185660.4.peg.2157 or 1185660.4.peg.3257)	-1000	1000
# ACPh	3pg_c + h_c + pi_c <-- 13dpg_c + h2o_c	1185660.4.peg.966	-1000	0
# ACPS1	apoACP_c + coa_c --> ACP_c + h_c + pap_c	Unknown	0	1000
# ACS	accoa_c + amp_c + ppi_c <-- ac_c + atp_c + coa_c	1185660.4.peg.4012	-1000	0
# ACt4pp	ac_p + na1_p <=> ac_c + na1_c	xanmn_chr15_0167	-1000	1000
# ACYP_2	ac_c + h_c + pi_c <-- actp_c + h2o_c	1185660.4.peg.966	-1000	0
# ADA	adn_c + h2o_c + h_c --> ins_c + nh4_c	1185660.4.peg.306	0	1000
# ADCL	4adcho_c --> 4abz_c + h_c + pyr_c	1185660.4.peg.4543	0	1000
# ADCS	4adcho_c + glu__L_c <=> chor_c + gln__L_c	(1185660.4.peg.452 or 1185660.4.peg.452 or 1185660.4.peg.1146)	-1000	1000
# ADCYRS	adcobhex_c + 4.0 adp_c + 4.0 glu__L_c + 4.0 h_c + 4.0 pi_c <=> adcobdam_c + 4.0 atp_c + 4.0 gln__L_c + 4.0 h2o_c	1185660.4.peg.2928	-1000	1000
# ADECn	camp_c + ppi_c <-- atp_c	((1185660.4.peg.247 or 1185660.4.peg.245 or 1185660.4.peg.178) or (1185660.4.peg.178 or 1185660.4.peg.245 or 1185660.4.peg.247))	-1000	0
# ADK1	amp_c + atp_c <=> 2.0 adp_c	(1185660.4.peg.3265 or 1185660.4.peg.1793)	-1000	1000
# ADK2	adp_c + ppi_c <=> amp_c + pppi_c	1185660.4.peg.3265	-1000	1000
# ADMDC	ametam_c + co2_c <-- amet_c + h_c	1185660.4.peg.457	-1000	0
# ADNK1	adp_c + amp_c + h_c <=> adn_c + atp_c	1185660.4.peg.4445	-1000	1000
# ADNt2	adn_e + h_e <=> adn_c + h_c	1185660.4.peg.866	-1000	1000
# ADNUC	ade_c + rib__D_c <-- adn_c + h2o_c	((1185660.4.peg.305 or 1185660.4.peg.1160 or 1185660.4.peg.3218) or (1185660.4.peg.1888 or 1185660.4.peg.847))	-1000	0
# ADOCBIK	adocbip_c + adp_c + h_c <=> adocbi_c + atp_c	1185660.4.peg.2927	-1000	1000
# ADOCBLS	agdpcbi_c + rdmbzi_c <=> adocbl_c + gmp_c + h_c	1185660.4.peg.2916	-1000	1000
# ADPRDP	amp_c + 2.0 h_c + r5p_c <-- adprib_c + h2o_c	(1185660.4.peg.941 or 1185660.4.peg.705)	-1000	0
# ADPT	amp_c + ppi_c <-- ade_c + prpp_c	1185660.4.peg.2042	-1000	0
# ADSL1r	amp_c + fum_c <-- dcamp_c	(1185660.4.peg.1394 or 1185660.4.peg.1394)	-1000	0
# ADSL2r	aicar_c + fum_c <=> 25aics_c	(1185660.4.peg.1394 or 1185660.4.peg.1394)	-1000	1000
# ADSS	asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + 2.0 h_c + pi_c	1185660.4.peg.1178	0	1000
# AFAT	atp_c + fmn_c + h_c --> fad_c + ppi_c	(1185660.4.peg.2974 and 1185660.4.peg.2974)	0	1000
# AGDC	ac_c + gam6p_c <=> acgam6p_c + h2o_c	1185660.4.peg.747	-1000	1000
# AGDI	Ncbmpts_c + nh4_c <-- agm_c + h2o_c	1185660.4.peg.2408	-1000	0
# AGGPR	acg5sa_c + nadp_c + pi_c <-- acg5p_c + h_c + nadph_c	1185660.4.peg.2002	-1000	0
# AGMHE	adphep_DD_c --> adphep_LD_c	Unknown	0	1000
# AGPAT120	1ddecg3p_c + ddcaACP_c + h_c --> ACP_c + pa120_c	(1185660.4.peg.502 or 1185660.4.peg.487 or 1185660.4.peg.176)	0	1000
# AGPAT140	1tdecg3p_c + myrsACP_c --> ACP_c + pa140_c	(1185660.4.peg.487 or 1185660.4.peg.176 or 1185660.4.peg.502)	0	0
# AGPAT141	1tdec7eg3p_c + tdeACP_c --> ACP_c + pa141_c	(1185660.4.peg.502 or 1185660.4.peg.487 or 1185660.4.peg.176)	0	1000
# AGPAT160	ACP_c + pa160_c <-- 1hdecg3p_c + palmACP_c	(1185660.4.peg.487 or 1185660.4.peg.176 or 1185660.4.peg.502)	-1000	0
# AGPAT161	1hdec9eg3p_c + h_c + hdeACP_c --> ACP_c + pa161_c	(1185660.4.peg.487 or 1185660.4.peg.176 or 1185660.4.peg.502)	0	1000
# AGPAT180	1odecg3p_c + 2.0 h_c + ocdcaACP_c --> ACP_c + pa180_c	(1185660.4.peg.176 or 1185660.4.peg.487 or 1185660.4.peg.502)	0	1000
# AGPAT181	1odec11eg3p_c + octeACP_c --> ACP_c + pa181_c	(1185660.4.peg.502 or 1185660.4.peg.176 or 1185660.4.peg.487)	0	1000
# AGTi	gly_c + pyr_c <-- ala__L_c + glx_c	(1185660.4.peg.295 and 1185660.4.peg.295)	-1000	0
# AICART	10fthf_c + aicar_c <=> fprica_c + thf_c	(1185660.4.peg.495 and 1185660.4.peg.495)	-1000	1000
# AIRCr	air_c + co2_c <-- 5aizc_c + h_c	((1185660.4.peg.2586 and 1185660.4.peg.2585) or 1185660.4.peg.2585 or 1185660.4.peg.2586)	-1000	0
# AKGDH	co2_c + nadh_c + succoa_c <-- akg_c + coa_c + nad_c	(1185660.4.peg.1389 or 1185660.4.peg.1386 or (1185660.4.peg.1388 or 1185660.4.peg.1387))	-1000	0
# AKGDHe2r	dhlam_c + succoa_c <=> coa_c + sdhlam_c	(1185660.4.peg.1388 or 1185660.4.peg.1387)	-1000	1000
# AKGt2r	akg_e + h_e <=> akg_c + h_c	Unknown	-1000	1000
# AKP1	dhnpt_c + 2.0 h_c + 3.0 pi_c <-- ahdt_c + 3.0 h2o_c	1185660.4.peg.1832	-1000	0
# ALAALAr	2.0 ala__D_c + atp_c --> adp_c + alaala_c + h_c + pi_c	Unknown	0	1000
# ALAR	ala__D_c <=> ala__L_c	(1185660.4.peg.3765 or 1185660.4.peg.1846)	-1000	1000
# ALCD19	glyald_c + h_c + nadh_c <=> glyc_c + nad_c	(1185660.4.peg.3115 or 1185660.4.peg.3035 or 1185660.4.peg.2389 or 1185660.4.peg.29 or 1185660.4.peg.180)	-1000	1000
# ALCD2ir	acald_c + h_c + nadh_c <=> etoh_c + nad_c	((1185660.4.peg.2389 or 1185660.4.peg.3115 or 1185660.4.peg.3035 or 1185660.4.peg.180 or 1185660.4.peg.29) or (1185660.4.peg.3115 or 1185660.4.peg.3035 or 1185660.4.peg.2389 or 1185660.4.peg.29 or 1185660.4.peg.180))	-1000	1000
# ALDD22x	ala_B_c + 2.0 h_c + nadh_c <=> aproa_c + h2o_c + nad_c	(1185660.4.peg.4080 or 1185660.4.peg.911 or 1185660.4.peg.4079 or 1185660.4.peg.4081)	-1000	1000
# ALDD2x	ac_c + 2.0 h_c + nadh_c <-- acald_c + h2o_c + nad_c	(1185660.4.peg.4079 or 1185660.4.peg.4080 or 1185660.4.peg.911 or 1185660.4.peg.4081)	-1000	0
# ALDD31	gly_c + 2.0 h_c + nadh_c <-- aacald_c + h2o_c + nad_c	(1185660.4.peg.911 or 1185660.4.peg.4080 or 1185660.4.peg.4079 or 1185660.4.peg.4081)	-1000	0
# ALKP	dhap_c + h2o_c --> dha_c + pi_c	1185660.4.peg.1832	0	1000
# AM6PTh	atp_c + man_c <=> adp_c + h_c + man6p_c	1185660.4.peg.1413	-1000	1000
# AMAOTr	amob_c + dann_c <=> 8aonn_c + amet_c	(1185660.4.peg.4342 or 1185660.4.peg.2795)	-1000	1000
# AMID	4gudbutn_c + nh4_c <-- 4gudbd_c + h2o_c	(1185660.4.peg.1978 or 1185660.4.peg.2410)	-1000	0
# AMID2	h2o_c + pad_c <=> nh4_c + pac_c	(1185660.4.peg.2410 or 1185660.4.peg.1978)	-1000	1000
# AMID3	h2o_c + iad_c --> ind3ac_c + nh4_c	(1185660.4.peg.1978 or 1185660.4.peg.2410)	0	1000
# AMID4	ac_c + nh4_c <-- ad_c + h2o_c	(1185660.4.peg.2410 or 1185660.4.peg.1978)	-1000	0
# AMID5	acryl_c + nh4_c <-- aa_c + h2o_c	(1185660.4.peg.2410 or 1185660.4.peg.1978)	-1000	0
# AMMQT8_2	2dmmq8_c + amet_c --> ahcys_c + h_c + mqn8_c	1185660.4.peg.668	0	1000
# AMPTASECG	cys__L_c + gly_c <=> cgly_c + h2o_c	((1185660.4.peg.3572 or 1185660.4.peg.1672) or 1185660.4.peg.3472 or 1185660.4.peg.3347 or 1185660.4.peg.231 or 1185660.4.peg.3858 or 1185660.4.peg.231)	-1000	1000
# ANNAT	nad_c + ppi_c <=> atp_c + h_c + nmn_c	1185660.4.peg.705	-1000	1000
# ANS	anth_c + glu__L_c + h_c + pyr_c <-- chor_c + gln__L_c	((1185660.4.peg.449 and 1185660.4.peg.452) or 1185660.4.peg.1153)	-1000	0
# ANS2	anth_c + h2o_c + h_c + pyr_c <-- chor_c + nh4_c	((1185660.4.peg.452 and 1185660.4.peg.449) or 1185660.4.peg.1153)	-1000	0
# AOOA	glu__L_c + imacp_c <=> akg_c + hisp_c	(Unknown and 1185660.4.peg.1874)	-1000	1000
# AOXHEXCYCL	1pipdn2c_c + h2o_c <-- 6a2ohxnt_c	Unknown	-1000	0
# AOXSr	8aonn_c + co2_c + coa_c <-- ala__L_c + h_c + pmcoa_c	1185660.4.peg.1114	-1000	0
# APAPTm	ametam_c + ptrc_c --> 5mta_c + h_c + spmd_c	1185660.4.peg.3804	0	1000
# APATr	ala_B_c + pyr_c <=> ala__L_c + msa_c	(1185660.4.peg.2124 or 1185660.4.peg.2108)	-1000	1000
# APLh	alac__S_c + thmpp_c <=> 2ahethmpp_c + pyr_c	((Unknown and 1185660.4.peg.3281) or 1185660.4.peg.3282)	-1000	1000
# APPAT	dpcoa_c + ppi_c <=> atp_c + h_c + pan4p_c	1185660.4.peg.2169	-1000	1000
# APRAUR	5aprbu_c + nadp_c <=> 5apru_c + h_c + nadph_c	(1185660.4.peg.775 or 1185660.4.peg.775)	-1000	1000
# APSR	amp_c + 2.0 h_c + hso3_c + trdox_c <-- aps_c + trdrd_c	(Unknown and 1185660.4.peg.3356)	-1000	0
# ARBTptspp	arbt6p_c + pyr_c <=> arbt_e + pep_c	(Unknown and Unknown and (1185660.4.peg.2139 or 1185660.4.peg.2706) and Unknown and Unknown)	-1000	1000
# ARD_1	4met2obut_c + for_c + 2.0 h_c <-- 12dmpo_c + o2_c	1185660.4.peg.1884	-1000	0
# ARGDC	agm_c + co2_c <-- arg__L_c + h_c	1185660.4.peg.3803	-1000	0
# ARGN	orn_c + urea_c <-- arg__L_c + h2o_c	1185660.4.peg.3883	-1000	0
# ARGORNt7	arg__L_e + orn_c <=> arg__L_c + orn_e	(1185660.4.peg.4523 or 1185660.4.peg.3296)	-1000	1000
# ARGSL	argsuc_c <=> arg__L_c + fum_c	1185660.4.peg.2001	-1000	1000
# ARGSS	amp_c + argsuc_c + h_c + ppi_c <=> asp__L_c + atp_c + citr__L_c	1185660.4.peg.2007	-1000	1000
# ASAD	4pasp_c + h_c + nadph_c --> aspsa_c + nadp_c + pi_c	(1185660.4.peg.2630 or 1185660.4.peg.2630)	0	1000
# ASNN	asn__L_c + h2o_c --> asp__L_c + nh4_c	(1185660.4.peg.959 or 1185660.4.peg.2814)	0	0
# ASNS1	amp_c + asn__L_c + glu__L_c + h_c + ppi_c <-- asp__L_c + atp_c + gln__L_c + h2o_c	(1185660.4.peg.1339 or 1185660.4.peg.1291)	-1000	0
# ASP1DC	ala_B_c + co2_c <-- asp__L_c + h_c	1185660.4.peg.1828	-1000	0
# ASPATh	akg_c + asp__L_c <=> glu__L_c + oaa_c	(1185660.4.peg.3324 or 1185660.4.peg.655)	-1000	1000
# ASPCT	asp__L_c + cbp_c --> cbasp_c + h_c + pi_c	1185660.4.peg.3128	0	1000
# ASPK	4pasp_c + adp_c <-- asp__L_c + atp_c	((1185660.4.peg.3122 or 1185660.4.peg.1860) or 1185660.4.peg.2004)	-1000	0
# ASPt2_2	asp__L_e + 2.0 h_e <=> asp__L_c + 2.0 h_c	1185660.4.peg.3301	-1000	1000
# ATDAMh	adp_c + dadp_c <=> atp_c + damp_c	(1185660.4.peg.3265 or 1185660.4.peg.1793)	-1000	1000
# ATDGDm	adp_c + dgtp_c <=> atp_c + dgdp_c	1185660.4.peg.2232	-1000	1000
# ATGDm	atp_c + gdp_c <=> adp_c + gtp_c	1185660.4.peg.2232	-1000	1000
# ATPM	atp_c + h2o_c --> adp_c + h_c + pi_c	Unknown	0	0
# ATPPRT	ppi_c + prbatp_c <-- atp_c + prpp_c	1185660.4.peg.1872	-1000	0
# ATPS4r	adp_c + h_e + pi_c <=> atp_c + h2o_c + 3.0 h_c	(1185660.4.peg.3724 and Unknown and 1185660.4.peg.3721 and 1185660.4.peg.3725 and 1185660.4.peg.3723 and 1185660.4.peg.3722 and Unknown and Unknown and Unknown)	-1000	1000
# AUS	5aprbu_c + h2o_c --> 4r5au_c + pi_c	Unknown	0	1000
# BACCL	btamp_c + ppi_c --> atp_c + btn_c + h_c	(1185660.4.peg.3996 or 1185660.4.peg.3842)	0	1000
# BCTA_glu_h	akg_c + leu__L_c <=> 4mop_c + glu__L_c	1185660.4.peg.953	-1000	1000
# BCTA_val_h	akg_c + val__L_c <=> 3mob_c + glu__L_c	1185660.4.peg.953	-1000	1000
# BDH	acac_c + h_c + nadh_c <=> bhb_c + nad_c	1185660.4.peg.2357	-1000	1000
# BETALDHx	glyb_c + 2.0 h_c + nadh_c <-- betald_c + h2o_c + nad_c	1185660.4.peg.752	-1000	0
# BETALDHy	glyb_c + 2.0 h_c + nadph_c <-- betald_c + h2o_c + nadp_c	1185660.4.peg.752	-1000	0
# Biomass	0.00309646685193 10fthf_c + 0.00309646685193 2dmmq8_c + 0.00309646685193 5mthf_c + 0.00309646685193 ACP_c + 0.0106480421342 MNXM5124_c + 0.0106480421342 MNXM5129_c + 0.00309646685193 MNXM57_c + 0.0106480421342 MNXM6175_c + 0.0106480421342 MNXM6297_c + 0.0106480421342 MNXM6440_c + 0.0106480421342 MNXM7294_c + 0.0106480421342 MNXM7305_c + 0.0250105977109 MNXM7630_c + 0.00309646685193 adocbl_c + 0.427934380173 ala__L_c + 0.00309646685193 amet_c + 0.246696822701 arg__L_c + 0.200830806928 asn__L_c + 0.200830806928 asp__L_c + 40.1101757365 atp_c + 0.00309646685193 ca2_c + 0.00309646685193 cl_c + 0.00309646685193 coa_c + 0.00309646685193 cobalt2_c + 0.0250105977109 colipa_c + 0.0841036156545 ctp_c + 0.00309646685193 cu2_c + 0.0761464922056 cys__L_c + 0.0160206718346 datp_c + 0.0160206718346 dctp_c + 0.0160206718346 dgtp_c + dna_c + 0.0250105977109 dtpcudcpp_c + 0.0160206718346 dttp_c + 0.00309646685193 fad_c + 0.00309646685193 fe2_c + 0.00309646685193 fe3_c + 0.219088153013 gln__L_c + 0.219088153013 glu__L_c + 0.509869786991 gly_c + 0.135406821204 gtp_c + 35.540309243 h2o_c + 0.0792636000737 his__L_c + 0.241798510337 ile__L_c + 0.00309646685193 k_c + 0.37538884754 leu__L_c + 0.28543802049 lys__L_c + 0.127801422591 met__L_c + 0.00309646685193 mg2_c + 0.00309646685193 mn2_c + 0.00309646685193 mqn8_c + 0.00309646685193 nad_c + 0.00309646685193 nadp_c + 0.0106480421342 pe180_c + 0.0106480421342 pg180_c + 0.154519490031 phe__L_c + 0.00309646685193 pheme_c + 0.18435466534 pro__L_c + protein_c + 0.00309646685193 ptrc_c + 0.00309646685193 pydx5p_c + 0.00309646685193 q8_c + 0.00309646685193 ribflv_c + rna_c + 0.179456352976 ser__L_c + 0.00309646685193 sheme_c + 0.00309646685193 so4_c + 0.00309646685193 spmd_c + 0.00309646685193 thf_c + 0.00309646685193 thmpp_c + 0.211072732781 thr__L_c + 0.047201919145 trp__L_c + 0.120676604607 tyr__L_c + 0.0908319049068 utp_c + 0.352233189092 val__L_c + 0.00309646685193 zn2_c --> BIOMASS_c + 0.0250105977109 MNXM5258_c + 40.0 adp_c + 0.00309646685193 apoACP_c + 0.00309646685193 cbi_c + 0.00309646685193 dmbzid_c + 40.0562052099 h_c + 39.9969035331 pi_c + 0.484600765611 ppi_c	Unknown	0	1000
# BPNT	amp_c + pi_c <-- h2o_c + pap_c	(1185660.4.peg.2793 or 1185660.4.peg.2792)	-1000	0
# BTNC	adp_c + cbtnCCP_c + h_c + pi_c <=> atp_c + btnCCP_c + hco3_c	(1185660.4.peg.3996 and 1185660.4.peg.3996 and 1185660.4.peg.513 and 1185660.4.peg.511)	-1000	1000
# BTND1	biocyt_c + h2o_c <=> btn_c + lys__L_c	1185660.4.peg.2005	-1000	1000
# BTS4	amet_c + dtbt_c + s_c --> btn_c + dad_5_c + h_c + met__L_c	1185660.4.peg.1115	0	1000
# CA2t3pp	ca2_c + h_e <-- ca2_e + h_c	Unknown	-1000	0
# CAT	2.0 h2o2_c --> 2.0 h2o_c + o2_c	((1185660.4.peg.3862 or 1185660.4.peg.4194 or 1185660.4.peg.3039 or 1185660.4.peg.4534) or (1185660.4.peg.3039 or 1185660.4.peg.4534 or 1185660.4.peg.3862 or 1185660.4.peg.4194))	0	1000
# CBIAT	atp_c + cbi_c + h_c <=> adocbi_c + pppi_c	(1185660.4.peg.2929 or 1185660.4.peg.2885)	-1000	1000
# CBL1abc	atp_c + cbl1_e + h2o_c + h_e --> adp_c + cbl1_c + 2.0 h_c + pi_c	(Unknown and Unknown and 1185660.4.peg.2932 and Unknown)	0	1000
# CBPS	2.0 adp_c + cbp_c + glu__L_c + 2.0 h_c + pi_c <-- 2.0 atp_c + gln__L_c + h2o_c + hco3_c	(1185660.4.peg.1910 and 1185660.4.peg.1908)	-1000	0
# CD2t4pp	cd2_c + h_e + k_e <=> cd2_e + h_c + k_c	(1185660.4.peg.1542 or 1185660.4.peg.3989 or 1185660.4.peg.4230)	-1000	1000
# CDPGLC46DH	cdp4dh6doglc_c + h2o_c <-- cdpglc_c	1185660.4.peg.1496	-1000	0
# CDPMEK	2p4c2me_c + adp_c + h_c <=> 4c2me_c + atp_c	1185660.4.peg.977	-1000	1000
# CHLt2	chol_e + h_e <=> chol_c + h_c	1185660.4.peg.753	-1000	1000
# CHOLD	betald_c + h_c + nadh_c --> chol_c + nad_c	(1185660.4.peg.751 or (1185660.4.peg.29 or 1185660.4.peg.180 or 1185660.4.peg.3035 or 1185660.4.peg.3115 or 1185660.4.peg.2389))	0	0
# CHORM	chor_c --> pphn_c	1185660.4.peg.3719	0	1000
# CHORS	3psme_c --> chor_c + pi_c	1185660.4.peg.2632	0	1000
# CITMCOAHm	citmcoa__L_c <=> h2o_c + itaccoa_c	1185660.4.peg.1805	-1000	1000
# CITt2r	cit_e + h_e <=> cit_c + h_c	1185660.4.peg.3316	-1000	1000
# CLtex	cl_e <=> cl_c	1185660.4.peg.3569	-1000	1000
# CMPA	co2_c + nh4_c + ptrc_c <-- Ncbmpts_c + h2o_c + 2.0 h_c	1185660.4.peg.2410	-1000	0
# CMS	4c2me_c + ppi_c <=> 2me4p_c + ctp_c + h_c	1185660.4.peg.1763	-1000	1000
# CO2t	co2_e <=> co2_c	Unknown	-1000	1000
# COALDDH	fer_c + 2.0 h_c + nadh_c --> conialdh_c + h2o_c + nad_c	1185660.4.peg.974	0	0
# COBALT2tex	cobalt2_e <=> cobalt2_c	1185660.4.peg.2098	-1000	1000
# CPPPGO	2.0 co2_c + 2.0 h2o_c + pppg9_c <-- cpppg3_c + 2.0 h_c + o2_c	1185660.4.peg.3922	-1000	0
# CPS	2.0 adp_c + cbp_c + 3.0 h_c + pi_c <=> 2.0 atp_c + co2_c + h2o_c + nh4_c	1185660.4.peg.1757	-1000	1000
# CS	cit_c + coa_c + h_c <-- accoa_c + h2o_c + oaa_c	(1185660.4.peg.3216 or 1185660.4.peg.3284)	-1000	0
# CSND	nh4_c + ura_c <-- csn_c + h2o_c + h_c	1185660.4.peg.664	-1000	0
# CTPS1	atp_c + nh4_c + utp_c <=> adp_c + ctp_c + 2.0 h_c + pi_c	(1185660.4.peg.1757 or 1185660.4.peg.2007)	-1000	1000
# CTPS2	atp_c + gln__L_c + h2o_c + utp_c --> adp_c + ctp_c + glu__L_c + 2.0 h_c + pi_c	(1185660.4.peg.1757 or 1185660.4.peg.2007)	0	0
# CU2abcpp	adp_c + cu2_c + h_c + pi_c <-- atp_c + cu2_e + h2o_c	Unknown	-1000	0
# CYARTMT	amet_c + cyart_c <=> ahcys_c + h_c + menecyart_c	1185660.4.peg.890	-1000	1000
# CYOO2pp	2.0 ficytC_c + h2o_c + 4.0 h_e <-- 2.0 focytC_c + 2.0 h_c + 0.5 o2_c	(1185660.4.peg.3680 or 1185660.4.peg.3677)	-1000	0
# CYRDAAT	atp_c + co1dam_c + h_c <=> adcobdam_c + pppi_c	(1185660.4.peg.2929 or 1185660.4.peg.2885)	-1000	1000
# CYS	h2s_c + h_c + ser__L_c <=> cys__L_c + h2o_c	(1185660.4.peg.4405 or 1185660.4.peg.3491)	-1000	1000
# CYSDS	h2s_c + h_c + nh4_c + pyr_c <-- cys__L_c + h2o_c	(1185660.4.peg.4403 or 1185660.4.peg.3490)	-1000	0
# CYSS	ac_c + cys__L_c <-- acser_c + h2s_c	(1185660.4.peg.3364 or 1185660.4.peg.3699)	-1000	0
# CYSS_trdrd	ac_c + cys__L_c + 2.0 h_c + hso3_c + trdox_c <-- acser_c + trdrd_c + tsul_c	(1185660.4.peg.3364 or 1185660.4.peg.3699)	-1000	0
# CYTBD2pp	h2o_c + 2.0 h_e + mqn8_c <-- 2.0 h_c + mql8_c + 0.5 o2_c	(1185660.4.peg.2080 or 1185660.4.peg.2971 or 1185660.4.peg.1992 or 1185660.4.peg.2081 or 1185660.4.peg.2969 or 1185660.4.peg.1993 or 1185660.4.peg.2332 or 1185660.4.peg.2968 or 1185660.4.peg.2970)	-1000	0
# CYTBO3	h2o_c + 2.5 h_e + q8_c <-- 2.5 h_c + 0.5 o2_c + q8h2_c	(1185660.4.peg.2971 or 1185660.4.peg.2969 or 1185660.4.peg.2968 or 1185660.4.peg.2970 or (1185660.4.peg.1992 and 1185660.4.peg.1993) or (1185660.4.peg.2332 and Unknown and Unknown and Unknown and Unknown) or (Unknown and Unknown and Unknown and 1185660.4.peg.2081 and Unknown and 1185660.4.peg.2080 and Unknown and Unknown and Unknown and Unknown) or (Unknown and Unknown and 1185660.4.peg.1991 and 1185660.4.peg.1990 and Unknown and Unknown))	-1000	0
# CYTD	cytd_c + h2o_c + h_c --> nh4_c + uri_c	1185660.4.peg.2394	0	1000
# CYTDt2	cytd_e + h_e <=> cytd_c + h_c	1185660.4.peg.866	-1000	1000
# CYTK1	adp_c + cdp_c <=> atp_c + cmp_c	1185660.4.peg.2405	-1000	1000
# CYTK2	atp_c + dcmp_c <=> adp_c + dcdp_c	1185660.4.peg.2405	-1000	1000
# DAAD	ala__D_c + fad_c + h2o_c + h_c <=> fadh2_c + nh4_c + pyr_c	(1185660.4.peg.3766 or 1185660.4.peg.2660)	-1000	1000
# DADA	dad_2_c + h2o_c + h_c --> din_c + nh4_c	1185660.4.peg.306	0	1000
# DADNt2	dad_2_e + h_e <=> dad_2_c + h_c	(Unknown and 1185660.4.peg.866)	-1000	1000
# DAGK160	adp_c + h_c + pa160_c <=> 12dgr160_c + atp_c	1185660.4.peg.885	-1000	1000
# DALAt2pp	ala__D_e + h_e <=> ala__D_c + h_c	(1185660.4.peg.604 or (Unknown and 1185660.4.peg.604))	-1000	1000
# DAPDA	h2o_c + n6all26d_c <=> 26dap_LL_c + ac_c	(1185660.4.peg.3638 or 1185660.4.peg.3639)	-1000	1000
# DAPDC	co2_c + lys__L_c <=> 26dap__M_c + h_c	1185660.4.peg.3122	-1000	1000
# DAPE	26dap__M_c <=> 26dap_LL_c	1185660.4.peg.659	-1000	1000
# DASYN120	cdpdddecg_c + ppi_c <=> ctp_c + pa120_c	(1185660.4.peg.503 or 1185660.4.peg.1658)	-1000	1000
# DASYN140	cdpdtdecg_c + ppi_c <=> ctp_c + h_c + pa140_c	(1185660.4.peg.503 or 1185660.4.peg.1658)	-1000	1000
# DASYN141	cdpdtdec7eg_c + ppi_c <=> ctp_c + pa141_c	(1185660.4.peg.1658 or 1185660.4.peg.503)	-1000	1000
# DASYN160	cdpdhdecg_c + ppi_c <=> ctp_c + h_c + pa160_c	(1185660.4.peg.1658 or 1185660.4.peg.503)	-1000	1000
# DASYN161	cdpdhdec9eg_c + ppi_c <=> ctp_c + pa161_c	(1185660.4.peg.1658 or 1185660.4.peg.503)	-1000	1000
# DASYN180	cdpdodecg_c + ppi_c <=> ctp_c + h_c + pa180_c	(1185660.4.peg.1658 or 1185660.4.peg.503)	-1000	1000
# DASYN181	cdpdodec11eg_c + ppi_c <=> ctp_c + pa181_c	(1185660.4.peg.1658 or 1185660.4.peg.503)	-1000	1000
# DB4PS	ru5p__D_c --> db4p_c + for_c + h_c	((1185660.4.peg.778 or 1185660.4.peg.3586) and (1185660.4.peg.778 or 1185660.4.peg.3586))	0	1000
# DBTS	adp_c + dtbt_c + 3.0 h_c + pi_c <-- atp_c + co2_c + dann_c	1185660.4.peg.3688	-1000	0
# DCTPD	dctp_c + h2o_c + h_c --> dutp_c + nh4_c	1185660.4.peg.2648	0	1000
# DCTPD2	nh4_c + utp_c <-- ctp_c + h2o_c + h_c	1185660.4.peg.2648	-1000	0
# DCYTD	dcyt_c + h2o_c + h_c --> duri_c + nh4_c	1185660.4.peg.2394	0	1000
# DCYTt2	dcyt_e + h_e <=> dcyt_c + h_c	1185660.4.peg.866	-1000	1000
# DDGALK	2dh3dgal_c + atp_c <=> 2dh3dgal6p_c + adp_c + h_c	1185660.4.peg.1803	-1000	1000
# DDGLCNt2r	2ddglcn_e + h_e <=> 2ddglcn_c + h_c	1185660.4.peg.340	-1000	1000
# DDGLK	2ddg6p_c + adp_c + h_c <=> 2ddglcn_c + atp_c	1185660.4.peg.99	-1000	1000
# DDPA	2dda7p_c + pi_c <-- e4p_c + h2o_c + pep_c	(1185660.4.peg.1030 and 1185660.4.peg.524 and Unknown)	-1000	0
# DDPGA	glx_c + pyr_c <=> 4h2oglt_c	((1185660.4.peg.2340 and 1185660.4.peg.2340) or 1185660.4.peg.2340)	-1000	1000
# DDPGALA	g3p_c + pyr_c <=> 2dh3dgal6p_c	(1185660.4.peg.1806 or 1185660.4.peg.3663)	-1000	1000
# DGC3D	3ddgc_c + h_c + nadh_c <=> 2dglcn_c + nad_c	1185660.4.peg.145	-1000	1000
# DGK1	atp_c + dgmp_c <=> adp_c + dgdp_c	(1185660.4.peg.3224 or 1185660.4.peg.3224)	-1000	1000
# DGSNt2	dgsn_e + h_e <=> dgsn_c + h_c	1185660.4.peg.866	-1000	1000
# DHAD1	23dhmb_c --> 3mob_c + h2o_c	1185660.4.peg.392	0	1000
# DHCIND	dhcinnm_c + h_c + nadh_c <=> cenchddd_c + nad_c	1185660.4.peg.633	-1000	1000
# DHFR	dhf_c + h_c + nadph_c <=> nadp_c + thf_c	(1185660.4.peg.722 or 1185660.4.peg.892)	-1000	1000
# DHFS	adp_c + dhf_c + h_c + pi_c <-- atp_c + dhpt_c + glu__L_c	(1185660.4.peg.1057 and 1185660.4.peg.1057)	-1000	0
# DHNPA2r	6hmhpt_c + gcald_c <=> dhnpt_c	1185660.4.peg.3663	-1000	1000
# DHORD2	orot_c + q8h2_c <-- dhor__S_c + q8_c	1185660.4.peg.1849	-1000	0
# DHORD5	mql8_c + orot_c <-- dhor__S_c + mqn8_c	1185660.4.peg.1849	-1000	0
# DHORTS	cbasp_c + h_c <=> dhor__S_c + h2o_c	(1185660.4.peg.2015 or 1185660.4.peg.1499)	-1000	1000
# DHPD	cala_c + h_c <-- 56dura_c + h2o_c	(1185660.4.peg.3381 or 1185660.4.peg.2778 or 1185660.4.peg.2895 or 1185660.4.peg.2831)	-1000	0
# DHPM2	3uib_c + h_c <-- 56dthm_c + h2o_c	(1185660.4.peg.3381 or 1185660.4.peg.2895 or 1185660.4.peg.2831 or 1185660.4.peg.2778)	-1000	0
# DHPPD	dhpppn_c + h_c + nadh_c <=> cechddd_c + nad_c	1185660.4.peg.633	-1000	1000
# DHPPDA2	5apru_c + nh4_c <-- 25drapp_c + h2o_c + h_c	(1185660.4.peg.775 and 1185660.4.peg.775)	-1000	0
# DHPS2	4abz_c + 6hmhptpp_c --> dhpt_c + ppi_c	1185660.4.peg.1775	0	1000
# DHQS	2dda7p_c --> 3dhq_c + pi_c	1185660.4.peg.2743	0	1000
# DHQTi	3dhsk_c + h2o_c <-- 3dhq_c	(1185660.4.peg.514 or 1185660.4.peg.4039)	-1000	0
# DHRT_ivcoa	dhlam_c + ivcoa_c <=> 3mbdhl_c + coa_c	1185660.4.peg.412	-1000	1000
# DINSt2	din_e + h_e <=> din_c + h_c	1185660.4.peg.866	-1000	1000
# DLDLBT	dmlz_c + 2.0 h2o_c + h_c + pi_c <=> 4r5au_c + db4p_c	1185660.4.peg.779	-1000	1000
# DMATT	grdp_c + ppi_c <-- dmpp_c + ipdp_c	((1185660.4.peg.2670 or 1185660.4.peg.3117) and Unknown and (1185660.4.peg.3117 or 1185660.4.peg.2670) and (1185660.4.peg.2670 or 1185660.4.peg.3117))	-1000	0
# DMORh	alac__S_c + h_c + nadph_c <=> 23dhmb_c + nadp_c	(1185660.4.peg.3280 or 1185660.4.peg.3280)	-1000	1000
# DMPH	dgmp_c + h2o_c --> dgsn_c + pi_c	1185660.4.peg.1452	0	1000
# DMPPS	h2mb4p_c + h_c + nadh_c --> dmpp_c + h2o_c + nad_c	1185660.4.peg.2972	0	1000
# DMPPS_syn	dmpp_c + h2o_c + nadp_c <-- h2mb4p_c + h_c + nadph_c	1185660.4.peg.2972	-1000	0
# DMTPHT	ahcys_c + h_c + phllqne_c <-- amet_c + dmtphllqne_c	1185660.4.peg.668	-1000	0
# DNGALh	amp_c + glu__L_c + h_c + nad_c + ppi_c <-- atp_c + dnad_c + gln__L_c + h2o_c	1185660.4.peg.4569	-1000	0
# DPCOAK	adp_c + coa_c + h_c <-- atp_c + dpcoa_c	1185660.4.peg.4445	-1000	0
# DPR	2dhp_c + h_c + nadph_c <=> nadp_c + pant__R_c	(1185660.4.peg.3280 or 1185660.4.peg.4233 or 1185660.4.peg.4233)	-1000	1000
# DSERt2	h_e + ser__D_e <=> h_c + ser__D_c	1185660.4.peg.604	-1000	1000
# DTMPK	adp_c + dtdp_c <=> atp_c + dtmp_c	1185660.4.peg.3888	-1000	1000
# DURIK1	adp_c + dump_c + h_c <=> atp_c + duri_c	1185660.4.peg.4131	-1000	1000
# DURIt2	duri_e + h_e <=> duri_c + h_c	1185660.4.peg.866	-1000	1000
# DUTPDP	dump_c + h_c + ppi_c --> dutp_c + h2o_c	(1185660.4.peg.3789 or 1185660.4.peg.181)	0	0
# DXPRIi	2me4p_c + nadp_c <=> dxyl5p_c + h_c + nadph_c	1185660.4.peg.1657	-1000	1000
# DXPS	co2_c + dxyl5p_c <-- g3p_c + h_c + pyr_c	1185660.4.peg.2487	-1000	0
# E4PD	4per_c + 2.0 h_c + nadh_c <-- e4p_c + h2o_c + nad_c	1185660.4.peg.3376	-1000	0
# EAR100y	h_c + nadph_c + tdec2eACP_c --> dcaACP_c + nadp_c	1185660.4.peg.375	0	1000
# EAR120y	2.0 h_c + nadph_c + tddec2eACP_c --> ddcaACP_c + nadp_c	1185660.4.peg.375	0	1000
# EAR140y	2.0 h_c + nadph_c + tmrs2eACP_c --> myrsACP_c + nadp_c	1185660.4.peg.375	0	1000
# EAR40y	but2eACP_c + 2.0 h_c + nadph_c --> butACP_c + nadp_c	1185660.4.peg.375	0	1000
# EAR60y	h_c + nadph_c + thex2eACP_c --> hexACP_c + nadp_c	1185660.4.peg.375	0	1000
# EAR80y	h_c + nadph_c + toct2eACP_c --> nadp_c + ocACP_c	1185660.4.peg.375	0	1000
# ECOAH1	b2coa_c + h2o_c <=> 3hbcoa_c	(1185660.4.peg.912 or 1185660.4.peg.1548 or 1185660.4.peg.1440 or 1185660.4.peg.2234 or 1185660.4.peg.2984)	-1000	1000
# ECOAH12	2mp2coa_c + h2o_c <=> 3hibutcoa_c	(1185660.4.peg.1538 or (1185660.4.peg.912 or 1185660.4.peg.1548 or 1185660.4.peg.1440 or 1185660.4.peg.2234 or 1185660.4.peg.2984))	-1000	1000
# ECOAH3	h2o_c + oc2coa_c <=> 3hocoa_c	(1185660.4.peg.912 or 1185660.4.peg.2984 or 1185660.4.peg.1548 or 1185660.4.peg.1440 or 1185660.4.peg.2234)	-1000	1000
# ECOAH4	dc2coa_c + h2o_c <=> 3hdcoa_c	(1185660.4.peg.912 or 1185660.4.peg.2984 or 1185660.4.peg.1548 or 1185660.4.peg.2234 or 1185660.4.peg.1440)	-1000	1000
# ECOAH5	dd2coa_c + h2o_c <=> 3hddcoa_c	(1185660.4.peg.912 or 1185660.4.peg.1440 or 1185660.4.peg.1548 or 1185660.4.peg.2234 or 1185660.4.peg.2984)	-1000	1000
# ECOAH6	h2o_c + td2coa_c <=> 3htdcoa_c	(1185660.4.peg.912 or 1185660.4.peg.1548 or 1185660.4.peg.1440 or 1185660.4.peg.2234 or 1185660.4.peg.2984)	-1000	1000
# ECOAH7	h2o_c + hdd2coa_c <=> 3hhdcoa_c	(1185660.4.peg.912 or 1185660.4.peg.1548 or 1185660.4.peg.2234 or 1185660.4.peg.1440 or 1185660.4.peg.2984)	-1000	1000
# ECOAH9ir	2mb2coa_c + h2o_c <=> 3hmbcoa_c	((1185660.4.peg.912 or 1185660.4.peg.2984 or 1185660.4.peg.1548 or 1185660.4.peg.1440 or 1185660.4.peg.2234) or 1185660.4.peg.1538)	-1000	1000
# EDA	g3p_c + pyr_c <-- 2ddg6p_c	(1185660.4.peg.2340 and 1185660.4.peg.2340)	-1000	0
# EDD	2ddg6p_c + h2o_c <-- 6pgc_c	1185660.4.peg.2339	-1000	0
# EDTXS1	ACP_c + kdo2lipid4L_c <-- ddcaACP_c + kdo2lipid4_c	(1185660.4.peg.3583 or 1185660.4.peg.3295)	-1000	0
# EDTXS2	kdo2lipid4L_c + myrsACP_c --> ACP_c + lipa_c	Unknown	0	1000
# ENO	2pg_c --> h2o_c + pep_c	1185660.4.peg.1761	0	1000
# ETHAAL	etha_c --> acald_c + nh4_c	(1185660.4.peg.2019 or 1185660.4.peg.2020 or 1185660.4.peg.1394)	0	1000
# ETHAt2pp	etha_e + h_e <=> etha_c + h_c	1185660.4.peg.2018	-1000	1000
# ETOHti	etoh_c <=> etoh_e	Unknown	-1000	1000
# EX_2ddglcn_e	2ddglcn_e <=> 	Unknown	-10	1000
# EX_4hbz_e	4hbz_e <=> 	Unknown	-10	1000
# EX_ac_e	ac_e <=> 	Unknown	-10	1000
# EX_acald_e	acald_e <=> 	Unknown	-10	1000
# EX_acgam_e	acgam_e <=> 	Unknown	-10	1000
# EX_adn_e	adn_e <=> 	Unknown	-10	1000
# EX_akg_e	akg_e <=> 	Unknown	-10	1000
# EX_ala__D_e	ala__D_e <=> 	Unknown	-10	1000
# EX_arab__L_e	arab__L_e <=> 	Unknown	-10	1000
# EX_arbt_e	arbt_e <=> 	Unknown	-10	1000
# EX_arg__L_e	arg__L_e <=> 	Unknown	-10	1000
# EX_ASPt5n_e	asp__L_e <=> 	Unknown	-10	1000
# EX_Biomass_e	BIOMASS_c <=> 	Unknown	-10	1000
# EX_ca2_e	ca2_e <=> 	Unknown	-10	1000
# EX_cbl1_e	cbl1_e <=> 	Unknown	-10	1000
# EX_cd2_e	cd2_e <=> 	Unknown	-10	1000
# EX_chol_e	chol_e <=> 	Unknown	-10	1000
# EX_cit_e	cit_e <=> 	Unknown	-10	1000
# EX_cl_e	cl_e <=> 	Unknown	-10	1000
# EX_co2_e	co2_e <=> 	Unknown	-10	1000
# EX_cobalt2_e	cobalt2_e <=> 	Unknown	-10	1000
# EX_cu2_e	cu2_e <=> 	Unknown	-10	1000
# EX_cytd_e	cytd_e <=> 	Unknown	-10	1000
# EX_dad_2_e	dad_2_e <=> 	Unknown	-10	1000
# EX_dcyt_e	dcyt_e <=> 	Unknown	-10	1000
# EX_dgsn_e	dgsn_e <=> 	Unknown	-10	1000
# EX_din_e	din_e <=> 	Unknown	-10	1000
# EX_DNA_e	dna_c <=> 	(1185660.4.peg.2424 and 1185660.4.peg.1489 and Unknown and 1185660.4.peg.1148 and (1185660.4.peg.4396 or 1185660.4.peg.3601) and 1185660.4.peg.2423 and 1185660.4.peg.1485 and (1185660.4.peg.580 or 1185660.4.peg.4515 or 1185660.4.peg.1475 or 1185660.4.peg.1684 or 1185660.4.peg.3669 or 1185660.4.peg.811) and Unknown and 1185660.4.peg.1754 and Unknown and (1185660.4.peg.1299 or 1185660.4.peg.1300) and Unknown and 1185660.4.peg.88 and (1185660.4.peg.87 or 1185660.4.peg.3168) and 1185660.4.peg.3616 and 1185660.4.peg.2559 and 1185660.4.peg.3977 and 1185660.4.peg.1493 and 1185660.4.peg.90 and (1185660.4.peg.4372 or 1185660.4.peg.3116) and 1185660.4.peg.1127 and (1185660.4.peg.1226 or 1185660.4.peg.1648))	-10	1000
# EX_duri_e	duri_e <=> 	Unknown	-10	1000
# EX_etha_e	etha_e <=> 	Unknown	-10	1000
# EX_etoh_e	etoh_e <=> 	Unknown	-10	1000
# EX_fe2_e	fe2_e <=> 	Unknown	-10	1000
# EX_fe3_e	fe3_e <=> 	Unknown	-10	1000
# EX_for_e	for_e <=> 	Unknown	-10	1000
# EX_fru_e	fru_e <=> 	Unknown	-10	1000
# EX_fum_e	fum_e <=> 	Unknown	-10	1000
# EX_galt_e	galt_e <=> 	Unknown	-10	1000
# EX_galur_e	galur_e <=> 	Unknown	-10	1000
# EX_gam_e	gam_e <=> 	Unknown	-10	1000
# EX_glc__D_e	glc__D_e <=> 	Unknown	-10	1000
# EX_glcur_e	glcur_e <=> 	Unknown	-10	1000
# EX_gln__L_e	gln__L_e <=> 	Unknown	-10	1000
# EX_glu__L_e	glu__L_e <=> 	Unknown	-10	1000
# EX_gly_e	gly_e <=> 	Unknown	-10	1000
# EX_glyb_e	glyb_e <=> 	Unknown	-10	1000
# EX_glyc_e	glyc_e <=> 	Unknown	-10	1000
# EX_glycogen_e	glycogen_c <=> 	Unknown	-10	1000
# EX_h_e	h_e <=> 	Unknown	-10	1000
# EX_h2o_e	h2o_e <=> 	Unknown	-10	1000
# EX_hdca_e	hdca_e <=> 	Unknown	-10	1000
# EX_hxan_e	hxan_e <=> 	Unknown	-10	1000
# EX_ins_e	ins_e <=> 	Unknown	-10	1000
# EX_k_e	k_e <=> 	Unknown	-10	1000
# EX_lys__L_e	lys__L_e <=> 	Unknown	-10	1000
# EX_mal__L_e	mal__L_e <=> 	Unknown	-10	1000
# EX_malt_e	malt_e <=> 	Unknown	-10	1000
# EX_man_e	man_e <=> 	Unknown	-10	1000
# EX_met__D_e	met__D_e <=> 	Unknown	-10	1000
# EX_met__L_e	met__L_e <=> 	Unknown	-10	1000
# EX_metox__R_e	metox__R_e <=> 	Unknown	-10	1000
# EX_metsox_S__L_e	metsox_S__L_e <=> 	Unknown	-10	1000
# EX_mg2_e	mg2_e <=> 	Unknown	-10	1000
# EX_mn2_e	mn2_e <=> 	Unknown	-10	1000
# EX_mqn7_e	mqn7_e <=> 	Unknown	-10	1000
# EX_na1_e	na1_e <=> 	Unknown	-10	1000
# EX_nh4_e	nh4_e <=> 	Unknown	-10	1000
# EX_nmn_e	nmn_e <=> 	Unknown	-10	1000
# EX_no2_e	no2_e <=> 	Unknown	-10	1000
# EX_no3_e	no3_e <=> 	Unknown	-10	1000
# EX_o2_e	o2_e <=> 	Unknown	-20	1000
# EX_ocdca_e	ocdca_e <=> 	Unknown	-10	1000
# EX_orn_e	orn_e <=> 	Unknown	-10	1000
# EX_pi_e	pi_e <=> 	Unknown	-10	1000
# EX_ppi_e	ppi_e <=> 	Unknown	-10	1000
# EX_pro__L_e	pro__L_e <=> 	Unknown	-10	1000
# EX_protein_e	protein_c <=> 	(1185660.4.peg.3070 and 1185660.4.peg.1664 and 1185660.4.peg.3594 and 1185660.4.peg.1480 and 1185660.4.peg.2973 and Unknown and 1185660.4.peg.1139 and 1185660.4.peg.2979 and 1185660.4.peg.3792 and 1185660.4.peg.993 and 1185660.4.peg.1006 and 1185660.4.peg.1625 and 1185660.4.peg.2513 and 1185660.4.peg.1014 and 1185660.4.peg.2510 and 1185660.4.peg.1017 and 1185660.4.peg.3217 and 1185660.4.peg.1021 and 1185660.4.peg.460 and 1185660.4.peg.2976 and 1185660.4.peg.2514 and 1185660.4.peg.2516 and 1185660.4.peg.1008 and 1185660.4.peg.2406 and 1185660.4.peg.461 and 1185660.4.peg.1015 and 1185660.4.peg.1001 and 1185660.4.peg.3475 and 1185660.4.peg.1003 and 1185660.4.peg.4046 and 1185660.4.peg.1010 and 1185660.4.peg.1023 and 1185660.4.peg.1870 and 1185660.4.peg.1016 and 1185660.4.peg.1917 and 1185660.4.peg.1018 and 1185660.4.peg.3665 and 1185660.4.peg.1002 and 1185660.4.peg.987 and 1185660.4.peg.2887 and 1185660.4.peg.1011 and 1185660.4.peg.1022 and Unknown and 1185660.4.peg.2561 and 1185660.4.peg.1000 and 1185660.4.peg.1009 and 1185660.4.peg.4539 and 1185660.4.peg.1012 and 1185660.4.peg.988 and 1185660.4.peg.989 and 1185660.4.peg.4542 and 1185660.4.peg.3772 and 1185660.4.peg.999 and 1185660.4.peg.1019 and Unknown and 1185660.4.peg.2010 and Unknown and 1185660.4.peg.2978 and 1185660.4.peg.3987 and 1185660.4.peg.4047 and 1185660.4.peg.1013 and 1185660.4.peg.1007 and 1185660.4.peg.85 and 1185660.4.peg.1484 and 1185660.4.peg.1483 and 1185660.4.peg.1005 and 1185660.4.peg.1004 and 1185660.4.peg.2511 and 1185660.4.peg.1482 and 1185660.4.peg.2668 and 1185660.4.peg.2592 and 1185660.4.peg.1515 and 1185660.4.peg.3988 and 1185660.4.peg.992 and 1185660.4.peg.3879 and (1185660.4.peg.1786 or 1185660.4.peg.1976) and 1185660.4.peg.1025)	-10	1000
# EX_ptrc_e	ptrc_e <=> 	Unknown	-10	1000
# EX_pyr_e	pyr_e <=> 	Unknown	-10	1000
# EX_q8_e	q8_e <=> 	Unknown	-10	1000
# EX_q8h2_e	q8h2_e <=> 	Unknown	-10	1000
# EX_rna_c0	rna_c <=> 	(Unknown and 1185660.4.peg.3581 and 1185660.4.peg.1556 and 1185660.4.peg.4540 and Unknown and 1185660.4.peg.84 and 1185660.4.peg.991 and Unknown and 1185660.4.peg.749 and 1185660.4.peg.2596 and Unknown and 1185660.4.peg.990 and 1185660.4.peg.1024)	-10	1000
# EX_salcn_e	salcn_e <=> 	Unknown	-10	1000
# EX_sbt__D_e	sbt__D_e <=> 	Unknown	-10	1000
# EX_ser__D_e	ser__D_e <=> 	Unknown	-10	1000
# EX_ser__L_e	ser__L_e <=> 	Unknown	-10	1000
# EX_so4_e	so4_e <=> 	Unknown	-10	1000
# EX_spmd_e	spmd_e <=> 	Unknown	-10	1000
# EX_succ_e	succ_e <=> 	Unknown	-10	1000
# EX_sucr_e	sucr_e <=> 	Unknown	-10	1000
# EX_taur_e	taur_e <=> 	Unknown	-10	1000
# EX_thmmp_e	thmmp_e <=> 	Unknown	-10	1000
# EX_thymd_e	thymd_e <=> 	Unknown	-10	1000
# EX_tre_e	tre_e <=> 	Unknown	-10	1000
# EX_trp__L_e	trp__L_e <=> 	Unknown	-10	1000
# EX_tsul_e	tsul_e <=> 	Unknown	-10	1000
# EX_ttdca_e	ttdca_e <=> 	Unknown	-10	1000
# EX_uri_e	uri_e <=> 	Unknown	-10	1000
# EX_xyl__D_e	xyl__D_e <=> 	Unknown	-10	1000
# EX_zn2_e	zn2_e <=> 	Unknown	-10	1000
# FA100ACPHi	ACP_c + dca_c + h_c <=> dcaACP_c + h2o_c	1185660.4.peg.769	-1000	1000
# FA80ACPHi	ACP_c + h_c + octa_c <=> h2o_c + ocACP_c	1185660.4.peg.769	-1000	1000
# FACOAE160	coa_c + h_c + hdca_c --> h2o_c + pmtcoa_c	1185660.4.peg.2982	0	0
# FACOAE180	coa_c + h_c + ocdca_c --> h2o_c + stcoa_c	1185660.4.peg.2982	0	0
# FACOAE1836Z9Z12Z	coa_c + h_c + lnlncg_c <=> h2o_c + lnlncgcoa_c	1185660.4.peg.2982	-1000	1000
# FACOAL140	amp_c + ppi_c + tdcoa_c <-- atp_c + coa_c + ttdca_c	(1185660.4.peg.1922 or 1185660.4.peg.3392)	-1000	0
# FACOAL160	atp_c + coa_c + hdca_c --> amp_c + pmtcoa_c + ppi_c	(1185660.4.peg.3392 or 1185660.4.peg.1922)	0	0
# FACOAL180	amp_c + ppi_c + stcoa_c --> atp_c + coa_c + ocdca_c	(1185660.4.peg.1922 or 1185660.4.peg.3392)	0	0
# FAS140ACPm	ACP_c + co2_c + h2o_c + myrsACP_c + 2.0 nadp_c --> ddcaACP_c + 2.0 h_c + malACP_c + 2.0 nadph_c	Unknown	0	1000
# FBA	dhap_c + g3p_c <=> fdp_c	1185660.4.peg.3367	-1000	1000
# FBA3	s17bp_c <=> dhap_c + e4p_c	1185660.4.peg.3367	-1000	1000
# FBP	fdp_c + h2o_c --> f6p_c + pi_c	(1185660.4.peg.118 or 1185660.4.peg.1875)	0	1000
# FCLT	fe2_c + ppp9_c <=> pheme_c	1185660.4.peg.4059	-1000	1000
# FDH	co2_c + nadh_c <-- for_c + nad_c	(1185660.4.peg.2120 or 1185660.4.peg.2121)	-1000	0
# FE2abc	atp_c + fe2_e + h2o_c --> adp_c + fe2_c + h_c + pi_c	1185660.4.peg.1902	0	1000
# FE3abc	atp_c + fe3_e + h2o_c --> adp_c + fe3_c + h_c + pi_c	Unknown	0	1000
# FERO	4.0 fe2_c + 4.0 h_c + o2_c --> 4.0 fe3_c + 2.0 h2o_c	1185660.4.peg.2856	0	1000
# FGFTh	fgam_c + 2.0 h_c + thf_c <-- gar_c + h2o_c + methf_c	1185660.4.peg.3174	-1000	0
# FGLU	foam_c + glu__L_c --> forglu_c + h2o_c	1185660.4.peg.495	0	1000
# FK	adp_c + fuc1p__L_c + h_c <=> atp_c + fuc__L_c	1185660.4.peg.2140	-1000	1000
# FLVRx	2.0 h_c + nadh_c + ribflv_c <=> nad_c + rbflvrd_c	1185660.4.peg.2394	-1000	1000
# FMNRx	fmn_c + 2.0 h_c + nadh_c --> fmnh2_c + nad_c	1185660.4.peg.337	0	1000
# FOLR2	fol_c + h_c + nadph_c <=> dhf_c + nadp_c	(1185660.4.peg.722 or 1185660.4.peg.892)	-1000	1000
# FOMETRi	5fthf_c + h_c --> h2o_c + methf_c	1185660.4.peg.3174	0	0
# FORti	for_c --> for_e	Unknown	0	1000
# FPGFTh	fgam_c + h_c + thf_c --> 10fthf_c + gar_c	(1185660.4.peg.3174 or 1185660.4.peg.3174)	0	1000
# FPGS_tm	adp_c + h_c + pi_c + thfglu_c <-- atp_c + glu__L_c + thf_c	(1185660.4.peg.1057 and 1185660.4.peg.1057)	-1000	0
# FPPSh	grdp_c + ipdp_c --> frdp_c + ppi_c	(((1185660.4.peg.2670 or 1185660.4.peg.3117) and (1185660.4.peg.3117 or 1185660.4.peg.2670) and (1185660.4.peg.2670 or 1185660.4.peg.3117) and Unknown) or (1185660.4.peg.3117 or 1185660.4.peg.2670))	0	1000
# FRD	fad_c + h_c + succ_c --> fadh2_c + fum_c	(1185660.4.peg.2332 or 1185660.4.peg.2331 or (1185660.4.peg.2330 and 1185660.4.peg.2328 and Unknown))	0	1000
# FRD2	fum_c + mql8_c --> mqn8_c + succ_c	(1185660.4.peg.2330 or (1185660.4.peg.2332 and Unknown and 1185660.4.peg.2331 and Unknown and Unknown and Unknown) or (1185660.4.peg.2328 and 1185660.4.peg.2330))	0	1000
# FRD3	2dmmq8_c + succ_c <-- 2dmmql8_c + fum_c	(1185660.4.peg.2330 or (Unknown and Unknown and Unknown and 1185660.4.peg.2331 and 1185660.4.peg.2332 and Unknown) or (1185660.4.peg.2330 and 1185660.4.peg.2328))	-1000	0
# FRD7	fum_c + q8h2_c --> q8_c + succ_c	(1185660.4.peg.2330 or (1185660.4.peg.2332 and Unknown and Unknown and Unknown and Unknown and 1185660.4.peg.2331) or (1185660.4.peg.2330 and 1185660.4.peg.2328))	0	0
# FRTT	ggdp_c + ppi_c <-- frdp_c + ipdp_c	(1185660.4.peg.3117 or 1185660.4.peg.2670)	-1000	0
# FRUK	adp_c + fdp_c + h_c <=> atp_c + f1p_c	(Unknown and 1185660.4.peg.2140)	-1000	1000
# FRUpts	fru_e + pep_c <=> f1p_c + pyr_c	(1185660.4.peg.2141 and Unknown and (1185660.4.peg.2139 or 1185660.4.peg.2706) and 1185660.4.peg.2141 and Unknown)	-1000	1000
# FT	ppi_c + ttc_ggdp_c <-- frdp_c + ipdp_c	1185660.4.peg.1659	-1000	0
# FTCL	5fthf_c + atp_c --> adp_c + methf_c + pi_c	1185660.4.peg.3239	0	0
# FTHFD	for_c + h_c + thf_c --> 10fthf_c + h2o_c	1185660.4.peg.325	0	0
# FUM	fum_c + h2o_c --> mal__L_c	(1185660.4.peg.1324 or 1185660.4.peg.1397)	0	1000
# FUMt2r	fum_e + h_e <=> fum_c + h_c	(1185660.4.peg.139 or 1185660.4.peg.3301)	-1000	1000
# G1PACT	acgam1p_c + coa_c + h_c <-- accoa_c + gam1p_c	(1185660.4.peg.3717 and 1185660.4.peg.3717)	-1000	0
# G1PTT	dtdpglu_c + ppi_c <=> dttp_c + g1p_c + h_c	1185660.4.peg.3421	-1000	1000
# G1SAT	glu1sa_c <=> 5aop_c	(1185660.4.peg.3247 or 1185660.4.peg.4083)	-1000	1000
# G3PAT120	1ddecg3p_c + ACP_c <-- ddcaACP_c + glyc3p_c	1185660.4.peg.4105	-1000	0
# G3PAT140	1tdecg3p_c + ACP_c --> glyc3p_c + myrsACP_c	1185660.4.peg.4105	0	0
# G3PAT141	glyc3p_c + h_c + tdeACP_c --> 1tdec7eg3p_c + ACP_c	1185660.4.peg.4105	0	1000
# G3PAT160	glyc3p_c + 3.0 h_c + palmACP_c --> 1hdecg3p_c + ACP_c	1185660.4.peg.4105	0	1000
# G3PAT160_1	1hdecg3p_c + coa_c <-- glyc3p_c + h_c + pmtcoa_c	1185660.4.peg.4105	-1000	0
# G3PAT161	glyc3p_c + 3.0 h_c + hdeACP_c --> 1hdec9eg3p_c + ACP_c	1185660.4.peg.4105	0	1000
# G3PAT180	glyc3p_c + h_c + ocdcaACP_c --> 1odecg3p_c + ACP_c	1185660.4.peg.4105	0	1000
# G3PAT181	glyc3p_c + h_c + octeACP_c --> 1odec11eg3p_c + ACP_c	1185660.4.peg.4105	0	1000
# G3PD	fad_c + glyc3p_c + h_c <=> dhap_c + fadh2_c	1185660.4.peg.640	-1000	1000
# G3PD1	dhap_c + h_c + nadh_c <=> glyc3p_c + nad_c	(1185660.4.peg.202 or 1185660.4.peg.202)	-1000	1000
# G3PD5	dhap_c + q8h2_c --> glyc3p_c + q8_c	1185660.4.peg.640	0	0
# G3PD6	dhap_c + mql8_c <-- glyc3p_c + mqn8_c	1185660.4.peg.640	-1000	0
# G3PD7	2dmmq8_c + glyc3p_c --> 2dmmql8_c + dhap_c	1185660.4.peg.640	0	0
# G3PL	g3p_c + indole_c <=> 3ig3p_c	((1185660.4.peg.2625 and 1185660.4.peg.2623) or 1185660.4.peg.4208)	-1000	1000
# G5DHx	glu5p_c + h_c + nadph_c --> glu5sa_c + nadp_c + pi_c	1185660.4.peg.1998	0	1000
# G5SADrm	1pyr5c_c + h2o_c + h_c --> glu5sa_c	Unknown	0	0
# G6PBDH	6pgl_c + h_c + nadph_c <-- g6p_B_c + nadp_c	(1185660.4.peg.4250 or 1185660.4.peg.2336)	-1000	0
# G6PDA	gam6p_c + h2o_c --> f6p_c + nh4_c	1185660.4.peg.746	0	1000
# G6PDH2r	g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c	(1185660.4.peg.2336 or 1185660.4.peg.4250)	-1000	1000
# G6PI	g6p_c <=> g6p_B_c	1185660.4.peg.1829	-1000	1000
# G6PI3	g6p_B_c <=> f6p_c	1185660.4.peg.1829	-1000	1000
# GALCTD	galct__D_c --> 5dh4dglc_c + h2o_c	(1185660.4.peg.3784 or 1185660.4.peg.3422)	0	1000
# GALCTND	2dh3dgal_c + h2o_c <-- galctn__D_c	(1185660.4.peg.1805 or 1185660.4.peg.1805)	-1000	0
# GALh	adp_c + gln__L_c + h_c + pi_c --> atp_c + glu__L_c + nh4_c	1185660.4.peg.182	0	0
# GALM1	glc_bD_c --> glc__D_c	1185660.4.peg.4549	0	0
# GALT1	gagicolipa_c + h_c + udp_c <-- gicolipa_c + udpg_c	Unknown	-1000	0
# GALTpts	galt_e + pep_c <=> galt1p_c + h_c + pyr_c	(Unknown and Unknown and Unknown and Unknown and (1185660.4.peg.2139 or 1185660.4.peg.2706))	-1000	1000
# GALUi	ppi_c + udpg_c <=> g1p_c + h_c + utp_c	1185660.4.peg.2398	-1000	1000
# GAM	gln__L_c + h2o_c --> glu__L_c + nh4_c	1185660.4.peg.4569	0	0
# GAMpts	gam6p_c + pyr_c <=> gam_e + pep_c	(Unknown and (1185660.4.peg.2139 or 1185660.4.peg.2706))	-1000	1000
# GAPD	13dpg_c + h_c + nadh_c <=> g3p_c + nad_c + pi_c	1185660.4.peg.3376	-1000	1000
# GAPDH_nadp_hi	13dpg_c + h_c + nadph_c --> g3p_c + nadp_c + pi_c	1185660.4.peg.2099	0	1000
# GART	adp_c + fgam_c + h_c + pi_c <-- atp_c + for_c + gar_c	1185660.4.peg.2992	-1000	0
# GCC2cm	h_c + lpam_c + nadh_c <=> dhlam_c + nad_c	(1185660.4.peg.1386 or 1185660.4.peg.3732)	-1000	1000
# GCCa	alpro_c + co2_c <-- gly_c + lpro_c	1185660.4.peg.3027	-1000	0
# GCCb	dhlpro_c + mlthf_c + nh4_c <-- alpro_c + h_c + thf_c	((1185660.4.peg.2787 and 1185660.4.peg.2786) or 1185660.4.peg.3174)	-1000	0
# GCCc	h_c + lpro_c + nadh_c <=> dhlpro_c + nad_c	((1185660.4.peg.3027 and 1185660.4.peg.2786) or (1185660.4.peg.2786 and Unknown and Unknown))	-1000	1000
# GCL	adp_c + glucys_c + h_c + pi_c <-- atp_c + cys__L_c + glu__L_c	1185660.4.peg.760	-1000	0
# GDH	akg_c + h_c + nadh_c + nh4_c <=> glu__L_c + h2o_c + nad_c	1185660.4.peg.2135	-1000	1000
# GF6PTA	gam6p_c + glu__L_c --> f6p_c + gln__L_c	1185660.4.peg.3708	0	0
# GGGABADr	ggbutal_c + h2o_c + nadp_c --> gg4abut_c + 2.0 h_c + nadph_c	1185660.4.peg.2630	0	1000
# GGTT	pendp_c + ppi_c <-- ggdp_c + ipdp_c	(1185660.4.peg.2670 or 1185660.4.peg.3117)	-1000	0
# GHMT	gly_c + h2o_c + mlthf_c --> ser__L_c + thf_c	1185660.4.peg.772	0	1000
# GK1	atp_c + gmp_c <=> adp_c + gdp_c	(1185660.4.peg.3224 or 1185660.4.peg.3224)	-1000	1000
# GK2	datp_c + gmp_c <=> dadp_c + gdp_c	1185660.4.peg.3224	-1000	1000
# GLCabcpp	adp_c + glc__D_c + h_c + pi_c <-- atp_c + glc__D_e + h2o_c	1185660.4.peg.2334	-1000	0
# GLCpts	g6p_c + pyr_c <=> glc__D_e + pep_c	(Unknown and Unknown and Unknown and (1185660.4.peg.2139 or 1185660.4.peg.2706) and Unknown)	-1000	1000
# GLCTR2	ggagicolipa_c + h_c + udp_c <-- gagicolipa_c + udpg_c	Unknown	-1000	0
# GLCTR3	gggagicolipa_c + h_c + udp_c <-- ggagicolipa_c + udpg_c	Unknown	-1000	0
# GLNabc	atp_c + gln__L_e + h2o_c <=> adp_c + gln__L_c + h_c + pi_c	xanmn_chr13_0041	-1000	1000
# GLNSP1	adp_c + h_c + pi_c + uaaAgtla_c <-- atp_c + nh4_c + uaaAgla_c	1185660.4.peg.182	-1000	0
# GLNSP2	atp_c + nh4_c + uaaGgla_c --> adp_c + h_c + pi_c + uaaGgtla_c	1185660.4.peg.182	0	1000
# GLNSP3	atp_c + nh4_c + uaagmda_c --> adp_c + h_c + pi_c + uaagtmda_c	1185660.4.peg.182	0	1000
# GLU5K	adp_c + glu5p_c <=> atp_c + glu__L_c	1185660.4.peg.1999	-1000	1000
# GLUFORT	forglu_c + thf_c <=> 5forthf_c + glu__L_c	1185660.4.peg.3594	-1000	1000
# GLUFT	Nforglu_c + h_c + thf_c <-- 5fthf_c + glu__L_c	1185660.4.peg.3594	-1000	0
# GLUK_syn	atp_c + glc_bD_c --> adp_c + g6p_B_c + h_c	1185660.4.peg.2337	0	0
# GLUPRT	glu__L_c + ppi_c + pram_c <-- gln__L_c + h2o_c + prpp_c	1185660.4.peg.1060	-1000	0
# ...
# rxn01080_c0	fruur_c <=> glcur_c	1185660.4.peg.4092	-1000	1000
# rxn01292_c0	arab__L_c <=> rbl__L_c	1185660.4.peg.3417	-1000	1000
# rxn01457_c0	tagur_c <=> galur_c	1185660.4.peg.4092	-1000	1000
# rxn02362_c0	13dpg_c + atp_c <=> adp_c + cdpg_c + pi_c	1185660.4.peg.1764	-1000	1000
# rxn03462_c0	MNXM63441_c + gal_bD_c <=> MNXM2977_c + h2o_c	(1185660.4.peg.2807 or 1185660.4.peg.1532 or 1185660.4.peg.1812 or 1185660.4.peg.1531 or 1185660.4.peg.4091)	-1000	1000
# rxn03893_c0	3ophb_c + h_c + ppi_c <-- 4hbz_c + MNXM53112_c	1185660.4.peg.1241	-1000	0
# rxn04052_c0	copre8_c + h_c <=> cobn_c	1185660.4.peg.3788	-1000	1000
# rxn05336_c0	3opalmACP_c + nadph_c <=> 3hpalmACP_c + nadp_c	(1185660.4.peg.1112 or 1185660.4.peg.3753 or 1185660.4.peg.3578 or 1185660.4.peg.409 or 1185660.4.peg.401 or 1185660.4.peg.4522 or 1185660.4.peg.1143)	-1000	1000
# rxn05342_c0	3omrsACP_c + nadph_c <=> 3hmrsACP_c + nadp_c	(1185660.4.peg.3578 or 1185660.4.peg.1143 or 1185660.4.peg.4522 or 1185660.4.peg.401 or 1185660.4.peg.409 or 1185660.4.peg.1112 or 1185660.4.peg.3753)	-1000	1000
# rxn05343_c0	3odecACP_c + ACP_c + co2_c <-- malACP_c + ocACP_c	(((1185660.4.peg.1140 or 1185660.4.peg.2283) and 1185660.4.peg.1145) or 1185660.4.peg.3695)	-1000	0
# rxn05344_c0	3opalmACP_c + ACP_c + co2_c <-- malACP_c + myrsACP_c	(((1185660.4.peg.2283 or 1185660.4.peg.1140) and 1185660.4.peg.1145) or 1185660.4.peg.3695)	-1000	0
# rxn05345_c0	3omrsACP_c + ACP_c + co2_c <-- ddcaACP_c + malACP_c	(((1185660.4.peg.1140 or 1185660.4.peg.2283) and 1185660.4.peg.1145) or 1185660.4.peg.3695)	-1000	0
# rxn05346_c0	3ohexACP_c + ACP_c + co2_c <-- butACP_c + malACP_c	((1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283)) or 1185660.4.peg.3695)	-1000	0
# rxn05347_c0	ACP_c + actACP_c + co2_c <-- acACP_c + malACP_c	((1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283)) or 1185660.4.peg.3695)	-1000	0
# rxn05348_c0	3oddecACP_c + ACP_c + co2_c <-- dcaACP_c + malACP_c	((1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283)) or 1185660.4.peg.3695)	-1000	0
# rxn05359_c0	ACP_c + MNXM10219_c + co2_c <-- MNXM9860_c + malACP_c	(1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283))	-1000	0
# rxn05363_c0	ACP_c + MNXM10370_c + co2_c <-- MNXM8147_c + malACP_c	((1185660.4.peg.2283 or 1185660.4.peg.1140) and 1185660.4.peg.1145)	-1000	0
# rxn05367_c0	ACP_c + MNXM10448_c + co2_c <-- MNXM8195_c + malACP_c	(1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283))	-1000	0
# rxn05371_c0	ACP_c + MNXM9655_c + co2_c <-- MNXM8218_c + malACP_c	(1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283))	-1000	0
# rxn05375_c0	ACP_c + MNXM9684_c + co2_c <-- MNXM8003_c + malACP_c	(1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283))	-1000	0
# rxn05379_c0	ACP_c + MNXM9700_c + co2_c <-- MNXM6636_c + malACP_c	((1185660.4.peg.1140 or 1185660.4.peg.2283) and 1185660.4.peg.1145)	-1000	0
# rxn05384_c0	ACP_c + MNXM10327_c + co2_c <-- MNXM11926_c + malACP_c	(1185660.4.peg.1145 and (1185660.4.peg.2283 or 1185660.4.peg.1140))	-1000	0
# rxn05388_c0	ACP_c + MNXM10423_c + co2_c <-- MNXM8175_c + malACP_c	((1185660.4.peg.1140 or 1185660.4.peg.2283) and 1185660.4.peg.1145)	-1000	0
# rxn05392_c0	ACP_c + MNXM10475_c + co2_c <-- MNXM8209_c + malACP_c	((1185660.4.peg.2283 or 1185660.4.peg.1140) and 1185660.4.peg.1145)	-1000	0
# rxn05396_c0	ACP_c + MNXM9671_c + co2_c <-- MNXM8225_c + malACP_c	(1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283))	-1000	0
# rxn05400_c0	ACP_c + MNXM9695_c + co2_c <-- MNXM8010_c + malACP_c	(1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283))	-1000	0
# rxn05404_c0	ACP_c + MNXM9707_c + co2_c <-- MNXM6644_c + malACP_c	((1185660.4.peg.1140 or 1185660.4.peg.2283) and 1185660.4.peg.1145)	-1000	0
# rxn05409_c0	ACP_c + MNXM10220_c + co2_c <-- MNXM11912_c + malACP_c	((1185660.4.peg.1140 or 1185660.4.peg.2283) and 1185660.4.peg.1145)	-1000	0
# rxn05413_c0	ACP_c + MNXM10369_c + co2_c <-- MNXM8148_c + malACP_c	(1185660.4.peg.1145 and (1185660.4.peg.2283 or 1185660.4.peg.1140))	-1000	0
# rxn05417_c0	ACP_c + MNXM10449_c + co2_c <-- MNXM8194_c + malACP_c	(1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283))	-1000	0
# rxn05421_c0	ACP_c + MNXM9656_c + co2_c <-- MNXM8219_c + malACP_c	((1185660.4.peg.2283 or 1185660.4.peg.1140) and 1185660.4.peg.1145)	-1000	0
# rxn05425_c0	ACP_c + MNXM9685_c + co2_c <-- MNXM8006_c + malACP_c	(1185660.4.peg.1145 and (1185660.4.peg.1140 or 1185660.4.peg.2283))	-1000	0
# rxn05429_c0	ACP_c + MNXM9701_c + co2_c <-- MNXM6637_c + malACP_c	((1185660.4.peg.2283 or 1185660.4.peg.1140) and 1185660.4.peg.1145)	-1000	0
# rxn05460_c0	ACP_c + MNXM10116_c + co2_c <-- MNXM25932_c + malACP_c	((1185660.4.peg.2283 or 1185660.4.peg.1140) and 1185660.4.peg.1145)	-1000	0
# rxn06181_c0	MNXM7713_c + atp_c + h_c <=> MNXM9056_c + adp_c	1185660.4.peg.2256	-1000	1000
# rxn06453_c0	MNXM8658_c + udp_c <=> MNXM93437_c + udpg_c	1185660.4.peg.2519	-1000	1000
# rxn06723_c0	ACP_c + u23ga_c <-- 3hmrsACP_c + u3hga_c	1185660.4.peg.1653	-1000	0
# rxn08333_c0	2dmmql8_c + co2_c + ppi_c <-- MNXM53112_c + dhna_c	Unknown	-1000	0
# rxn09448_c0	amp_c + odecoa_c + ppi_c <-- MNXM65309_c + atp_c + coa_c	(1185660.4.peg.3392 or 1185660.4.peg.1922)	-1000	0
# rxn09988_c0	3.0 arab__L_c <-- MNXM42463_c + 2.0 h2o_c	1185660.4.peg.4551	-1000	0
# rxn11612_c0	MNXM7555_c + gal_bD_c <=> MNXM1225_c + h2o_c	(1185660.4.peg.1812 or 1185660.4.peg.1532 or 1185660.4.peg.2807 or 1185660.4.peg.4091 or 1185660.4.peg.1531)	-1000	1000
# rxn12008_c0	MNXM53112_c + ppi_c <-- hepdp_c + ipdp_c	(1185660.4.peg.2670 or 1185660.4.peg.3117)	-1000	0
# rxn13990_c0	acgam1p_c + adp_c + h_c <=> acgam_c + atp_c	1185660.4.peg.1095	-1000	1000
# RZ5PP	5prdmbz_c + h2o_c --> pi_c + rdmbzi_c	1185660.4.peg.2925	0	1000
# S7PI	gmhep7p_c <-- s7p_c	Unknown	-1000	0
# SADT	aps_c + ppi_c <-- atp_c + h_c + so4_c	(1185660.4.peg.3353 or 1185660.4.peg.3352)	-1000	0
# SADT2	aps_c + gdp_c + pi_c + ppi_c <-- atp_c + gtp_c + h2o_c + so4_c	(1185660.4.peg.3353 and 1185660.4.peg.3352)	-1000	0
# SALCpts	pyr_c + salc6p_c <=> pep_c + salcn_e	(Unknown and (1185660.4.peg.2139 or 1185660.4.peg.2706) and Unknown and Unknown and Unknown)	-1000	1000
# SAM24MT	amet_c + zymst_c <=> ahcys_c + fecost_c + h_c	1185660.4.peg.890	-1000	1000
# SBP	h2o_c + s17bp_c --> pi_c + s7p_c	1185660.4.peg.1875	0	0
# SBTPD	f6p_c + h_c + nadh_c <=> nad_c + sbt6p_c	(1185660.4.peg.3428 or 1185660.4.peg.3428)	-1000	1000
# SBTpts	pyr_c + sbt6p_c <=> pep_c + sbt__D_e	(Unknown and (1185660.4.peg.2706 or 1185660.4.peg.2139) and Unknown and Unknown and Unknown)	-1000	1000
# SDPDS	h2o_c + sl26da_c <=> 26dap_LL_c + succ_c	1185660.4.peg.1289	-1000	1000
# SDPTA	akg_c + sl26da_c <=> glu__L_c + sl2a6o_c	1185660.4.peg.2157	-1000	1000
# SELCYSTS	h2o_c + selcyst_c <=> selhcys_c + ser__L_c	(1185660.4.peg.3491 or 1185660.4.peg.4405)	-1000	1000
# SERD_L	nh4_c + pyr_c <-- ser__L_c	(1185660.4.peg.2756 and 1185660.4.peg.2756)	-1000	0
# SERH	g3p_c + h2o_c + trp__L_c <-- 3ig3p_c + ser__L_c	((1185660.4.peg.2625 and 1185660.4.peg.2623) or 1185660.4.peg.4208)	-1000	0
# SERt2m	h_e + ser__L_e <=> h_c + ser__L_c	1185660.4.peg.604	-1000	1000
# SHCHD2	2.0 h_c + nadh_c + scl_c <-- dscl_c + nad_c	Unknown	-1000	0
# SHCHF	fe2_c + scl_c <=> 2.0 h_c + sheme_c	1185660.4.peg.2210	-1000	1000
# SHK3Dr	3dhsk_c + h_c + nadph_c <=> nadp_c + skm_c	1185660.4.peg.4204	-1000	1000
# SHKK	adp_c + h_c + skm5p_c <-- atp_c + skm_c	Unknown	-1000	0
# SHSL4h	2obut_c + h_c + nh4_c + succ_c <-- h2o_c + suchms_c	1185660.4.peg.2760	-1000	0
# SO4t2	h_e + so4_e <=> h_c + so4_c	(1185660.4.peg.620 or 1185660.4.peg.3568)	-1000	1000
# SOTA	akg_c + sucorn_c <=> glu__L_c + sucgsa_c	1185660.4.peg.2157	-1000	1000
# SPMDabc	atp_c + h2o_c + spmd_e --> adp_c + h_c + pi_c + spmd_c	(Unknown and Unknown and Unknown and 1185660.4.peg.2103 and 1185660.4.peg.2101 and 1185660.4.peg.2102 and Unknown)	0	1000
# SPODM	2.0 h_c + 2.0 o2s_c --> h2o2_c + o2_c	(1185660.4.peg.2037 or 1185660.4.peg.2584 or (1185660.4.peg.188 or 1185660.4.peg.187))	0	1000
# SPTc	pyr_c + ser__L_c <=> ala__L_c + hpyr_c	(1185660.4.peg.295 and 1185660.4.peg.295)	-1000	1000
# SSALx	2.0 h_c + nadh_c + succ_c <-- h2o_c + nad_c + sucsal_c	1185660.4.peg.2099	-1000	0
# SUCBZL	amp_c + ppi_c + sbzcoa_c <-- atp_c + coa_c + sucbz_c	1185660.4.peg.910	-1000	0
# SUCCt2b	h_e + succ_e <=> h_c + succ_c	1185660.4.peg.139	-1000	1000
# SUCD4	fad_c + h_c + q8h2_c <-- fadh2_c + q8_c	((1185660.4.peg.2330 and 1185660.4.peg.2328) or 1185660.4.peg.2332 or 1185660.4.peg.2331)	-1000	0
# SUCLm	atp_c + coa_c + succ_c <-- adp_c + pi_c + succoa_c	(1185660.4.peg.4572 and 1185660.4.peg.4573)	-1000	0
# SUCRe	h2o_c + sucr_c --> fru_c + glc__D_c	(1185660.4.peg.2799 or 1185660.4.peg.1529)	0	1000
# SUCRt2	h_e + sucr_e <=> h_c + sucr_c	xanmn_chr08_0051	-1000	1000
# SULabc	adp_c + h_c + pi_c + so4_c <-- atp_c + h2o_c + so4_e	(1185660.4.peg.1048 and 1185660.4.peg.1046 and 1185660.4.peg.1049 and 1185660.4.peg.1047)	-1000	0
# SULR	4.0 h_c + hso3_c + 3.0 nadph_c <=> 3.0 h2o_c + h2s_c + 3.0 nadp_c	(1185660.4.peg.3355 and 1185660.4.peg.3354)	-1000	1000
# TAL	thr__L_c --> 2obut_c + nh4_c	(1185660.4.peg.1107 or 1185660.4.peg.3283)	0	1000
# TALA	g3p_c + s7p_c <=> e4p_c + f6p_c	1185660.4.peg.933	-1000	1000
# TAUDO	aacald_c + co2_c + h_c + hso3_c + succ_c <-- akg_c + o2_c + taur_c	1185660.4.peg.876	-1000	0
# TAURabc	adp_c + h_c + pi_c + taur_c <-- atp_c + h2o_c + taur_e	(1185660.4.peg.874 or 1185660.4.peg.875 or 1185660.4.peg.873)	-1000	0
# TDPDRE	dtdp4d6dm_c <=> dtdp4d6dg_c	1185660.4.peg.3420	-1000	1000
# TDPDRR	dtdp4d6dm_c + h_c + nadph_c <=> dtdprmn_c + nadp_c	(1185660.4.peg.3419 or 1185660.4.peg.3419)	-1000	1000
# TDPGDH	dtdpglu_c --> dtdp4d6dg_c + h2o_c	(1185660.4.peg.3422 or 1185660.4.peg.3784)	0	1000
# TDSK	atp_c + lipidAds_c <=> adp_c + h_c + lipidA_c	1185660.4.peg.2318	-1000	1000
# TDSRh	h_c + nadph_c + trdox_c <=> nadp_c + trdrd_c	(1185660.4.peg.596 or 1185660.4.peg.1207 or 1185660.4.peg.1206 or 1185660.4.peg.2243)	-1000	1000
# THD2	2.0 h_e + nadh_c + nadp_c <=> 2.0 h_c + nad_c + nadph_c	(Unknown and (1185660.4.peg.950 or 1185660.4.peg.946))	-1000	1000
# THDPS	coa_c + sl2a6o_c --> h2o_c + succoa_c + thdp_c	(1185660.4.peg.1287 or 1185660.4.peg.1287)	0	1000
# THIORDXi	2.0 h2o_c + trdox_c <-- h2o2_c + trdrd_c	(1185660.4.peg.3628 or 1185660.4.peg.4558)	-1000	0
# THMDt2	h_e + thymd_e <=> h_c + thymd_c	1185660.4.peg.866	-1000	1000
# THRA	thr__L_c --> acald_c + gly_c	1185660.4.peg.450	0	1000
# THRS	h2o_c + phom_c --> pi_c + thr__L_c	1185660.4.peg.1865	0	1000
# THZPSN	4hba_c + 4mpetz_c + ala__L_c + amp_c + co2_c + h2o_c + h_c + ppi_c <-- atp_c + cys__L_c + dxyl5p_c + tyr__L_c	(Unknown and 1185660.4.peg.3178 and 1185660.4.peg.3179 and Unknown and Unknown and 1185660.4.peg.162)	-1000	0
# TKT1	r5p_c + xu5p__D_c <=> g3p_c + s7p_c	1185660.4.peg.3200	-1000	1000
# TKT2	e4p_c + xu5p__D_c <=> f6p_c + g3p_c	1185660.4.peg.3200	-1000	1000
# TMDK1	adp_c + dtmp_c + h_c <=> atp_c + thymd_c	1185660.4.peg.4131	-1000	1000
# TMDPP	2dr1p_c + thym_c <=> pi_c + thymd_c	(1185660.4.peg.3230 or 1185660.4.peg.945)	-1000	1000
# TMDS	dump_c + mlthf_c --> dhf_c + dtmp_c	1185660.4.peg.890	0	1000
# TMPK	adp_c + thmpp_c <=> atp_c + thmmp_c	1185660.4.peg.781	-1000	1000
# TMPPP	2mahmp_c + 4mpetz_c + h_c <=> ppi_c + thmmp_c	1185660.4.peg.3245	-1000	1000
# TPI	g3p_c <=> dhap_c	1185660.4.peg.2612	-1000	1000
# TPRDCOAS	2tpr3dpcoa_c + ade_c <=> atp_c + dpcoa_c	1185660.4.peg.2162	-1000	1000
# TRE6PP	pi_c + tre_c <-- h2o_c + tre6p_c	(1185660.4.peg.2947 or 1185660.4.peg.3934)	-1000	0
# TRE6PS	g6p_c + udpg_c <=> h_c + tre6p_c + udp_c	1185660.4.peg.2949	-1000	1000
# TREpts	pep_c + tre_e <=> pyr_c + tre6p_c	(Unknown and (1185660.4.peg.2139 or 1185660.4.peg.2706) and Unknown and Unknown)	-1000	1000
# TRPO2	Lfmkynr_c <-- o2_c + trp__L_c	((1185660.4.peg.419 or 1185660.4.peg.418) or (1185660.4.peg.419 or 1185660.4.peg.418))	-1000	0
# TRPS2	h2o_c + trp__L_c <-- indole_c + ser__L_c	((1185660.4.peg.2623 and 1185660.4.peg.2625) or 1185660.4.peg.4208)	-1000	0
# TRPt2m	h_e + trp__L_e --> h_c + trp__L_c	Unknown	0	1000
# TSULabc	adp_c + h_e + pi_c + tsul_c <-- atp_c + h2o_c + tsul_e	(1185660.4.peg.1046 or 1185660.4.peg.1049)	-1000	0
# TTDCAt2	h_e + ttdca_e <=> h_c + ttdca_c	1185660.4.peg.14	-1000	1000
# TYRCBOX	co2_c + tym_c <-- h_c + tyr__L_c	1185660.4.peg.850	-1000	0
# UAAGDS	adp_c + h_c + pi_c + ugmd_c <-- 26dap__M_c + atp_c + uamag_c	1185660.4.peg.817	-1000	0
# UAAGLS1	adp_c + h_c + pi_c + uAgl_c <=> atp_c + lys__L_c + uamag_c	1185660.4.peg.3239	-1000	1000
# UAGAAT	3hmrsACP_c + h_c + uacgam_c --> ACP_c + u3aga_c	1185660.4.peg.1651	0	1000
# UAGCVT	pi_c + uaccg_c <=> pep_c + uacgam_c	1185660.4.peg.2692	-1000	1000
# UAGDP	ppi_c + uacgam_c <=> acgam1p_c + h_c + utp_c	(1185660.4.peg.3717 and 1185660.4.peg.3717)	-1000	1000
# UAGPT2	h_c + uaaGgla_c + udp_c <=> uaGgla_c + uacgam_c	1185660.4.peg.820	-1000	1000
# UAGPT3	h_c + uaagmda_c + udp_c <=> uacgam_c + uagmda_c	1185660.4.peg.820	-1000	1000
# UAMAGS	atp_c + glu__D_c + uama_c --> adp_c + h_c + pi_c + uamag_c	1185660.4.peg.3119	0	1000
# UAMAS	adp_c + h_c + pi_c + uama_c <-- ala__L_c + atp_c + uamr_c	1185660.4.peg.821	-1000	0
# UAPGR	h_c + nadph_c + uaccg_c <=> nadp_c + uamr_c	1185660.4.peg.1848	-1000	1000
# UDPGD	3.0 h_c + 2.0 nadh_c + udpglcur_c <=> h2o_c + 2.0 nad_c + udpg_c	(1185660.4.peg.3418 or 1185660.4.peg.1406)	-1000	1000
# UGAH	h2o_c + udg_c <=> nh4_c + urdglyc_c	1185660.4.peg.2408	-1000	1000
# UGMDDS	alaala_c + atp_c + ugmd_c --> adp_c + h_c + pi_c + ugmda_c	1185660.4.peg.818	0	1000
# UHBZ1t_pp	4hbz_e + h_e --> 4hbz_c + h_c	Unknown	0	1000
# UHGADA	ac_c + u3hga_c <=> h2o_c + u3aga_c	1185660.4.peg.826	-1000	1000
# UMPK	adp_c + udp_c <=> atp_c + ump_c	(1185660.4.peg.3265 or 1185660.4.peg.3224)	-1000	1000
# UPP3S	h2o_c + uppg3_c <=> hmbil_c	1185660.4.peg.196	-1000	1000
# UPPDC1	4.0 co2_c + cpppg3_c <=> 4.0 h_c + uppg3_c	1185660.4.peg.2745	-1000	1000
# UPPDC2	4.0 h_c + uppg1_c <=> 4.0 co2_c + cpppg1_c	1185660.4.peg.2745	-1000	1000
# UPPRT	ppi_c + ump_c <-- prpp_c + ura_c	(1185660.4.peg.2162 and Unknown)	-1000	0
# URCN	h2o_c + urcan_c <=> 4iz5pp_c	1185660.4.peg.1496	-1000	1000
# UREA	h2o_c + 2.0 h_c + urea_c --> co2_c + 2.0 nh4_c	1185660.4.peg.1032	0	1000
# URFGTT	2ombz_c + amet_c --> 2ommb_c + ahcys_c + h_c	1185660.4.peg.668	0	1000
# URIDK2m	atp_c + dump_c --> adp_c + dudp_c	1185660.4.peg.3224	0	0
# URIt2	h_e + uri_e <=> h_c + uri_c	1185660.4.peg.866	-1000	1000
# VPAMTr	pyr_c + val__L_c <=> 3mob_c + ala__L_c	1185660.4.peg.1905	-1000	1000
# X5PL3E	xu5p__L_c <=> ru5p__L_c	1185660.4.peg.4549	-1000	1000
# XAND	h_c + nadh_c + urate_c <-- h2o_c + nad_c + xan_c	(1185660.4.peg.1213 or 1185660.4.peg.3113)	-1000	0
# XPPT	ppi_c + xmp_c <-- prpp_c + xan_c	1185660.4.peg.1567	-1000	0
# XTSNH	rib__D_c + xan_c <=> h2o_c + xtsn_c	(1185660.4.peg.3218 or 1185660.4.peg.305 or 1185660.4.peg.1160)	-1000	1000
# XYLI1	xyl__D_c <=> xylu__D_c	((1185660.4.peg.4064 or 1185660.4.peg.1816) or 1185660.4.peg.1829)	-1000	1000
# XYLI2	fru_c <=> glc__D_c	((1185660.4.peg.1816 or 1185660.4.peg.4064) or 1185660.4.peg.1829)	-1000	1000
# XYLK	adp_c + h_c + xu5p__D_c <=> atp_c + xylu__D_c	1185660.4.peg.1815	-1000	1000
# XYLt2	h_e + xyl__D_e <=> h_c + xyl__D_c	(1185660.4.peg.1817 and Unknown)	-1000	1000
# ZN2t4pp	h_e + k_e + zn2_c <=> h_c + k_c + zn2_e	(1185660.4.peg.1542 or 1185660.4.peg.4230 or 1185660.4.peg.3989)	-1000	1000
# G-12289	dtpcudcpp_c + udpg_c --> MXNM5615_c + ump_c	xanmn_chr08_0038	0	1000
# G-12290	MXNM5615_c + udpg_c --> MNXM5639_c + ump_c	xanmn_chr08_0029	0	1000
# MNXR113143	MNXM5639_c + gdpmann_c + h_c --> MNXM2971_c + gdp_c	xanmn_chr08_0034	0	1000
# MNXR113142	MNXM2971_c + h_c + udpglcur_c --> MNXM2980_c + udp_c	xanmn_chr08_0031	0	1000
# MNXR113144	MNXM2980_c + gdpmann_c --> MNXM3223_c + gdp_c + h_c	xanmn_chr08_0033	0	1000
# MNXR117163	MNXM3223_c + accoa_c --> MNXM8499_c + coa_c	xanmn_chr08_0036	0	1000
# MNXR117165	MNXM8499_c + pep_c --> MNXM10150_c + pi_c	xanmn_chr08_0030	0	1000
# G-12296	MNXM8499_c + accoa_c --> MNXM12362_c + coa_c	xanmn_chr08_0035	0	1000
# gumBCEJ	MNXM10150_c + MNXM12362_c --> MNXM22459_c + dtpcudcpp_c	(xanmn_chr08_0040 and xanmn_chr08_0039 and xanmn_chr08_0037 and xanmn_chr08_0032)	0	1000
# OF_Biomass_Synthesis	0.2 BIOMASS_c + 0.8 MNXM22459_c --> 	Unknown	0	1000

# %% [markdown]
# ### Genes

# %%
print("")
print("Genes")
print("-----")
for x in Xam_draft.genes:
    print(x.id)
# Out:
# Genes
# -----
# 1185660.4.peg.1057
# 1185660.4.peg.495
# 1185660.4.peg.109
# 1185660.4.peg.1883
# 1185660.4.peg.2389
# 1185660.4.peg.3115
# 1185660.4.peg.29
# 1185660.4.peg.180
# 1185660.4.peg.3035
# 1185660.4.peg.424
# 1185660.4.peg.1461
# 1185660.4.peg.1539
# 1185660.4.peg.850
# 1185660.4.peg.3753
# 1185660.4.peg.1143
# 1185660.4.peg.4522
# 1185660.4.peg.1112
# 1185660.4.peg.3578
# 1185660.4.peg.409
# 1185660.4.peg.401
# 1185660.4.peg.2283
# 1185660.4.peg.1140
# 1185660.4.peg.1145
# 1185660.4.peg.3695
# 1185660.4.peg.4079
# 1185660.4.peg.911
# 1185660.4.peg.4081
# 1185660.4.peg.4080
# 1185660.4.peg.800
# 1185660.4.peg.3063
# 1185660.4.peg.1865
# 1185660.4.peg.3381
# 1185660.4.peg.2778
# 1185660.4.peg.2831
# 1185660.4.peg.2895
# 1185660.4.peg.1060
# 1185660.4.peg.144
# 1185660.4.peg.2694
# 1185660.4.peg.2053
# 1185660.4.peg.3317
# 1185660.4.peg.3392
# Unknown
# 1185660.4.peg.1922
# 1185660.4.peg.3352
# 1185660.4.peg.2630
# 1185660.4.peg.1581
# 1185660.4.peg.2235
# 1185660.4.peg.709
# 1185660.4.peg.193
# 1185660.4.peg.3281
# 1185660.4.peg.3282
# 1185660.4.peg.2927
# 1185660.4.peg.3842
# 1185660.4.peg.1647
# 1185660.4.peg.2620
# 1185660.4.peg.4012
# 1185660.4.peg.2706
# 1185660.4.peg.2139
# 1185660.4.peg.2004
# 1185660.4.peg.3151
# 1185660.4.peg.774
# 1185660.4.peg.2003
# 1185660.4.peg.4127
# 1185660.4.peg.3346
# 1185660.4.peg.2286
# 1185660.4.peg.1448
# 1185660.4.peg.256
# 1185660.4.peg.2776
# 1185660.4.peg.1419
# 1185660.4.peg.1537
# 1185660.4.peg.3164
# 1185660.4.peg.2005
# 1185660.4.peg.1925
# 1185660.4.peg.3257
# 1185660.4.peg.2157
# 1185660.4.peg.966
# xanmn_chr15_0167
# 1185660.4.peg.306
# 1185660.4.peg.4543
# 1185660.4.peg.452
# 1185660.4.peg.1146
# 1185660.4.peg.2928
# 1185660.4.peg.245
# 1185660.4.peg.178
# 1185660.4.peg.247
# 1185660.4.peg.1793
# 1185660.4.peg.3265
# 1185660.4.peg.457
# 1185660.4.peg.4445
# 1185660.4.peg.866
# 1185660.4.peg.847
# 1185660.4.peg.1888
# 1185660.4.peg.1160
# 1185660.4.peg.305
# 1185660.4.peg.3218
# 1185660.4.peg.2916
# 1185660.4.peg.705
# 1185660.4.peg.941
# 1185660.4.peg.2042
# 1185660.4.peg.1394
# 1185660.4.peg.1178
# 1185660.4.peg.2974
# 1185660.4.peg.747
# 1185660.4.peg.2408
# 1185660.4.peg.2002
# 1185660.4.peg.487
# 1185660.4.peg.176
# 1185660.4.peg.502
# 1185660.4.peg.295
# 1185660.4.peg.2585
# 1185660.4.peg.2586
# 1185660.4.peg.1387
# 1185660.4.peg.1386
# 1185660.4.peg.1389
# 1185660.4.peg.1388
# 1185660.4.peg.1832
# 1185660.4.peg.1846
# 1185660.4.peg.3765
# 1185660.4.peg.1413
# 1185660.4.peg.2795
# 1185660.4.peg.4342
# 1185660.4.peg.1978
# 1185660.4.peg.2410
# 1185660.4.peg.668
# 1185660.4.peg.231
# 1185660.4.peg.1672
# 1185660.4.peg.3572
# 1185660.4.peg.3858
# 1185660.4.peg.3472
# 1185660.4.peg.3347
# 1185660.4.peg.1153
# 1185660.4.peg.449
# 1185660.4.peg.1874
# 1185660.4.peg.1114
# 1185660.4.peg.3804
# 1185660.4.peg.2108
# 1185660.4.peg.2124
# 1185660.4.peg.2169
# 1185660.4.peg.775
# 1185660.4.peg.3356
# 1185660.4.peg.1884
# 1185660.4.peg.3803
# 1185660.4.peg.3883
# 1185660.4.peg.3296
# 1185660.4.peg.4523
# 1185660.4.peg.2001
# 1185660.4.peg.2007
# 1185660.4.peg.959
# 1185660.4.peg.2814
# 1185660.4.peg.1291
# 1185660.4.peg.1339
# 1185660.4.peg.1828
# 1185660.4.peg.655
# 1185660.4.peg.3324
# 1185660.4.peg.3128
# 1185660.4.peg.3122
# 1185660.4.peg.1860
# 1185660.4.peg.3301
# 1185660.4.peg.2232
# 1185660.4.peg.1872
# 1185660.4.peg.3725
# 1185660.4.peg.3724
# 1185660.4.peg.3723
# 1185660.4.peg.3722
# 1185660.4.peg.3721
# 1185660.4.peg.3996
# 1185660.4.peg.953
# 1185660.4.peg.2357
# 1185660.4.peg.752
# 1185660.4.peg.2793
# 1185660.4.peg.2792
# 1185660.4.peg.511
# 1185660.4.peg.513
# 1185660.4.peg.1115
# 1185660.4.peg.4194
# 1185660.4.peg.3862
# 1185660.4.peg.3039
# 1185660.4.peg.4534
# 1185660.4.peg.2885
# 1185660.4.peg.2929
# 1185660.4.peg.2932
# 1185660.4.peg.1908
# 1185660.4.peg.1910
# 1185660.4.peg.4230
# 1185660.4.peg.3989
# 1185660.4.peg.1542
# 1185660.4.peg.1496
# 1185660.4.peg.977
# 1185660.4.peg.753
# 1185660.4.peg.751
# 1185660.4.peg.3719
# 1185660.4.peg.2632
# 1185660.4.peg.1805
# 1185660.4.peg.3316
# 1185660.4.peg.3569
# 1185660.4.peg.1763
# 1185660.4.peg.974
# 1185660.4.peg.2098
# 1185660.4.peg.3922
# 1185660.4.peg.1757
# 1185660.4.peg.3216
# 1185660.4.peg.3284
# 1185660.4.peg.664
# 1185660.4.peg.890
# 1185660.4.peg.3677
# 1185660.4.peg.3680
# 1185660.4.peg.3491
# 1185660.4.peg.4405
# 1185660.4.peg.4403
# 1185660.4.peg.3490
# 1185660.4.peg.3699
# 1185660.4.peg.3364
# 1185660.4.peg.2081
# 1185660.4.peg.2080
# 1185660.4.peg.2968
# 1185660.4.peg.2969
# 1185660.4.peg.2970
# 1185660.4.peg.2971
# 1185660.4.peg.2332
# 1185660.4.peg.1992
# 1185660.4.peg.1993
# 1185660.4.peg.1990
# 1185660.4.peg.1991
# 1185660.4.peg.2394
# 1185660.4.peg.2405
# 1185660.4.peg.2660
# 1185660.4.peg.3766
# 1185660.4.peg.885
# 1185660.4.peg.604
# 1185660.4.peg.3639
# 1185660.4.peg.3638
# 1185660.4.peg.659
# 1185660.4.peg.503
# 1185660.4.peg.1658
# 1185660.4.peg.778
# 1185660.4.peg.3586
# 1185660.4.peg.3688
# 1185660.4.peg.2648
# 1185660.4.peg.1803
# 1185660.4.peg.340
# 1185660.4.peg.99
# 1185660.4.peg.1030
# 1185660.4.peg.524
# 1185660.4.peg.2340
# 1185660.4.peg.1806
# 1185660.4.peg.3663
# 1185660.4.peg.145
# 1185660.4.peg.3224
# 1185660.4.peg.392
# 1185660.4.peg.633
# 1185660.4.peg.722
# 1185660.4.peg.892
# 1185660.4.peg.1849
# 1185660.4.peg.1499
# 1185660.4.peg.2015
# 1185660.4.peg.1775
# 1185660.4.peg.2743
# 1185660.4.peg.514
# 1185660.4.peg.4039
# 1185660.4.peg.412
# 1185660.4.peg.779
# 1185660.4.peg.2670
# 1185660.4.peg.3117
# 1185660.4.peg.3280
# 1185660.4.peg.1452
# 1185660.4.peg.2972
# 1185660.4.peg.4569
# 1185660.4.peg.4233
# 1185660.4.peg.3888
# 1185660.4.peg.4131
# 1185660.4.peg.181
# 1185660.4.peg.3789
# 1185660.4.peg.1657
# 1185660.4.peg.2487
# 1185660.4.peg.3376
# 1185660.4.peg.375
# 1185660.4.peg.2984
# 1185660.4.peg.2234
# 1185660.4.peg.1440
# 1185660.4.peg.1548
# 1185660.4.peg.912
# 1185660.4.peg.1538
# 1185660.4.peg.2339
# 1185660.4.peg.3295
# 1185660.4.peg.3583
# 1185660.4.peg.1761
# 1185660.4.peg.2020
# 1185660.4.peg.2019
# 1185660.4.peg.2018
# 1185660.4.peg.1648
# 1185660.4.peg.3168
# 1185660.4.peg.87
# 1185660.4.peg.88
# 1185660.4.peg.811
# 1185660.4.peg.1754
# 1185660.4.peg.3601
# 1185660.4.peg.3669
# 1185660.4.peg.1148
# 1185660.4.peg.580
# 1185660.4.peg.1127
# 1185660.4.peg.1493
# 1185660.4.peg.2559
# 1185660.4.peg.4372
# 1185660.4.peg.3977
# 1185660.4.peg.90
# 1185660.4.peg.3116
# 1185660.4.peg.1299
# 1185660.4.peg.4515
# 1185660.4.peg.3616
# 1185660.4.peg.1684
# 1185660.4.peg.1489
# 1185660.4.peg.2424
# 1185660.4.peg.2423
# 1185660.4.peg.1475
# 1185660.4.peg.1300
# 1185660.4.peg.1485
# 1185660.4.peg.1226
# 1185660.4.peg.4396
# 1185660.4.peg.2592
# 1185660.4.peg.1010
# 1185660.4.peg.4047
# 1185660.4.peg.4046
# 1185660.4.peg.1515
# 1185660.4.peg.2887
# 1185660.4.peg.1009
# 1185660.4.peg.1625
# 1185660.4.peg.1786
# 1185660.4.peg.85
# 1185660.4.peg.1870
# 1185660.4.peg.992
# 1185660.4.peg.2561
# 1185660.4.peg.1025
# 1185660.4.peg.3217
# 1185660.4.peg.1023
# 1185660.4.peg.1006
# 1185660.4.peg.1021
# 1185660.4.peg.3594
# 1185660.4.peg.1001
# 1185660.4.peg.1002
# 1185660.4.peg.3070
# 1185660.4.peg.2513
# 1185660.4.peg.989
# 1185660.4.peg.2510
# 1185660.4.peg.1008
# 1185660.4.peg.2516
# 1185660.4.peg.2514
# 1185660.4.peg.2979
# 1185660.4.peg.2978
# 1185660.4.peg.999
# 1185660.4.peg.3987
# 1185660.4.peg.3475
# 1185660.4.peg.1003
# 1185660.4.peg.2973
# 1185660.4.peg.1976
# 1185660.4.peg.2976
# 1185660.4.peg.1022
# 1185660.4.peg.987
# 1185660.4.peg.3792
# 1185660.4.peg.3879
# 1185660.4.peg.1005
# 1185660.4.peg.1004
# 1185660.4.peg.1019
# 1185660.4.peg.1007
# 1185660.4.peg.3988
# 1185660.4.peg.460
# 1185660.4.peg.461
# 1185660.4.peg.1482
# 1185660.4.peg.1000
# 1185660.4.peg.4539
# 1185660.4.peg.1018
# 1185660.4.peg.1664
# 1185660.4.peg.3772
# 1185660.4.peg.1917
# 1185660.4.peg.993
# 1185660.4.peg.1013
# 1185660.4.peg.1012
# 1185660.4.peg.1011
# 1185660.4.peg.2406
# 1185660.4.peg.1017
# 1185660.4.peg.1016
# 1185660.4.peg.1015
# 1185660.4.peg.1014
# 1185660.4.peg.2668
# 1185660.4.peg.3665
# 1185660.4.peg.4542
# 1185660.4.peg.988
# 1185660.4.peg.1480
# 1185660.4.peg.1139
# 1185660.4.peg.2511
# 1185660.4.peg.1483
# 1185660.4.peg.1484
# 1185660.4.peg.2010
# 1185660.4.peg.749
# 1185660.4.peg.990
# 1185660.4.peg.991
# 1185660.4.peg.3581
# 1185660.4.peg.4540
# 1185660.4.peg.1556
# 1185660.4.peg.84
# 1185660.4.peg.1024
# 1185660.4.peg.2596
# 1185660.4.peg.769
# 1185660.4.peg.2982
# 1185660.4.peg.3367
# 1185660.4.peg.1875
# 1185660.4.peg.118
# 1185660.4.peg.4059
# 1185660.4.peg.2120
# 1185660.4.peg.2121
# 1185660.4.peg.1902
# 1185660.4.peg.2856
# 1185660.4.peg.3174
# 1185660.4.peg.2140
# 1185660.4.peg.337
# 1185660.4.peg.2331
# 1185660.4.peg.2330
# 1185660.4.peg.2328
# 1185660.4.peg.2141
# 1185660.4.peg.1659
# 1185660.4.peg.3239
# 1185660.4.peg.325
# 1185660.4.peg.1324
# 1185660.4.peg.1397
# 1185660.4.peg.139
# 1185660.4.peg.3717
# 1185660.4.peg.3421
# 1185660.4.peg.3247
# 1185660.4.peg.4083
# 1185660.4.peg.4105
# 1185660.4.peg.640
# 1185660.4.peg.202
# 1185660.4.peg.2625
# 1185660.4.peg.4208
# 1185660.4.peg.2623
# 1185660.4.peg.1998
# 1185660.4.peg.4250
# 1185660.4.peg.2336
# 1185660.4.peg.746
# 1185660.4.peg.1829
# 1185660.4.peg.3784
# 1185660.4.peg.3422
# 1185660.4.peg.182
# 1185660.4.peg.4549
# 1185660.4.peg.2398
# 1185660.4.peg.2099
# 1185660.4.peg.2992
# 1185660.4.peg.3732
# 1185660.4.peg.3027
# 1185660.4.peg.2786
# 1185660.4.peg.2787
# 1185660.4.peg.760
# 1185660.4.peg.2135
# 1185660.4.peg.3708
# 1185660.4.peg.772
# 1185660.4.peg.2334
# xanmn_chr13_0041
# 1185660.4.peg.1999
# 1185660.4.peg.2337
# 1185660.4.peg.1228
# 1185660.4.peg.31
# 1185660.4.peg.32
# 1185660.4.peg.4102
# 1185660.4.peg.3201
# 1185660.4.peg.2666
# 1185660.4.peg.1337
# 1185660.4.peg.933
# 1185660.4.peg.1045
# 1185660.4.peg.159
# 1185660.4.peg.160
# 1185660.4.peg.2631
# 1185660.4.peg.1376
# 1185660.4.peg.639
# 1185660.4.peg.638
# 1185660.4.peg.2392
# 1185660.4.peg.4053
# 1185660.4.peg.715
# 1185660.4.peg.4036
# 1185660.4.peg.1567
# 1185660.4.peg.78
# 1185660.4.peg.1164
# 1185660.4.peg.1823
# 1185660.4.peg.4161
# 1185660.4.peg.2847
# 1185660.4.peg.1209
# 1185660.4.peg.3221
# 1185660.4.peg.1462
# 1185660.4.peg.4248
# 1185660.4.peg.1437
# 1185660.4.peg.1327
# 1185660.4.peg.14
# 1185660.4.peg.1873
# 1185660.4.peg.1094
# 1185660.4.peg.426
# 1185660.4.peg.1540
# 1185660.4.peg.1498
# 1185660.4.peg.785
# 1185660.4.peg.787
# 1185660.4.peg.786
# 1185660.4.peg.1458
# 1185660.4.peg.646
# 1185660.4.peg.1897
# 1185660.4.peg.1896
# 1185660.4.peg.721
# 1185660.4.peg.1825
# 1185660.4.peg.2759
# 1185660.4.peg.2761
# 1185660.4.peg.2762
# 1185660.4.peg.1988
# 1185660.4.peg.1861
# 1185660.4.peg.2760
# 1185660.4.peg.1213
# 1185660.4.peg.3113
# 1185660.4.peg.307
# 1185660.4.peg.1077
# 1185660.4.peg.242
# 1185660.4.peg.3270
# 1185660.4.peg.1876
# 1185660.4.peg.1878
# 1185660.4.peg.706
# 1185660.4.peg.454
# 1185660.4.peg.3286
# 1185660.4.peg.2393
# 1185660.4.peg.2768
# 1185660.4.peg.3285
# 1185660.4.peg.2317
# 1185660.4.peg.2695
# 1185660.4.peg.1759
# 1185660.4.peg.1275
# 1185660.4.peg.1457
# 1185660.4.peg.1853
# 1185660.4.peg.477
# 1185660.4.peg.2865
# 1185660.4.peg.241
# 1185660.4.peg.2522
# 1185660.4.peg.4068
# 1185660.4.peg.1813
# 1185660.4.peg.2526
# 1185660.4.peg.3193
# 1185660.4.peg.3417
# 1185660.4.peg.4073
# 1185660.4.peg.2704
# 1185660.4.peg.859
# 1185660.4.peg.255
# 1185660.4.peg.254
# 1185660.4.peg.1155
# 1185660.4.peg.1154
# 1185660.4.peg.1142
# 1185660.4.peg.1764
# 1185660.4.peg.1036
# 1185660.4.peg.3300
# 1185660.4.peg.1843
# 1185660.4.peg.3743
# 1185660.4.peg.3742
# 1185660.4.peg.930
# 1185660.4.peg.1900
# 1185660.4.peg.2036
# 1185660.4.peg.1624
# 1185660.4.peg.455
# 1185660.4.peg.1536
# 1185660.4.peg.2366
# 1185660.4.peg.4235
# 1185660.4.peg.1833
# 1185660.4.peg.2802
# 1185660.4.peg.3662
# 1185660.4.peg.1420
# 1185660.4.peg.1308
# 1185660.4.peg.1822
# 1185660.4.peg.2057
# 1185660.4.peg.3651
# 1185660.4.peg.2210
# 1185660.4.peg.1781
# 1185660.4.peg.1278
# 1185660.4.peg.224
# 1185660.4.peg.2440
# 1185660.4.peg.1705
# 1185660.4.peg.895
# 1185660.4.peg.3096
# 1185660.4.peg.2892
# 1185660.4.peg.1053
# 1185660.4.peg.819
# 1185660.4.peg.767
# 1185660.4.peg.677
# 1185660.4.peg.676
# 1185660.4.peg.1321
# 1185660.4.peg.1088
# 1185660.4.peg.403
# 1185660.4.peg.3978
# 1185660.4.peg.2659
# 1185660.4.peg.2826
# 1185660.4.peg.4401
# 1185660.4.peg.3488
# 1185660.4.peg.2356
# 1185660.4.peg.3482
# 1185660.4.peg.2635
# 1185660.4.peg.2313
# 1185660.4.peg.496
# 1185660.4.peg.1751
# 1185660.4.peg.339
# 1185660.4.peg.1633
# 1185660.4.peg.3279
# 1185660.4.peg.302
# 1185660.4.peg.2166
# 1185660.4.peg.3703
# 1185660.4.peg.3266
# 1185660.4.peg.3372
# 1185660.4.peg.865
# 1185660.4.peg.1885
# 1185660.4.peg.1417
# 1185660.4.peg.1415
# 1185660.4.peg.2318
# 1185660.4.peg.3634
# 1185660.4.peg.1329
# 1185660.4.peg.1377
# 1185660.4.peg.1066
# 1185660.4.peg.2204
# 1185660.4.peg.1650
# 1185660.4.peg.4413
# 1185660.4.peg.528
# 1185660.4.peg.916
# 1185660.4.peg.4088
# 1185660.4.peg.2464
# 1185660.4.peg.2152
# 1185660.4.peg.4091
# 1185660.4.peg.1532
# 1185660.4.peg.1531
# 1185660.4.peg.2807
# 1185660.4.peg.1812
# 1185660.4.peg.459
# 1185660.4.peg.902
# 1185660.4.peg.1837
# 1185660.4.peg.1804
# 1185660.4.peg.3107
# 1185660.4.peg.3371
# 1185660.4.peg.3692
# 1185660.4.peg.1497
# 1185660.4.peg.3611
# 1185660.4.peg.3213
# 1185660.4.peg.2843
# 1185660.4.peg.4095
# 1185660.4.peg.2593
# 1185660.4.peg.285
# 1185660.4.peg.3755
# 1185660.4.peg.2837
# 1185660.4.peg.4566
# 1185660.4.peg.2089
# 1185660.4.peg.2628
# 1185660.4.peg.2862
# 1185660.4.peg.149
# 1185660.4.peg.945
# 1185660.4.peg.3230
# 1185660.4.peg.1241
# 1185660.4.peg.1510
# 1185660.4.peg.4025
# 1185660.4.peg.1776
# 1185660.4.peg.2627
# 1185660.4.peg.3790
# 1185660.4.peg.3138
# 1185660.4.peg.1130
# 1185660.4.peg.516
# 1185660.4.peg.1826
# 1185660.4.peg.3321
# 1185660.4.peg.2692
# 1185660.4.peg.415
# 1185660.4.peg.414
# 1185660.4.peg.393
# 1185660.4.peg.3276
# 1185660.4.peg.4173
# 1185660.4.peg.3980
# 1185660.4.peg.4257
# 1185660.4.peg.9
# 1185660.4.peg.901
# 1185660.4.peg.1287
# 1185660.4.peg.1071
# 1185660.4.peg.1286
# 1185660.4.peg.673
# 1185660.4.peg.162
# 1185660.4.peg.3682
# 1185660.4.peg.2619
# 1185660.4.peg.3769
# 1185660.4.peg.1298
# 1185660.4.peg.2085
# 1185660.4.peg.1816
# 1185660.4.peg.4064
# 1185660.4.peg.1169
# 1185660.4.peg.147
# 1185660.4.peg.1488
# 1185660.4.peg.3251
# 1185660.4.peg.2797
# 1185660.4.peg.2853
# 1185660.4.peg.7
# 1185660.4.peg.3200
# 1185660.4.peg.2008
# 1185660.4.peg.543
# 1185660.4.peg.542
# 1185660.4.peg.547
# 1185660.4.peg.546
# 1185660.4.peg.545
# 1185660.4.peg.544
# 1185660.4.peg.548
# 1185660.4.peg.609
# 1185660.4.peg.3404
# 1185660.4.peg.917
# 1185660.4.peg.1583
# 1185660.4.peg.1879
# 1185660.4.peg.2465
# 1185660.4.peg.1500
# 1185660.4.peg.2028
# 1185660.4.peg.3595
# 1185660.4.peg.3339
# 1185660.4.peg.1032
# 1185660.4.peg.396
# 1185660.4.peg.4561
# 1185660.4.peg.1451
# 1185660.4.peg.3294
# 1185660.4.peg.3416
# 1185660.4.peg.3788
# 1185660.4.peg.1568
# 1185660.4.peg.833
# 1185660.4.peg.334
# 1185660.4.peg.131
# 1185660.4.peg.1492
# 1185660.4.peg.798
# 1185660.4.peg.3500
# 1185660.4.peg.2385
# 1185660.4.peg.2606
# 1185660.4.peg.2599
# 1185660.4.peg.2598
# 1185660.4.peg.2607
# 1185660.4.peg.2609
# 1185660.4.peg.2608
# 1185660.4.peg.2610
# 1185660.4.peg.2611
# 1185660.4.peg.2605
# 1185660.4.peg.2604
# 1185660.4.peg.2603
# 1185660.4.peg.2602
# 1185660.4.peg.2601
# 1185660.4.peg.2600
# 1185660.4.peg.950
# 1185660.4.peg.946
# 1185660.4.peg.184
# 1185660.4.peg.3442
# 1185660.4.peg.2926
# 1185660.4.peg.2588
# 1185660.4.peg.2207
# 1185660.4.peg.2205
# 1185660.4.peg.2206
# 1185660.4.peg.1767
# 1185660.4.peg.3415
# 1185660.4.peg.1509
# 1185660.4.peg.4114
# 1185660.4.peg.138
# 1185660.4.peg.3780
# 1185660.4.peg.903
# 1185660.4.peg.905
# 1185660.4.peg.1929
# 1185660.4.peg.799
# 1185660.4.peg.1827
# 1185660.4.peg.907
# 1185660.4.peg.710
# 1185660.4.peg.711
# xanmn_chr13_0065
# xanmn_chr03_0256
# xanmn_chr13_0067
# 1185660.4.peg.559
# 1185660.4.peg.3734
# 1185660.4.peg.3735
# 1185660.4.peg.2023
# 1185660.4.peg.1747
# 1185660.4.peg.4422
# 1185660.4.peg.2203
# 1185660.4.peg.2742
# 1185660.4.peg.17
# 1185660.4.peg.1889
# 1185660.4.peg.2338
# 1185660.4.peg.117
# 1185660.4.peg.1434
# 1185660.4.peg.1432
# 1185660.4.peg.1431
# 1185660.4.peg.1430
# 1185660.4.peg.1429
# 1185660.4.peg.3939
# 1185660.4.peg.204
# 1185660.4.peg.493
# 1185660.4.peg.2361
# 1185660.4.peg.3171
# 1185660.4.peg.444
# 1185660.4.peg.4309
# 1185660.4.peg.4324
# 1185660.4.peg.3465
# 1185660.4.peg.1877
# 1185660.4.peg.727
# 1185660.4.peg.1584
# 1185660.4.peg.354
# 1185660.4.peg.978
# 1185660.4.peg.1511
# 1185660.4.peg.2954
# 1185660.4.peg.2102
# 1185660.4.peg.2103
# 1185660.4.peg.2101
# 1185660.4.peg.3369
# 1185660.4.peg.1051
# 1185660.4.peg.777
# 1185660.4.peg.4241
# 1185660.4.peg.4242
# 1185660.4.peg.3420
# 1185660.4.peg.3241
# 1185660.4.peg.2801
# 1185660.4.peg.4092
# 1185660.4.peg.2256
# 1185660.4.peg.2519
# 1185660.4.peg.1653
# 1185660.4.peg.4551
# 1185660.4.peg.1095
# 1185660.4.peg.2925
# 1185660.4.peg.3353
# 1185660.4.peg.3428
# 1185660.4.peg.1289
# 1185660.4.peg.2756
# 1185660.4.peg.4204
# 1185660.4.peg.3568
# 1185660.4.peg.620
# 1185660.4.peg.2584
# 1185660.4.peg.2037
# 1185660.4.peg.187
# 1185660.4.peg.188
# 1185660.4.peg.910
# 1185660.4.peg.4573
# 1185660.4.peg.4572
# 1185660.4.peg.1529
# 1185660.4.peg.2799
# xanmn_chr08_0051
# 1185660.4.peg.1048
# 1185660.4.peg.1049
# 1185660.4.peg.1046
# 1185660.4.peg.1047
# 1185660.4.peg.3354
# 1185660.4.peg.3355
# 1185660.4.peg.1107
# 1185660.4.peg.3283
# 1185660.4.peg.876
# 1185660.4.peg.873
# 1185660.4.peg.875
# 1185660.4.peg.874
# 1185660.4.peg.3419
# 1185660.4.peg.1206
# 1185660.4.peg.1207
# 1185660.4.peg.2243
# 1185660.4.peg.596
# 1185660.4.peg.3628
# 1185660.4.peg.4558
# 1185660.4.peg.450
# 1185660.4.peg.3178
# 1185660.4.peg.3179
# 1185660.4.peg.781
# 1185660.4.peg.3245
# 1185660.4.peg.2612
# 1185660.4.peg.2162
# 1185660.4.peg.2947
# 1185660.4.peg.3934
# 1185660.4.peg.2949
# 1185660.4.peg.419
# 1185660.4.peg.418
# 1185660.4.peg.817
# 1185660.4.peg.1651
# 1185660.4.peg.820
# 1185660.4.peg.3119
# 1185660.4.peg.821
# 1185660.4.peg.1848
# 1185660.4.peg.3418
# 1185660.4.peg.1406
# 1185660.4.peg.818
# 1185660.4.peg.826
# 1185660.4.peg.196
# 1185660.4.peg.2745
# 1185660.4.peg.1905
# 1185660.4.peg.1815
# 1185660.4.peg.1817
# xanmn_chr08_0038
# xanmn_chr08_0029
# xanmn_chr08_0034
# xanmn_chr08_0031
# xanmn_chr08_0033
# xanmn_chr08_0036
# xanmn_chr08_0030
# xanmn_chr08_0035
# xanmn_chr08_0037
# xanmn_chr08_0039
# xanmn_chr08_0032
# xanmn_chr08_0040

# %% [markdown]
# #### Gene Associations

# %%
print("")
print("Genes")
print("-----")
for x in Xam_draft.genes:
    associated_ids = (i.id for i in x.reactions)
    print("%s is associated with reactions: %s" %
          (x.id, "{" + ", ".join(associated_ids) + "}"))
# Out:
# Genes
# -----
# 1185660.4.peg.1057 is associated with reactions: {10FTHFGLULL, DHFS, FPGS_tm}
# 1185660.4.peg.495 is associated with reactions: {AICART, FGLU, MOHMT, 2DHPFALDL, ICH}
# 1185660.4.peg.109 is associated with reactions: {L_LACD2, L_LACDcm, 2HBO, LDH_L, L_LACD3, MCLOR}
# 1185660.4.peg.1883 is associated with reactions: {2OH3K5MPPISO}
# 1185660.4.peg.2389 is associated with reactions: {34DHOXPEGOX, MNXR18214, ALCD2ir, MNXR15972, CHOLD, MNXR15973, MNXR17999, MNXR8926, MNXR17153, MNXR18003, MNXR15797, ALCD19, MNXR12173, MNXR16994, MNXR17974, RDH1, MNXR5765}
# 1185660.4.peg.3115 is associated with reactions: {34DHOXPEGOX, MNXR18214, ALCD2ir, MNXR15972, CHOLD, MNXR15973, MNXR17999, MNXR8926, MNXR17153, MNXR18003, MNXR15797, ALCD19, MNXR12173, MNXR16994, MNXR17974, RDH1, MNXR5765}
# 1185660.4.peg.29 is associated with reactions: {34DHOXPEGOX, MNXR18214, ALCD2ir, MNXR15972, CHOLD, MNXR15973, MNXR17999, MNXR8926, MNXR17153, MNXR18003, MNXR15797, ALCD19, MNXR12173, MNXR16994, MNXR17974, RDH1, MNXR5765}
# 1185660.4.peg.180 is associated with reactions: {34DHOXPEGOX, MNXR18214, ALCD2ir, MNXR15972, CHOLD, MNXR15973, MNXR17999, MNXR8926, MNXR17153, MNXR18003, MNXR15797, ALCD19, MNXR12173, MNXR16994, MNXR17974, RDH1, MNXR5765}
# 1185660.4.peg.3035 is associated with reactions: {34DHOXPEGOX, MNXR18214, ALCD2ir, MNXR15972, CHOLD, MNXR15973, MNXR17999, MNXR8926, MNXR17153, MNXR18003, MNXR15797, ALCD19, MNXR12173, MNXR16994, MNXR17974, RDH1, MNXR5765}
# 1185660.4.peg.424 is associated with reactions: {34HPPOR, PPOR}
# 1185660.4.peg.1461 is associated with reactions: {3HAO, QUILSYN}
# 1185660.4.peg.1539 is associated with reactions: {MNXR5724, MNXR5910, MNXR160, MNXR15262, 3HBCOAHL}
# 1185660.4.peg.850 is associated with reactions: {HDC, 3HLYTCL, 5HLTDL, PHYCBOXL, TYRCBOX, PPC, LTDCL, 5HXKYNDCL}
# 1185660.4.peg.3753 is associated with reactions: {MNXR27650, MNXR27679, MNXR27634, MNXR27692, MNXR27671, MNXR27663, MNXR27735, MNXR27696, MNXR27654, MNXR27638, MNXR27684, 3OAR40_1, MNXR27646, MNXR27700, MNXR27675, 3OAR80, 3OAR100, MNXR27659, rxn05336_c0, MNXR27667, rxn05342_c0, MNXR27642, MNXR27704, MNXR27688, 3OAR120, 3OAR60}
# 1185660.4.peg.1143 is associated with reactions: {MNXR27650, MNXR27679, MNXR27634, MNXR27692, MNXR27671, MNXR27663, MNXR27735, MNXR27696, MNXR27654, MNXR27638, MNXR27684, 3OAR40_1, MNXR27646, MNXR27700, MNXR27675, 3OAR80, 3OAR100, MNXR27659, rxn05336_c0, MNXR27667, rxn05342_c0, MNXR27642, MNXR27704, MNXR27688, 3OAR120, 3OAR60}
# 1185660.4.peg.4522 is associated with reactions: {MNXR27650, MNXR27679, MNXR27634, MNXR27692, MNXR27671, MNXR27663, MNXR27735, MNXR27696, MNXR27654, MNXR27638, MNXR27684, 3OAR40_1, MNXR27646, MNXR27700, MNXR27675, 3OAR80, 3OAR100, MNXR27659, rxn05336_c0, MNXR27667, rxn05342_c0, MNXR27642, MNXR27704, MNXR27688, 3OAR120, 3OAR60}
# 1185660.4.peg.1112 is associated with reactions: {MNXR27650, MNXR27679, MNXR27634, MNXR27692, MNXR27671, MNXR27663, MNXR27735, MNXR27696, MNXR27654, MNXR27638, MNXR27684, 3OAR40_1, MNXR27646, MNXR27700, MNXR27675, 3OAR80, 3OAR100, MNXR27659, rxn05336_c0, MNXR27667, rxn05342_c0, MNXR27642, MNXR27704, MNXR27688, 3OAR120, 3OAR60}
# 1185660.4.peg.3578 is associated with reactions: {MNXR27650, MNXR27679, MNXR27634, MNXR27692, MNXR27671, MNXR27663, MNXR27735, MNXR27696, MNXR27654, MNXR27638, MNXR27684, 3OAR40_1, MNXR27646, MNXR27700, MNXR27675, 3OAR80, 3OAR100, MNXR27659, rxn05336_c0, MNXR27667, rxn05342_c0, MNXR27642, MNXR27704, MNXR27688, 3OAR120, 3OAR60}
# 1185660.4.peg.409 is associated with reactions: {MNXR27650, MNXR27679, MNXR27634, MNXR27692, MNXR27671, MNXR27663, MNXR27735, MNXR27696, MNXR27654, MNXR27638, MNXR27684, 3OAR40_1, MNXR27646, MNXR27700, MNXR27675, 3OAR80, 3OAR100, MNXR27659, rxn05336_c0, MNXR27667, rxn05342_c0, MNXR27642, MNXR27704, MNXR27688, 3OAR120, 3OAR60}
# 1185660.4.peg.401 is associated with reactions: {MNXR27650, MNXR27679, MNXR27634, MNXR27692, MNXR27671, MNXR27663, MNXR27735, MNXR27696, MNXR27654, MNXR27638, MNXR27684, 3OAR40_1, MNXR27646, MNXR27700, MNXR27675, 3OAR80, 3OAR100, MNXR27659, rxn05336_c0, MNXR27667, rxn05342_c0, MNXR27642, MNXR27704, MNXR27688, 3OAR120, 3OAR60}
# 1185660.4.peg.2283 is associated with reactions: {rxn05344_c0, rxn05421_c0, 3OAS80, rxn05388_c0, rxn05396_c0, rxn05400_c0, rxn05460_c0, rxn05347_c0, rxn05345_c0, rxn05413_c0, ACOATA, rxn05346_c0, rxn05343_c0, rxn05348_c0, rxn05359_c0, rxn05404_c0, rxn05363_c0, rxn05367_c0, rxn05417_c0, rxn05371_c0, rxn05375_c0, rxn05429_c0, rxn05379_c0, rxn05392_c0, rxn05425_c0, rxn05384_c0, rxn05409_c0}
# 1185660.4.peg.1140 is associated with reactions: {rxn05344_c0, rxn05421_c0, 3OAS80, rxn05388_c0, rxn05396_c0, rxn05400_c0, rxn05460_c0, rxn05347_c0, rxn05345_c0, rxn05413_c0, ACOATA, rxn05346_c0, rxn05343_c0, rxn05348_c0, rxn05359_c0, rxn05404_c0, rxn05363_c0, rxn05367_c0, rxn05417_c0, rxn05371_c0, rxn05375_c0, rxn05429_c0, rxn05379_c0, rxn05392_c0, rxn05425_c0, rxn05384_c0, rxn05409_c0}
# 1185660.4.peg.1145 is associated with reactions: {rxn05344_c0, rxn05421_c0, 3OAS80, rxn05388_c0, rxn05396_c0, rxn05400_c0, rxn05460_c0, rxn05347_c0, rxn05345_c0, rxn05413_c0, ACOATA, rxn05346_c0, rxn05343_c0, rxn05348_c0, rxn05359_c0, rxn05404_c0, rxn05363_c0, rxn05367_c0, rxn05417_c0, rxn05371_c0, rxn05375_c0, rxn05429_c0, rxn05379_c0, rxn05392_c0, rxn05425_c0, rxn05384_c0, rxn05409_c0}
# 1185660.4.peg.3695 is associated with reactions: {rxn05347_c0, rxn05344_c0, 3OAS80, rxn05348_c0, rxn05343_c0, rxn05346_c0, rxn05345_c0}
# 1185660.4.peg.4079 is associated with reactions: {GLXO1, IMACTD, GLYALDDr, ALDD2x, 4ABUTD, ALDD31, ALDD22x, ABUTD}
# 1185660.4.peg.911 is associated with reactions: {GLXO1, IMACTD, GLYALDDr, ALDD2x, 4ABUTD, ALDD31, ALDD22x, ABUTD}
# 1185660.4.peg.4081 is associated with reactions: {GLXO1, IMACTD, GLYALDDr, ALDD2x, 4ABUTD, ALDD31, ALDD22x, ABUTD}
# 1185660.4.peg.4080 is associated with reactions: {GLXO1, IMACTD, GLYALDDr, ALDD2x, 4ABUTD, ALDD31, ALDD22x, ABUTD}
# 1185660.4.peg.800 is associated with reactions: {4CMLCL_kt, HPYRDC}
# 1185660.4.peg.3063 is associated with reactions: {4CMLCL_kt, HPYRDC}
# 1185660.4.peg.1865 is associated with reactions: {THRS, 4HTHRS}
# 1185660.4.peg.3381 is associated with reactions: {MNXR70220, DHPD, DHPM2, MNXR85427, 56DH5FLURAAMH}
# 1185660.4.peg.2778 is associated with reactions: {MNXR70220, DHPD, DHPM2, MNXR85427, 56DH5FLURAAMH}
# 1185660.4.peg.2831 is associated with reactions: {MNXR70220, DHPD, DHPM2, MNXR85427, 56DH5FLURAAMH}
# 1185660.4.peg.2895 is associated with reactions: {MNXR70220, DHPD, DHPM2, MNXR85427, 56DH5FLURAAMH}
# 1185660.4.peg.1060 is associated with reactions: {GLUPRT, ORPT, 5FLURAPRT}
# 1185660.4.peg.144 is associated with reactions: {A5PISO}
# 1185660.4.peg.2694 is associated with reactions: {A5PISO}
# 1185660.4.peg.2053 is associated with reactions: {AACOAR_syn, MNXR6908}
# 1185660.4.peg.3317 is associated with reactions: {AACOAR_syn, MNXR6908}
# 1185660.4.peg.3392 is associated with reactions: {MNXR27603, MNXR27606, FACOAL160, MNXR27602, FACOAL140, AACOAT, MNXR27601, rxn09448_c0, MNXR80370, MNXR27604, MNXR27605, FACOAL180}
# Unknown is associated with reactions: {EX_gln__L_e, EX_glyb_e, EX_no3_e, EX_taur_e, EX_ins_e, GAMpts, APLh, GMHEPAT, CBL1abc, AGMHE, EX_tsul_e, EX_orn_e, MNXR28653, EX_xyl__D_e, GCCc, EX_pi_e, FPPSh, CO2t, APSR, EX_ppi_e, EX_rna_c0, EX_pro__L_e, TREpts, EX_akg_e, ARBTptspp, ATPM, EX_ptrc_e, EX_4hbz_e, EX_glc__D_e, SALCpts, EX_pyr_e, EX_q8_e, EX_o2_e, AUS, TRPt2m, MANpts, FRD7, EX_salcn_e, EX_spmd_e, FRD3, FAS140ACPm, EX_din_e, EX_arab__L_e, FRUpts, EX_sbt__D_e, SHKK, CYTBO3, MNXR27655, EX_ser__L_e, MNXR27639, EX_ocdca_e, MOAT3C, EX_so4_e, EX_k_e, EX_metsox_S__L_e, PPPGO, EX_zn2_e, GLCpts, FRUK, PAPSR, EX_etha_e, EX_sucr_e, EX_arg__L_e, EX_malt_e, ACALDt, FRD2, EX_fru_e, EX_man_e, EX_thmmp_e, EX_ser__D_e, EX_met__D_e, HEPT1, Biomass, EX_hdca_e, EX_metox__R_e, MNXR94192, EX_q8h2_e, EX_fe2_e, FE3abc, PRFGS, ACPS1, EX_mg2_e, HYD1, EX_mn2_e, EX_h_e, EX_gam_e, EX_tre_e, MNXR28654, EX_na1_e, AACOAT, EX_2ddglcn_e, EX_nh4_e, EX_cit_e, EX_nmn_e, EX_glyc_e, ACAS_2ahbut, UHBZ1t_pp, EX_ca2_e, DADNt2, CU2abcpp, DALAt2pp, PHETA1, EX_adn_e, MNXR15641, ACGApts, MNXR32524, EX_met__L_e, EX_ala__D_e, FORti, MNXR85363, EX_acald_e, MNXR27643, ACCOAL, MNXR79883, DMATT, MNXR28652, MNXR70083, EX_ASPt5n_e, EX_DNA_e, PFK_2, EX_cd2_e, MNXR74782, EX_cbl1_e, DDPA, ALAALAr, IMDHT, MNXR27635, MNXR27647, EX_chol_e, AKGt2r, IMDHT_3c2hmp, EX_cl_e, EX_co2_e, GLCTR3, EX_cobalt2_e, EX_trp__L_e, EX_cu2_e, EX_mqn7_e, NA1Hth, O2t, EX_lys__L_e, EX_succ_e, EX_dad_2_e, MNXR74626, EX_dcyt_e, MNXR94267, EX_dgsn_e, OHPHM, EX_protein_e, MNXR93881, PDHam1hi, EX_duri_e, MNXR27651, METSOX1abcpp, EX_etoh_e, NTRIR2x, GLCTR2, OPHBDC, MNXR27680, SBTpts, HEPT4, EX_for_e, PTRCabc, EX_mal__L_e, THD2, METabc, XYLt2, MNXR81103, MG2abc, MCCC, MQN7t, HEPK2, EX_fum_e, EX_galt_e, EDTXS2, EX_galur_e, MNXR28722, H2Ot, MNXR27664, HEPK1, EX_ttdca_e, MNXR27668, PYDXS, MNXR58824, FRD, Ht, AOXHEXCYCL, UPPRT, EX_glcur_e, G5SADrm, GALT1, EX_fe3_e, PYRt2, CA2t3pp, EX_glu__L_e, EX_h2o_e, ETOHti, MALTpts, EX_gly_e, THZPSN, EX_thymd_e, EX_cytd_e, MNXR27805, MNXR27672, EX_Biomass_e, EX_no2_e, HEPT3, METDabc, MNXR27856, MNXR28723, SPMDabc, EX_glycogen_e, SHCHD2, S7PI, MNXR2786, EX_ac_e, EX_hxan_e, OF_Biomass_Synthesis, GALTpts, EX_arbt_e, MNXR27676, AOOA, MNXR27660, EX_acgam_e, EX_uri_e, rxn08333_c0, ATPS4r}
# 1185660.4.peg.1922 is associated with reactions: {MNXR27603, MNXR27606, FACOAL160, MNXR27602, FACOAL140, AACOAT, MNXR27601, rxn09448_c0, MNXR80370, MNXR27604, MNXR27605, FACOAL180}
# 1185660.4.peg.3352 is associated with reactions: {AASPh, SADT, SADT2}
# 1185660.4.peg.2630 is associated with reactions: {MNXR9029, MNXR84631, ASAD, MNXR74716, MNXR15436, MNXR74717, MNXR85287, MNXR60319, MNXR17004, ABUTD, MNXR17835, MNXR16239, MNXR85589, MNXR22677, MNXR16018, MNXR8994, MNXR16995, MNXR60651, MNXR6969, MNXR74931, MNXR17827, GGGABADr}
# 1185660.4.peg.1581 is associated with reactions: {ACACT1, ACACT4m, ACACT5m, ACACT2, ACACT7m, ACACT3, ACACT10m, ACACT6m}
# 1185660.4.peg.2235 is associated with reactions: {ACACT1, ACACT4m, ACACT5m, ACACT2, ACACT7m, ACACT3, ACACT10m, ACACT6m}
# 1185660.4.peg.709 is associated with reactions: {ACACT1, ACACT2}
# 1185660.4.peg.193 is associated with reactions: {ACACT1, ACACT4m, ACACT5m, ACACT2, ACACT7m, ACACT3, ACACT10m, ACACT6m}
# 1185660.4.peg.3281 is associated with reactions: {ACAS_2ahbut, APLh, PDHam1hi}
# 1185660.4.peg.3282 is associated with reactions: {ACAS_2ahbut, APLh, PDHam1hi}
# 1185660.4.peg.2927 is associated with reactions: {ADOCBIK, ACBIPGT, MNXR85460}
# 1185660.4.peg.3842 is associated with reactions: {ACCOAC, MNXR85314, BACCL, MNXR20056}
# 1185660.4.peg.1647 is associated with reactions: {ACCOAC_1}
# 1185660.4.peg.2620 is associated with reactions: {ACCOAC_1}
# 1185660.4.peg.4012 is associated with reactions: {ACCOAL, MNXR5887, ACS, MNXR5630}
# 1185660.4.peg.2706 is associated with reactions: {GALTpts, ARBTptspp, MALTpts, ACGApts, SALCpts, GLCpts, SBTpts, FRUpts, MANpts, TREpts, GAMpts}
# 1185660.4.peg.2139 is associated with reactions: {GALTpts, ARBTptspp, MALTpts, ACGApts, SALCpts, GLCpts, SBTpts, FRUpts, MANpts, TREpts, GAMpts}
# 1185660.4.peg.2004 is associated with reactions: {ACGK, ASPK}
# 1185660.4.peg.3151 is associated with reactions: {ACGS}
# 1185660.4.peg.774 is associated with reactions: {ACGS}
# 1185660.4.peg.2003 is associated with reactions: {ACGS}
# 1185660.4.peg.4127 is associated with reactions: {ACGS}
# 1185660.4.peg.3346 is associated with reactions: {ACGS}
# 1185660.4.peg.2286 is associated with reactions: {ACGS}
# 1185660.4.peg.1448 is associated with reactions: {ACGS}
# 1185660.4.peg.256 is associated with reactions: {ACOA40OR, ACOAD8m}
# 1185660.4.peg.2776 is associated with reactions: {ACOAD5, ACOAD6, ACOAD1, ACOAD7, ACOAD3, ACOAD4, MNXR79601, ACOAD2}
# 1185660.4.peg.1419 is associated with reactions: {ACOAD1, ACOADH2, MNXR79601}
# 1185660.4.peg.1537 is associated with reactions: {ACOAD9m, ACOAD10m}
# 1185660.4.peg.3164 is associated with reactions: {ACODA, MNXR14762}
# 1185660.4.peg.2005 is associated with reactions: {ACODA, MNXR93703, BTND1, MNXR94094}
# 1185660.4.peg.1925 is associated with reactions: {ACONTa, MICITDr, ACONTb, MNXR71393}
# 1185660.4.peg.3257 is associated with reactions: {ACOTA}
# 1185660.4.peg.2157 is associated with reactions: {SDPTA, MNXR8691, ACOTA, SOTA, ORNTA}
# 1185660.4.peg.966 is associated with reactions: {ACPh, ACYP_2}
# xanmn_chr15_0167 is associated with reactions: {ACt4pp}
# 1185660.4.peg.306 is associated with reactions: {ADA, DADA, GUAD}
# 1185660.4.peg.4543 is associated with reactions: {MNXR7118, ADCL}
# 1185660.4.peg.452 is associated with reactions: {ANS2, ADCS, ANS}
# 1185660.4.peg.1146 is associated with reactions: {ADCS}
# 1185660.4.peg.2928 is associated with reactions: {ADCYRS}
# 1185660.4.peg.245 is associated with reactions: {ADECn, MNXR8571}
# 1185660.4.peg.178 is associated with reactions: {ADECn, MNXR8571}
# 1185660.4.peg.247 is associated with reactions: {ADECn, MNXR8571}
# 1185660.4.peg.1793 is associated with reactions: {ATDAMh, PMPK, ADK1}
# 1185660.4.peg.3265 is associated with reactions: {ADK1, ADK2, UMPK, ATDAMh}
# 1185660.4.peg.457 is associated with reactions: {ADMDC}
# 1185660.4.peg.4445 is associated with reactions: {DPCOAK, ADNK1}
# 1185660.4.peg.866 is associated with reactions: {ADNt2, DURIt2, DINSt2, DCYTt2, INSt2, CYTDt2, DGSNt2, DADNt2, THMDt2, URIt2}
# 1185660.4.peg.847 is associated with reactions: {ADNUC, MNXR578}
# 1185660.4.peg.1888 is associated with reactions: {ADNUC, MNXR578}
# 1185660.4.peg.1160 is associated with reactions: {INSH, GNNUC, XTSNH, ADNUC}
# 1185660.4.peg.305 is associated with reactions: {INSH, GNNUC, XTSNH, ADNUC}
# 1185660.4.peg.3218 is associated with reactions: {INSH, GNNUC, XTSNH, ADNUC}
# 1185660.4.peg.2916 is associated with reactions: {ADOCBLS}
# 1185660.4.peg.705 is associated with reactions: {ADPRDP, ANNAT}
# 1185660.4.peg.941 is associated with reactions: {ADPRDP}
# 1185660.4.peg.2042 is associated with reactions: {ADPT}
# 1185660.4.peg.1394 is associated with reactions: {ADSL2r, ADSL1r, ETHAAL}
# 1185660.4.peg.1178 is associated with reactions: {ADSS}
# 1185660.4.peg.2974 is associated with reactions: {AFAT, RNMK, RBFK}
# 1185660.4.peg.747 is associated with reactions: {AGDC, MNXR6532}
# 1185660.4.peg.2408 is associated with reactions: {AGDI, MNXR93834, UGAH}
# 1185660.4.peg.2002 is associated with reactions: {AGGPR}
# 1185660.4.peg.487 is associated with reactions: {AGPAT140, MNXR28672, AGPAT180, MNXR94332, AGPAT141, MNXR28674, MNXR28675, MNXR94334, MNXR94333, MNXR28676, AGPAT161, AGPAT160, AGPAT181, AGPAT120, MNXR28671, MNXR28673}
# 1185660.4.peg.176 is associated with reactions: {AGPAT140, MNXR28672, AGPAT180, MNXR94332, AGPAT141, MNXR28674, MNXR28675, MNXR94334, MNXR94333, MNXR28676, AGPAT161, AGPAT160, AGPAT181, AGPAT120, MNXR28671, MNXR28673}
# 1185660.4.peg.502 is associated with reactions: {AGPAT140, MNXR28672, AGPAT180, MNXR94332, AGPAT141, MNXR28674, MNXR28675, MNXR94334, MNXR94333, MNXR28676, AGPAT161, AGPAT160, AGPAT181, AGPAT120, MNXR28671, MNXR28673}
# 1185660.4.peg.295 is associated with reactions: {AGTi, SPTc}
# 1185660.4.peg.2585 is associated with reactions: {AIRCr, MNXR79878}
# 1185660.4.peg.2586 is associated with reactions: {AIRCr, MNXR79878}
# 1185660.4.peg.1387 is associated with reactions: {AKGDH, AKGDHe2r}
# 1185660.4.peg.1386 is associated with reactions: {AKGDH, GCC2cm}
# 1185660.4.peg.1389 is associated with reactions: {AKGDH, MNXR70375, MNXR79613}
# 1185660.4.peg.1388 is associated with reactions: {AKGDH, AKGDHe2r}
# 1185660.4.peg.1832 is associated with reactions: {ALKP, AKP1, MNXR6332}
# 1185660.4.peg.1846 is associated with reactions: {ALAR}
# 1185660.4.peg.3765 is associated with reactions: {ALAR, MNXR8700}
# 1185660.4.peg.1413 is associated with reactions: {AM6PTh}
# 1185660.4.peg.2795 is associated with reactions: {AMAOTr}
# 1185660.4.peg.4342 is associated with reactions: {AMAOTr}
# 1185660.4.peg.1978 is associated with reactions: {AMID, AMID4, AMID5, MNXR93869, AMID3, AMID2}
# 1185660.4.peg.2410 is associated with reactions: {AMID, AMID4, AMID5, MNXR93869, AMID3, CMPA, AMID2}
# 1185660.4.peg.668 is associated with reactions: {URFGTT, AMMQT8_2, DMTPHT}
# 1185660.4.peg.231 is associated with reactions: {MNXR63969, MNXR63971, MNXR63965, MNXR80879, MNXR29607, AMPTASECG, MNXR63972, MNXR63973, MNXR63966, MNXR63975, MNXR80876, MNXR14387, MNXR63967, MNXR94492, MNXR46338, MNXR29604, MNXR29606, MNXR63968, MNXR80878}
# 1185660.4.peg.1672 is associated with reactions: {MNXR63969, MNXR63971, MNXR63965, MNXR80879, MNXR29607, AMPTASECG, MNXR63972, MNXR63973, MNXR63966, MNXR63975, MNXR80876, MNXR14387, MNXR63967, MNXR94492, MNXR46338, MNXR29604, MNXR29606, MNXR63968, MNXR80878}
# 1185660.4.peg.3572 is associated with reactions: {MNXR63969, MNXR63971, MNXR63965, MNXR80879, MNXR29607, AMPTASECG, MNXR63972, MNXR63973, MNXR63966, MNXR63975, MNXR80876, MNXR14387, MNXR63967, MNXR94492, MNXR46338, MNXR29604, MNXR29606, MNXR63968, MNXR80878}
# 1185660.4.peg.3858 is associated with reactions: {MNXR63969, MNXR63971, MNXR63965, MNXR80879, MNXR29607, AMPTASECG, MNXR63972, MNXR63973, MNXR63966, MNXR63975, MNXR80876, MNXR14387, MNXR63967, MNXR94492, MNXR46338, MNXR29604, MNXR29606, MNXR63968, MNXR80878}
# 1185660.4.peg.3472 is associated with reactions: {MNXR63969, MNXR63971, MNXR63965, MNXR80879, MNXR29607, AMPTASECG, MNXR63972, MNXR63973, MNXR63966, MNXR63975, MNXR80876, MNXR14387, MNXR63967, MNXR94492, MNXR46338, MNXR29604, MNXR29606, MNXR63968, MNXR80878}
# 1185660.4.peg.3347 is associated with reactions: {MNXR63969, MNXR63971, MNXR63965, MNXR80879, MNXR29607, AMPTASECG, MNXR63972, MNXR63973, MNXR63966, MNXR63975, MNXR80876, MNXR14387, MNXR63967, MNXR94492, MNXR46338, MNXR29604, MNXR29606, MNXR63968, MNXR80878}
# 1185660.4.peg.1153 is associated with reactions: {ANS2, ANS, MCITL2}
# 1185660.4.peg.449 is associated with reactions: {ANS2, ANS}
# 1185660.4.peg.1874 is associated with reactions: {AOOA, MNXR32524, PHETA1}
# 1185660.4.peg.1114 is associated with reactions: {MNXR84910, AOXSr}
# 1185660.4.peg.3804 is associated with reactions: {APAPTm}
# 1185660.4.peg.2108 is associated with reactions: {APATr, MNXR6030}
# 1185660.4.peg.2124 is associated with reactions: {APATr, MNXR6030}
# 1185660.4.peg.2169 is associated with reactions: {APPAT}
# 1185660.4.peg.775 is associated with reactions: {DHPPDA2, APRAUR, MNXR93752}
# 1185660.4.peg.3356 is associated with reactions: {APSR, PAPSR}
# 1185660.4.peg.1884 is associated with reactions: {ARD_1}
# 1185660.4.peg.3803 is associated with reactions: {ARGDC}
# 1185660.4.peg.3883 is associated with reactions: {ARGN, IZPN}
# 1185660.4.peg.3296 is associated with reactions: {ARGORNt7}
# 1185660.4.peg.4523 is associated with reactions: {ARGORNt7}
# 1185660.4.peg.2001 is associated with reactions: {ARGSL, MNXR93778}
# 1185660.4.peg.2007 is associated with reactions: {ARGSS, CTPS1, CTPS2}
# 1185660.4.peg.959 is associated with reactions: {ASNN}
# 1185660.4.peg.2814 is associated with reactions: {ASNN}
# 1185660.4.peg.1291 is associated with reactions: {ASNS1}
# 1185660.4.peg.1339 is associated with reactions: {ASNS1}
# 1185660.4.peg.1828 is associated with reactions: {ASP1DC}
# 1185660.4.peg.655 is associated with reactions: {MNXR32524, MNXR33771, ASPATh}
# 1185660.4.peg.3324 is associated with reactions: {MNXR32524, MNXR33771, ASPATh}
# 1185660.4.peg.3128 is associated with reactions: {ASPCT, MNXR14578, MNXR84576}
# 1185660.4.peg.3122 is associated with reactions: {DAPDC, ASPK, ORDCh}
# 1185660.4.peg.1860 is associated with reactions: {HSDH, ASPK, HSDx}
# 1185660.4.peg.3301 is associated with reactions: {ASPt2_2, MALt2_2, FUMt2r}
# 1185660.4.peg.2232 is associated with reactions: {ATGDm, NDPK3, NDPK2, NDPK4, NDPK6, NDPK8, NDPK9, ATDGDm, NDPK7}
# 1185660.4.peg.1872 is associated with reactions: {ATPPRT}
# 1185660.4.peg.3725 is associated with reactions: {ATPS4r}
# 1185660.4.peg.3724 is associated with reactions: {ATPS4r}
# 1185660.4.peg.3723 is associated with reactions: {ATPS4r}
# 1185660.4.peg.3722 is associated with reactions: {ATPS4r}
# 1185660.4.peg.3721 is associated with reactions: {ATPS4r}
# 1185660.4.peg.3996 is associated with reactions: {BACCL, BTNC}
# 1185660.4.peg.953 is associated with reactions: {BCTA_val_h, BCTA_glu_h, MNXR79548}
# 1185660.4.peg.2357 is associated with reactions: {BDH}
# 1185660.4.peg.752 is associated with reactions: {BETALDHx, BETALDHy}
# 1185660.4.peg.2793 is associated with reactions: {IBPHn, BPNT, MNXR75041}
# 1185660.4.peg.2792 is associated with reactions: {IBPHn, BPNT, MNXR75041}
# 1185660.4.peg.511 is associated with reactions: {BTNC}
# 1185660.4.peg.513 is associated with reactions: {BTNC}
# 1185660.4.peg.1115 is associated with reactions: {MNXR70329, BTS4, MCPST}
# 1185660.4.peg.4194 is associated with reactions: {CAT, MNXR73934, PRDX}
# 1185660.4.peg.3862 is associated with reactions: {CAT, MNXR73934, PRDX}
# 1185660.4.peg.3039 is associated with reactions: {CAT, MNXR73934, PRDX}
# 1185660.4.peg.4534 is associated with reactions: {CAT, MNXR73934, PRDX}
# 1185660.4.peg.2885 is associated with reactions: {CYRDAAT, CBIAT}
# 1185660.4.peg.2929 is associated with reactions: {CYRDAAT, CBIAT}
# 1185660.4.peg.2932 is associated with reactions: {CBL1abc}
# 1185660.4.peg.1908 is associated with reactions: {CBPS}
# 1185660.4.peg.1910 is associated with reactions: {CBPS}
# 1185660.4.peg.4230 is associated with reactions: {CD2t4pp, ZN2t4pp}
# 1185660.4.peg.3989 is associated with reactions: {CD2t4pp, ZN2t4pp}
# 1185660.4.peg.1542 is associated with reactions: {CD2t4pp, ZN2t4pp}
# 1185660.4.peg.1496 is associated with reactions: {CDPGLC46DH, URCN}
# 1185660.4.peg.977 is associated with reactions: {CDPMEK}
# 1185660.4.peg.753 is associated with reactions: {CHLt2}
# 1185660.4.peg.751 is associated with reactions: {CHOLD}
# 1185660.4.peg.3719 is associated with reactions: {CHORM}
# 1185660.4.peg.2632 is associated with reactions: {MNXR57329, CHORS}
# 1185660.4.peg.1805 is associated with reactions: {GALCTND, CITMCOAHm, MNXR7644}
# 1185660.4.peg.3316 is associated with reactions: {CITt2r}
# 1185660.4.peg.3569 is associated with reactions: {CLtex}
# 1185660.4.peg.1763 is associated with reactions: {CMS, MNXR71295}
# 1185660.4.peg.974 is associated with reactions: {MNXR17296, MNXR17297, COALDDH, MNXR6970, GLUTRR}
# 1185660.4.peg.2098 is associated with reactions: {COBALT2tex, MG2t}
# 1185660.4.peg.3922 is associated with reactions: {CPPPGO}
# 1185660.4.peg.1757 is associated with reactions: {CTPS1, CPS, CTPS2}
# 1185660.4.peg.3216 is associated with reactions: {CS}
# 1185660.4.peg.3284 is associated with reactions: {IPPS, CS}
# 1185660.4.peg.664 is associated with reactions: {GUDBUTNAH, CSND, MCSNAH}
# 1185660.4.peg.890 is associated with reactions: {CYARTMT, SAM24MT, TMDS}
# 1185660.4.peg.3677 is associated with reactions: {CYOO2pp}
# 1185660.4.peg.3680 is associated with reactions: {CYOO2pp}
# 1185660.4.peg.3491 is associated with reactions: {IGPDH, SELCYSTS, MNXR14768, CYS}
# 1185660.4.peg.4405 is associated with reactions: {IGPDH, SELCYSTS, MNXR14768, CYS}
# 1185660.4.peg.4403 is associated with reactions: {CYSDS, MNXR93698}
# 1185660.4.peg.3490 is associated with reactions: {CYSDS, MNXR93698}
# 1185660.4.peg.3699 is associated with reactions: {CYSS_trdrd, CYSS, MNXR8221}
# 1185660.4.peg.3364 is associated with reactions: {CYSS_trdrd, CYSS, MNXR8221}
# 1185660.4.peg.2081 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2080 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2968 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2969 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2970 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2971 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.2332 is associated with reactions: {FRD3, FRD2, SUCD4, CYTBD2pp, FRD, FRD7, CYTBO3}
# 1185660.4.peg.1992 is associated with reactions: {CYTBD2pp, HYD1, CYTBO3}
# 1185660.4.peg.1993 is associated with reactions: {CYTBD2pp, CYTBO3}
# 1185660.4.peg.1990 is associated with reactions: {CYTBO3}
# 1185660.4.peg.1991 is associated with reactions: {CYTBO3}
# 1185660.4.peg.2394 is associated with reactions: {MNXR94426, MTHFC, MTHFD, CYTD, FLVRx, DCYTD}
# 1185660.4.peg.2405 is associated with reactions: {CYTK1, CYTK2, ITCY}
# 1185660.4.peg.2660 is associated with reactions: {DAAD}
# 1185660.4.peg.3766 is associated with reactions: {DAAD}
# 1185660.4.peg.885 is associated with reactions: {MNXR94180, DAGK160, MNXR28712, MNXR94182, MNXR28713, MNXR94179, MNXR94183, MNXR8252, MNXR28710, MNXR94181, MNXR94184, MNXR28711, MNXR28715, MNXR28714}
# 1185660.4.peg.604 is associated with reactions: {GLYt2m, DSERt2, DALAt2pp, SERt2m}
# 1185660.4.peg.3639 is associated with reactions: {DAPDA}
# 1185660.4.peg.3638 is associated with reactions: {DAPDA}
# 1185660.4.peg.659 is associated with reactions: {DAPE, GLUR}
# 1185660.4.peg.503 is associated with reactions: {DASYN180, DASYN141, MNXR80503, DASYN160, MNXR80502, MNXR80506, DASYN181, KDOCT, DASYN120, DASYN140, MNXR80505, MNXR80501, MNXR80504, DASYN161}
# 1185660.4.peg.1658 is associated with reactions: {DASYN180, DASYN141, MNXR80503, DASYN160, MNXR80502, MNXR80506, DASYN181, KDOCT, DASYN120, DASYN140, MNXR80505, MNXR80501, MNXR80504, DASYN161}
# 1185660.4.peg.778 is associated with reactions: {DB4PS, GTPCII2, MNXR93771}
# 1185660.4.peg.3586 is associated with reactions: {DB4PS, GTPCII2, MNXR93771}
# 1185660.4.peg.3688 is associated with reactions: {DBTS}
# 1185660.4.peg.2648 is associated with reactions: {DCTPD, DCTPD2}
# 1185660.4.peg.1803 is associated with reactions: {DDGALK, MNXR8073}
# 1185660.4.peg.340 is associated with reactions: {DDGLCNt2r}
# 1185660.4.peg.99 is associated with reactions: {DDGLK}
# 1185660.4.peg.1030 is associated with reactions: {DDPA}
# 1185660.4.peg.524 is associated with reactions: {DDPA}
# 1185660.4.peg.2340 is associated with reactions: {EDA, DDPGA}
# 1185660.4.peg.1806 is associated with reactions: {DDPGALA}
# 1185660.4.peg.3663 is associated with reactions: {DDPGALA, DHNPA2r}
# 1185660.4.peg.145 is associated with reactions: {MNXR6834, DGC3D}
# 1185660.4.peg.3224 is associated with reactions: {DGK1, MNXR84761, GK2, UMPK, URIDK2m, GK1}
# 1185660.4.peg.392 is associated with reactions: {DHAD1, MNXR79704}
# 1185660.4.peg.633 is associated with reactions: {DHCIND, DHPPD}
# 1185660.4.peg.722 is associated with reactions: {FOLR2, DHFR}
# 1185660.4.peg.892 is associated with reactions: {FOLR2, DHFR, MNXR8404}
# 1185660.4.peg.1849 is associated with reactions: {DHORD2, DHORD5}
# 1185660.4.peg.1499 is associated with reactions: {DHORTS, IZPN}
# 1185660.4.peg.2015 is associated with reactions: {DHORTS, HIUH}
# 1185660.4.peg.1775 is associated with reactions: {MNXR75271, MNXR1587, DHPS2, MNXR85709}
# 1185660.4.peg.2743 is associated with reactions: {DHQS}
# 1185660.4.peg.514 is associated with reactions: {DHQTi}
# 1185660.4.peg.4039 is associated with reactions: {DHQTi}
# 1185660.4.peg.412 is associated with reactions: {DHRT_ivcoa, MNXR79575, MNXR80058}
# 1185660.4.peg.779 is associated with reactions: {DLDLBT}
# 1185660.4.peg.2670 is associated with reactions: {MNXR85248, GGTT, MNXR8219, FRTT, PPTTm, MNXR94061, FPPSh, MNXR85270, MNXR85306, rxn12008_c0, MNXR85267, DMATT, HEXTT}
# 1185660.4.peg.3117 is associated with reactions: {MNXR85248, GGTT, MNXR8219, FRTT, PPTTm, MNXR94061, FPPSh, MNXR85270, MNXR85306, rxn12008_c0, MNXR85267, DMATT, HEXTT}
# 1185660.4.peg.3280 is associated with reactions: {KARI_23dhmb, KARI_23dhmp, KARI_3hmoa, DMORh, DPR, KARI}
# 1185660.4.peg.1452 is associated with reactions: {NTD3, NTD11, NT5C, NMNHYD, NTD1, NTD5, DMPH, NTD6, NTD4, NTD7, GMP5N, MNXR84794, NTD2, NTD10}
# 1185660.4.peg.2972 is associated with reactions: {DMPPS, IDS1, IPDPS, DMPPS_syn}
# 1185660.4.peg.4569 is associated with reactions: {GAM, DNGALh, NADS1}
# 1185660.4.peg.4233 is associated with reactions: {DPR}
# 1185660.4.peg.3888 is associated with reactions: {DTMPK}
# 1185660.4.peg.4131 is associated with reactions: {MNXR87173, DURIK1, TMDK1}
# 1185660.4.peg.181 is associated with reactions: {DUTPDP, MNXR55989}
# 1185660.4.peg.3789 is associated with reactions: {DUTPDP}
# 1185660.4.peg.1657 is associated with reactions: {DXPRIi}
# 1185660.4.peg.2487 is associated with reactions: {DXPS}
# 1185660.4.peg.3376 is associated with reactions: {E4PD, GAPD}
# 1185660.4.peg.375 is associated with reactions: {MNXR27690, MNXR27737, MNXR27673, MNXR27702, MNXR27677, MNXR27661, MNXR74373, EAR60y, EAR100y, MNXR27652, MNXR27694, EAR80y, MNXR27644, MNXR27669, MNXR27706, EAR140y, MNXR27686, MNXR27665, MNXR27640, EAR120y, MNXR27681, MNXR27656, MNXR27636, MNXR27648, EAR40y, MNXR27698}
# 1185660.4.peg.2984 is associated with reactions: {ECOAH1, ECOAH5, ECOAH4, ECOAH6, ECOAH12, ECOAH9ir, ECOAH3, MNXR4458, MNXR59771, ECOAH7}
# 1185660.4.peg.2234 is associated with reactions: {MNXR17657, MNXR16204, HACD4, MNXR5449, ECOAH4, HACD3, MNXR17833, ECOAH12, ECOAH7, ECOAH6, HACD1, HACDp, MNXR17649, ECOAH5, ECOAH1, HACD5, HACD2, HACD7, MNXR4458, HIBDkt, MNXR84520, MNXR59771, ECOAH9ir, HACD6, ECOAH3, MNXR17653, HADPCOADH3, HACD9}
# 1185660.4.peg.1440 is associated with reactions: {ECOAH1, ECOAH5, ECOAH4, ECOAH6, ECOAH12, ECOAH9ir, ECOAH3, MNXR4458, MNXR59771, ECOAH7}
# 1185660.4.peg.1548 is associated with reactions: {MNXR16204, ECOAH12, MNXR17649, ECOAH1, ECOAH9ir, MNXR4458, MNXR84520, HACD2, MNXR6494, ECOAH3, HACD1, MNXR17657, ECOAH5, MNXR5449, ECOAH4, MNXR17833, HACD4, ECOAH7, ECOAH6, MNXR17653, MNXR59771, HACD3, HACD5, LYSRC, HACD6, HIBDkt, MNXR40035, HACD9, MNXR6493, HACDp, HADPCOADH3, HACD7}
# 1185660.4.peg.912 is associated with reactions: {ECOAH1, ECOAH5, ECOAH4, ECOAH6, ECOAH12, ECOAH9ir, ECOAH3, MNXR4458, MNXR59771, ECOAH7}
# 1185660.4.peg.1538 is associated with reactions: {HACD3, HACD5, HACD2, HACD7, HACD6, HACD4, ECOAH9ir, ECOAH12, HACD1, HADPCOADH3, HACD9}
# 1185660.4.peg.2339 is associated with reactions: {MNXR4458, EDD}
# 1185660.4.peg.3295 is associated with reactions: {EDTXS1}
# 1185660.4.peg.3583 is associated with reactions: {EDTXS1}
# 1185660.4.peg.1761 is associated with reactions: {ENO}
# 1185660.4.peg.2020 is associated with reactions: {ETHAAL}
# 1185660.4.peg.2019 is associated with reactions: {ETHAAL}
# 1185660.4.peg.2018 is associated with reactions: {ETHAt2pp}
# 1185660.4.peg.1648 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3168 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.87 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.88 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.811 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1754 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3601 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3669 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1148 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.580 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1127 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1493 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.2559 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.4372 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3977 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.90 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3116 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1299 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.4515 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.3616 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1684 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1489 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.2424 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.2423 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1475 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1300 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1485 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.1226 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.4396 is associated with reactions: {EX_DNA_e}
# 1185660.4.peg.2592 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1010 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.4047 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.4046 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1515 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2887 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1009 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1625 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1786 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.85 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1870 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.992 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2561 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1025 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3217 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1023 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1006 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1021 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3594 is associated with reactions: {EX_protein_e, GLUFORT, GLUFT}
# 1185660.4.peg.1001 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1002 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3070 is associated with reactions: {EX_protein_e, GLUTRS}
# 1185660.4.peg.2513 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.989 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2510 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1008 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2516 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2514 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2979 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2978 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.999 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3987 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3475 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1003 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2973 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1976 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2976 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1022 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.987 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3792 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3879 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1005 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1004 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1019 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1007 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3988 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.460 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.461 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1482 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1000 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.4539 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1018 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1664 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3772 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1917 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.993 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1013 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1012 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1011 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2406 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1017 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1016 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1015 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1014 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2668 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.3665 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.4542 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.988 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1480 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1139 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2511 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1483 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.1484 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.2010 is associated with reactions: {EX_protein_e}
# 1185660.4.peg.749 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.990 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.991 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.3581 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.4540 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.1556 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.84 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.1024 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.2596 is associated with reactions: {EX_rna_c0}
# 1185660.4.peg.769 is associated with reactions: {MNXR60686, MNXR60689, MNXR60692, PTE5x, MNXR85362, MNXR60685, MNXR17916, MNXR85739, MNXR62992, MNXR60687, FA100ACPHi, MNXR59886, MNXR74722, FA80ACPHi, MNXR60688}
# 1185660.4.peg.2982 is associated with reactions: {MNXR17903, FACOAE180, FACOAE1836Z9Z12Z, MNXR17904, FACOAE160, MNXR60684, MNXR10705, MNXR1991, MNXR60681, MNXR60682, MNXR85731}
# 1185660.4.peg.3367 is associated with reactions: {FBA, FBA3}
# 1185660.4.peg.1875 is associated with reactions: {FBP, HISTP, IGPDH, SBP}
# 1185660.4.peg.118 is associated with reactions: {FBP}
# 1185660.4.peg.4059 is associated with reactions: {FCLT}
# 1185660.4.peg.2120 is associated with reactions: {FDH}
# 1185660.4.peg.2121 is associated with reactions: {FDH}
# 1185660.4.peg.1902 is associated with reactions: {FE2abc}
# 1185660.4.peg.2856 is associated with reactions: {MNXR7459, FERO}
# 1185660.4.peg.3174 is associated with reactions: {FOMETRi, FGFTh, FPGFTh, GLYCL, GCCb}
# 1185660.4.peg.2140 is associated with reactions: {FK, FRUK, PFK_2}
# 1185660.4.peg.337 is associated with reactions: {MNXR15642, MNXR7594, FMNRx}
# 1185660.4.peg.2331 is associated with reactions: {FRD3, FRD2, FRD, FRD7, SUCD4}
# 1185660.4.peg.2330 is associated with reactions: {FRD3, FRD2, FRD, FRD7, SUCD4}
# 1185660.4.peg.2328 is associated with reactions: {FRD3, FRD2, FRD, FRD7, SUCD4}
# 1185660.4.peg.2141 is associated with reactions: {FRUpts}
# 1185660.4.peg.1659 is associated with reactions: {FT, MNXR55990}
# 1185660.4.peg.3239 is associated with reactions: {UAAGLS1, FTCL}
# 1185660.4.peg.325 is associated with reactions: {FTHFD}
# 1185660.4.peg.1324 is associated with reactions: {FUM}
# 1185660.4.peg.1397 is associated with reactions: {FUM}
# 1185660.4.peg.139 is associated with reactions: {FUMt2r, SUCCt2b}
# 1185660.4.peg.3717 is associated with reactions: {MNXR75249, MNXR75220, G1PACT, MNXR75221, MNXR75218, UAGDP, MNXR60581, MNXR75248}
# 1185660.4.peg.3421 is associated with reactions: {G1PTT}
# 1185660.4.peg.3247 is associated with reactions: {G1SAT}
# 1185660.4.peg.4083 is associated with reactions: {G1SAT}
# 1185660.4.peg.4105 is associated with reactions: {G3PAT120, G3PAT161, MNXR28664, MNXR28662, MNXR92341, MNXR28665, MNXR28667, G3PAT180, G3PAT160_1, G3PAT140, MNXR28663, G3PAT181, G3PAT160, MNXR28666, G3PAT141, MNXR28660}
# 1185660.4.peg.640 is associated with reactions: {G3PD6, G3PD5, G3PD7, G3PD}
# 1185660.4.peg.202 is associated with reactions: {G3PD1}
# 1185660.4.peg.2625 is associated with reactions: {G3PL, TRPS2, SERH}
# 1185660.4.peg.4208 is associated with reactions: {G3PL, TRPS2, PPBNGS, SERH}
# 1185660.4.peg.2623 is associated with reactions: {G3PL, TRPS2, SERH}
# 1185660.4.peg.1998 is associated with reactions: {G5DHx}
# 1185660.4.peg.4250 is associated with reactions: {G6PBDH, G6PDH2r}
# 1185660.4.peg.2336 is associated with reactions: {G6PBDH, G6PDH2r}
# 1185660.4.peg.746 is associated with reactions: {G6PDA}
# 1185660.4.peg.1829 is associated with reactions: {G6PI3, G6PI, XYLI2, PGI, XYLI1}
# 1185660.4.peg.3784 is associated with reactions: {GALCTD, TDPGDH}
# 1185660.4.peg.3422 is associated with reactions: {GALCTD, TDPGDH}
# 1185660.4.peg.182 is associated with reactions: {GALh, GLNSP1, GLNSP2, GLNSP3}
# 1185660.4.peg.4549 is associated with reactions: {GALM1, X5PL3E}
# 1185660.4.peg.2398 is associated with reactions: {GALUi}
# 1185660.4.peg.2099 is associated with reactions: {GAPDH_nadp_hi, SSALx}
# 1185660.4.peg.2992 is associated with reactions: {GART}
# 1185660.4.peg.3732 is associated with reactions: {GCC2cm}
# 1185660.4.peg.3027 is associated with reactions: {GCCc, GCCa}
# 1185660.4.peg.2786 is associated with reactions: {GCCb, GCCc}
# 1185660.4.peg.2787 is associated with reactions: {GCCb}
# 1185660.4.peg.760 is associated with reactions: {GCL}
# 1185660.4.peg.2135 is associated with reactions: {GDH}
# 1185660.4.peg.3708 is associated with reactions: {GF6PTA}
# 1185660.4.peg.772 is associated with reactions: {GHMT}
# 1185660.4.peg.2334 is associated with reactions: {MALTabc, MNXR86939, GLCabcpp}
# xanmn_chr13_0041 is associated with reactions: {GLNabc}
# 1185660.4.peg.1999 is associated with reactions: {GLU5K}
# 1185660.4.peg.2337 is associated with reactions: {HEX1, GLUK_syn}
# 1185660.4.peg.1228 is associated with reactions: {GLUS_nadph}
# 1185660.4.peg.31 is associated with reactions: {GLUS_nadph}
# 1185660.4.peg.32 is associated with reactions: {GLUS_nadph}
# 1185660.4.peg.4102 is associated with reactions: {GLUS_nadph}
# 1185660.4.peg.3201 is associated with reactions: {GLUt2r}
# 1185660.4.peg.2666 is associated with reactions: {GLUt2r}
# 1185660.4.peg.1337 is associated with reactions: {GLUTCOADHc}
# 1185660.4.peg.933 is associated with reactions: {TALA, MNXR40622, MNXR47135, GLYAMDTRc}
# 1185660.4.peg.1045 is associated with reactions: {GLYAT}
# 1185660.4.peg.159 is associated with reactions: {GLYBabc, PROabc}
# 1185660.4.peg.160 is associated with reactions: {GLYBabc, PROabc}
# 1185660.4.peg.2631 is associated with reactions: {GLYCLTDx, GLYCOR_nadp, GLYCLTDy, GLYCDH_1}
# 1185660.4.peg.1376 is associated with reactions: {GLYCK2, PYDXK, PYDAMK, PYDXNK, GLYCK}
# 1185660.4.peg.639 is associated with reactions: {GLYCt}
# 1185660.4.peg.638 is associated with reactions: {GLYK, MNXR8269}
# 1185660.4.peg.2392 is associated with reactions: {GMPS2}
# 1185660.4.peg.4053 is associated with reactions: {GMPS2}
# 1185660.4.peg.715 is associated with reactions: {GND}
# 1185660.4.peg.4036 is associated with reactions: {GNK}
# 1185660.4.peg.1567 is associated with reactions: {HXPRT, GPAR, XPPT}
# 1185660.4.peg.78 is associated with reactions: {GPDDA2, GPDDA4, GPDDA1}
# 1185660.4.peg.1164 is associated with reactions: {GPDDA2, GPDDA4, GPDDA1}
# 1185660.4.peg.1823 is associated with reactions: {MNXR73656, GTPCI, MNXR74304, MNXR74388, MNXR85297}
# 1185660.4.peg.4161 is associated with reactions: {MNXR73656, GTPCI, MNXR74304, MNXR74388, MNXR85297}
# 1185660.4.peg.2847 is associated with reactions: {GTPDPK}
# 1185660.4.peg.1209 is associated with reactions: {GTPDPK}
# 1185660.4.peg.3221 is associated with reactions: {PPGPPDP, GTPDPK}
# 1185660.4.peg.1462 is associated with reactions: {HCO3E}
# 1185660.4.peg.4248 is associated with reactions: {HCO3E}
# 1185660.4.peg.1437 is associated with reactions: {HCO3E}
# 1185660.4.peg.1327 is associated with reactions: {HCO3E}
# 1185660.4.peg.14 is associated with reactions: {HDCAt2, TTDCAt2, OCDCAt2}
# 1185660.4.peg.1873 is associated with reactions: {MNXR59227, HDH, MNXR58251}
# 1185660.4.peg.1094 is associated with reactions: {HEPT2}
# 1185660.4.peg.426 is associated with reactions: {HGNTOR}
# 1185660.4.peg.1540 is associated with reactions: {HIBDkt}
# 1185660.4.peg.1498 is associated with reactions: {HISDr, MNXR93681}
# 1185660.4.peg.785 is associated with reactions: {HKt}
# 1185660.4.peg.787 is associated with reactions: {HKt}
# 1185660.4.peg.786 is associated with reactions: {HKt}
# 1185660.4.peg.1458 is associated with reactions: {HKYNH, MNXR80323}
# 1185660.4.peg.646 is associated with reactions: {HMBS}
# 1185660.4.peg.1897 is associated with reactions: {HMGL, NPHS, MNXR6311}
# 1185660.4.peg.1896 is associated with reactions: {HMGL, NPHS, MNXR6311}
# 1185660.4.peg.721 is associated with reactions: {HPPK2}
# 1185660.4.peg.1825 is associated with reactions: {HPPK2}
# 1185660.4.peg.2759 is associated with reactions: {HSDH, HSDx}
# 1185660.4.peg.2761 is associated with reactions: {HSERTA, MNXR7792}
# 1185660.4.peg.2762 is associated with reactions: {HSERTA, MNXR7792}
# 1185660.4.peg.1988 is associated with reactions: {HSERTA, MNXR7792}
# 1185660.4.peg.1861 is associated with reactions: {PYDAMK, PYDXK, HSK, PYDXNK}
# 1185660.4.peg.2760 is associated with reactions: {HSPMS, MNXR79604, SHSL4h, MNXR8129, MNXR15065}
# 1185660.4.peg.1213 is associated with reactions: {HXAND, XAND}
# 1185660.4.peg.3113 is associated with reactions: {HXAND, XAND}
# 1185660.4.peg.307 is associated with reactions: {HXANt2pp}
# 1185660.4.peg.1077 is associated with reactions: {ICDHx}
# 1185660.4.peg.242 is associated with reactions: {ICL}
# 1185660.4.peg.3270 is associated with reactions: {IDPh}
# 1185660.4.peg.1876 is associated with reactions: {IG3PS}
# 1185660.4.peg.1878 is associated with reactions: {IG3PS}
# 1185660.4.peg.706 is associated with reactions: {PUNP7, MNXR65498, NAPT, IG3PS}
# 1185660.4.peg.454 is associated with reactions: {IGPS}
# 1185660.4.peg.3286 is associated with reactions: {IMDHT, IMDHT_3c2hmp}
# 1185660.4.peg.2393 is associated with reactions: {IMPD}
# 1185660.4.peg.2768 is associated with reactions: {IMPD}
# 1185660.4.peg.3285 is associated with reactions: {IPMD, MNXR14719, OMCDC}
# 1185660.4.peg.2317 is associated with reactions: {KDOCT, MNXR73710}
# 1185660.4.peg.2695 is associated with reactions: {KDOPP}
# 1185660.4.peg.1759 is associated with reactions: {KDOPS}
# 1185660.4.peg.1275 is associated with reactions: {Kt1}
# 1185660.4.peg.1457 is associated with reactions: {KYN3OX, MNXR71411}
# 1185660.4.peg.1853 is associated with reactions: {LCADi}
# 1185660.4.peg.477 is associated with reactions: {MNXR94221, MNXR69337, LPLIPAL2A141, MNXR94222, MNXR3312, LPLIPAL1A180pp, LPLIPAL1A120pp, MNXR94194, MNXR94224, MNXR94195, MNXR94196, MNXR6274, LPLIPAL1A141pp, LPLIPAL1A140pp, LPLIPAL1A160pp, MNXR94197, MNXR94225, MNXR94227, LPLIPAL2A120, MNXR94198, LPLIPAL2A140, MNXR80382, MNXR80380, MNXR94199, LPLIPAL2A160, MNXR69346, MNXR94200, LPLIPAL2A180, MNXR94201, LPLIPAL2E160, LPLIPAL2E180, MNXR94226, MNXR94217, MNXR94223, MNXR94218, MNXR94219, MNXR69352, MNXR3279, MNXR94220, MNXR80385, MNXR80383, MNXR3277, MNXR94202}
# 1185660.4.peg.2865 is associated with reactions: {LYSt2m}
# 1185660.4.peg.241 is associated with reactions: {MALS, MCITS}
# 1185660.4.peg.2522 is associated with reactions: {MALT}
# 1185660.4.peg.4068 is associated with reactions: {MALT}
# 1185660.4.peg.1813 is associated with reactions: {MALT}
# 1185660.4.peg.2526 is associated with reactions: {MALT}
# 1185660.4.peg.3193 is associated with reactions: {MALT}
# 1185660.4.peg.3417 is associated with reactions: {MAN6PI, rxn01292_c0, MAN1PT2}
# 1185660.4.peg.4073 is associated with reactions: {MANAO}
# 1185660.4.peg.2704 is associated with reactions: {MANpts}
# 1185660.4.peg.859 is associated with reactions: {MATm}
# 1185660.4.peg.255 is associated with reactions: {MCCC}
# 1185660.4.peg.254 is associated with reactions: {MCCC}
# 1185660.4.peg.1155 is associated with reactions: {MCITD}
# 1185660.4.peg.1154 is associated with reactions: {MNXR71184, MCITS}
# 1185660.4.peg.1142 is associated with reactions: {MNXR53363, MNXR53360, MNXR53365, MCOATA, MNXR53361, MNXR53359, MNXR53364, MNXR78083, MNXR53366, MNXR53357, MNXR53368, MNXR53362, MNXR53358}
# 1185660.4.peg.1764 is associated with reactions: {MCS, rxn02362_c0}
# 1185660.4.peg.1036 is associated with reactions: {MDH}
# 1185660.4.peg.3300 is associated with reactions: {MDHC_nadp_hr}
# 1185660.4.peg.1843 is associated with reactions: {MECDPDH2}
# 1185660.4.peg.3743 is associated with reactions: {METDabc, METSOX1abcpp, METabc, MNXR27805}
# 1185660.4.peg.3742 is associated with reactions: {METDabc, METSOX1abcpp, METabc, MNXR27805}
# 1185660.4.peg.930 is associated with reactions: {METSOXR1}
# 1185660.4.peg.1900 is associated with reactions: {MGC}
# 1185660.4.peg.2036 is associated with reactions: {MI1PP, MI3PP, MI4PP}
# 1185660.4.peg.1624 is associated with reactions: {MIHKPP, PSP}
# 1185660.4.peg.455 is associated with reactions: {MIHKPP, PSP}
# ...
# 1185660.4.peg.3213 is associated with reactions: {MNXR67415}
# 1185660.4.peg.2843 is associated with reactions: {MNXR67415}
# 1185660.4.peg.4095 is associated with reactions: {MNXR69161, MNXR90744}
# 1185660.4.peg.2593 is associated with reactions: {MNXR70083}
# 1185660.4.peg.285 is associated with reactions: {MNXR70083}
# 1185660.4.peg.3755 is associated with reactions: {MNXR70083}
# 1185660.4.peg.2837 is associated with reactions: {MNXR70083}
# 1185660.4.peg.4566 is associated with reactions: {MNXR70083}
# 1185660.4.peg.2089 is associated with reactions: {MNXR70083}
# 1185660.4.peg.2628 is associated with reactions: {MNXR70083}
# 1185660.4.peg.2862 is associated with reactions: {MNXR70083}
# 1185660.4.peg.149 is associated with reactions: {PHETHPTOX, MNXR70958}
# 1185660.4.peg.945 is associated with reactions: {MNXR71149, TMDPP}
# 1185660.4.peg.3230 is associated with reactions: {MNXR71149, TMDPP}
# 1185660.4.peg.1241 is associated with reactions: {MNXR85555, MNXR71171, rxn03893_c0}
# 1185660.4.peg.1510 is associated with reactions: {MNXR7133, PPNDH}
# 1185660.4.peg.4025 is associated with reactions: {MNXR7136}
# 1185660.4.peg.1776 is associated with reactions: {MNXR71500}
# 1185660.4.peg.2627 is associated with reactions: {PRAI, MNXR71594}
# 1185660.4.peg.3790 is associated with reactions: {PEPCK_re, MNXR71850, PPNCL2, PPCDC, PPNCL3}
# 1185660.4.peg.3138 is associated with reactions: {MNXR7297, P5CR, P5CRx}
# 1185660.4.peg.1130 is associated with reactions: {MNXR73713}
# 1185660.4.peg.516 is associated with reactions: {MNXR7442}
# 1185660.4.peg.1826 is associated with reactions: {MOHMT, MNXR7721}
# 1185660.4.peg.3321 is associated with reactions: {MNXR79288}
# 1185660.4.peg.2692 is associated with reactions: {MNXR79735, UAGCVT}
# 1185660.4.peg.415 is associated with reactions: {MOD_3mhtpp, MOD_4mop, MNXR80309, MNXR80306, MNXR80308, MOD}
# 1185660.4.peg.414 is associated with reactions: {MOD_3mhtpp, MOD_4mop, MNXR80309, MNXR80306, MNXR80308, MOD}
# 1185660.4.peg.393 is associated with reactions: {MNXR80378}
# 1185660.4.peg.3276 is associated with reactions: {MNXR80464}
# 1185660.4.peg.4173 is associated with reactions: {MNXR80558, MNXR80559, MNXR80560, MNXR80561, MNXR94338, MNXR80553, MNXR80557, MNXR80556, MNXR80555}
# 1185660.4.peg.3980 is associated with reactions: {MNXR80558, MNXR80559, MNXR80560, MNXR80561, MNXR94338, MNXR80553, MNXR80557, MNXR80556, MNXR80555}
# 1185660.4.peg.4257 is associated with reactions: {MNXR80558, MNXR80559, MNXR80560, MNXR80561, MNXR94338, MNXR80553, MNXR80557, MNXR80556, MNXR80555}
# 1185660.4.peg.9 is associated with reactions: {MNXR80558, MNXR80559, MNXR80560, MNXR80561, MNXR94338, MNXR80553, MNXR80557, MNXR80556, MNXR80555}
# 1185660.4.peg.901 is associated with reactions: {MNXR80794}
# 1185660.4.peg.1287 is associated with reactions: {MNXR8203, THDPS}
# 1185660.4.peg.1071 is associated with reactions: {MNXR8303}
# 1185660.4.peg.1286 is associated with reactions: {MNXR8328}
# 1185660.4.peg.673 is associated with reactions: {MNXR84532}
# 1185660.4.peg.162 is associated with reactions: {MNXR84885, THZPSN}
# 1185660.4.peg.3682 is associated with reactions: {P5CD, PROD2, PUTA3, MNXR85051}
# 1185660.4.peg.2619 is associated with reactions: {PGAMT, MNXR85058}
# 1185660.4.peg.3769 is associated with reactions: {MNXR85179}
# 1185660.4.peg.1298 is associated with reactions: {MNXR85205}
# 1185660.4.peg.2085 is associated with reactions: {MNXR85277}
# 1185660.4.peg.1816 is associated with reactions: {XYLI1, MNXR85335, XYLI2}
# 1185660.4.peg.4064 is associated with reactions: {XYLI1, MNXR85335, XYLI2}
# 1185660.4.peg.1169 is associated with reactions: {MNXR85534, MNXR85754}
# 1185660.4.peg.147 is associated with reactions: {MNXR85856}
# 1185660.4.peg.1488 is associated with reactions: {MNXR8691, PHETA1}
# 1185660.4.peg.3251 is associated with reactions: {MNXR8691, PHETA1}
# 1185660.4.peg.2797 is associated with reactions: {MNXR87148}
# 1185660.4.peg.2853 is associated with reactions: {MNXR87148}
# 1185660.4.peg.7 is associated with reactions: {MNXR8716}
# 1185660.4.peg.3200 is associated with reactions: {TKT1, MNXR8742, TKT2}
# 1185660.4.peg.2008 is associated with reactions: {MNXR8742, OXAMTC}
# 1185660.4.peg.543 is associated with reactions: {MNXR8903}
# 1185660.4.peg.542 is associated with reactions: {MNXR8903}
# 1185660.4.peg.547 is associated with reactions: {MNXR8903}
# 1185660.4.peg.546 is associated with reactions: {MNXR8903}
# 1185660.4.peg.545 is associated with reactions: {MNXR8903}
# 1185660.4.peg.544 is associated with reactions: {MNXR8903}
# 1185660.4.peg.548 is associated with reactions: {MNXR8903}
# 1185660.4.peg.609 is associated with reactions: {MNXR93624}
# 1185660.4.peg.3404 is associated with reactions: {MNXR93625, NAPRT}
# 1185660.4.peg.917 is associated with reactions: {MNXR93694}
# 1185660.4.peg.1583 is associated with reactions: {MNXR93715, MNXR93704, MNXR93946, MNXR93966, MNXR93748, MNXR93945}
# 1185660.4.peg.1879 is associated with reactions: {PRACHh, PRADPh, MNXR93746}
# 1185660.4.peg.2465 is associated with reactions: {MNXR93752, PRACHh}
# 1185660.4.peg.1500 is associated with reactions: {MNXR93753}
# 1185660.4.peg.2028 is associated with reactions: {MNXR93774}
# 1185660.4.peg.3595 is associated with reactions: {MNXR93864, MNXR93865}
# 1185660.4.peg.3339 is associated with reactions: {MNXR93864, MNXR93865}
# 1185660.4.peg.1032 is associated with reactions: {MNXR94094, UREA}
# 1185660.4.peg.396 is associated with reactions: {MNXR94164, MNXR94165, MNXR94166, MNXR94163}
# 1185660.4.peg.4561 is associated with reactions: {MNXR94190}
# 1185660.4.peg.1451 is associated with reactions: {MNXR94325, NADK}
# 1185660.4.peg.3294 is associated with reactions: {MOAT, MOAT2}
# 1185660.4.peg.3416 is associated with reactions: {MPPM}
# 1185660.4.peg.3788 is associated with reactions: {rxn04052_c0, PC8XM, PGMT, MPPM}
# 1185660.4.peg.1568 is associated with reactions: {MTAP}
# 1185660.4.peg.833 is associated with reactions: {MTHFO, MTHFO_nadp}
# 1185660.4.peg.334 is associated with reactions: {MTHFO, MTHFO_nadp}
# 1185660.4.peg.131 is associated with reactions: {MTI}
# 1185660.4.peg.1492 is associated with reactions: {MTRI}
# 1185660.4.peg.798 is associated with reactions: {MUCCY_kt}
# 1185660.4.peg.3500 is associated with reactions: {NA1Hth}
# 1185660.4.peg.2385 is associated with reactions: {NADH10, NADH5, NADH9}
# 1185660.4.peg.2606 is associated with reactions: {NADH6}
# 1185660.4.peg.2599 is associated with reactions: {NADH6}
# 1185660.4.peg.2598 is associated with reactions: {NADH6}
# 1185660.4.peg.2607 is associated with reactions: {NADH6}
# 1185660.4.peg.2609 is associated with reactions: {NADH6}
# 1185660.4.peg.2608 is associated with reactions: {NADH6}
# 1185660.4.peg.2610 is associated with reactions: {NADH6}
# 1185660.4.peg.2611 is associated with reactions: {NADH6}
# 1185660.4.peg.2605 is associated with reactions: {NADH6}
# 1185660.4.peg.2604 is associated with reactions: {NADH6}
# 1185660.4.peg.2603 is associated with reactions: {NADH6}
# 1185660.4.peg.2602 is associated with reactions: {NADH6}
# 1185660.4.peg.2601 is associated with reactions: {NADH6}
# 1185660.4.peg.2600 is associated with reactions: {NADH6}
# 1185660.4.peg.950 is associated with reactions: {NADTRHD, THD2}
# 1185660.4.peg.946 is associated with reactions: {NADTRHD, THD2}
# 1185660.4.peg.184 is associated with reactions: {NH4t}
# 1185660.4.peg.3442 is associated with reactions: {NMNTP}
# 1185660.4.peg.2926 is associated with reactions: {NNDMBRT}
# 1185660.4.peg.2588 is associated with reactions: {NNDPR}
# 1185660.4.peg.2207 is associated with reactions: {NO2t2r, NO3t2}
# 1185660.4.peg.2205 is associated with reactions: {NO3R1, NTRIR2x, NO3R2}
# 1185660.4.peg.2206 is associated with reactions: {NO3R2, NTRIR2x, NTRIR2y}
# 1185660.4.peg.1767 is associated with reactions: {NTD1}
# 1185660.4.peg.3415 is associated with reactions: {OCOAT1}
# 1185660.4.peg.1509 is associated with reactions: {OHPBAT, PSAT}
# 1185660.4.peg.4114 is associated with reactions: {OMPDC}
# 1185660.4.peg.138 is associated with reactions: {OP4ENH}
# 1185660.4.peg.3780 is associated with reactions: {ORPT}
# 1185660.4.peg.903 is associated with reactions: {OXOAEL}
# 1185660.4.peg.905 is associated with reactions: {OXOAEL}
# 1185660.4.peg.1929 is associated with reactions: {OXOAEL}
# 1185660.4.peg.799 is associated with reactions: {OXOAEL}
# 1185660.4.peg.1827 is associated with reactions: {PANTS}
# 1185660.4.peg.907 is associated with reactions: {PCADYOX}
# 1185660.4.peg.710 is associated with reactions: {PCADYOX}
# 1185660.4.peg.711 is associated with reactions: {PCADYOX}
# xanmn_chr13_0065 is associated with reactions: {PDH}
# xanmn_chr03_0256 is associated with reactions: {PDH}
# xanmn_chr13_0067 is associated with reactions: {PDH}
# 1185660.4.peg.559 is associated with reactions: {PDHam2hi, PDHam1hi}
# 1185660.4.peg.3734 is associated with reactions: {PDHbr}
# 1185660.4.peg.3735 is associated with reactions: {PDHbr}
# 1185660.4.peg.2023 is associated with reactions: {PDX5POi, PYAM5PO}
# 1185660.4.peg.1747 is associated with reactions: {PDX5POi, PYAM5PO}
# 1185660.4.peg.4422 is associated with reactions: {PDX5POi, PYAM5PO}
# 1185660.4.peg.2203 is associated with reactions: {PDX5POi, PYAM5PO}
# 1185660.4.peg.2742 is associated with reactions: {PDX5POi, PYAM5PO}
# 1185660.4.peg.17 is associated with reactions: {PGCD}
# 1185660.4.peg.1889 is associated with reactions: {PGCD}
# 1185660.4.peg.2338 is associated with reactions: {PGL}
# 1185660.4.peg.117 is associated with reactions: {PHETA1}
# 1185660.4.peg.1434 is associated with reactions: {PIabc}
# 1185660.4.peg.1432 is associated with reactions: {PIabc}
# 1185660.4.peg.1431 is associated with reactions: {PIabc}
# 1185660.4.peg.1430 is associated with reactions: {PIabc}
# 1185660.4.peg.1429 is associated with reactions: {PIabc}
# 1185660.4.peg.3939 is associated with reactions: {PNTK}
# 1185660.4.peg.204 is associated with reactions: {POX}
# 1185660.4.peg.493 is associated with reactions: {PPRGL}
# 1185660.4.peg.2361 is associated with reactions: {PPS}
# 1185660.4.peg.3171 is associated with reactions: {PRAIS, PRAISh}
# 1185660.4.peg.444 is associated with reactions: {PRAISh}
# 1185660.4.peg.4309 is associated with reactions: {PRFGS}
# 1185660.4.peg.4324 is associated with reactions: {PRFGS}
# 1185660.4.peg.3465 is associated with reactions: {PRFGS}
# 1185660.4.peg.1877 is associated with reactions: {PRICIh}
# 1185660.4.peg.727 is associated with reactions: {PROAKGOX1}
# 1185660.4.peg.1584 is associated with reactions: {PROAKGOX1}
# 1185660.4.peg.354 is associated with reactions: {PROt2r}
# 1185660.4.peg.978 is associated with reactions: {PRPPS}
# 1185660.4.peg.1511 is associated with reactions: {PSCIT}
# 1185660.4.peg.2954 is associated with reactions: {PSP, PSP_D}
# 1185660.4.peg.2102 is associated with reactions: {SPMDabc, PTRCabc}
# 1185660.4.peg.2103 is associated with reactions: {SPMDabc, PTRCabc}
# 1185660.4.peg.2101 is associated with reactions: {SPMDabc, PTRCabc}
# 1185660.4.peg.3369 is associated with reactions: {PYK}
# 1185660.4.peg.1051 is associated with reactions: {R01465m}
# 1185660.4.peg.777 is associated with reactions: {RBFSb}
# 1185660.4.peg.4241 is associated with reactions: {RNDR1, RNDR3, RNDR4, RNDR2}
# 1185660.4.peg.4242 is associated with reactions: {RNDR1, RNDR3, RNDR4, RNDR2}
# 1185660.4.peg.3420 is associated with reactions: {RPE, TDPDRE}
# 1185660.4.peg.3241 is associated with reactions: {RPI}
# 1185660.4.peg.2801 is associated with reactions: {rxn00016_c0}
# 1185660.4.peg.4092 is associated with reactions: {rxn01080_c0, rxn01457_c0}
# 1185660.4.peg.2256 is associated with reactions: {rxn06181_c0}
# 1185660.4.peg.2519 is associated with reactions: {rxn06453_c0}
# 1185660.4.peg.1653 is associated with reactions: {rxn06723_c0}
# 1185660.4.peg.4551 is associated with reactions: {rxn09988_c0}
# 1185660.4.peg.1095 is associated with reactions: {rxn13990_c0}
# 1185660.4.peg.2925 is associated with reactions: {RZ5PP}
# 1185660.4.peg.3353 is associated with reactions: {SADT, SADT2}
# 1185660.4.peg.3428 is associated with reactions: {SBTPD}
# 1185660.4.peg.1289 is associated with reactions: {SDPDS}
# 1185660.4.peg.2756 is associated with reactions: {SERD_L}
# 1185660.4.peg.4204 is associated with reactions: {SHK3Dr}
# 1185660.4.peg.3568 is associated with reactions: {SO4t2}
# 1185660.4.peg.620 is associated with reactions: {SO4t2}
# 1185660.4.peg.2584 is associated with reactions: {SPODM}
# 1185660.4.peg.2037 is associated with reactions: {SPODM}
# 1185660.4.peg.187 is associated with reactions: {SPODM}
# 1185660.4.peg.188 is associated with reactions: {SPODM}
# 1185660.4.peg.910 is associated with reactions: {SUCBZL}
# 1185660.4.peg.4573 is associated with reactions: {SUCLm}
# 1185660.4.peg.4572 is associated with reactions: {SUCLm}
# 1185660.4.peg.1529 is associated with reactions: {SUCRe}
# 1185660.4.peg.2799 is associated with reactions: {SUCRe}
# xanmn_chr08_0051 is associated with reactions: {SUCRt2}
# 1185660.4.peg.1048 is associated with reactions: {SULabc}
# 1185660.4.peg.1049 is associated with reactions: {TSULabc, SULabc}
# 1185660.4.peg.1046 is associated with reactions: {TSULabc, SULabc}
# 1185660.4.peg.1047 is associated with reactions: {SULabc}
# 1185660.4.peg.3354 is associated with reactions: {SULR}
# 1185660.4.peg.3355 is associated with reactions: {SULR}
# 1185660.4.peg.1107 is associated with reactions: {TAL}
# 1185660.4.peg.3283 is associated with reactions: {TAL}
# 1185660.4.peg.876 is associated with reactions: {TAUDO}
# 1185660.4.peg.873 is associated with reactions: {TAURabc}
# 1185660.4.peg.875 is associated with reactions: {TAURabc}
# 1185660.4.peg.874 is associated with reactions: {TAURabc}
# 1185660.4.peg.3419 is associated with reactions: {TDPDRR}
# 1185660.4.peg.1206 is associated with reactions: {TDSRh}
# 1185660.4.peg.1207 is associated with reactions: {TDSRh}
# 1185660.4.peg.2243 is associated with reactions: {TDSRh}
# 1185660.4.peg.596 is associated with reactions: {TDSRh}
# 1185660.4.peg.3628 is associated with reactions: {THIORDXi}
# 1185660.4.peg.4558 is associated with reactions: {THIORDXi}
# 1185660.4.peg.450 is associated with reactions: {THRA}
# 1185660.4.peg.3178 is associated with reactions: {THZPSN}
# 1185660.4.peg.3179 is associated with reactions: {THZPSN}
# 1185660.4.peg.781 is associated with reactions: {TMPK}
# 1185660.4.peg.3245 is associated with reactions: {TMPPP}
# 1185660.4.peg.2612 is associated with reactions: {TPI}
# 1185660.4.peg.2162 is associated with reactions: {TPRDCOAS, UPPRT}
# 1185660.4.peg.2947 is associated with reactions: {TRE6PP}
# 1185660.4.peg.3934 is associated with reactions: {TRE6PP}
# 1185660.4.peg.2949 is associated with reactions: {TRE6PS}
# 1185660.4.peg.419 is associated with reactions: {TRPO2}
# 1185660.4.peg.418 is associated with reactions: {TRPO2}
# 1185660.4.peg.817 is associated with reactions: {UAAGDS}
# 1185660.4.peg.1651 is associated with reactions: {UAGAAT}
# 1185660.4.peg.820 is associated with reactions: {UAGPT2, UAGPT3}
# 1185660.4.peg.3119 is associated with reactions: {UAMAGS}
# 1185660.4.peg.821 is associated with reactions: {UAMAS}
# 1185660.4.peg.1848 is associated with reactions: {UAPGR}
# 1185660.4.peg.3418 is associated with reactions: {UDPGD}
# 1185660.4.peg.1406 is associated with reactions: {UDPGD}
# 1185660.4.peg.818 is associated with reactions: {UGMDDS}
# 1185660.4.peg.826 is associated with reactions: {UHGADA}
# 1185660.4.peg.196 is associated with reactions: {UPP3S}
# 1185660.4.peg.2745 is associated with reactions: {UPPDC1, UPPDC2}
# 1185660.4.peg.1905 is associated with reactions: {VPAMTr}
# 1185660.4.peg.1815 is associated with reactions: {XYLK}
# 1185660.4.peg.1817 is associated with reactions: {XYLt2}
# xanmn_chr08_0038 is associated with reactions: {G-12289}
# xanmn_chr08_0029 is associated with reactions: {G-12290}
# xanmn_chr08_0034 is associated with reactions: {MNXR113143}
# xanmn_chr08_0031 is associated with reactions: {MNXR113142}
# xanmn_chr08_0033 is associated with reactions: {MNXR113144}
# xanmn_chr08_0036 is associated with reactions: {MNXR117163}
# xanmn_chr08_0030 is associated with reactions: {MNXR117165}
# xanmn_chr08_0035 is associated with reactions: {G-12296}
# xanmn_chr08_0037 is associated with reactions: {gumBCEJ}
# xanmn_chr08_0039 is associated with reactions: {gumBCEJ}
# xanmn_chr08_0032 is associated with reactions: {gumBCEJ}
# xanmn_chr08_0040 is associated with reactions: {gumBCEJ}

# %% [markdown]
# ### Defining Objective Function

# %%
Xam_draft.objective = "Biomass"

# %%
Xam_draft.objective
# Out:
# {<Reaction Biomass at 0x11976b9d0>: 1}

# %%
FBA_sol = Xam_draft.optimize()
print (FBA_sol)
# Out:
# <Solution 1.73 at 0x119722c10>

# %% [markdown]
# ### Export Model

# %%
cobra.io.write_sbml_model(Xam_draft, "Xam_BiGG_minmal_media.xml")
cobra.io.save_json_model(Xam_draft, "Xam_BiGG_minimal_media.json")

# %%
Xam_draft.reactions.get_by_id("Biomass").reaction
# Out:
# '0.00309646685193 10fthf_c + 0.00309646685193 2dmmq8_c + 0.00309646685193 5mthf_c + 0.00309646685193 ACP_c + 0.0106480421342 MNXM5124_c + 0.0106480421342 MNXM5129_c + 0.00309646685193 MNXM57_c + 0.0106480421342 MNXM6175_c + 0.0106480421342 MNXM6297_c + 0.0106480421342 MNXM6440_c + 0.0106480421342 MNXM7294_c + 0.0106480421342 MNXM7305_c + 0.0250105977109 MNXM7630_c + 0.00309646685193 adocbl_c + 0.427934380173 ala__L_c + 0.00309646685193 amet_c + 0.246696822701 arg__L_c + 0.200830806928 asn__L_c + 0.200830806928 asp__L_c + 40.1101757365 atp_c + 0.00309646685193 ca2_c + 0.00309646685193 cl_c + 0.00309646685193 coa_c + 0.00309646685193 cobalt2_c + 0.0250105977109 colipa_c + 0.0841036156545 ctp_c + 0.00309646685193 cu2_c + 0.0761464922056 cys__L_c + 0.0160206718346 datp_c + 0.0160206718346 dctp_c + 0.0160206718346 dgtp_c + dna_c + 0.0250105977109 dtpcudcpp_c + 0.0160206718346 dttp_c + 0.00309646685193 fad_c + 0.00309646685193 fe2_c + 0.00309646685193 fe3_c + 0.219088153013 gln__L_c + 0.219088153013 glu__L_c + 0.509869786991 gly_c + 0.135406821204 gtp_c + 35.540309243 h2o_c + 0.0792636000737 his__L_c + 0.241798510337 ile__L_c + 0.00309646685193 k_c + 0.37538884754 leu__L_c + 0.28543802049 lys__L_c + 0.127801422591 met__L_c + 0.00309646685193 mg2_c + 0.00309646685193 mn2_c + 0.00309646685193 mqn8_c + 0.00309646685193 nad_c + 0.00309646685193 nadp_c + 0.0106480421342 pe180_c + 0.0106480421342 pg180_c + 0.154519490031 phe__L_c + 0.00309646685193 pheme_c + 0.18435466534 pro__L_c + protein_c + 0.00309646685193 ptrc_c + 0.00309646685193 pydx5p_c + 0.00309646685193 q8_c + 0.00309646685193 ribflv_c + rna_c + 0.179456352976 ser__L_c + 0.00309646685193 sheme_c + 0.00309646685193 so4_c + 0.00309646685193 spmd_c + 0.00309646685193 thf_c + 0.00309646685193 thmpp_c + 0.211072732781 thr__L_c + 0.047201919145 trp__L_c + 0.120676604607 tyr__L_c + 0.0908319049068 utp_c + 0.352233189092 val__L_c + 0.00309646685193 zn2_c --> BIOMASS_c + 0.0250105977109 MNXM5258_c + 40.0 adp_c + 0.00309646685193 apoACP_c + 0.00309646685193 cbi_c + 0.00309646685193 dmbzid_c + 40.0562052099 h_c + 39.9969035331 pi_c + 0.484600765611 ppi_c'
